# %% [markdown]
# <a href="https://www.iptcnet.org/"><img src = "https://cdn.asp.events/CLIENT_SPE__29FE44FF_5056_B733_49EC4D60A02A6A7D/sites/IPTC-2023/media/logos/IPTCglobal.png" width = 500>
#
# <h1 align=center><font size = 5>A Monte Carlo Based Approach to Greenhouse Gases Emissions Modelling and Forecasting</font></h1>

# %% [markdown]
# <h1 align=center><font size = 4> Munish Kumar</font></h1>
# <h1 align=center><font size = 3> ERCE 2022 </font></h1>

# %% [markdown]
# #### Libraries

# %%
# Only install the following libraries if you dont have it, otherwise leave it commented out

#!conda install -c anaconda natsort --yes
#!conda install -c anaconda xlrd --yes

# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
import time
import re
import requests
import pickle
import seaborn as sns
import os
import glob
import sys
import random
from natsort import natsorted
sns.set()

# Sklearn Liraries
from sklearn import preprocessing
from scipy.stats import truncnorm

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

# Forces the print statement to show everything and not truncate
# np.set_printoptions(threshold=sys.maxsize) 
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# ###### Declare some global variables

# %%
dir_name = r'C:\Users\mkumar\Documents\GitHub\IPTC_Paper'
filename_suffix = 'csv'

# %% [markdown]
# ###### Function

# %%
def ends(df, x=5):
    return df.head(x).append(df.tail(x))
setattr(pd.DataFrame,'ends',ends)

# %%
def normal_dist_create(a1, b1, s):
    
    w = b1-a1
    lower = -w/s
    upper = w/s

    r = truncnorm.rvs(a=lower, b=upper, loc=((a1+b1)/2), scale=s ,size=1000)

    fig, ax = plt.subplots(1, 1)
    ax.hist(r, density=True, histtype='bar', alpha=0.2)

    mean_val =  truncnorm.mean(a=lower, b=upper, loc=((a1+b1)/2), scale=s)
    
    print('The mean value of the distribution is: ', mean_val)
    
    return r

# %% [markdown]
# ##### Read in the data and some preprocessing

# %%
#Combines the first 2 rows of header into 1 header

df = pd.read_excel('Inputs.xlsx', header=[0, 2], sheet_name='Sheet1')
df.columns=df.columns.to_flat_index()

df.ends(10)
# Out:
#     (Project, Unnamed: 0_level_1)  (Production (MMBOE), Low )  \
# 0                            2024                    0.500000
# 1                            2025                   10.800000
# 2                            2026                   18.150000
# 3                            2027                   18.150000
# 4                            2028                   18.150000
# 5                            2029                   12.775000
# 6                            2030                    9.255357
# 7                            2031                    6.648214
# 8                            2032                    4.953571
# 9                            2033                    3.650000
# 10                           2034                    2.737500
# 11                           2035                    1.955357
# 12                           2036                    1.000000
# 13                           2037                    1.000000
# 14                           2038                    0.500000
# 15                           2039                    0.500000
# 16                           2040                    0.500000
# 17                           2041                    0.500000
# 18                           2042                    0.500000
# 19                           2043                    0.500000
#
#     (Production (MMBOE), Mid)  (Production (MMBOE), High)
# 0                    0.956556                    1.830000
# 1                   10.900000                   11.000000
# 2                   18.325000                   18.500000
# 3                   18.325000                   18.500000
# 4                   18.575000                   19.000000
# 5                   15.887500                   19.000000
# 6                   14.127679                   19.000000
# 7                   11.239042                   19.000000
# 8                    9.701436                   19.000000
# 9                    8.327665                   19.000000
# 10                   7.211969                   19.000000
# 11                   4.946706                   12.514286
# 12                   3.042262                    9.255357
# 13                   2.578413                    6.648214
# 14                   1.573781                    4.953571
# 15                   1.326583                    3.519643
# 16                   1.141741                    2.607143
# 17                   0.955249                    1.825000
# 18                   0.955249                    1.825000
# 19                   0.955249                    1.825000

# %%
df.columns.values
# Out:
# array([('Project', 'Unnamed: 0_level_1'), ('Production (MMBOE)', 'Low '),
#        ('Production (MMBOE)', 'Mid'), ('Production (MMBOE)', 'High')],
#       dtype=object)

# %%
s=0.1
 
for i in range(len(df)):
    a1 = df.iloc[i][('Production (MMBOE)', 'Low ')]
    b1 = df.iloc[i][('Production (MMBOE)', 'High')]
    
    print("Low case input:", a1)
    print("High case input:", b1)
    
    norm_df = normal_dist_create(a1, b1, s)
# Out:
# Low case input: 0.5
# High case input: 1.83
# The mean value of the distribution is:  1.165
# Low case input: 10.8
# High case input: 11.0
# The mean value of the distribution is:  10.9
# Low case input: 18.15
# High case input: 18.5
# The mean value of the distribution is:  18.325
# Low case input: 18.15
# High case input: 18.5
# The mean value of the distribution is:  18.325
# Low case input: 18.15
# High case input: 19.0
# The mean value of the distribution is:  18.575
# Low case input: 12.775
# High case input: 19.0
# The mean value of the distribution is:  15.8875
# Low case input: 9.255357142857141
# High case input: 19.0
# The mean value of the distribution is:  14.127678571428572
# Low case input: 6.648214285714286
# High case input: 19.0
# The mean value of the distribution is:  12.824107142857143
# Low case input: 4.953571428571429
# High case input: 19.0
# The mean value of the distribution is:  11.976785714285715
# Low case input: 3.65
# High case input: 19.0
# The mean value of the distribution is:  11.325
# Low case input: 2.7375
# High case input: 19.0
# The mean value of the distribution is:  10.86875
# Low case input: 1.9553571428571426
# High case input: 12.514285714285714
# The mean value of the distribution is:  7.234821428571428
# Low case input: 1.0
# High case input: 9.255357142857141
# The mean value of the distribution is:  5.127678571428571
# Low case input: 1.0
# High case input: 6.648214285714286
# The mean value of the distribution is:  3.824107142857143
# Low case input: 0.5
# High case input: 4.953571428571429
# The mean value of the distribution is:  2.7267857142857146
# Low case input: 0.5
# High case input: 3.519642857142857
# The mean value of the distribution is:  2.0098214285714286
# Low case input: 0.5
# High case input: 2.607142857142857
# The mean value of the distribution is:  1.5535714285714286
# Low case input: 0.5
# High case input: 1.825
# The mean value of the distribution is:  1.1625
# Low case input: 0.5
# High case input: 1.825
# The mean value of the distribution is:  1.1625
# Low case input: 0.5
# High case input: 1.825
# The mean value of the distribution is:  1.1625

# %%
norm_df
# Out:
# array([1.01182006, 1.18062855, 1.18154618, 0.99382701, 1.11503265,
#        1.19101573, 1.08111625, 1.35659043, 1.18354329, 0.9327208 ,
#        1.15240387, 1.06751335, 1.18269207, 1.15985596, 1.24068684,
#        0.9029628 , 1.13562896, 1.13444461, 1.16502829, 1.36039696,
#        1.01081539, 1.21865477, 1.19160917, 1.03341775, 1.13095489,
#        1.06324799, 1.19817622, 1.04583642, 1.14261551, 1.03429275,
#        1.08093666, 1.25865548, 1.07516968, 1.1075557 , 1.3210907 ,
#        1.12928983, 1.06305352, 1.17520012, 1.18524385, 1.2239278 ,
#        1.11517597, 1.05064761, 1.11711768, 1.06189844, 1.24174728,
#        1.01851567, 1.18170554, 1.16722864, 1.07669623, 1.27663835,
#        0.99419652, 1.00353215, 1.16456996, 1.09250178, 1.18959355,
#        1.28303493, 1.16218713, 1.03783883, 1.18928689, 1.14432814,
#        1.02233241, 1.18557731, 1.19472885, 1.20375633, 0.97026349,
#        1.0790599 , 0.90499272, 1.21649668, 1.13766753, 0.94243224,
#        1.30062225, 0.9771961 , 1.20597212, 1.25302733, 1.27609787,
#        1.34418661, 1.15229118, 1.30619881, 1.17682758, 1.13939133,
#        1.05806267, 1.23012833, 1.18319347, 1.33353057, 1.06177172,
#        1.03143478, 1.10470024, 1.19853488, 1.14611066, 1.21016661,
#        1.14250905, 1.10379421, 1.13653296, 1.10607965, 1.28680275,
#        1.15056398, 1.07740656, 1.1908846 , 1.11068673, 1.09893588,
#        1.21278474, 1.01472448, 1.17154718, 1.13520447, 1.08954389,
#        1.15937919, 0.95681978, 1.07997704, 1.04580451, 1.06084596,
#        1.24665884, 1.19400966, 1.07138235, 1.1138656 , 1.21221948,
#        1.13290656, 1.23481639, 1.13029327, 0.98062536, 1.27806006,
#        1.14891818, 1.1965304 , 1.0853517 , 1.16559643, 1.06218401,
#        1.14187882, 0.93919286, 1.18379494, 1.01410703, 1.03880044,
#        1.06309818, 1.32793939, 1.06818648, 1.09127232, 1.18583979,
#        1.10993424, 1.11393072, 1.06877686, 1.1333937 , 1.22655954,
#        1.17661367, 1.00666306, 1.03538812, 1.11930242, 1.24226235,
#        0.97753505, 1.20601249, 1.09463107, 1.26430846, 1.28387031,
#        1.26084377, 1.36306177, 1.32536376, 1.1610142 , 1.12006075,
#        1.28437542, 1.23486938, 1.31149094, 1.2211731 , 0.97451942,
#        1.02281646, 0.96145668, 1.15878025, 1.16324377, 1.08537325,
#        1.08690435, 1.0250335 , 1.28148292, 1.09144774, 1.10894409])

# %% [markdown]
# #### Monte Carlo Simulator

# %%
# Creating Roll Dice Function
def roll_dice():
    die_1 = random.randint(1, 6)
    die_2 = random.randint(1, 6)

    # Determining if the dice are the same number
    if die_1 == die_2:
        same_num = True
    else:
        same_num = False
    return same_num

# %%
# Inputs
num_simulations = 10000
max_num_rolls = 1000
bet = 1

# Tracking
win_probability = []
end_balance = []

# %%
# Creating Figure for Simulation Balances
fig = plt.figure()

# For loop to run for the number of simulations desired
for i in range(num_simulations):
    balance = [1000]
    num_rolls = [0]
    num_wins = 0
    # Run until the player has rolled 1,000 times
    while num_rolls[-1] < max_num_rolls:
        same = roll_dice()
        # Result if the dice are the same number
        if same:
            balance.append(balance[-1] + 4 * bet)
            num_wins += 1
        # Result if the dice are different numbers
        else:
            balance.append(balance[-1] - bet)

        num_rolls.append(num_rolls[-1] + 1)

    # Store tracking variables and add line to figure
    win_probability.append(num_wins/num_rolls[-1])
    end_balance.append(balance[-1])
    plt.plot(num_rolls, balance)

plt.title("Monte Carlo [" + str(num_simulations) + "simulations]")
plt.xlabel("Roll Number")
plt.ylabel("Balance [$]")
plt.xlim([0, max_num_rolls])
# Out:
# (0.0, 1000.0)

# %%
# Showing the plot after the simulations are finished
plt.show()

# Averaging win probability and end balance
overall_win_probability = sum(win_probability)/len(win_probability)
overall_end_balance = sum(end_balance)/len(end_balance)
# Displaying the averages
print("Average win probability after " + str(num_simulations) + "runs: " + str(overall_win_probability))
print("Average ending balance after " + str(num_simulations) + "runs: $" + str(overall_end_balance))
# Out:
# Average win probability after 10000runs: 0.16665160000000007
# Average ending balance after 10000runs: $833.258

# %%
sns.histplot(win_probability, bins=100, kde = True, element="step")
# Out:
# <AxesSubplot:ylabel='Count'>
