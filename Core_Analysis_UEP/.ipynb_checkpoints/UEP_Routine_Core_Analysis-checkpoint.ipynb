# %% [markdown]
# <table><tr>
# <td> <img src="data:image/jpeg;base64,..." alt="Drawing" style="width: 200px;"/> </td>
# <td> <img src="https://npc-core.com/npc-content/uploads/2021/03/core-analysis-cores-combo.jpeg" alt="Drawing" style="width: 250px;"/> </td>
# </tr></table>

# %% [markdown]
# <h1 align=center><font size = 4> Munish Kumar </font></h1>
# <h1 align=center><font size = 4> P6163_YE2022_Reserves_Audit </font></h1>
# <h1 align=center><font size = 4> Routine Core Analysis </font></h1>
# <h1 align=center><font size = 3> ERCE 2022 </font></h1>

# %% [markdown]
# #### Libraries

# %%
# Only install the following libraries if you dont have it, otherwise leave it commented out

#!conda install -c anaconda natsort --yes
#!conda install -c anaconda xlrd --yes
#!pip install sympy --user

# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
import time
import re
import requests
import pickle
import seaborn as sns
import os
import glob
import sys
from natsort import natsorted
sns.set()

# Sklearn Liraries
from sklearn import preprocessing

# For Latex style text
from sympy import S, symbols, printing

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

# Display max rows
pd.set_option('display.max_rows', 500)

# Forces the print statement to show everything and not truncate
# np.set_printoptions(threshold=sys.maxsize) 
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# ###### Declare some global variables

# %%
dir_name = r'C:\Users\mkumar\Documents\GitHub\munishkumar-gh.github.io\Core_Analysis_UEP'
filename_suffix = 'csv'

# Font, marker size and axis rotation
edgecolors = 'black'
markersize = 16
alpha = 0.5
size = 18
rotation = 0

# %% [markdown]
# ###### Series of Functions

# %%
# Function to look at first 5 and last 5 elements in a dataframe
def ends(df, x=5):
    return df.head(x).append(df.tail(x))
setattr(pd.DataFrame,'ends',ends)

# %%
# Function to read out file
def file_out(df, dir_name, base_filename, filename_suffix):
    try:
        csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
        df.to_csv(csvs_sht, index = False, header=True)
        print ("Final File Extract Produced")
    except IOError:
        print("I/O error")
    return

# %%
# Function to search for a text string
def search_words(text):
    result = re.findall(r'\b[^\d\W]+\b', text)
    return " ".join(result)

# %%
# Function to plot grain density
def plot_grain_density(mod_df, title, bins, xmin, xmax, savefn):
    sns.set()
    sns.set_style("whitegrid")     
    sns.set_style("ticks", 
                  {"xtick.major.size":size,
                  "ytick.major.size":size}
                 )
    sns.axes_style("whitegrid")
    kwargs = {'cumulative': True}

    ax = sns.distplot(mod_df, 
                      bins = bins, 
                      kde=False, 
                      norm_hist=False, 
                      color = 'r',
                      #bw_adjust=.25,
                      #hist_kws=kwargs, 
                      #kde_kws=kwargs
                     )

    ax.set(ylabel='Frequency', 
           #xlabel='common ylabel',
           xlim = (xmin, xmax),
          )

    ax.legend(labels=['Histogram', 'Frequency'])
    plt.title(title)
    plt.grid(True)

    plt.savefig(savefn, transparent=True)
    return

# %%
# Plotting the effect of NOBP
def plot_NOBP(mod_df, df_sub, grouped, color, savefn):
    # Plot per group
    fig = plt.figure(figsize=(14, 8))
    ax = fig.add_subplot(121)

    for i, (name, group) in enumerate(grouped):
        sc = ax.scatter(
            group["NOB (psi)"],
            group["Porosity (%)"],
            s = markersize**2,
            alpha=0.5,
            label=name,
            edgecolors = edgecolors,
        )  

    # Add legends (one for gender, other for size)
    ax.add_artist(ax.legend(title='Well Name'))
    ax.legend(*sc.legend_elements("colors", num=6))
    ax.set_xlabel('Net Overburden Pressure (psi)', fontsize=size)
    ax.set_ylabel('Porosity (%)', fontsize=size)

    plt.xticks(rotation = rotation, fontsize=size)
    plt.yticks(rotation = rotation, fontsize=size)
    plt.ylim(0,20) 
    plt.grid(True)
    
    ax1 = fig.add_subplot(122)

    for i, (name, group) in enumerate(grouped):
        sc1 = ax1.scatter(
            group["NOB (psi)"],
            group["K (mD)"],
            s = markersize**2,
            alpha=0.5,
            label=name,
            edgecolors = edgecolors,
        )  

    # Add legends 
    ax1.add_artist(ax1.legend(title='Well Name'))
    ax1.legend(*sc1.legend_elements("colors", num=6))
    ax1.set_xlabel('Net Overburden Pressure (psi)', fontsize=size)
    ax1.set_ylabel('Permeability (mD)', fontsize=size)

    plt.xticks(rotation = rotation, fontsize=size)
    plt.yticks(rotation = rotation, fontsize=size)
    #plt.ylim(0,20)

    plt.tight_layout()
    plt.grid(True)

    plt.savefig(savefn, transparent=True)
    return

# %%
def plot_PP(df_sub, grouped, color, title, savefn, xint1, yint1, xint2, yint2, xlimit, ylimit, plot_line_eqn):
    fig = plt.figure(figsize=(14, 8))
    ax = fig.add_subplot(111)

    for i, (name, group) in enumerate(grouped):
        sc = ax.scatter(
            group["Porosity (%)"],
            group["K (mD)"],
            s = markersize**2,
            alpha=0.5,
            label=name,
            edgecolors = edgecolors,
        )  

    # Add legends
    ax.add_artist(ax.legend(title='Well Name'))
    ax.legend(*sc.legend_elements("colors", num=6), prop={'size': 20})
    ax.set_xlabel('Porosity (%)', fontsize=size)
    ax.set_ylabel('Permeability (mD)', fontsize=size)

    plt.xticks(rotation = rotation, fontsize=size)
    plt.yticks(rotation = rotation, fontsize=size)
    plt.xlim(0, xlimit)
    plt.ylim(0.01, ylimit)
    
    df_sub = df_sub[['Porosity (%)', 'K (mD)']].sort_values(by = 'Porosity (%)', ascending = True)
    
    # Fit to linear-log
    y1 = df_sub["Porosity (%)"] #x-value
    y2 = df_sub["K (mD)"] #y-value 
   
    ## Eqn Fit 1 ##
    # For fitting y = Ax^B, ln y = ln A + B ln x. So fit (ln y) against (ln x).
    # p = np.polyfit(np.log(y1), np.log(y2), 1, w=np.sqrt(y2/2)) # w is weight to bias against larger values of y
    # p = np.polyfit(np.log(y1), np.log(y2), 1)
    # f = np.poly1d(p)

    ## Eqn Fit 2 ##
    # For fitting y = Ae^(Bx), ln y = ln A + Bx. So fit (ln y) against x.
    # p = np.polyfit(y1, np.log(y2), 1, w=np.sqrt(y2)) # w is weight to bias against larger values of y
     p = np.polyfit(y1, np.log(y2), 1)
     f = np.poly1d(p)

    if plot_line_eqn == True: 
        ax.semilogy(y1, np.exp(p[0] * np.log(y1) + p[1]), 'k--', linewidth = 2.5)
        # Display Equation
        plt.text(17.5, 100, r'Equation ={}'.format(f), fontsize = size,bbox=dict(facecolor='white', alpha=0.25))
        plt.title (title, fontsize = size)
    else:
        p[0] = 0
        p [1] = 0
        f = np.poly1d(p)
    
    # here we add the vertical and horizontal line 1
    plt.axvline(x=xint1, color='darkorange',linestyle='--',linewidth=2)
    plt.axhline(y=yint1, color='darkorange',linestyle='--',linewidth=2)
    
    # here we add the horizontal and horizontal line 2
    plt.axvline(x=xint2, color='darkgreen',linestyle=':',linewidth=2)
    plt.axhline(y=yint2, color='darkgreen',linestyle=':',linewidth=2)

    ax.set_yscale('log')

    plt.tight_layout()
    plt.grid(True)
    
    plt.savefig(savefn, transparent=True)
    return f, p[0], p[1]

# %% [markdown]
# ##### Read in the data and some preprocessing

# %%
# Header file comes preformatted as 1st row is variable name, 2nd row reads "Low, Best, High"
# Combines the first 2 rows of header into 1 header

df = pd.read_excel(
    'CoreData_UEP.xlsx', 
    header=[0, 1], 
    sheet_name='MASTER', 
    keep_default_na=False,
    #usecols="A,C:AA"
)
df.columns=df.columns.to_flat_index()

# renaming the columns
df.columns = ['Well Name', 'Sample ID', 'Depth (m)', 'NOB (psi)', 'K (mD)', 'Porosity (%)', 'Grain Density (g/cc)', 'Core Type']
df.ends(10)
# Out:
# C:\Users\mkumar\AppData\Local\Temp\ipykernel_18896\3237448987.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return df.head(x).append(df.tail(x))
#      Well Name  Sample ID  Depth (m)  NOB (psi)    K (mD) Porosity (%)  \
# 0    Khararo_1          1    2968.20          0      1.61         7.95
# 1    Khararo_1          2    2968.30          0      11.5          3.2
# 2    Khararo_1          3    2968.68          0                     11
# 3    Khararo_1          4    2969.20          0      0.01         7.73
# 4    Khararo_1          5    2969.50          0
# 5    Khararo_1          6    2969.90          0      0.43        19.97
# 6    Khararo_1          7    2970.48          0       0.7           18
# 7    Khararo_1          8    2971.00          0      0.37        20.06
# 8    Khararo_1          9    2971.12          0       1.2         18.3
# 9    Khararo_1         10    2971.85          0      0.04         9.75
# 702    Mehar-3        703    3835.23          0  10.73895     7.444433
# 703    Mehar-3        704    3838.65          0  4.912933     6.867596
# 704    Mehar-3        705    3852.66          0  30.30062    11.285706
# 705    Mehar-3        706    3830.24          0  69.28573        8.816
# 706    Mehar-3        707    3831.17          0  116.6586     8.374576
# 707    Mehar-3        708    3835.16          0  11.20054     7.445728
# 708    Mehar-3        709    3841.05          0  8.784493     7.194769
# 709    Mehar-3        710    3852.74          0  43.87638    12.589561
# 710    Mehar-3        711    3836.28          0    5.6472     5.650368
# 711    Mehar-3        712    3850.41          0  1.381069     9.044101
#
#     Grain Density (g/cc) Core Type
# 0                              CCA
# 1                   2.68       CCA
# 2                   2.71       CCA
# 3                              CCA
# 4                              CCA
# 5                              CCA
# 6                   2.71       CCA
# 7                              CCA
# 8                    2.7       CCA
# 9                              CCA
# 702                2.654       CCA
# 703                2.648       CCA
# 704                 2.67       CCA
# 705                2.663       CCA
# 706                2.668       CCA
# 707                2.653       CCA
# 708                 2.65       CCA
# 709                2.657       CCA
# 710                 2.67       CCA
# 711                2.649       CCA

# %% [markdown]
# ##### Remove Missing Rows based on Missing Permeability and Porosity Values

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)

cols = ['K (mD)', 'Porosity (%)']

mod_df = df.dropna(how='any', subset=cols)
mod_df = df[df['K (mD)'] > 0]
mod_df = mod_df[mod_df['Grain Density (g/cc)'] > 2.55]
mod_df = mod_df[mod_df['Grain Density (g/cc)'] < 2.85]
mod_df
# Out:
#      Well Name  Sample ID  Depth (m)  NOB (psi)     K (mD)  Porosity (%)  \
# 1    Khararo_1          2    2968.30          0  11.500000      3.200000
# 6    Khararo_1          7    2970.48          0   0.700000     18.000000
# 8    Khararo_1          9    2971.12          0   1.200000     18.300000
# 15   Khararo_1         16    3150.18          0  10.400000      7.100000
# 28    Khipro_1         29    3313.40          0   1.350000     10.800000
# ..         ...        ...        ...        ...        ...           ...
# 707    Mehar-3        708    3835.16          0  11.200540      7.445728
# 708    Mehar-3        709    3841.05          0   8.784493      7.194769
# 709    Mehar-3        710    3852.74          0  43.876380     12.589561
# 710    Mehar-3        711    3836.28          0   5.647200      5.650368
# 711    Mehar-3        712    3850.41          0   1.381069      9.044101
#
#      Grain Density (g/cc) Core Type
# 1                   2.680       CCA
# 6                   2.710       CCA
# 8                   2.700       CCA
# 15                  2.640       CCA
# 28                  2.830       CCA
# ..                    ...       ...
# 707                 2.653       CCA
# 708                 2.650       CCA
# 709                 2.657       CCA
# 710                 2.670       CCA
# 711                 2.649       CCA
#
# [616 rows x 8 columns]

# %% [markdown]
# ###### Mapping each well to a colour

# %%
df_colors = pd.read_csv('https://raw.githubusercontent.com/codebrainz/color-names/master/output/colors.csv',header=None)
df_colors.columns = ['color_name', 'color_description', 'hex_value', 'r', 'g','b']

names = mod_df['Well Name'].unique()
c = df_colors[['hex_value']].astype(str).agg(','.join,axis=1).tolist()
colors = dict(zip(names,c))

mod_df['color'] = mod_df['Well Name'].apply(lambda x: colors[x])
mod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 616 entries, 1 to 711
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             616 non-null    object
#  1   Sample ID             616 non-null    int64
#  2   Depth (m)             616 non-null    float64
#  3   NOB (psi)             616 non-null    int64
#  4   K (mD)                616 non-null    float64
#  5   Porosity (%)          616 non-null    float64
#  6   Grain Density (g/cc)  616 non-null    float64
#  7   Core Type             616 non-null    object
#  8   color                 616 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 48.1+ KB

# %%
for well in mod_df['Well Name'].unique():
        print(mod_df[mod_df['Well Name'] == well].info())      
        print(mod_df[mod_df['Well Name'] == well].describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 1 to 15
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             4 non-null      object
#  1   Sample ID             4 non-null      int64
#  2   Depth (m)             4 non-null      float64
#  3   NOB (psi)             4 non-null      int64
#  4   K (mD)                4 non-null      float64
#  5   Porosity (%)          4 non-null      float64
#  6   Grain Density (g/cc)  4 non-null      float64
#  7   Core Type             4 non-null      object
#  8   color                 4 non-null      object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 320.0+ bytes
# None
#         Well Name  Sample ID    Depth (m)  NOB (psi)     K (mD)  Porosity (%)  \
# count           4   4.000000     4.000000        4.0   4.000000      4.000000
# unique          1        NaN          NaN        NaN        NaN           NaN
# top     Khararo_1        NaN          NaN        NaN        NaN           NaN
# freq            4        NaN          NaN        NaN        NaN           NaN
# mean          NaN   8.500000  3015.020000        0.0   5.950000     11.650000
# std           NaN   5.802298    90.114752        0.0   5.794538      7.673548
# min           NaN   2.000000  2968.300000        0.0   0.700000      3.200000
# 25%           NaN   5.750000  2969.935000        0.0   1.075000      6.125000
# 50%           NaN   8.000000  2970.800000        0.0   5.800000     12.550000
# 75%           NaN  10.750000  3015.885000        0.0  10.675000     18.075000
# max           NaN  16.000000  3150.180000        0.0  11.500000     18.300000
#
#         Grain Density (g/cc) Core Type    color
# count               4.000000         4        4
# unique                   NaN         1        1
# top                      NaN       CCA  #5d8aa8
# freq                     NaN         4        4
# mean                2.682500       NaN      NaN
# std                 0.030957       NaN      NaN
# min                 2.640000       NaN      NaN
# 25%                 2.670000       NaN      NaN
# 50%                 2.690000       NaN      NaN
# 75%                 2.702500       NaN      NaN
# max                 2.710000       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 28 to 83
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             43 non-null     object
#  1   Sample ID             43 non-null     int64
#  2   Depth (m)             43 non-null     float64
#  3   NOB (psi)             43 non-null     int64
#  4   K (mD)                43 non-null     float64
#  5   Porosity (%)          43 non-null     float64
#  6   Grain Density (g/cc)  43 non-null     float64
#  7   Core Type             43 non-null     object
#  8   color                 43 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 3.4+ KB
# None
#        Well Name  Sample ID    Depth (m)  NOB (psi)      K (mD)  Porosity (%)  \
# count         43  43.000000    43.000000       43.0   43.000000     43.000000
# unique         1        NaN          NaN        NaN         NaN           NaN
# top     Khipro_1        NaN          NaN        NaN         NaN           NaN
# freq          43        NaN          NaN        NaN         NaN           NaN
# mean         NaN  60.953488  3743.709535        0.0   65.783953      6.539535
# std          NaN  15.708587   357.780344        0.0  143.893215      4.372704
# min          NaN  29.000000  3313.400000        0.0    0.010000      0.500000
# 25%          NaN  51.000000  3421.750000        0.0    0.100000      2.850000
# 50%          NaN  63.000000  3514.030000        0.0    1.200000      6.700000
# 75%          NaN  73.500000  4115.200000        0.0   56.100000      9.400000
# max          NaN  84.000000  4119.920000        0.0  654.000000     18.900000
#
#         Grain Density (g/cc) Core Type    color
# count              43.000000        43       43
# unique                   NaN         1        1
# top                      NaN       CCA  #00308f
# freq                     NaN        43       43
# mean                2.679767       NaN      NaN
# std                 0.041775       NaN      NaN
# min                 2.640000       NaN      NaN
# 25%                 2.650000       NaN      NaN
# 50%                 2.660000       NaN      NaN
# 75%                 2.700000       NaN      NaN
# max                 2.830000       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 85 to 100
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             15 non-null     object
#  1   Sample ID             15 non-null     int64
#  2   Depth (m)             15 non-null     float64
#  3   NOB (psi)             15 non-null     int64
#  4   K (mD)                15 non-null     float64
#  5   Porosity (%)          15 non-null     float64
#  6   Grain Density (g/cc)  15 non-null     float64
#  7   Core Type             15 non-null     object
#  8   color                 15 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 1.2+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)       K (mD)  \
# count         15   15.000000    15.000000       15.0    15.000000
# unique         1         NaN          NaN        NaN          NaN
# top      Miano-1         NaN          NaN        NaN          NaN
# freq          15         NaN          NaN        NaN          NaN
# mean         NaN   93.866667  3508.534667        0.0   108.044667
# std          NaN    4.688385    37.316507        0.0   264.415069
# min          NaN   86.000000  3431.980000        0.0     0.020000
# 25%          NaN   90.500000  3524.195000        0.0     0.165000
# 50%          NaN   94.000000  3525.740000        0.0     0.570000
# 75%          NaN   97.500000  3527.420000        0.0    61.500000
# max          NaN  101.000000  3529.300000        0.0  1016.000000
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count      15.000000             15.000000        15       15
# unique           NaN                   NaN         1        1
# top              NaN                   NaN       CCA  #72a0c1
# freq             NaN                   NaN        15       15
# mean        9.773333              2.716667       NaN      NaN
# std         6.892487              0.055891       NaN      NaN
# min         1.100000              2.660000       NaN      NaN
# 25%         3.200000              2.665000       NaN      NaN
# 50%         8.000000              2.710000       NaN      NaN
# 75%        16.200000              2.755000       NaN      NaN
# max        20.100000              2.840000       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83 entries, 101 to 202
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             83 non-null     object
#  1   Sample ID             83 non-null     int64
#  2   Depth (m)             83 non-null     float64
#  3   NOB (psi)             83 non-null     int64
#  4   K (mD)                83 non-null     float64
#  5   Porosity (%)          83 non-null     float64
#  6   Grain Density (g/cc)  83 non-null     float64
#  7   Core Type             83 non-null     object
#  8   color                 83 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 6.5+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)       K (mD)  \
# count         83   83.000000    83.000000       83.0    83.000000
# unique         1         NaN          NaN        NaN          NaN
# top      Miano-2         NaN          NaN        NaN          NaN
# freq          83         NaN          NaN        NaN          NaN
# mean         NaN  153.879518  3295.633976        0.0   434.354819
# std          NaN   29.223027   114.712901        0.0  1192.051965
# min          NaN  102.000000  3130.050000        0.0     0.010000
# 25%          NaN  127.500000  3158.225000        0.0     0.030000
# 50%          NaN  155.000000  3303.450000        0.0     0.080000
# 75%          NaN  177.500000  3311.045000        0.0     4.450000
# max          NaN  203.000000  3493.750000        0.0  5780.000000
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count      83.000000             83.000000        83       83
# unique           NaN                   NaN         1        1
# top              NaN                   NaN       CCA  #a32638
# freq             NaN                   NaN        83       83
# mean       12.120482              2.722771       NaN      NaN
# std         6.759722              0.058483       NaN      NaN
# min         1.500000              2.620000       NaN      NaN
# 25%         7.350000              2.685000       NaN      NaN
# 50%        11.400000              2.720000       NaN      NaN
# 75%        15.350000              2.760000       NaN      NaN
# max        39.100000              2.840000       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 203 to 267
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             54 non-null     object
#  1   Sample ID             54 non-null     int64
#  2   Depth (m)             54 non-null     float64
#  3   NOB (psi)             54 non-null     int64
#  4   K (mD)                54 non-null     float64
#  5   Porosity (%)          54 non-null     float64
#  6   Grain Density (g/cc)  54 non-null     float64
#  7   Core Type             54 non-null     object
#  8   color                 54 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 4.2+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)       K (mD)  \
# count         54   54.000000    54.000000       54.0    54.000000
# unique         1         NaN          NaN        NaN          NaN
# top      Miano-3         NaN          NaN        NaN          NaN
# freq          54         NaN          NaN        NaN          NaN
# mean         NaN  232.000000  3262.974444        0.0    70.486296
# std          NaN   17.143127    54.282777        0.0   285.350449
# min          NaN  204.000000  3227.400000        0.0     0.010000
# 25%          NaN  218.250000  3233.800000        0.0     0.232500
# 50%          NaN  231.500000  3242.260000        0.0     0.720000
# 75%          NaN  244.750000  3251.767500        0.0     2.067500
# max          NaN  268.000000  3419.450000        0.0  1642.000000
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count      54.000000             54.000000        54       54
# unique           NaN                   NaN         1        1
# top              NaN                   NaN       CCA  #f0f8ff
# freq             NaN                   NaN        54       54
# mean       13.500000              2.703889       NaN      NaN
# std         5.307924              0.026806       NaN      NaN
# min         3.200000              2.660000       NaN      NaN
# 25%        10.325000              2.690000       NaN      NaN
# 50%        12.700000              2.700000       NaN      NaN
# 75%        17.725000              2.720000       NaN      NaN
# max        22.400000              2.790000       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 270 to 309
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             40 non-null     object
#  1   Sample ID             40 non-null     int64
#  2   Depth (m)             40 non-null     float64
#  3   NOB (psi)             40 non-null     int64
#  4   K (mD)                40 non-null     float64
#  5   Porosity (%)          40 non-null     float64
#  6   Grain Density (g/cc)  40 non-null     float64
#  7   Core Type             40 non-null     object
#  8   color                 40 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 3.1+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)       K (mD)  \
# count         40   40.000000    40.000000       40.0    40.000000
# unique         1         NaN          NaN        NaN          NaN
# top      Miano-4         NaN          NaN        NaN          NaN
# freq          40         NaN          NaN        NaN          NaN
# mean         NaN  290.500000  3333.356250        0.0    38.318250
# std          NaN   11.690452    63.772626        0.0   201.449026
# min          NaN  271.000000  3290.500000        0.0     0.030000
# 25%          NaN  280.750000  3300.812500        0.0     0.380000
# 50%          NaN  290.500000  3309.650000        0.0     0.815000
# 75%          NaN  300.250000  3321.205000        0.0     1.570000
# max          NaN  310.000000  3485.810000        0.0  1272.000000
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count       40.00000             40.000000        40       40
# unique           NaN                   NaN         1        1
# top              NaN                   NaN       CCA  #e32636
# freq             NaN                   NaN        40       40
# mean        12.78450              2.717500       NaN      NaN
# std          5.60059              0.032245       NaN      NaN
# min          0.30000              2.650000       NaN      NaN
# 25%          8.76750              2.690000       NaN      NaN
# 50%         13.46500              2.710000       NaN      NaN
# 75%         17.38000              2.750000       NaN      NaN
# max         23.06000              2.780000       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 311 to 424
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             105 non-null    object
#  1   Sample ID             105 non-null    int64
#  2   Depth (m)             105 non-null    float64
#  3   NOB (psi)             105 non-null    int64
#  4   K (mD)                105 non-null    float64
#  5   Porosity (%)          105 non-null    float64
#  6   Grain Density (g/cc)  105 non-null    float64
#  7   Core Type             105 non-null    object
#  8   color                 105 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 8.2+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)       K (mD)  \
# count        105  105.000000   105.000000      105.0   105.000000
# unique         1         NaN          NaN        NaN          NaN
# top      Miano-5         NaN          NaN        NaN          NaN
# freq         105         NaN          NaN        NaN          NaN
# mean         NaN  367.200000  3340.544952        0.0    53.355905
# std          NaN   31.942075    10.228274        0.0   199.998070
# min          NaN  312.000000  3323.300000        0.0     0.010000
# 25%          NaN  340.000000  3331.680000        0.0     0.010000
# 50%          NaN  367.000000  3340.700000        0.0     0.040000
# 75%          NaN  393.000000  3349.040000        0.0     1.080000
# max          NaN  425.000000  3358.610000        0.0  1516.740000
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count     105.000000            105.000000       105      105
# unique           NaN                   NaN         1        1
# top              NaN                   NaN       CCA  #c46210
# freq             NaN                   NaN       105      105
# mean       10.116952              2.710000       NaN      NaN
# std         5.526087              0.041948       NaN      NaN
# min         0.270000              2.610000       NaN      NaN
# 25%         6.600000              2.690000       NaN      NaN
# 50%         8.250000              2.710000       NaN      NaN
# 75%        12.570000              2.730000       NaN      NaN
# max        23.650000              2.810000       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 426 to 482
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             55 non-null     object
#  1   Sample ID             55 non-null     int64
#  2   Depth (m)             55 non-null     float64
#  3   NOB (psi)             55 non-null     int64
#  4   K (mD)                55 non-null     float64
#  5   Porosity (%)          55 non-null     float64
#  6   Grain Density (g/cc)  55 non-null     float64
#  7   Core Type             55 non-null     object
#  8   color                 55 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 4.3+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)     K (mD)  Porosity (%)  \
# count         55   55.000000    55.000000       55.0  55.000000     55.000000
# unique         1         NaN          NaN        NaN        NaN           NaN
# top      Miano-6         NaN          NaN        NaN        NaN           NaN
# freq          55         NaN          NaN        NaN        NaN           NaN
# mean         NaN  455.818182  3221.811455        0.0   0.230545     11.934727
# std          NaN   16.303931     6.409800        0.0   0.547531      5.101827
# min          NaN  427.000000  3214.110000        0.0   0.010000      5.530000
# 25%          NaN  442.500000  3217.010000        0.0   0.015000      7.780000
# 50%          NaN  456.000000  3220.150000        0.0   0.030000     10.260000
# 75%          NaN  469.500000  3224.120000        0.0   0.080000     16.705000
# max          NaN  483.000000  3240.900000        0.0   2.360000     22.200000
#
#         Grain Density (g/cc) Core Type    color
# count              55.000000        55       55
# unique                   NaN         1        1
# top                      NaN       CCA  #efdecd
# freq                     NaN        55       55
# mean                2.716727       NaN      NaN
# std                 0.035852       NaN      NaN
# min                 2.670000       NaN      NaN
# 25%                 2.690000       NaN      NaN
# 50%                 2.710000       NaN      NaN
# 75%                 2.730000       NaN      NaN
# max                 2.840000       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 485 to 586
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             98 non-null     object
#  1   Sample ID             98 non-null     int64
#  2   Depth (m)             98 non-null     float64
#  3   NOB (psi)             98 non-null     int64
#  4   K (mD)                98 non-null     float64
#  5   Porosity (%)          98 non-null     float64
#  6   Grain Density (g/cc)  98 non-null     float64
#  7   Core Type             98 non-null     object
#  8   color                 98 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 7.7+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)       K (mD)  \
# count         98   98.000000    98.000000       98.0    98.000000
# unique         1         NaN          NaN        NaN          NaN
# top      Miano-7         NaN          NaN        NaN          NaN
# freq          98         NaN          NaN        NaN          NaN
# mean         NaN  537.908163  3342.263776        0.0    75.265357
# std          NaN   28.956450    10.945372        0.0   559.931553
# min          NaN  486.000000  3316.890000        0.0     0.005359
# 25%          NaN  513.250000  3335.857500        0.0     0.009700
# 50%          NaN  537.500000  3343.420000        0.0     0.012297
# 75%          NaN  562.750000  3350.625000        0.0     0.019700
# max          NaN  587.000000  3367.910000        0.0  5188.527448
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count      98.000000             98.000000        98       98
# unique           NaN                   NaN         1        1
# top              NaN                   NaN       CCA  #e52b50
# freq             NaN                   NaN        98       98
# mean       10.683018              2.706509       NaN      NaN
# std         4.170320              0.029443       NaN      NaN
# min         2.660413              2.649061       NaN      NaN
# 25%         8.056448              2.688070       NaN      NaN
# 50%        10.089656              2.703863       NaN      NaN
# 75%        12.294053              2.723142       NaN      NaN
# max        29.092827              2.790586       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 587 to 639
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             53 non-null     object
#  1   Sample ID             53 non-null     int64
#  2   Depth (m)             53 non-null     float64
#  3   NOB (psi)             53 non-null     int64
#  4   K (mD)                53 non-null     float64
#  5   Porosity (%)          53 non-null     float64
#  6   Grain Density (g/cc)  53 non-null     float64
#  7   Core Type             53 non-null     object
#  8   color                 53 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 4.1+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)      K (mD)  \
# count         53   53.000000    53.000000       53.0   53.000000
# unique         1         NaN          NaN        NaN         NaN
# top     Miano-8A         NaN          NaN        NaN         NaN
# freq          53         NaN          NaN        NaN         NaN
# mean         NaN  614.000000  3387.601698        0.0    7.794694
# std          NaN   15.443445    11.195445        0.0   52.958860
# min          NaN  588.000000  3371.060000        0.0    0.005851
# 25%          NaN  601.000000  3375.370000        0.0    0.010000
# 50%          NaN  614.000000  3387.560000        0.0    0.022532
# 75%          NaN  627.000000  3398.440000        0.0    0.170850
# max          NaN  640.000000  3404.200000        0.0  385.929842
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count      53.000000             53.000000        53       53
# unique           NaN                   NaN         1        1
# top              NaN                   NaN       CCA  #ffbf00
# freq             NaN                   NaN        53       53
# mean       11.414030              2.706374       NaN      NaN
# std         6.166642              0.036728       NaN      NaN
# min         4.263572              2.666478       NaN      NaN
# 25%         6.165769              2.680554       NaN      NaN
# 50%         8.078977              2.690894       NaN      NaN
# 75%        17.543627              2.719792       NaN      NaN
# max        22.534134              2.814071       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 641 to 682
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             37 non-null     object
#  1   Sample ID             37 non-null     int64
#  2   Depth (m)             37 non-null     float64
#  3   NOB (psi)             37 non-null     int64
#  4   K (mD)                37 non-null     float64
#  5   Porosity (%)          37 non-null     float64
#  6   Grain Density (g/cc)  37 non-null     float64
#  7   Core Type             37 non-null     object
#  8   color                 37 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 2.9+ KB
# None
#         Well Name   Sample ID    Depth (m)  NOB (psi)      K (mD)  \
# count          37   37.000000    37.000000       37.0   37.000000
# unique          1         NaN          NaN        NaN         NaN
# top     Kundahu-1         NaN          NaN        NaN         NaN
# freq           37         NaN          NaN        NaN         NaN
# mean          NaN  664.351351  3398.772162        0.0   28.282703
# std           NaN   11.554740   113.037279        0.0   93.643029
# min           NaN  642.000000  3142.800000        0.0    0.020000
# 25%           NaN  655.000000  3312.700000        0.0    0.150000
# 50%           NaN  665.000000  3328.400000        0.0    0.260000
# 75%           NaN  674.000000  3503.170000        0.0    1.570000
# max           NaN  683.000000  3686.370000        0.0  405.840000
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count      37.000000             37.000000        37       37
# unique           NaN                   NaN         1        1
# top              NaN                   NaN       CCA  #ff7e00
# freq             NaN                   NaN        37       37
# mean        9.145946              2.703784       NaN      NaN
# std         4.694637              0.048382       NaN      NaN
# min         0.080000              2.640000       NaN      NaN
# 25%         5.790000              2.670000       NaN      NaN
# 50%         7.900000              2.700000       NaN      NaN
# 75%        13.190000              2.720000       NaN      NaN
# max        17.700000              2.810000       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 683 to 711
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             29 non-null     object
#  1   Sample ID             29 non-null     int64
#  2   Depth (m)             29 non-null     float64
#  3   NOB (psi)             29 non-null     int64
#  4   K (mD)                29 non-null     float64
#  5   Porosity (%)          29 non-null     float64
#  6   Grain Density (g/cc)  29 non-null     float64
#  7   Core Type             29 non-null     object
#  8   color                 29 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 2.3+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)      K (mD)  \
# count         29   29.000000    29.000000       29.0   29.000000
# unique         1         NaN          NaN        NaN         NaN
# top      Mehar-3         NaN          NaN        NaN         NaN
# freq          29         NaN          NaN        NaN         NaN
# mean         NaN  698.000000  3812.656207        0.0  123.985090
# std          NaN    8.514693    37.748577        0.0  189.245329
# min          NaN  684.000000  3754.510000        0.0    0.055290
# 25%          NaN  691.000000  3768.590000        0.0   10.738950
# 50%          NaN  698.000000  3831.080000        0.0   50.381700
# 75%          NaN  705.000000  3838.650000        0.0  124.260500
# max          NaN  712.000000  3852.740000        0.0  664.862100
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count      29.000000             29.000000        29       29
# unique           NaN                   NaN         1        1
# top              NaN                   NaN       CCA  #ff033e
# freq             NaN                   NaN        29       29
# mean        9.634337              2.656828       NaN      NaN
# std         2.293030              0.008590       NaN      NaN
# min         5.606273              2.644000       NaN      NaN
# 25%         8.272503              2.650000       NaN      NaN
# 50%         9.062619              2.654000       NaN      NaN
# 75%        11.380796              2.663000       NaN      NaN
# max        13.663596              2.676000       NaN      NaN

# %%
print(mod_df.info())
print(mod_df.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 616 entries, 1 to 711
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             616 non-null    object
#  1   Sample ID             616 non-null    int64
#  2   Depth (m)             616 non-null    float64
#  3   NOB (psi)             616 non-null    int64
#  4   K (mD)                616 non-null    float64
#  5   Porosity (%)          616 non-null    float64
#  6   Grain Density (g/cc)  616 non-null    float64
#  7   Core Type             616 non-null    object
#  8   color                 616 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 48.1+ KB
# None
#        Well Name   Sample ID    Depth (m)  NOB (psi)       K (mD)  \
# count        616  616.000000   616.000000      616.0   616.000000
# unique        12         NaN          NaN        NaN          NaN
# top      Miano-5         NaN          NaN        NaN          NaN
# freq         105         NaN          NaN        NaN          NaN
# mean         NaN  380.988636  3376.791055        0.0   103.749710
# std          NaN  196.843568   190.629763        0.0   527.847756
# min          NaN    2.000000  2968.300000        0.0     0.005359
# 25%          NaN  212.750000  3302.537500        0.0     0.020000
# 50%          NaN  383.500000  3336.860000        0.0     0.113348
# 75%          NaN  552.250000  3383.382500        0.0     1.546047
# max          NaN  712.000000  4119.920000        0.0  5780.000000
#
#         Porosity (%)  Grain Density (g/cc) Core Type    color
# count     616.000000            616.000000       616      616
# unique           NaN                   NaN         1       12
# top              NaN                   NaN       CCA  #c46210
# freq             NaN                   NaN       616      105
# mean       10.891469              2.706402       NaN      NaN
# std         5.567981              0.042534       NaN      NaN
# min         0.080000              2.610000       NaN      NaN
# 25%         6.972661              2.680000       NaN      NaN
# 50%         9.869310              2.700000       NaN      NaN
# 75%        13.965000              2.730000       NaN      NaN
# max        39.100000              2.840000       NaN      NaN

# %% [markdown]
# ## Determine Properties based on a particular Net Overburden Pressure (NOBP) value

# %%
a = mod_df['NOB (psi)'].unique()
print(sorted(a))
# Out:
# [0]

# %% [markdown]
# Some of the net overburden values are missing. It will be assumed that these are ambient values i.e. 800 psi

# %%
mod_df['NOB (psi)'].fillna(14.7, inplace=True)
mod_df['NOB (psi)'].isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Histogram - Plotting the Grain Density, Porosity and Permeability at Ambient (800 psi)

# %%
NOBP = 0

# %%
df_sub = mod_df[mod_df['NOB (psi)'] <= NOBP]
grouped = df_sub.groupby("Well Name")
color = df_sub['color']

# %%
savefn = "Hist_GD_amb.png"

## fuction to plot - usage
## plot_grain_density (dataframe_column, plot_title, number_bins, x-axis_min, x_axis_max savefile_name)
plot_grain_density(df_sub['Grain Density (g/cc)'], "Grain Density (Ambient)", 20, 2.55, 2.85, savefn)

# %%
savefn = "Hist_Poro_amb.png"
plot_grain_density(df_sub["Porosity (%)"], "Porosity (%) (Ambient)", 20, 0, 30, savefn)

# %%
savefn = "Hist_Perm_amb.png"

x= df_sub["K (mD)"]

logbins = np.geomspace(x.min(), x.max(), 20)
plot_grain_density(df_sub["K (mD)"], "Permeability (mD) (Ambient)", logbins, 0.001, x.max()+5000, savefn)
plt.xscale('log')

# %% [markdown]
# #### Plot cross-plot of Porosity-Permeability

# %%
savefn = "Poro_Perm_amb.png"

xlimit = 30
ylimit = 100000

#Cutoff intercept
yint1 = 0
xint1 = 0

yint2 = 0.01
xint2 = 3.8

plot_line_eqn = False

f, p0, p1 = plot_PP(df_sub, grouped, color, 
                    "Ambient Porosity vs Permeability", savefn, xint1, yint1, 
                    xint2, yint2, xlimit, ylimit, plot_line_eqn)
print("Equation of line:", f)
print("Intercept:", p0)
print("Gradient Coefficient:", p1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py:1099: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 15>()
#      11 xint2 = 3.8
#      13 plot_line_eqn = True
# ---> 15 f, p0, p1 = plot_PP(df_sub, grouped, color,
#      16                     "Ambient Porosity vs Permeability", savefn, xint1, yint1,
#      17                     xint2, yint2, xlimit, ylimit, plot_line_eqn)
#      18 print("Equation of line:", f)
#      19 print("Intercept:", p0)
#
# Input In [8], in plot_PP(df_sub, grouped, color, title, savefn, xint1, yint1, xint2, yint2, xlimit, ylimit, plot_line_eqn)
#      32 ## Eqn Fit 1 ##
#      33 # For fitting y = Ax^B, ln y = ln A + B ln x. So fit (ln y) against (ln x).
#      34 # p = np.polyfit(np.log(y1), np.log(y2), 1, w=np.sqrt(y2/2)) # w is weight to bias against larger values of y
#    (...)
#      41 # p = np.polyfit(y1, np.log(y2), 1)
#      42 # f = np.poly1d(p)
#      44 if plot_line_eqn == True:
# ---> 45     ax.semilogy(y1, np.exp(p[0] * np.log(y1) + p[1]), 'k--', linewidth = 2.5)
#      46     # Display Equation
#      47     # plt.text(17.5, 100, r'Equation ={}'.format(f), fontsize = size,bbox=dict(facecolor='white', alpha=0.25))
#      48     # plt.title (title, fontsize = size)
#      49 else:
#      50     p[0] = 0
#
# NameError: name 'p' is not defined

# %% [markdown]
# ##### Cross-plot for values at overburden

# %% [markdown]
# df_sub = mod_df[mod_df['NOB (psi)'] > NOBP]
# grouped = df_sub.groupby("Well Name")
# color = df_sub['color']

# %% [markdown]
# savefn = "Hist_GD_OB.png"
#
# # fuction to plot - usage
# # plot_grain_density (dataframe_column, plot_title, number_bins, x-axis_min, x_axis_max, savefile_name)
#
# plot_grain_density(df_sub['Grain Density (g/cc)'], "Grain Density (Overburden)", 20, 2.55, 2.9, savefn)

# %% [markdown]
# savefn = "Hist_Poro_OB.png"
# plot_grain_density(df_sub["Porosity (%)"], "Porosity (%) (Overburden)", 20, 0, 35, savefn)

# %% [markdown]
# savefn = "Hist_Perm_OB.png"
#
# x= df_sub["K (mD)"]
#
# logbins = np.geomspace(x.min(), x.max(), 20)
# plot_grain_density(df_sub["K (mD)"], "Permeability (mD) (Ambient)", logbins, 0.01, x.max()+1000, savefn)
# plt.xscale('log')

# %% [markdown]
# savefn = "Poro_Perm_Overburden.png"
#
# xlimit = 35
# ylimit = 10000
#
# #Cutoff intercept
# yint1 = 1
# xint1 = 16
#
# yint2 = 0.1
# xint2 = 12
#
# plot_line_eqn = True
#
# f, p0, p1 = plot_PP(df_sub, grouped, color,
#                     "Overburden Porosity vs Permeability", savefn,
#                     xint1, yint1, xint2, yint2, xlimit, ylimit, plot_line_eqn)
# print("Equation of line:", f)
# print("Intercept:", p0)
# print("Gradient Coefficient:", p1)

# %% [markdown]
# ### K means clustering of Core Data

# %% [markdown]
# #### Step 1: Normalise Data Set

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# #### Step 1: Elbow Plot

# %%
mod_df_copy = mod_df.copy()
mod_df_copy.columns.values

# %%
# Select columns to do prediction on
X_drop = mod_df_copy.drop(['Well Name', 'Sample ID', 'Depth (m)', 'NOB (psi)',
                           #'Grain Density (g/cc)', 
                           'Core Type', 'color'], axis = 1)

# %%
distortions = []

min_el = 1
max_el = 10

# A loop runs thorugh your min and max clusters. 
# We dont complicate the K-Means at this stage
# We store an "intertia" number which is the measurement of the distortions in different K clustering solutions

for i in range (min_el,max_el):
    km = KMeans(n_clusters= i, init = "k-means++")
    km.fit(X_drop)
    distortions.append(km.inertia_)

# %%
# elbow curve
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (5,3), dpi = 150)
plt.plot(range (min_el,max_el), distortions, marker='o', markersize=5,
    markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.grid(True)
plt.xlabel('Number of clusters')
plt.ylabel('Average within-cluster sum of squares')
plt.title('Elbow for KMeans clustering')

# %% [markdown]
# #### Looks like 3 is the optimal number of clusters. Lets do the K means proper now

# %% [markdown]
# #### Step 2: K-means Plot

# %%
# This normalizes the data set
scaler = preprocessing.StandardScaler()
scaler.fit(X_drop)
X_drop_Norm = scaler.transform(X_drop)

# Now we convert to a pandas array
#car_norm_price = pd.DataFrame(X_drop_Norm, columns = DF_model_toNorm_colnam, index = DF_model_toNorm_rownam)
#car_norm_price

# %%
# Fitting the K-Means with the optimal number of cluster
k = 3
km = KMeans(n_clusters=k, init = "k-means++", random_state = 0)
km_fit = km.fit(X_drop_Norm)

# Predicting the Classificaiton of the Data
y_pred = km.fit_predict(X_drop_Norm)
display(y_pred)

# %%
# The predicted results should now be converted to a pandas dataframe
y_pred_data = pd.DataFrame({"cluster":y_pred},index = X_drop.index)
y_pred_data

# %%
core_pred = pd.concat([X_drop , y_pred_data], axis = 1)
core_pred

# %%
names = core_pred['cluster'].unique()
c = df_colors[['hex_value']].astype(str).agg(','.join,axis=1).tolist()
colors = dict(zip(names,c))

core_pred['color'] = core_pred['cluster'].apply(lambda x: colors[x])
core_pred = core_pred.sort_values(by = 'Porosity (%)', ascending = True)
core_pred

# %%
pd.crosstab(core_pred['Porosity (%)'], core_pred['cluster'], normalize='index', margins = True)

# %%
filtered_label0 = core_pred[core_pred['cluster'] == 0]
filtered_label1 = core_pred[core_pred['cluster'] == 1]
filtered_label2 = core_pred[core_pred['cluster'] == 2]
#filtered_label3 = core_pred[core_pred['cluster'] == 3]

# %%
fs = 12

#markers - https://matplotlib.org/stable/api/markers_api.html
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (5,3), dpi = 150,)
plt.scatter(filtered_label0['Porosity (%)'], filtered_label0['K (mD)'], marker='o')
plt.scatter(filtered_label1['Porosity (%)'], filtered_label1['K (mD)'], marker='v')
plt.scatter(filtered_label2['Porosity (%)'], filtered_label2['K (mD)'], marker='+')
#plt.scatter(filtered_label3['Porosity (%)'], filtered_label3['K (mD)'], marker='s')

x_pts = list(range(0,20,1))

#Line styles - https://matplotlib.org/2.0.2/api/lines_api.html
p = np.polyfit(np.log(filtered_label0['Porosity (%)']), np.log(filtered_label0['K (mD)']), 1)
f = np.poly1d(p)
plt.semilogy(x_pts, np.exp(p[0] * np.log(x_pts) + p[1]), 'k-', linewidth = 1.5)
plt.text(12.5, 15, r'Equation ={}'.format(f), fontsize = fs/1.5, bbox=dict(facecolor='white', alpha=0.25))

p = np.polyfit(np.log(filtered_label1['Porosity (%)']), np.log(filtered_label1['K (mD)']), 1)
f = np.poly1d(p)
plt.semilogy(x_pts, np.exp(p[0] * np.log(x_pts) + p[1]), 'k--', linewidth = 1.5)
plt.text(6, 0.5, r'Equation ={}'.format(f), fontsize = fs/1.5, bbox=dict(facecolor='white', alpha=0.25))

p = np.polyfit(np.log(filtered_label2['Porosity (%)']), np.log(filtered_label2['K (mD)']), 1)
f = np.poly1d(p)
plt.semilogy(x_pts, np.exp(p[0] * np.log(x_pts) + p[1]), 'k-.', linewidth = 1.5)
plt.text(17.8, 200, r'Equation ={}'.format(f), fontsize = fs/1.5, bbox=dict(facecolor='white', alpha=0.5))

# p = np.polyfit(np.log(filtered_label3['Porosity (%)']), np.log(filtered_label3['K (mD)']), 1)
# f = np.poly1d(p)
# plt.semilogy(filtered_label3['Porosity (%)'], np.exp(p[0] * np.log(filtered_label3['Porosity (%)']) + p[1]), 'k.', linewidth = 1.5)
# plt.text(17.8, 200, r'Equation ={}'.format(f), fontsize = fs/1.5, bbox=dict(facecolor='white', alpha=0.5))

plt.yscale('log')
plt.xlim(0, xlimit)
plt.ylim(1, ylimit)
plt.xticks(fontsize=fs-3)
plt.xlabel('Porosity (%)',fontsize=fs)
plt.ylabel('Permeability (mD)',fontsize=fs)
plt.title('Cluster Distribution',fontsize=fs+2)
plt.grid(True)

plt.savefig('Cluster_Dist.png', transparent=True)

# %%
count = 'Completed Process'
elapsed = (time.time() - start)
print ("%s in %s seconds" % (count,elapsed))
