# %% [markdown]
# <a href="https://www.dialogasia.com/"><img src = "https://www.eog-asia.com/wp-content/uploads/2018/02/Dialog-Group.jpg" width = 200>
#
# <h1 align=center><font size = 5>Core Analysis Baram Delta</font></h1>

# %% [markdown]
# <h1 align=center><font size = 4> Munish Kumar </font></h1>
# <h1 align=center><font size = 4> P5935_Baram_Junior_Cluster_DRO </font></h1>
# <h1 align=center><font size = 3> ERCE 2022 </font></h1>

# %% [markdown]
# #### Libraries

# %%
# Only install the following libraries if you dont have it, otherwise leave it commented out

#!conda install -c anaconda natsort --yes
#!conda install -c anaconda xlrd --yes
#!pip install sympy --user

# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
import time
import re
import requests
import pickle
import seaborn as sns
import os
import glob
import sys
from natsort import natsorted
sns.set()

# Sklearn Liraries
from sklearn import preprocessing

# For Latex style text
from sympy import S, symbols, printing

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

# Forces the print statement to show everything and not truncate
# np.set_printoptions(threshold=sys.maxsize) 
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# ###### Declare some global variables

# %%
dir_name = r'C:\Users\mkumar\Documents\GitHub\Core_Analysis_BD_Dialog'
filename_suffix = 'csv'

# Font, marker size and axis rotation
edgecolors = 'black'
markersize = 16
alpha = 0.5
size = 18
rotation = 0

# %% [markdown]
# ###### Series of Functions

# %%
# Function to look at first 5 and last 5 elements in a dataframe
def ends(df, x=5):
    return df.head(x).append(df.tail(x))
setattr(pd.DataFrame,'ends',ends)

# %%
# Function to read out file
def file_out(df, dir_name, base_filename, filename_suffix):
    try:
        csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
        df.to_csv(csvs_sht, index = False, header=True)
        print ("Final File Extract Produced")
    except IOError:
        print("I/O error")
    return

# %%
# Function to search for a text string
def search_words(text):
    result = re.findall(r'\b[^\d\W]+\b', text)
    return " ".join(result)

# %%
# Function to plot grain density
def plot_grain_density(mod_df, title, bins, xmin, xmax, savefn):
    sns.set()
    sns.set_style("whitegrid")     
    sns.set_style("ticks", 
                  {"xtick.major.size":size,
                  "ytick.major.size":size}
                 )
    sns.axes_style("whitegrid")
    kwargs = {'cumulative': True}

    ax = sns.distplot(mod_df, 
                      bins = bins, 
                      kde=False, 
                      norm_hist=False, 
                      color = 'r',
                      #bw_adjust=.25,
                      #hist_kws=kwargs, 
                      #kde_kws=kwargs
                     )
    ax.set(ylabel='Frequency', 
           #xlabel='common ylabel',
           xlim = (xmin, xmax),
          )

    ax.legend(labels=['Histogram', 'Frequency'])
    plt.title(title)
    plt.grid(True)

    plt.savefig(savefn, transparent=True)
    return

# %%
# Plotting the effect of NOBP
def plot_NOBP(mod_df, df_sub, grouped, color, savefn):
    # Plot per group
    fig = plt.figure(figsize=(14, 8))
    ax = fig.add_subplot(121)

    for i, (name, group) in enumerate(grouped):
        sc = ax.scatter(
            group["NOB (psi)"],
            group["Porosity (%)"],
            s = markersize**2,
            alpha=0.5,
            label=name,
            edgecolors = edgecolors,
        )  

    # Add legends (one for gender, other for size)
    ax.add_artist(ax.legend(title='Well Name'))
    ax.legend(*sc.legend_elements("colors", num=6))
    ax.set_xlabel('Net Overburden Pressure (psi)', fontsize=size)
    ax.set_ylabel('Porosity (%)', fontsize=size)

    plt.xticks(rotation = rotation, fontsize=size)
    plt.yticks(rotation = rotation, fontsize=size)
    plt.ylim(0,20) 
    plt.grid(True)
    
    ax1 = fig.add_subplot(122)

    for i, (name, group) in enumerate(grouped):
        sc1 = ax1.scatter(
            group["NOB (psi)"],
            group["K_klin (mD)"],
            s = markersize**2,
            alpha=0.5,
            label=name,
            edgecolors = edgecolors,
        )  

    # Add legends (one for gender, other for size)
    ax1.add_artist(ax1.legend(title='Well Name'))
    ax1.legend(*sc1.legend_elements("colors", num=6))
    ax1.set_xlabel('Net Overburden Pressure (psi)', fontsize=size)
    ax1.set_ylabel('Permeability (mD)', fontsize=size)

    plt.xticks(rotation = rotation, fontsize=size)
    plt.yticks(rotation = rotation, fontsize=size)
    #plt.ylim(0,20)

    plt.tight_layout()
    plt.grid(True)

    plt.savefig(savefn, transparent=True)
    return

# %%
def plot_PP(mod_df, df_sub, grouped, color, title, savefn, xint, yint):
    fig = plt.figure(figsize=(14, 8))
    ax = fig.add_subplot(111)

    for i, (name, group) in enumerate(grouped):
        sc = ax.scatter(
            group["Porosity (%)"],
            group["K_klin (mD)"],
            s = markersize**2,
            alpha=0.5,
            label=name,
            edgecolors = edgecolors,
        )  

    # Add legends
    ax.add_artist(ax.legend(title='Well Name'))
    ax.legend(*sc.legend_elements("colors", num=6), prop={'size': 20})
    ax.set_xlabel('Porosity (%)', fontsize=size)
    ax.set_ylabel('Permeability (mD)', fontsize=size)

    plt.xticks(rotation = rotation, fontsize=size)
    plt.yticks(rotation = rotation, fontsize=size)
    plt.xlim(0,30)
    plt.ylim(0.001,10000)

    # Fit to linear-log
    y1 = df_sub["Porosity (%)"] # x-value
    y2 = df_sub["K_klin (mD)"] #y-value
    
    # For fitting y = Ae^(Bx), log y = log A + Bx. So fit (log y) against x.
    #p = np.polyfit(y1, np.log(y2), 1, w=np.sqrt(y2)) # w is weight to bias against larger values of y
    p = np.polyfit(y1, np.log(y2), 1)
    f = np.poly1d(p)

    ax.semilogy(y1, np.exp(p[0] * y1 + p[1]), 'k--', linewidth = 2.5)
    ax.set_yscale('log')

    #Display Equation
    plt.text(16, 10, r'Equation ={}'.format(f), fontsize = size,bbox=dict(facecolor='white', alpha=0.25))
    plt.title (title, fontsize = size)

    # here we add the vertical line
    plt.axvline(x=xint, color='darkgreen',linestyle='--',linewidth=2)
    
    # here we add the horizontal line
    plt.axhline(y=yint, color='darkorange',linestyle='--',linewidth=2)

    plt.tight_layout()
    plt.grid(True)
    
    plt.savefig(savefn, transparent=True)
    return

# %% [markdown]
# ##### Read in the data and some preprocessing

# %%
# Header file comes preformatted as 1st row is variable name, 2nd row reads "Low, Best, High"
# Combines the first 2 rows of header into 1 header

df = pd.read_excel(
    'Cluster 3 Offset Core Data.xlsx', 
    header=[0, 1], 
    sheet_name='MASTER', 
    keep_default_na=False,
    #usecols="A,C:AA"
)
df.columns=df.columns.to_flat_index()

# renaming the columns
df.columns = ['Well Name', 'Depth (m)', 'NOB (psi)', 'K_klin (mD)', 'Porosity (%)', 'Grain Density (g/cc)']
df.ends(10)
# Out:
# C:\Users\mkumar\AppData\Local\Temp\ipykernel_9444\3237448987.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return df.head(x).append(df.tail(x))
#                Well Name    Depth (m) NOB (psi) K_klin (mD) Porosity (%)  \
# 0     Tukau Timur West 1  3323.579615       800         103         18.3
# 1     Tukau Timur West 1  3323.579615      3633          97         17.7
# 2     Tukau Timur West 1  3323.640575       800        73.2         18.1
# 3     Tukau Timur West 1  3323.640575      3633        68.3         17.3
# 4     Tukau Timur West 1  3323.853938       800        84.3         17.6
# 5     Tukau Timur West 1  3323.853938      3633        78.8         16.9
# 6     Tukau Timur West 1  3324.097781       800         1.4         12.1
# 7     Tukau Timur West 1  3324.097781      3633        1.09         11.3
# 8     Tukau Timur West 1  3324.311144       800        3.02         13.4
# 9     Tukau Timur West 1  3324.311144      3633        2.44         12.7
# 2026             Laila 3   3768.57768      4100       0.108         10.2
# 2027             Laila 3   3768.88248      4100       0.239         12.1
# 2028             Laila 3   3768.88248      4100       0.116         11.7
# 2029             Laila 3   3769.18728      4100       0.606         12.5
# 2030             Laila 3   3769.49208      4100        0.47         11.8
# 2031             Laila 3   3769.79688      4100        3.28         13.8
# 2032             Laila 3   3770.10168      4100       0.192         10.8
# 2033             Laila 3   3770.40648      4100       0.085         10.9
# 2034             Laila 3   3770.40648      4100       0.417         12.4
# 2035             Laila 3   3770.71128      4100         1.5         13.3
#
#      Grain Density (g/cc)
# 0                    2.67
# 1                    2.67
# 2                    2.66
# 3                    2.66
# 4                    2.67
# 5                    2.67
# 6                    2.69
# 7                    2.69
# 8                    2.67
# 9                    2.67
# 2026                 2.68
# 2027                 2.67
# 2028                 2.67
# 2029                 2.67
# 2030                 2.66
# 2031                 2.66
# 2032                 2.67
# 2033                 2.68
# 2034                 2.68
# 2035                 2.67

# %% [markdown]
# ##### Remove Missing Rows based on Missing Permeability and Porosity Values

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)

cols = ['K_klin (mD)', 'Porosity (%)']

mod_df = df.dropna(how='any', subset=cols)
mod_df
# Out:
#                Well Name    Depth (m)  NOB (psi)  K_klin (mD)  Porosity (%)  \
# 0     Tukau Timur West 1  3323.579615      800.0      103.000          18.3
# 1     Tukau Timur West 1  3323.579615     3633.0       97.000          17.7
# 2     Tukau Timur West 1  3323.640575      800.0       73.200          18.1
# 3     Tukau Timur West 1  3323.640575     3633.0       68.300          17.3
# 4     Tukau Timur West 1  3323.853938      800.0       84.300          17.6
# ...                  ...          ...        ...          ...           ...
# 2031             Laila 3  3769.796880     4100.0        3.280          13.8
# 2032             Laila 3  3770.101680     4100.0        0.192          10.8
# 2033             Laila 3  3770.406480     4100.0        0.085          10.9
# 2034             Laila 3  3770.406480     4100.0        0.417          12.4
# 2035             Laila 3  3770.711280     4100.0        1.500          13.3
#
#       Grain Density (g/cc)
# 0                     2.67
# 1                     2.67
# 2                     2.66
# 3                     2.66
# 4                     2.67
# ...                    ...
# 2031                  2.66
# 2032                  2.67
# 2033                  2.68
# 2034                  2.68
# 2035                  2.67
#
# [1967 rows x 6 columns]

# %% [markdown]
# ###### Mapping each well to a colour

# %%
df_colors = pd.read_csv('https://raw.githubusercontent.com/codebrainz/color-names/master/output/colors.csv',header=None)
df_colors.columns = ['color_name', 'color_description', 'hex_value', 'r', 'g','b']

names = mod_df['Well Name'].unique()
c = df_colors[['hex_value']].astype(str).agg(','.join,axis=1).tolist()
colors = dict(zip(names,c))

mod_df['color'] = mod_df['Well Name'].apply(lambda x: colors[x])
mod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1967 entries, 0 to 2035
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             1967 non-null   object
#  1   Depth (m)             660 non-null    float64
#  2   NOB (psi)             660 non-null    float64
#  3   K_klin (mD)           1967 non-null   float64
#  4   Porosity (%)          1967 non-null   float64
#  5   Grain Density (g/cc)  660 non-null    float64
#  6   color                 1967 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 122.9+ KB
# C:\Users\mkumar\AppData\Local\Temp\ipykernel_9444\949046389.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mod_df['color'] = mod_df['Well Name'].apply(lambda x: colors[x])

# %%
for well in mod_df['Well Name'].unique():
        print(mod_df[mod_df['Well Name'] == well].info())
        print(mod_df[mod_df['Well Name'] == well].describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412 entries, 0 to 445
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             412 non-null    object
#  1   Depth (m)             412 non-null    float64
#  2   NOB (psi)             412 non-null    float64
#  3   K_klin (mD)           412 non-null    float64
#  4   Porosity (%)          412 non-null    float64
#  5   Grain Density (g/cc)  412 non-null    float64
#  6   color                 412 non-null    object
# dtypes: float64(5), object(2)
# memory usage: 25.8+ KB
# None
#                  Well Name    Depth (m)    NOB (psi)  K_klin (mD)  \
# count                  412   412.000000   412.000000   412.000000
# unique                   1          NaN          NaN          NaN
# top     Tukau Timur West 1          NaN          NaN          NaN
# freq                   412          NaN          NaN          NaN
# mean                   NaN  3431.906112  2270.631068    21.421170
# std                    NaN    82.461052  1473.906028    55.580632
# min                    NaN  3323.579615   800.000000     0.010000
# 25%                    NaN  3338.393075   800.000000     0.093000
# 50%                    NaN  3492.517069  2216.500000     0.440500
# 75%                    NaN  3504.633016  3822.000000     7.262500
# max                    NaN  3516.124116  3822.000000   376.000000
#
#         Porosity (%)  Grain Density (g/cc)    color
# count     412.000000            412.000000      412
# unique           NaN                   NaN        1
# top              NaN                   NaN  #5d8aa8
# freq             NaN                   NaN      412
# mean       11.350971              2.689757      NaN
# std         3.329485              0.022003      NaN
# min         2.900000              2.660000      NaN
# 25%         9.100000              2.680000      NaN
# 50%        11.250000              2.690000      NaN
# 75%        13.100000              2.690000      NaN
# max        18.500000              2.870000      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 446 to 509
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             55 non-null     object
#  1   Depth (m)             55 non-null     float64
#  2   NOB (psi)             55 non-null     float64
#  3   K_klin (mD)           55 non-null     float64
#  4   Porosity (%)          55 non-null     float64
#  5   Grain Density (g/cc)  55 non-null     float64
#  6   color                 55 non-null     object
# dtypes: float64(5), object(2)
# memory usage: 3.4+ KB
# None
#                  Well Name    Depth (m)  NOB (psi)  K_klin (mD)  Porosity (%)  \
# count                   55    55.000000       55.0    55.000000     55.000000
# unique                   1          NaN        NaN          NaN           NaN
# top     Tukau Timur Deep 1          NaN        NaN          NaN           NaN
# freq                    55          NaN        NaN          NaN           NaN
# mean                   NaN  4252.754545      800.0    14.655036     10.307273
# std                    NaN   276.416694        0.0    32.842095      3.081657
# min                    NaN  3485.000000      800.0     0.011000      2.900000
# 25%                    NaN  4134.100000      800.0     0.035000      8.600000
# 50%                    NaN  4375.500000      800.0     0.256000     10.100000
# 75%                    NaN  4426.000000      800.0     8.670000     13.050000
# max                    NaN  4580.900000      800.0   157.700000     16.100000
#
#         Grain Density (g/cc)    color
# count              55.000000       55
# unique                   NaN        1
# top                      NaN  #00308f
# freq                     NaN       55
# mean                2.662727      NaN
# std                 0.024149      NaN
# min                 2.630000      NaN
# 25%                 2.650000      NaN
# 50%                 2.660000      NaN
# 75%                 2.670000      NaN
# max                 2.780000      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 658 entries, 511 to 1168
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             658 non-null    object
#  1   Depth (m)             0 non-null      float64
#  2   NOB (psi)             0 non-null      float64
#  3   K_klin (mD)           658 non-null    float64
#  4   Porosity (%)          658 non-null    float64
#  5   Grain Density (g/cc)  0 non-null      float64
#  6   color                 658 non-null    object
# dtypes: float64(5), object(2)
# memory usage: 41.1+ KB
# None
#        Well Name  Depth (m)  NOB (psi)  K_klin (mD)  Porosity (%)  \
# count        658        0.0        0.0   658.000000    658.000000
# unique         1        NaN        NaN          NaN           NaN
# top      Betty 1        NaN        NaN          NaN           NaN
# freq         658        NaN        NaN          NaN           NaN
# mean         NaN        NaN        NaN   279.913810     17.867698
# std          NaN        NaN        NaN   490.889369      4.158123
# min          NaN        NaN        NaN     0.968495      0.053144
# 25%          NaN        NaN        NaN     5.601056     15.604522
# 50%          NaN        NaN        NaN    43.803675     18.361380
# 75%          NaN        NaN        NaN   310.850800     20.932245
# max          NaN        NaN        NaN  3059.150000     26.147030
#
#         Grain Density (g/cc)    color
# count                    0.0      658
# unique                   NaN        1
# top                      NaN  #72a0c1
# freq                     NaN      658
# mean                     NaN      NaN
# std                      NaN      NaN
# min                      NaN      NaN
# 25%                      NaN      NaN
# 50%                      NaN      NaN
# 75%                      NaN      NaN
# max                      NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 649 entries, 1169 to 1817
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             649 non-null    object
#  1   Depth (m)             0 non-null      float64
#  2   NOB (psi)             0 non-null      float64
#  3   K_klin (mD)           649 non-null    float64
#  4   Porosity (%)          649 non-null    float64
#  5   Grain Density (g/cc)  0 non-null      float64
#  6   color                 649 non-null    object
# dtypes: float64(5), object(2)
# memory usage: 40.6+ KB
# None
#        Well Name  Depth (m)  NOB (psi)  K_klin (mD)  Porosity (%)  \
# count        649        0.0        0.0   649.000000    649.000000
# unique         1        NaN        NaN          NaN           NaN
# top      Betty 2        NaN        NaN          NaN           NaN
# freq         649        NaN        NaN          NaN           NaN
# mean         NaN        NaN        NaN   242.941230     17.280899
# std          NaN        NaN        NaN   467.514390      5.092149
# min          NaN        NaN        NaN     0.058539      2.164762
# 25%          NaN        NaN        NaN     2.803332     14.010820
# 50%          NaN        NaN        NaN    31.622790     18.250150
# 75%          NaN        NaN        NaN   243.572400     21.437160
# max          NaN        NaN        NaN  3058.196000     28.983760
#
#         Grain Density (g/cc)    color
# count                    0.0      649
# unique                   NaN        1
# top                      NaN  #a32638
# freq                     NaN      649
# mean                     NaN      NaN
# std                      NaN      NaN
# min                      NaN      NaN
# 25%                      NaN      NaN
# 50%                      NaN      NaN
# 75%                      NaN      NaN
# max                      NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 1818 to 2035
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             193 non-null    object
#  1   Depth (m)             193 non-null    float64
#  2   NOB (psi)             193 non-null    float64
#  3   K_klin (mD)           193 non-null    float64
#  4   Porosity (%)          193 non-null    float64
#  5   Grain Density (g/cc)  193 non-null    float64
#  6   color                 193 non-null    object
# dtypes: float64(5), object(2)
# memory usage: 12.1+ KB
# None
#        Well Name    Depth (m)  NOB (psi)  K_klin (mD)  Porosity (%)  \
# count        193   193.000000      193.0   193.000000    193.000000
# unique         1          NaN        NaN          NaN           NaN
# top      Laila 3          NaN        NaN          NaN           NaN
# freq         193          NaN        NaN          NaN           NaN
# mean         NaN  3652.735045     4100.0     5.407394     12.427461
# std          NaN   119.132291        0.0    12.703877      2.319510
# min          NaN  3503.706480     4100.0     0.010000      2.900000
# 25%          NaN  3520.775280     4100.0     0.193000     10.800000
# 50%          NaN  3746.022480     4100.0     1.080000     12.800000
# 75%          NaN  3758.214480     4100.0     3.790000     14.000000
# max          NaN  3770.711280     4100.0    77.900000     17.300000
#
#         Grain Density (g/cc)    color
# count             193.000000      193
# unique                   NaN        1
# top                      NaN  #f0f8ff
# freq                     NaN      193
# mean                2.676943      NaN
# std                 0.015394      NaN
# min                 2.660000      NaN
# 25%                 2.670000      NaN
# 50%                 2.670000      NaN
# 75%                 2.680000      NaN
# max                 2.780000      NaN

# %%
print(mod_df['Well Name'].unique())
print(mod_df.info())
print(mod_df.describe(include='all'))
# Out:
# ['Tukau Timur West 1' 'Tukau Timur Deep 1' 'Betty 1' 'Betty 2' 'Laila 3']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1967 entries, 0 to 2035
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             1967 non-null   object
#  1   Depth (m)             660 non-null    float64
#  2   NOB (psi)             660 non-null    float64
#  3   K_klin (mD)           1967 non-null   float64
#  4   Porosity (%)          1967 non-null   float64
#  5   Grain Density (g/cc)  660 non-null    float64
#  6   color                 1967 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 122.9+ KB
# None
#        Well Name    Depth (m)    NOB (psi)  K_klin (mD)  Porosity (%)  \
# count       1967   660.000000   660.000000  1967.000000   1967.000000
# unique         5          NaN          NaN          NaN           NaN
# top      Betty 1          NaN          NaN          NaN           NaN
# freq         658          NaN          NaN          NaN           NaN
# mean         NaN  3564.885882  2683.030303   179.220804     15.563929
# std          NaN   259.697291  1531.386987   408.578475      5.063210
# min          NaN  3323.579615   800.000000     0.010000      0.053144
# 25%          NaN  3349.426969   800.000000     1.011907     11.700000
# 50%          NaN  3505.830916  3633.000000    10.692270     15.677590
# 75%          NaN  3529.995480  4100.000000   113.188200     19.610280
# max          NaN  4580.900000  4100.000000  3059.150000     28.983760
#
#         Grain Density (g/cc)    color
# count             660.000000     1967
# unique                   NaN        5
# top                      NaN  #72a0c1
# freq                     NaN      658
# mean                2.683758      NaN
# std                 0.022176      NaN
# min                 2.630000      NaN
# 25%                 2.670000      NaN
# 50%                 2.680000      NaN
# 75%                 2.690000      NaN
# max                 2.870000      NaN

# %% [markdown]
# ## Determine Properties based on a particular Net Overburden Pressure (NOBP) value

# %%
mod_df['NOB (psi)'].unique()
# Out:
# array([ 800., 3633., 3822.,   nan, 4100.])

# %% [markdown]
# Some of the net overburden values are missing. It will be assumed that these are ambient values i.e. 800 psi

# %%
mod_df['NOB (psi)'].fillna(800, inplace=True)
mod_df['NOB (psi)'].isnull().values.any()
# Out:
# C:\Users\mkumar\AppData\Local\Temp\ipykernel_9444\2924631362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mod_df['NOB (psi)'].fillna(800, inplace=True)
# False

# %%
NOBP = 800

df_sub = mod_df[mod_df['NOB (psi)'] <= NOBP]
grouped = df_sub.groupby("Well Name")
color = df_sub['color']

# %% [markdown]
# #### Histogram - Plotting the Grain Density, Porosity and Permeability at Ambient (800 psi)

# %%
savefn = "Hist_GD_800.png"

# fuction to plot - usage
# plot_grain_density (dataframe_column, plot_title, number_bins, x-axis_min, x_axis_max savefile_name)

plot_grain_density(df_sub['Grain Density (g/cc)'], "Grain Density (800 psi)", 20, 2.6, 2.8, savefn)
# Out:
# C:\Users\mkumar\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
savefn = "Hist_Poro_800.png"
plot_grain_density(df_sub["Porosity (%)"], "Porosity (%) (800 psi)", 20, 0, 30, savefn)

# %%
savefn = "Hist_Perm_800.png"
plot_grain_density(df_sub["K_klin (mD)"], "Permeability (mD) (800 psi)", 100, 0, 200, savefn)

# %% [markdown]
# #### Plotting the Effect of NOBP

# %%
#savefn = "NOBP_800.png"
#plot_NOBP(mod_df, df_sub, grouped, color, savefn)

# %% [markdown]
# #### Plot cross-plot of Porosity-Permeability

# %%
savefn = "Poro_Perm_800.png"

#Cutoff intercept
yint = 1
xint = 5.4/0.50
plot_PP(mod_df, df_sub, grouped, color, "Ambient Porosity vs Permeability (800psi)", savefn, xint, yint)
# Out:
# C:\Users\mkumar\Anaconda3\lib\site-packages\matplotlib\collections.py:1039: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "

# %% [markdown]
# ##### Cross-plot for values not at NOBP of 800 psi

# %%
df_sub = mod_df[mod_df['NOB (psi)'] > NOBP]
grouped = df_sub.groupby("Well Name")
color = df_sub['color']

# %%
savefn = "Hist_GD_not_800.png"

# fuction to plot - usage
# plot_grain_density (dataframe_column, plot_title, number_bins, x-axis_min, x_axis_max savefile_name)

plot_grain_density(df_sub['Grain Density (g/cc)'], "Grain Density (3850 psi)", 20, 2.6, 2.8, savefn)
# Out:
# C:\Users\mkumar\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
savefn = "Hist_Poro_not_800.png"
plot_grain_density(df_sub["Porosity (%)"], "Porosity (%) (3850 psi)", 20, 0, 30, savefn)

# %%
savefn = "Hist_Perm_not_800.png"
plot_grain_density(df_sub["K_klin (mD)"], "Permeability (mD) (3850 psi)", 100, 0, 50, savefn)

# %%
savefn = "Poro_Perm_not_800.png"

plot_PP(mod_df, df_sub, grouped, color, "Overburden Porosity vs Permeability (3850 psi)", savefn, xint, yint)
# Out:
# C:\Users\mkumar\Anaconda3\lib\site-packages\matplotlib\collections.py:1039: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "

# %%
#NOBP = 800

#df_sub1 = mod_df[mod_df['NOB (psi)'] <= NOBP]
#df_sub2 = mod_df[mod_df['NOB (psi)'] > NOBP]

#a = df_sub1["Porosity (%)"]
#b = df_sub2["Porosity (%)"]

#fig = plt.figure(figsize=(14, 8))
#ax = fig.add_subplot(111)

#sc = ax.scatter(
#    a,
#    b,
#    s = markersize**2,
#    alpha=0.5,
#    label="Ambeint vs Overburden",
#    edgecolors = edgecolors,
#)

# Add labels
#ax.set_xlabel('Ambient Porosity (%)', fontsize=size)
#ax.set_ylabel('OB Porosity (%)', fontsize=size)
