# %% [markdown]
# <a href="https://www.spe.org/events/en/2022/conference/22apog/asia-pacific-oil-and-gas-conference-and-exhibition.html"><img src = "https://www.spe.org/binaries/content/gallery/specms/speevents/organization-logos/spe-logo-2020.png" width = 200>
#
# <h1 align=center><font size = 5>Prediction of Recovery Factor using Machine Learning Methods</font></h1>

# %% [markdown]
# <h1 align=center><font size = 4> Munish Kumar, Kannapan Swaminathan, Aizat Rusli, Abel Thomas-hy</font></h1>
# <h1 align=center><font size = 3> ERCE 2021 </font></h1>

# %% [markdown]
# #### Libraries

# %%
# Only install the following libraries if you dont have it, otherwise leave it commented out

#!conda install -c anaconda natsort --yes
#!conda install -c anaconda xlrd --yes

# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
import time
import re
import requests
import pickle
import seaborn as sns
import os
import glob
import sys
from natsort import natsorted
sns.set()

# Sklearn Liraries
from sklearn import preprocessing

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

# Forces the print statement to show everything and not truncate
# np.set_printoptions(threshold=sys.maxsize) 
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# ###### Declare some global variables

# %%
#dir_name = r'C:\Users\mkumar\Documents\GitHub\munishkumar-gh.github.io\@Working\SPE_Paper'
dir_name = r'C:\Users\mkumar\Documents\GitHub\@Working\SPE_Paper'
filename_suffix = 'csv'

# %% [markdown]
# ##### Read in the data and some preprocessing

# %%
skiprows = 4

#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
df = pd.read_csv("C&C_database.csv", thousands=',', skiprows = skiprows)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')] 
df.head()
# Out:
#              1_Field name 2_Reservoir unit  \
# 0  25 DE MAYO-MEDANITO SE         QUINTUCO
# 1            A.J.BERMUDEZ          UNNAMED
# 2               AB TEYMUR             ILAM
# 3               AB TEYMUR         SARVAK 1
# 4                   ABADI     UPPER PLOVER
#
#                    3_Unique Resource Name 4_Resource category  \
# 0  25 DE MAYO-MEDANITO SE(QUINTUCO)(R-1P)            RESERVES
# 1             A.J.BERMUDEZ(UNNAMED)(R-1P)            RESERVES
# 2                   AB TEYMUR(ILAM)(R-1P)            RESERVES
# 3               AB TEYMUR(SARVAK 1)(R-1P)            RESERVES
# 4               ABADI(UPPER PLOVER)(R-3P)            RESERVES
#
#           5_Resource uncertainty       6_Resource maturity  \
# 0                    1P (PROVED)             ON PRODUCTION
# 1                    1P (PROVED)             ON PRODUCTION
# 2                    1P (PROVED)             ON PRODUCTION
# 3                    1P (PROVED)             ON PRODUCTION
# 4  3P (PROVED+PROBABLE+POSSIBLE)  APPROVED FOR DEVELOPMENT
#
#                                        7_Field alias  8_Country  \
# 0                                                NaN  ARGENTINA
# 1  SAMARIA /CUNDUACAN /IRIDE /OXIACAQUE /TRES PUE...     MEXICO
# 2     ABTEYMUR /ABTEYMOUR /AB-E-TEIMUR /AB-E-TEYMOUR       IRAN
# 3     ABTEYMUR /ABTEYMOUR /AB-E-TEIMUR /AB-E-TEYMOUR       IRAN
# 4                                                NaN  INDONESIA
#
#   9_State in USA      10_Region  ... 330_EOR (pilot)  \
# 0            NaN  LATIN AMERICA  ...             NaN
# 1            NaN  LATIN AMERICA  ...             NaN
# 2            NaN    MIDDLE EAST  ...             NaN
# 3            NaN    MIDDLE EAST  ...             NaN
# 4            NaN   ASIA-PACIFIC  ...             NaN
#
#   331_EOR (partial application) 332_EOR (fieldwide)  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN                 NaN
# 3                           NaN                 NaN
# 4                           NaN                 NaN
#
#                333_Improved recovery methods (other)  \
# 0               DRILLING/STIMULATION/ARTIFICIAL LIFT
# 1  DRILLING/STIMULATION/ARTIFICIAL LIFT/SAND CONTROL
# 2                                        STIMULATION
# 3                                        STIMULATION
# 4                         OTHER RESERVOIR MANAGEMENT
#
#    334_Improved recovery methods (drilling)  \
# 0                               INFILL WELL
# 1               INFILL WELL/HORIZONTAL WELL
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#        335_Improved recovery methods (stimulation)  \
# 0  ACIDIZATION/HYDRAULIC FRACTURING (SINGLE STAGE)
# 1                                      ACIDIZATION
# 2                                      ACIDIZATION
# 3                                      ACIDIZATION
# 4                                              NaN
#
#   336_Improved recovery methods (water injection optimization)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   337_Improved recovery methods (artificial lift)  \
# 0                                             ESP
# 1                                        GAS LIFT
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   338_Improved recovery methods (sand control)  \
# 0                                          NaN
# 1                                SLOTTED LINER
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   339_Improved recovery methods (other reservoir management)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                       SIDETRACKING
#
# [5 rows x 341 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1447 entries, 0 to 1446
# Columns: 341 entries, 1_Field name to 339_Improved recovery methods (other reservoir management)
# dtypes: float64(226), object(115)
# memory usage: 3.8+ MB

# %% [markdown]
# There are a huge number of columns here (341 columns in total). This has to be reduced significantly.
#
# 1. Listing the column headers in the dataframe via the '.columns' parameter.
# 2. Executing a brute force drop i.e. if there are columns that have more than a certian % of missing cells, just drop the whole column

# %%
# The variable 'a' can be changed to determine which columns to exactly drop. So, if a = 0.9, than if the column contains
# more than 90% null values, drop the column
a = 0.9 

cols_to_delete = df.columns[df.isnull().sum()/len(df) > .90]
cols_to_delete
# Out:
# Index(['20_Hydrocarbon type (tertiary)',
#        '27_Discovery well IP (condensate) (BCPD)',
#        '30_Well rate (maximum reported condensate) (BCPD)',
#        '42_Well count (total suspended injector)',
#        '43_Well count (total abandoned injector)',
#        '44_Well count (total water injector)',
#        '45_Well count (total gas injector)',
#        '47_Well count (current active oil producer)',
#        '48_Well count (current active gas producer)',
#        '50_Well count (current active water injector)',
#        ...
#        '318_Techniques used to characterize remaining HC',
#        '321_Secondary recovery (pilot)',
#        '322_Secondary recovery (partial application)',
#        '326_EOR methods (thermal)', '327_EOR methods (chemical)',
#        '328_EOR methods (miscible)', '329_EOR methods (others)',
#        '330_EOR (pilot)', '331_EOR (partial application)',
#        '332_EOR (fieldwide)'],
#       dtype='object', length=115)

# %%
df_new=df[df.columns.drop(cols_to_delete)]
print(df_new.columns.values)
df_new.head(2)
# Out:
# ['1_Field name' '2_Reservoir unit' '3_Unique Resource Name'
#  '4_Resource category' '5_Resource uncertainty' '6_Resource maturity'
#  '7_Field alias' '8_Country' '9_State in USA' '10_Region' '11_Basin name'
#  '12_Basin type (Bally)' '13_Basin type (Klemme)' '14_Tectonic regime'
#  '15_Latitude' '16_Longitude' '17_Operator company'
#  '18_Hydrocarbon type (main)' '19_Hydrocarbon type (secondary)'
#  '21_Discovery concept' '22_Technical basis for discovery well'
#  '23_Discovery year' '24_Discovery well name'
#  '25_Discovery well IP (oil) (BOPD)'
#  '26_Discovery well IP (gas) (MMCFGPD)'
#  '28_Well rate (maximum reported oil) (BOPD)'
#  '29_Well rate (maximum reported gas) (MMCFGPD)'
#  '31_First production date' '32_Current status year'
#  '33_Current reservoir status' '34_Current production stage'
#  '35_Well count (total all wells)'
#  '36_Well count (total exploration well)'
#  '37_Well count (total appraisal well)' '38_Well count (total producer)'
#  '39_Well count (total oil producer)' '40_Well count (total gas producer)'
#  '41_Well count (total injector)'
#  '46_Well count (current active producer)'
#  '49_Well count (current active injector)'
#  '52_Well spacing (current oil average) (ac)'
#  '55_Well spacing (current gas average) (ac)'
#  '58_Production year (current)' '59_Production rate (current oil) (BOPD)'
#  '60_Production rate (current gas) (MMCFGPD)'
#  '62_Production rate (current oil equivalent) (BOEPD)'
#  '65_Water-cut (current) (%)' '66_Production year (peak)'
#  '67_Production rate (peak oil) (BOPD)'
#  '68_Production rate (peak gas) (MMCFGPD)'
#  '70_Production rate (peak oil equivalent) (BOEPD)'
#  '71_Production facilities' '72_Onshore or offshore' '73_Elevation (ft)'
#  '74_Water depth (ft)' '75_Temperature (original) (deg. F)'
#  '76_Temperature depth (ft TVDSS)' '77_Pressure (original) (psi)'
#  '78_Pressure depth (ft TVDSS)' '79_Pressure gradient (original) (psi/ft)'
#  '80_Pressure year (current)' '81_Pressure (current) (psi)'
#  '82_Drive mechanism (main)' '83_Drive mechanism (secondary)'
#  '84_Data quality' '85_Source rock unit' '86_Source rock period'
#  '87_Source rock epoch' '88_Source rock age'
#  '89_Source rock tectonic setting' '90_Source rock lithology'
#  '91_Source rock depositional system'
#  '92_Source rock thickness (average) (ft)'
#  '95_Hydrogen index (average) (mg HC/g TOC)' '104_Kerogen type'
#  '105_TOC (average) (%)' '106_TOC (minimum) (%)' '107_TOC (maximum) (%)'
#  '108_Timing of hydrocarbon expulsion (period)'
#  '109_Timing of hydrocarbon expulsion (epoch)' '110_Structural setting'
#  '111_Trapping mechanism (main)' '112_Trapping mechanism (secondary)'
#  '113_Trapping mechanism (tertiary)' '114_Seismic anomaly'
#  '115_Structural compartment count' '116_Depth to top reservoir (ft TVD)'
#  '117_Reservoir top subsea depth (ft TVDSS)'
#  '118_Structural flank dip (average) (deg.)'
#  '120_Structural flank dip (maximum) (deg.)' '121_Closure area (ac)'
#  '121a_Closure area (Sq Km)' '122_Closure height (ft)'
#  '123_Productive area (original) (ac)'
#  '123_Productive area (original) (Sq Km)'
#  '124_Original OWC (average) (ft TVDSS)'
#  '127_Original GOC (average) (ft TVDSS)'
#  '130_Original GWC (average) (ft TVDSS)'
#  '133_Hydrocarbon column height (original oil) (ft)'
#  '134_Hydrocarbon column height (original gas) (ft)'
#  '135_Hydrocarbon column height (original total) (ft)'
#  '136_Timing of trap formation (period)'
#  '137_Timing of trap formation (epoch)' '138_Seal unit (crestal)'
#  '139_Seal period' '140_Seal epoch' '141_Seal age'
#  '142_Seal tectonic setting' '143_Seal depositional system'
#  '144_Seal lithology' '145_Seal thickness (average) (ft)'
#  '148_Seal classification' '149_Reservoir period' '150_Reservoir epoch'
#  '151_Reservoir age' '152_Reservoir tectonic setting'
#  '153_Depositional system (main)' '154_Depositional system (secondary)'
#  '155_Depositional environment (main)'
#  '156_Depositional environment (secondary)'
#  '157_Depositional environment (tertiary)'
#  '158_Sandbody type for clastics (main)'
#  '159_Sandbody type for clastics (secondary)'
#  '160_Sandbody type for clastics (tertiary)'
#  '161_Reservoir architecture (main)'
#  '162_Reservoir architecture (secondary)'
#  '163_Fluid flow restriction (macro-scale)'
#  '164_Fluid flow restriction (meso-scale)'
#  '165_Fluid flow restriction (micro-scale)'
#  '166_Number of reservoir flow units'
#  '167_Single reservoir zone thickness (average) (ft)'
#  '168_Single reservoir zone thickness (minimum) (ft)'
#  '169_Single reservoir zone thickness (maximum) (ft)'
#  '170_Gross reservoir thickness (average) (ft)'
#  '171_Gross reservoir thickness (minimum) (ft)'
#  '172_Gross reservoir thickness (maximum) (ft)'
#  '173_Net reservoir thickness (average) (ft)'
#  '174_Net reservoir thickness (minimum) (ft)'
#  '175_Net reservoir thickness (maximum) (ft)'
#  '176_Net/gross ratio (average)' '179_Net pay (average) (m)'
#  '180_Net pay (minimum) (m)' '181_Net pay (maximum) (m)'
#  '182_Reservoir lithology (main)' '183_Reservoir lithology (secondary)'
#  '184_Grain size for clastics (dominant)'
#  '185_Grain size for clastics (minimum)'
#  '186_Grain size for clastics (maximum)'
#  '187_Depositional texture for carbonates (main)'
#  '188_Depositional texture for carbonates (secondary)'
#  '189_Depositional composition for clastics (main)'
#  '190_Depositional composition for clastics (secondary)'
#  '191_Depositional component for carbonates (main)'
#  '192_Depositional component for carbonates (secondary)'
#  '194_Clay mineral component (main)' '195_Unconventional reservoir type'
#  '196_Diagenetic reservoir type' '197_Fracture origin (main)'
#  '199_Fracture reservoir type' '200_Porosity type (main)'
#  '201_Porosity type (secondary)' '202_Porosity type (tertiary)'
#  '203_Porosity measurement source' '204_Porosity (matrix average) (%)'
#  '205_Porosity (matrix minimum) (%)' '206_Porosity (matrix maximum) (%)'
#  '210_Permeability (air average) (mD)'
#  '211_Permeability (air minimum) (mD)'
#  '212_Permeability (air maximum) (mD)'
#  '213_Permeability (well test average) (mD)'
#  '214_Permeability (well test minimum) (mD)'
#  '215_Permeability (well test maximum) (mD)'
#  '216_Vertical to horizontal permeability ratio (average)'
#  '217_Inter-layer permeability contrast (average)'
#  '218_API gravity (oil average) (deg. API)'
#  '221_API gravity (condensate average) (deg. API)'
#  '222_Specific gravity (gas average)' '225_Viscosity (oil average) (cp)'
#  '230_Mobility index (average) (mD/cp)'
#  '233_Flowability (average) (mD.ft/cp)' '236_Sulphur (average) (%)'
#  '239_Wax (average) (%)' '242_Methane (average) (%)'
#  '243_Carbon dioxide (average) (%)' '246_Hydrogen sulphide (average) (%)'
#  '249_Nitrogen (average) (%)' '252_GOR (initial average) (SCF/STB)'
#  '255_Condensate yield (initial average) (BC/MMCFG)'
#  '258_FVF (oil average) (RB/STB)'
#  '263_Bubble point pressure (average) (psi)'
#  '266_Pour point temperature (average) (deg. F)'
#  '273_Formation water salinity (average) (mg/L)'
#  '276_Water saturation (initial average) (%)'
#  '277_Water saturation (initial minimum) (%)'
#  '278_Water saturation (initial maximum) (%)'
#  '280_Oil saturation (original average) (%)'
#  '290_Original in-place oil (MMBO)' '291_Original in-place gas (BCFG)'
#  '293_Original in-place oil equivalent (MMBOE)'
#  '294_Resource density (oil) (MBO/ac)'
#  '295_Resource density (gas) (MMCFG/ac)' '297_EUR oil (MMBO)'
#  '298_EUR gas (BCFG)' '300_EUR oil equivalent (MMBOE)'
#  '301_Remaining EUR oil (MMBO)' '302_Remaining EUR gas (BCFG)'
#  '304_Recovery factor (primary oil) (%)'
#  '307_Recovery factor (ultimate oil) (%)'
#  '308_Recovery factor (ultimate gas) (%)'
#  '310_Recovery to date (of in-place oil) (%)'
#  '311_Recovery to date (of in-place gas) (%)'
#  '313_Recovery (best-fit ultimate oil) (%)'
#  '314_Reservoir performance index (decimal fraction)'
#  '315_EUR oil per production well (MMBO)'
#  '319_Secondary recovery start date' '320_Secondary recovery methods'
#  '323_Secondary recovery (fieldwide)' '324_EOR start date'
#  '325_EOR methods' '333_Improved recovery methods (other)'
#  '334_Improved recovery methods (drilling)'
#  '335_Improved recovery methods (stimulation)'
#  '336_Improved recovery methods (water injection optimization)'
#  '337_Improved recovery methods (artificial lift)'
#  '338_Improved recovery methods (sand control)'
#  '339_Improved recovery methods (other reservoir management)']
#              1_Field name 2_Reservoir unit  \
# 0  25 DE MAYO-MEDANITO SE         QUINTUCO
# 1            A.J.BERMUDEZ          UNNAMED
#
#                    3_Unique Resource Name 4_Resource category  \
# 0  25 DE MAYO-MEDANITO SE(QUINTUCO)(R-1P)            RESERVES
# 1             A.J.BERMUDEZ(UNNAMED)(R-1P)            RESERVES
#
#   5_Resource uncertainty 6_Resource maturity  \
# 0            1P (PROVED)       ON PRODUCTION
# 1            1P (PROVED)       ON PRODUCTION
#
#                                        7_Field alias  8_Country  \
# 0                                                NaN  ARGENTINA
# 1  SAMARIA /CUNDUACAN /IRIDE /OXIACAQUE /TRES PUE...     MEXICO
#
#   9_State in USA      10_Region  ... 323_Secondary recovery (fieldwide)  \
# 0            NaN  LATIN AMERICA  ...         CONTINUOUS WATER INJECTION
# 1            NaN  LATIN AMERICA  ...         CONTINUOUS WATER INJECTION
#
#   324_EOR start date 325_EOR methods  \
# 0                NaN             NaN
# 1                NaN             NaN
#
#                333_Improved recovery methods (other)  \
# 0               DRILLING/STIMULATION/ARTIFICIAL LIFT
# 1  DRILLING/STIMULATION/ARTIFICIAL LIFT/SAND CONTROL
#
#    334_Improved recovery methods (drilling)  \
# 0                               INFILL WELL
# 1               INFILL WELL/HORIZONTAL WELL
#
#        335_Improved recovery methods (stimulation)  \
# 0  ACIDIZATION/HYDRAULIC FRACTURING (SINGLE STAGE)
# 1                                      ACIDIZATION
#
#   336_Improved recovery methods (water injection optimization)  \
# 0                                                NaN
# 1                                                NaN
#
#   337_Improved recovery methods (artificial lift)  \
# 0                                             ESP
# 1                                        GAS LIFT
#
#   338_Improved recovery methods (sand control)  \
# 0                                          NaN
# 1                                SLOTTED LINER
#
#   339_Improved recovery methods (other reservoir management)
# 0                                                NaN
# 1                                                NaN
#
# [2 rows x 226 columns]

# %% [markdown]
# Checkpoint 1: Files here are partically cleaned. Columns that are a certain % empty are brute-force dropped

# %%
base_filename = 'CP1_Temp_RF_data'
csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
df_new.to_csv(csvs_sht, index = False, header=True)
print ("Final File Extract Produced")
# Out:
# Final File Extract Produced

# %% [markdown]
# ##### Dropping columns that are either duplicates or else are of secondary importance

# %%
# Using a regex method to drop columns pythonically.
# Based on the following syntax and modified
# drop_columns_regex = '^(?!(?:'+'|'.join(drop_column_names)+')$)'

# Column Names to drop
# 0-60 : General well/field information
# 61-80 : Pressure, temeprature, Drive Mech
# 81-109 : Source rock characteristics, incl TOC
# 110-135 : Structure, Depth, Column Height, Dips
# 136-149 : Trap & Seal
# 150-159 : Reservoir Age, Depo Setting, 
# 160-169 : Reservoir Architecture, Number of Reservoir Units
# 170-181 : Reservoir Thickness (Gross, Net), NTG, Net Pay
# 182-194 : Lithology, Grain-Size (SST), Depo texture (LST), Clay type
# 195-217 : Reservoir Type, Porosity Type, Porosity Values, Permeability Values
# 218-266 : PVT Properties, including API, SG, Sulphur, Wax, Methane, CO2, H2S, GOR etc
# 273-289 : Formation Water Properties
# 290-315 : Resource Estimate (OHCIP, EUR), RF
# 319-325 : Secondary Recovery and EOR
# 325-339: Improved Recovery Methods

drop_column_names = [
    '3_', '4_', '6_', '7_','9_','12_','13_','14_','17_', '19_',
    '21_', '22_', '23_', '24_', '25_', '26_', '28_', '29_', 
    '31_', '36_', '37_', '39_', '40_', '41_', '49_', '59_', '60_',
    
    '67_', '68_', '71_', '79_', '83_', '84_', '85_', '86_', '87_', '88_', 
    '89_', '90_', '91_', '92_', '95_', '104_', '105_', '106_', '107_',
    
    '108_', '109_', '110_', '112_', '113_', '114_', '115_', '120_',
    '121_', '121a_', '122_', '123_', '124_', '127_', '130_', '133_',
    '134_', '136_', '137_', '138_', '139_', '140_', '141_', '142_',
    '143_', '144_', '145_', '148_', 
    
    '150_', '151_', '152_', '154_', '155_', '156_', '157_', '158_',
    '159_', '160_', '162_', '165_', '166_', '167_', '168_', '169_',
    
    '171_', '172_', '174_', '175_', '180_', '181_', '183_', '185_',
    '186_', '188_', '190_', '192_', '194_', '195_', '196_',
    
    '197_', '201_', '202_', '203_', '205_', '206_', '211_', '212_',
    '214_', '215_', '216_', '217_', '233_',
    
    '277_', '278_', '280_',
    
    '290_', '291_', '294_', '295_', '297_', '298_',
    
    '323',   
                    ]

# String concat for column drop
drop_columns_regex = '^(('+'|'.join(drop_column_names)+'))'
print('Dropping columns:',', '.join([c for c in df_new.columns if re.search(drop_columns_regex,c)]))
# Out:
# Dropping columns: 3_Unique Resource Name, 4_Resource category, 6_Resource maturity, 7_Field alias, 9_State in USA, 12_Basin type (Bally), 13_Basin type (Klemme), 14_Tectonic regime, 17_Operator company, 19_Hydrocarbon type (secondary), 21_Discovery concept, 22_Technical basis for discovery well, 23_Discovery year, 24_Discovery well name, 25_Discovery well IP (oil) (BOPD), 26_Discovery well IP (gas) (MMCFGPD), 28_Well rate (maximum reported oil) (BOPD), 29_Well rate (maximum reported gas) (MMCFGPD), 31_First production date, 36_Well count (total exploration well), 37_Well count (total appraisal well), 39_Well count (total oil producer), 40_Well count (total gas producer), 41_Well count (total injector), 49_Well count (current active injector), 59_Production rate (current oil) (BOPD), 60_Production rate (current gas) (MMCFGPD), 67_Production rate (peak oil) (BOPD), 68_Production rate (peak gas) (MMCFGPD), 71_Production facilities, 79_Pressure gradient (original) (psi/ft), 83_Drive mechanism (secondary), 84_Data quality, 85_Source rock unit, 86_Source rock period, 87_Source rock epoch, 88_Source rock age, 89_Source rock tectonic setting, 90_Source rock lithology, 91_Source rock depositional system, 92_Source rock thickness (average) (ft), 95_Hydrogen index (average) (mg HC/g TOC), 104_Kerogen type, 105_TOC (average) (%), 106_TOC (minimum) (%), 107_TOC (maximum) (%), 108_Timing of hydrocarbon expulsion (period), 109_Timing of hydrocarbon expulsion (epoch), 110_Structural setting, 112_Trapping mechanism (secondary), 113_Trapping mechanism (tertiary), 114_Seismic anomaly, 115_Structural compartment count, 120_Structural flank dip (maximum) (deg.), 121_Closure area (ac), 121a_Closure area (Sq Km), 122_Closure height (ft), 123_Productive area (original) (ac), 123_Productive area (original) (Sq Km), 124_Original OWC (average) (ft TVDSS), 127_Original GOC (average) (ft TVDSS), 130_Original GWC (average) (ft TVDSS), 133_Hydrocarbon column height (original oil) (ft), 134_Hydrocarbon column height (original gas) (ft), 136_Timing of trap formation (period), 137_Timing of trap formation (epoch), 138_Seal unit (crestal), 139_Seal period, 140_Seal epoch, 141_Seal age, 142_Seal tectonic setting, 143_Seal depositional system, 144_Seal lithology, 145_Seal thickness (average) (ft), 148_Seal classification, 150_Reservoir epoch, 151_Reservoir age, 152_Reservoir tectonic setting, 154_Depositional system (secondary), 155_Depositional environment (main), 156_Depositional environment (secondary), 157_Depositional environment (tertiary), 158_Sandbody type for clastics (main), 159_Sandbody type for clastics (secondary), 160_Sandbody type for clastics (tertiary), 162_Reservoir architecture (secondary), 165_Fluid flow restriction (micro-scale), 166_Number of reservoir flow units, 167_Single reservoir zone thickness (average) (ft), 168_Single reservoir zone thickness (minimum) (ft), 169_Single reservoir zone thickness (maximum) (ft), 171_Gross reservoir thickness (minimum) (ft), 172_Gross reservoir thickness (maximum) (ft), 174_Net reservoir thickness (minimum) (ft), 175_Net reservoir thickness (maximum) (ft), 180_Net pay (minimum) (m), 181_Net pay (maximum) (m), 183_Reservoir lithology (secondary), 185_Grain size for clastics (minimum), 186_Grain size for clastics (maximum), 188_Depositional texture for carbonates (secondary), 190_Depositional composition for clastics (secondary), 192_Depositional component for carbonates (secondary), 194_Clay mineral component (main), 195_Unconventional reservoir type, 196_Diagenetic reservoir type, 197_Fracture origin (main), 201_Porosity type (secondary), 202_Porosity type (tertiary), 203_Porosity measurement source, 205_Porosity (matrix minimum) (%), 206_Porosity (matrix maximum) (%), 211_Permeability (air minimum) (mD), 212_Permeability (air maximum) (mD), 214_Permeability (well test minimum) (mD), 215_Permeability (well test maximum) (mD), 216_Vertical to horizontal permeability ratio (average), 217_Inter-layer permea ...

# %%
# in pandas axis=0 represents rows (default) and axis=1 represents columns.
# Filter based on selected drop columns. Use masking to create new dataframe
data = df_new.filter(regex=drop_columns_regex, axis=1)
data_preproc = df_new[df_new.columns.drop(list(data))]
data_preproc.head(2)
# Out:
#              1_Field name 2_Reservoir unit 5_Resource uncertainty  8_Country  \
# 0  25 DE MAYO-MEDANITO SE         QUINTUCO            1P (PROVED)  ARGENTINA
# 1            A.J.BERMUDEZ          UNNAMED            1P (PROVED)     MEXICO
#
#        10_Region    11_Basin name  15_Latitude  16_Longitude  \
# 0  LATIN AMERICA          NEUQUEN     -37.9935      -67.9567
# 1  LATIN AMERICA  CHIAPAS-TABASCO      17.9833      -93.1000
#
#   18_Hydrocarbon type (main)  32_Current status year  ...  \
# 0                        OIL                  2012.0  ...
# 1                        OIL                  2008.0  ...
#
#              320_Secondary recovery methods 324_EOR start date  \
# 0                CONTINUOUS WATER INJECTION                NaN
# 1  CONTINUOUS WATER INJECTION/GAS INJECTION                NaN
#
#    325_EOR methods              333_Improved recovery methods (other)  \
# 0              NaN               DRILLING/STIMULATION/ARTIFICIAL LIFT
# 1              NaN  DRILLING/STIMULATION/ARTIFICIAL LIFT/SAND CONTROL
#
#    334_Improved recovery methods (drilling)  \
# 0                               INFILL WELL
# 1               INFILL WELL/HORIZONTAL WELL
#
#        335_Improved recovery methods (stimulation)  \
# 0  ACIDIZATION/HYDRAULIC FRACTURING (SINGLE STAGE)
# 1                                      ACIDIZATION
#
#    336_Improved recovery methods (water injection optimization)  \
# 0                                                NaN
# 1                                                NaN
#
#    337_Improved recovery methods (artificial lift)  \
# 0                                              ESP
# 1                                         GAS LIFT
#
#    338_Improved recovery methods (sand control)  \
# 0                                           NaN
# 1                                 SLOTTED LINER
#
#    339_Improved recovery methods (other reservoir management)
# 0                                                NaN
# 1                                                NaN
#
# [2 rows x 97 columns]

# %% [markdown]
# ##### Rename and simply some of the elements in the various cells.

# %%
# Current name of items in column and sum count per type
print(data_preproc["5_Resource uncertainty"].str.get_dummies(sep=', ').sum())

#Split based on open bracket "(", drop extra columns
split_data = data_preproc["5_Resource uncertainty"].str.split("(")
data = split_data.to_list()
names = ["a", "b"]
new_df = pd.DataFrame(data, columns=names).drop(['b'], axis = 1)
#new_df.head()
print("")

# Rename items in column to simplify names
data_preproc2 = pd.concat([data_preproc, new_df], axis = 1)
data_preproc = data_preproc2.drop(['5_Resource uncertainty'], axis = 1)
data_preproc.rename(columns = {'a':'5_Resource uncertainty'}, inplace = True)
print(data_preproc["5_Resource uncertainty"].str.get_dummies(sep=', ').sum())
#print("")
#data_preproc.info()
#data_preproc.head()
# Out:
# 1P (PROVED)                      1358
# 2C (BEST ESTIMATE)                  7
# 2P (PROVED+PROBABLE)               39
# 3P (PROVED+PROBABLE+POSSIBLE)      43
# dtype: int64
#
# 1P     1358
# 2C        7
# 2P       39
# 3P       43
# dtype: int64

# %%
# Current name of items in column and sum count per type
print(data_preproc["18_Hydrocarbon type (main)"].str.get_dummies(sep=', ').sum())

#Replace names with simpler categories 
# Drop irrelevant data
data_preproc["18_Hydrocarbon type (main)"] = data_preproc["18_Hydrocarbon type (main)"].str.replace('COALBED METHANE', 'GAS')
data_preproc["18_Hydrocarbon type (main)"] = data_preproc["18_Hydrocarbon type (main)"].str.replace('BITUMEN', 'OIL')
data_preproc = data_preproc[~data_preproc["18_Hydrocarbon type (main)"].str.contains("CARBON DIOXIDE")] 

print("")
print(data_preproc["18_Hydrocarbon type (main)"].str.get_dummies(sep=', ').sum())
# Out:
# BITUMEN               6
# CARBON DIOXIDE        2
# COALBED METHANE       4
# GAS                 202
# GAS-CONDENSATE      128
# OIL                1105
# dtype: int64
#
# GAS                206
# GAS-CONDENSATE     128
# OIL               1111
# dtype: int64

# %%
# Fixing some of the errors assocaited with the year where the numbers are decimals. Only column 32 has this
data_preproc['32_Current status year'] = df['32_Current status year'].mask(df['32_Current status year'].astype(str).str.startswith('0.'), ' ')

# %%
# Current name of items in column and sum count per type
print(data_preproc["82_Drive mechanism (main)"].str.get_dummies(sep=', ').sum())

# Mask out term and replace 
data_preproc.loc[data_preproc["82_Drive mechanism (main)"].str.contains('aquifer of', case = False, na=False), '82_Drive mechanism (main)'] = 'AQUIFER DRIVE'
data_preproc.loc[data_preproc["82_Drive mechanism (main)"].str.contains('bottom', case = False, na=False), '82_Drive mechanism (main)'] = 'AQUIFER DRIVE'
data_preproc.loc[data_preproc["82_Drive mechanism (main)"].str.contains('edge', case = False, na=False), '82_Drive mechanism (main)'] = 'AQUIFER DRIVE'
data_preproc.loc[data_preproc["82_Drive mechanism (main)"].str.contains('weak', case = False, na=False), '82_Drive mechanism (main)'] = 'AQUIFER DRIVE'
data_preproc.loc[data_preproc["82_Drive mechanism (main)"].str.contains('moderate', case = False, na=False), '82_Drive mechanism (main)'] = 'AQUIFER DRIVE'
data_preproc.loc[data_preproc["82_Drive mechanism (main)"].str.contains('strong', case = False, na=False), '82_Drive mechanism (main)'] = 'AQUIFER DRIVE'
data_preproc.loc[data_preproc["82_Drive mechanism (main)"].str.contains('gas', case = False, na=False), '82_Drive mechanism (main)'] = 'GAS DRIVE'

print("")
print(data_preproc["82_Drive mechanism (main)"].str.get_dummies(sep=', ').sum())
# Out:
# AQUIFER OF UNSPECIFIED STRENGTH                                             30
# AQUIFER OF UNSPECIFIED STRENGTH/BOTTOM AQUIFER                               6
# AQUIFER OF UNSPECIFIED STRENGTH/BOTTOM AQUIFER/EDGE AQUIFER                  6
# AQUIFER OF UNSPECIFIED STRENGTH/BOTTOM AQUIFER/EDGE AQUIFER/SOLUTION GAS     2
# AQUIFER OF UNSPECIFIED STRENGTH/BOTTOM AQUIFER/SOLUTION GAS                  3
#                                                                             ..
# WEAK AQUIFER/MODERATE AQUIFER                                                1
# WEAK AQUIFER/SOLUTION GAS                                                   37
# WEAK AQUIFER/SOLUTION GAS/GAS CAP                                            3
# WEAK AQUIFER/SOLUTION GAS/GAS EXPANSION                                      1
# WEAK AQUIFER/SOLUTION GAS/GRAVITY DRAINAGE                                   4
# Length: 83, dtype: int64
#
# AQUIFER DRIVE           634
# CAPILLARY IMBIBITION      1
# COMPACTION               13
# GAS DRIVE               761
# GRAVITY DRAINAGE          7
# dtype: int64

# %%
# Current name of items in column and sum count per type
print(data_preproc["182_Reservoir lithology (main)"].str.get_dummies(sep=', ').sum())

data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('limestone', case = False, na=False), '182_Reservoir lithology (main)'] = 'CARBONATES'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('dolomite', case = False, na=False), '182_Reservoir lithology (main)'] = 'CARBONATES'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('chalk', case = False, na=False), '182_Reservoir lithology (main)'] = 'CARBONATES'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('diatomite', case = False, na=False), '182_Reservoir lithology (main)'] = 'SANDSTONE'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('chert', case = False, na=False), '182_Reservoir lithology (main)'] = 'SANDSTONE'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('Sandstone', case = False, na=False), '182_Reservoir lithology (main)'] = 'SANDSTONE'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('siltstone', case = False, na=False), '182_Reservoir lithology (main)'] = 'SANDSTONE'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('conglomerate', case = False, na=False), '182_Reservoir lithology (main)'] = 'OTHERS'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('volcanics', case = False, na=False), '182_Reservoir lithology (main)'] = 'OTHERS'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('coal', case = False, na=False), '182_Reservoir lithology (main)'] = 'OTHERS'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('basement', case = False, na=False), '182_Reservoir lithology (main)'] = 'OTHERS'
data_preproc.loc[data_preproc["182_Reservoir lithology (main)"].str.contains('shale', case = False, na=False), '182_Reservoir lithology (main)'] = 'OTHERS'

print("")
print(data_preproc["182_Reservoir lithology (main)"].str.get_dummies(sep=', ').sum())
# Out:
# BASEMENT                                        22
# CHALK                                           23
# CHALKY LIMESTONE                                27
# CHERT                                            4
# CHERT/SILTSTONE                                  1
# COAL                                             4
# CONGLOMERATE                                    18
# CONGLOMERATE/SANDSTONE                           1
# DIATOMITE                                        3
# DOLOMITE                                       165
# DOLOMITE/DOLOMITIC LIMESTONE                     3
# DOLOMITE/LIMESTONE                               1
# DOLOMITIC LIMESTONE                             16
# GLAUCONITIC SANDSTONE                            5
# LIMESTONE                                      200
# LOW-RESISTIVITY SANDSTONE                       39
# LOW-RESISTIVITY SANDSTONE/SHALY SANDSTONE        2
# SANDSTONE                                      822
# SANDSTONE/GLAUCONITIC SANDSTONE                  1
# SANDSTONE/SILICEOUS SHALE                        1
# SANDSTONE/SILTSTONE                              2
# SANDSTONE/THINLY-BEDDED SANDSTONE                1
# SANDSTONE/THINLY-BEDDED SANDSTONE/SILTSTONE      1
# SHALE                                           19
# SHALY SANDSTONE                                 12
# SILICEOUS SHALE                                  1
# SILTSTONE                                        8
# THINLY-BEDDED SANDSTONE                         33
# THINLY-BEDDED SANDSTONE/SHALY SANDSTONE          1
# VOLCANICS                                        9
# dtype: int64
#
# CARBONATES    435
# OTHERS         73
# SANDSTONE     937
# dtype: int64

# %%
# Combine some columns to reduce column count
data_preproc['52_Well spacing (average) (ac)'] = data_preproc['52_Well spacing (current oil average) (ac)'].fillna(0) + data_preproc['55_Well spacing (current gas average) (ac)'].fillna(0)
data_preproc['73_Water_Depth (ft)'] = data_preproc['74_Water depth (ft)'].fillna(0) - data_preproc['73_Elevation (ft)'].fillna(0)
data_preproc['218_API gravity (average) (deg. API)'] = data_preproc['218_API gravity (oil average) (deg. API)'].fillna(0) + data_preproc['221_API gravity (condensate average) (deg. API)'].fillna(0)
data_preproc['236_Oil_impurities (average)'] = data_preproc['236_Sulphur (average) (%)'].fillna(0) + data_preproc['239_Wax (average) (%)'].fillna(0)
data_preproc['243_Gas_impurities (average)'] = data_preproc['243_Carbon dioxide (average) (%)'].fillna(0) + data_preproc['246_Hydrogen sulphide (average) (%)'].fillna(0) + data_preproc['249_Nitrogen (average) (%)'].fillna(0)

data_preproc = data_preproc.drop([
    '52_Well spacing (current oil average) (ac)', '55_Well spacing (current gas average) (ac)',
    '74_Water depth (ft)', '73_Elevation (ft)',
    '218_API gravity (oil average) (deg. API)', '221_API gravity (condensate average) (deg. API)',
    '236_Sulphur (average) (%)', '239_Wax (average) (%)',
    '243_Carbon dioxide (average) (%)', '246_Hydrogen sulphide (average) (%)', '249_Nitrogen (average) (%)',   
], axis = 1)

# %%
data_preproc['184_Grain_Size_Texture'] = data_preproc['184_Grain size for clastics (dominant)'].fillna('') + data_preproc['187_Depositional texture for carbonates (main)'].fillna('')
data_preproc['189_Composition'] = data_preproc['189_Depositional composition for clastics (main)'].fillna('') + data_preproc['191_Depositional component for carbonates (main)'].fillna('')

data_preproc = data_preproc.drop([
    '184_Grain size for clastics (dominant)', '187_Depositional texture for carbonates (main)',
    '189_Depositional composition for clastics (main)', '191_Depositional component for carbonates (main)',
], axis = 1)

# %%
data_preproc.loc[data_preproc["163_Fluid flow restriction (macro-scale)"].str.contains('None', case = False, na=False), '163_Fluid flow restriction (macro-scale)'] = ' '

data_preproc['163_Fluid flow restriction'] = data_preproc['163_Fluid flow restriction (macro-scale)'].fillna('') + data_preproc['164_Fluid flow restriction (meso-scale)'].fillna('')

data_preproc = data_preproc.drop([
    '163_Fluid flow restriction (macro-scale)', '164_Fluid flow restriction (meso-scale)', 
], axis = 1)

# %% [markdown]
# ##### Sort the columns so that it reads incrementally

# %%
data_preproc = data_preproc.reindex(natsorted(data_preproc.columns), axis=1)
#data_preproc.columns.values
data_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1445 entries, 0 to 1446
# Data columns (total 88 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   1_Field name                                                  1445 non-null   object
#  1   2_Reservoir unit                                              1445 non-null   object
#  2   5_Resource uncertainty                                        1445 non-null   object
#  3   8_Country                                                     1445 non-null   object
#  4   10_Region                                                     1445 non-null   object
#  5   11_Basin name                                                 1445 non-null   object
#  6   15_Latitude                                                   1445 non-null   float64
#  7   16_Longitude                                                  1445 non-null   float64
#  8   18_Hydrocarbon type (main)                                    1445 non-null   object
#  9   32_Current status year                                        1440 non-null   object
#  10  33_Current reservoir status                                   1444 non-null   object
#  11  34_Current production stage                                   1357 non-null   object
#  12  35_Well count (total all wells)                               663 non-null    float64
#  13  38_Well count (total producer)                                1047 non-null   object
#  14  46_Well count (current active producer)                       852 non-null    float64
#  15  52_Well spacing (average) (ac)                                1445 non-null   float64
#  16  58_Production year (current)                                  1356 non-null   float64
#  17  62_Production rate (current oil equivalent) (BOEPD)           1177 non-null   float64
#  18  65_Water-cut (current) (%)                                    558 non-null    float64
#  19  66_Production year (peak)                                     1193 non-null   float64
#  20  70_Production rate (peak oil equivalent) (BOEPD)              1103 non-null   float64
#  21  72_Onshore or offshore                                        1445 non-null   object
#  22  73_Water_Depth (ft)                                           1445 non-null   float64
#  23  75_Temperature (original) (deg. F)                            1197 non-null   float64
#  24  76_Temperature depth (ft TVDSS)                               969 non-null    float64
#  25  77_Pressure (original) (psi)                                  1284 non-null   float64
#  26  78_Pressure depth (ft TVDSS)                                  1084 non-null   float64
#  27  80_Pressure year (current)                                    589 non-null    float64
#  28  81_Pressure (current) (psi)                                   585 non-null    float64
#  29  82_Drive mechanism (main)                                     1416 non-null   object
#  30  111_Trapping mechanism (main)                                 1445 non-null   object
#  31  116_Depth to top reservoir (ft TVD)                           1417 non-null   float64
#  32  117_Reservoir top subsea depth (ft TVDSS)                     1404 non-null   float64
#  33  118_Structural flank dip (average) (deg.)                     1338 non-null   float64
#  34  135_Hydrocarbon column height (original total) (ft)           1118 non-null   float64
#  35  149_Reservoir period                                          1444 non-null   object
#  36  153_Depositional system (main)                                1445 non-null   object
#  37  161_Reservoir architecture (main)                             1400 non-null   object
#  38  163_Fluid flow restriction                                    1445 non-null   object
#  39  170_Gross reservoir thickness (average) (ft)                  1216 non-null   float64
#  40  173_Net reservoir thickness (average) (ft)                    850 non-null    float64
#  41  176_Net/gross ratio (average)                                 913 non-null    float64
#  42  179_Net pay (average) (m)                                     850 non-null    float64
#  43  182_Reservoir lithology (main)                                1445 non-null   object
#  44  184_Grain_Size_Texture                                        1445 non-null   object
#  45  189_Composition                                               1445 non-null   object
#  46  199_Fracture reservoir type                                   339 non-null    object
#  47  200_Porosity type (main)                                      1404 non-null   object
#  48  204_Porosity (matrix average) (%)                             1409 non-null   float64
#  49  210_Permeability (air average) (mD)                           1304 non-null   float64
#  50  213_Permeability (well test average) (mD)                     228 non-null    float64
#  51  218_API gravity (average) (deg. API)                          1445 non-null   float64
#  52  222_Specific gravity (gas average)                            587 non-null    float64
#  53  225_Viscosity (oil average) (cp)                              895 non-null    float64
#  54  230_Mobility index (average) (mD/cp)                          726 non-null    float64
#  55  236_Oil_impurities (average)                                  1445 non-null   float64
#  56  242_Methane (average) (%)                                     343 non-null    float64
#  57  243_Gas_impurities (average)                                  1445 non-null   float64
#  58  252_GOR (initial average) (SCF/STB)                           1005 non-null   float64
#  59  255_Condensate yield (initial average) (BC/MMCFG)             280 non-null    float64
#  60  258_FVF (oil average) (RB/STB)                                744 non-null    float64
#  61  263_Bubble point pressure (average) (psi)                     712 non-null    float64
#  62  266_Pour point temperature (average) (deg. F)                 406 non-null    float64
#  63  273_Formation water salinity (average) (mg/L)                 837 non-null    float64
#  64  276_Water saturation (initial average) (%)                    1073 non-null   float64
#  65  293_Original in-place oil equivalent (MMBOE)                  1139 non-null   float64
#  66  300_EUR oil equivalent (MMBOE)                                1185 non-null   float64
#  67  301_Remaining EUR oil (MMBO)                                  626 non-null    float64
#  68  302_Remaining EUR gas (BCFG)                                  169 non-null    float64
#  69  304_Recovery factor (primary oil) (%)                         377 non-null    float64
#  70  307_Recovery factor (ultimate oil) (%)                        983 non-null    float64
#  71  308_Recovery factor (ultimate gas) (%)                        308 non-null    float64
#  72  310_Recovery to date (of in-place oil) (%)                    862 non-null    float64
#  73  311_Recovery to date (of in-place gas) (%)                    245 non-null    float64
#  74  313_Recovery (best-fit ultimate oil) (%)                      323 non-null    float64
#  75  314_Reservoir performance index (decimal fraction)            323 non-null    float64
#  76  315_EUR oil per production well (MMBO)                        500 non-null    float64
#  77  319_Secondary recovery start date                             682 non-null    object
#  78  320_Secondary recovery methods                                812 non-null    object
#  79  324_EOR start date                                            216 non-null    object
#  80  325_EOR methods                                               272 non-null    object
#  81  333_Improved recovery methods (other)                         1234 non-null   object
#  82  334_Improved recovery methods (drilling)                      875 non-null    object
#  83  335_Improved recovery methods (stimulation)                   737 non-null    object
#  84  336_Improved recovery methods (water injection optimization)  180 non-null    object
#  85  337_Improved recovery methods (artificial lift)               677 non-null    object
#  86  338_Improved recovery methods (sand control)                  240 non-null    object
#  87  339_Improved recovery methods (other reservoir management)    730 non-null    object
# dtypes: float64(54), object(34)
# memory usage: 1004.7+ KB

# %% [markdown]
# A quick visualisation to observe for empty cells, if cells have been dropped correctly and if the data needs more cleaning up

# %%
fig, ax = plt.subplots(figsize=(25,8))
sns.heatmap(data_preproc.isnull(), ax=ax, cmap="magma")
plt.grid()
plt.show()

# %% [markdown]
# Using a linear regression to fill in some of the null values. The 2 data sets that this can be applied to is the pressure and temperature. To ensure that there is no bias betweens sandstones and carbonates, split the data into the 2 different rock types

# %%
def plot_data(data_preproc):
    # Simple Scatter plot between depth and variable (pressure or temp)
    df_sst = data_preproc[data_preproc["182_Reservoir lithology (main)"] =='SANDSTONE']
    df_carb = data_preproc[data_preproc["182_Reservoir lithology (main)"] =='CARBONATES']

    a = df_sst['116_Depth to top reservoir (ft TVD)']
    b = df_sst['77_Pressure (original) (psi)']
    b1 = df_sst['75_Temperature (original) (deg. F)']

    c = df_carb['116_Depth to top reservoir (ft TVD)']
    d = df_carb['77_Pressure (original) (psi)']
    d1 = df_carb['75_Temperature (original) (deg. F)']

    plt.figure(figsize=(14, 8))
    plt.subplot(1, 2, 1)
    plt.scatter(a, b, color='blue')
    plt.scatter(c, d, color='orange')
    plt.xlabel("Depth (ftTVD)", size=14)
    plt.ylabel("Pressure (original) (psi)", size=14)
    plt.gca().invert_yaxis()

    plt.subplot(1, 2, 2)
    plt.scatter(a, b1, color='blue')
    plt.scatter(c, d1, color='orange')
    plt.xlabel("Depth (ftTVD)", size=14)
    plt.ylabel("Temperature (original) (deg. F)", size=14)
    plt.gca().invert_yaxis()

    plt.tight_layout()
    plt.show()

# %%
plot_data(data_preproc)

# %% [markdown]
# _Both data sets look broadly linear with respect to depth. The also seem to be generally independent of rock type. Therefore, using a simple linear regression will do for filling in the missing values. Statistically, the missing values from temperature and pressure form about 17% and 11% respectively._

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# Start with Pressure
cdf = data_preproc[['77_Pressure (original) (psi)', '116_Depth to top reservoir (ft TVD)']]
testdf = cdf[cdf['77_Pressure (original) (psi)'].isnull()==True].fillna(0)
traindf = cdf[cdf['77_Pressure (original) (psi)'].isnull()==False].fillna(0)

y = traindf['77_Pressure (original) (psi)']
traindf.drop('77_Pressure (original) (psi)', axis=1, inplace=True)

lr.fit(traindf,y)
testdf.drop('77_Pressure (original) (psi)', axis=1, inplace=True)
pred = lr.predict(testdf)
testdf['77_Pressure (original) (psi)'] = pred

#Coefficients
print("Gradient: ", lr.coef_)
print("Intercept: ", lr.intercept_)

testdf = testdf.rename(columns={'116_Depth to top reservoir (ft TVD)': '116_RPT_Depth to top reservoir (ft TVD)', 
                                '77_Pressure (original) (psi)': '77_RPT_Pressure (original) (psi)'
                               })
# Out:
# Gradient:  [0.57684445]
# Intercept:  79.7974254134433

# %%
data_preproc = pd.concat([data_preproc, testdf], axis=1)
data_preproc['77_Pressure (original) (psi)'] = data_preproc['77_Pressure (original) (psi)'].fillna(0) + data_preproc['77_RPT_Pressure (original) (psi)'].fillna(0)

data_preproc = data_preproc.drop([
    '116_RPT_Depth to top reservoir (ft TVD)', '77_RPT_Pressure (original) (psi)', 
], axis = 1)

# %%
lr1 = LinearRegression()

# Start with Pressure
cdf_n = data_preproc[['75_Temperature (original) (deg. F)', '116_Depth to top reservoir (ft TVD)']]
testdf_n = cdf_n[cdf_n['75_Temperature (original) (deg. F)'].isnull()==True].fillna(0)
traindf_n = cdf_n[cdf_n['75_Temperature (original) (deg. F)'].isnull()==False].fillna(0)

y1 = traindf_n['75_Temperature (original) (deg. F)']
traindf_n.drop('75_Temperature (original) (deg. F)', axis=1, inplace=True)

lr1.fit(traindf_n,y1)
testdf_n.drop('75_Temperature (original) (deg. F)', axis=1, inplace=True)
pred_n = lr1.predict(testdf_n)
testdf_n['75_Temperature (original) (deg. F)'] = pred_n

#Coefficients
print("Gradient: ", lr1.coef_)
print("Intercept: ", lr1.intercept_)

testdf_n = testdf_n.rename(columns={'116_Depth to top reservoir (ft TVD)': '116_RPT_Depth to top reservoir (ft TVD)', 
                                '75_Temperature (original) (deg. F)': '7_RPT_Temperature (original) (deg. F)'
                               })
# Out:
# Gradient:  [0.01230655]
# Intercept:  104.2322183960465

# %%
data_preproc = pd.concat([data_preproc, testdf_n], axis=1)
data_preproc['75_Temperature (original) (deg. F)'] = data_preproc['75_Temperature (original) (deg. F)'].fillna(0) + data_preproc['7_RPT_Temperature (original) (deg. F)'].fillna(0)

data_preproc = data_preproc.drop([
    '116_RPT_Depth to top reservoir (ft TVD)', '7_RPT_Temperature (original) (deg. F)', 
], axis = 1)

# %%
plot_data(data_preproc)

# %% [markdown]
# Checkpoint 2: Files here are fully cleaned and ready for modelling.

# %%
def file_out(df, dir_name, base_filename, filename_suffix):
    csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
    df.to_csv(csvs_sht, index = False, header=True)
    return

df_sst = data_preproc[data_preproc["182_Reservoir lithology (main)"] =='SANDSTONE']
df_carb = data_preproc[data_preproc["182_Reservoir lithology (main)"] =='CARBONATES']

file_out(data_preproc, dir_name, 'CP2_Clean_RF_data' , filename_suffix)
file_out(df_sst, dir_name, 'CP3_SST_RF_data' , filename_suffix)
file_out(df_carb, dir_name, 'CP4_CARB_RF_data' , filename_suffix)

print ("Final File Extract Produced")
# Out:
# Final File Extract Produced

# %%
count = 'Completed Process'
elapsed = (time.time() - start)
print ("%s in %s seconds" % (count,elapsed))
# Out:
# Completed Process in 9.395392417907715 seconds
