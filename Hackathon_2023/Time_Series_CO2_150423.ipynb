# %% [markdown]
# <a href="https://xeek.ai/challenges/using-ai-to-validate-carbon-containment-in-the-illinois-basin/data"><img src = "https://www.spe.org/binaries/content/gallery/specms/speevents/organization-logos/spe-logo-2020.png" width = 200>
#
# <h1 align=center><font size = 5>Time Series Prediction for Well Injection Rates</font></h1>

# %% [markdown]
# <h1 align=center><font size = 4> Munish Kumar$^{1}$, Kannapan Swaminathan$^{2}$</font></h1>
# <h1 align=center><font size = 4> $^{1}$Singapore University of Social Sciences, $^{2}$California Resources Corporation </font></h1>
# <h1 align=center><font size = 3> April 2023 </font></h1>

# %% [markdown]
# Problem Statement
#
# This challenge aims to use time series injection information and monitoring data on a carbon capture well to predict carbon capture well injection rates deltas. Correlating the change in injection rate to the behavior of other parameters in the well can be used to provide a checkpoint against carbon migration from the well or other losses during the process.  The code developed to predict injection rate deltas based on monitoring well data can be used to validate carbon containment throughout the injection of the well.

# %% [markdown]
# #### References

# %% [markdown]
# 1. https://www.tensorflow.org/tutorials/keras/regression
# 2. https://xeek.ai/challenges/using-ai-to-validate-carbon-containment-in-the-illinois-basin/data

# %% [markdown]
# ### Loading Libraries and Data

# %%
#!pip install tensorflow --user
#!pip install natsort --user

# %%
# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
import time
import re
import requests
import pickle
import seaborn as sns
import os
import glob
import sys
#from natsort import natsorted
sns.set()

import plotly.graph_objects as go
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

print('Libraries imported')
# Out:
# Libraries imported

# %%
#Receive Data
#dir_name = r'C:\Users\DELL\Documents\GitHub\munishkumar-gh.github.io\Hackathon_2023\1_RAW_Data'
dir_name = r'C:\Users\vasan\OneDrive - California Resources Corporation\01_Admin\07_MLChallenge'
filename_suffix = 'csv'

# %%
# Function to look at first 5 and last 5 elements in a dataframe
def ends(df, x=5):
    return df.head(x).append(df.tail(x))
setattr(pd.DataFrame,'ends',ends)

# %%
# Function to read out file
def file_out(df, dir_name, base_filename, filename_suffix):
    try:
        csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
        df.to_csv(csvs_sht, index = False, header=True)
        print ("Final File Extract Produced")
    except IOError:
        print("I/O error")
    returnb

# %%
# Function to search for a text string
def search_words(text):
    result = re.findall(r'\b[^\d\W]+\b', text)
    return " ".join(result)

# %%
# Function to create box plot and Histogram
def creating_box_hist(column, df):
    # creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, figsize=(20,6),
                                        gridspec_kw={"height_ratios": (.25, .75)})    

    # assigning a graph to each ax
    sns.boxplot(df[column], ax=ax_box)
    sns.histplot(data=df, x=column, ax=ax_hist)

    # Remove x axis name for the boxplot
    ax_box.set(xlabel='')
    plt.show()

# %%
# Font, marker size and axis rotation
edgecolors = 'black'
markersize = 16
fontsize = 25
alpha = 0.5
size = 18
rotation = 0

# %% [markdown]
# ### Loading and Preprocessing Data
#
# Load the dataset and perform some basic preprocessing steps. This includes removing any missing values, converting categorical variables into one-hot encoded format, and scaling the data using StandardScaler.

# %%
base_filename = 'illinois_basing_train_04112023'
csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
#df.to_csv(csvs_sht, index = True, header = True)
print ("File to be loaded:", csvs_sht)
# Out:
# File to be loaded: C:\Users\vasan\OneDrive - California Resources Corporation\01_Admin\07_MLChallenge\illinois_basing_train_04112023.csv

# %%
skiprows = 0
#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
df = pd.read_csv(csvs_sht, thousands=',', skiprows = skiprows)
df.columns = df.columns.str.replace('\xa0', '')
df.ends()
# Out:
#          SampleTimeUTC  Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# 0       10/1/2009 0:00                20.543221                 1.880208
# 1       10/1/2009 1:00                20.543221                 1.374349
# 2       10/1/2009 2:00                20.543221                 1.315104
# 3       10/1/2009 3:00                20.543221                 1.255859
# 4       10/1/2009 4:00                20.543221                 1.342448
# 27393  11/18/2012 3:00                 0.408333              1409.701282
# 27394  11/18/2012 4:00                 0.458333              1409.036129
# 27395  11/18/2012 5:00                 0.508333              1408.648841
# 27396  11/18/2012 6:00                 0.504202              1406.788722
# 27397  11/18/2012 7:00                 0.616667              1407.204333
#
#        Avg_CCS1_WHCO2InjTp_F  Avg_CCS1_ANPs_psi  Avg_CCS1_DH6325Ps_psi  \
# 0                  59.400879          89.967778            2893.787960
# 1                  55.654541          89.825334            2893.793620
# 2                  53.661254          89.806754            2893.791506
# 3                  52.319824          89.806754            2893.786399
# 4                  48.994263          89.610633            2893.774135
# 27393              95.934610         530.799145            3385.511261
# 27394              95.722206         531.937228            3387.451438
# 27395              95.857338         526.400194            3387.077108
# 27396              95.681030         532.481976            3387.618129
# 27397              95.600624         517.267830            3386.470343
#
#        Avg_CCS1_DH6325Tp_F  Avg_VW1_WBTbgPs_psi  Avg_VW1_WBTbgTp_F  \
# 0               116.539694          2173.710958         104.061007
# 1               116.538811          2173.762679         104.049292
# 2               116.538623          2173.754085         104.050357
# 3               116.537392          2173.734355         104.051422
# 4               116.537714          2173.738489         104.051422
# 27393           129.515436          2328.919804         104.920363
# 27394           129.559802          2328.912415         104.911993
# 27395           129.559708          2328.921606         104.916643
# 27396           129.578328          2328.940994         104.911782
# 27397           129.565695          2328.994653         104.907342
#
#        Avg_VW1_ANPs_psi  ...  Avg_VW1_Z04D6837Tp_F  Avg_VW1_Z03D6945Ps_psi  \
# 0           1599.975952  ...            120.209798             3164.194175
# 1           1599.975952  ...            120.211298             3164.154578
# 2           1599.975952  ...            120.204548             3164.142426
# 3           1599.975952  ...            120.209048             3164.138940
# 4           1599.975952  ...            120.206798             3164.143589
# 27393               NaN  ...            123.910423                     NaN
# 27394          0.100585  ...            123.913723                     NaN
# 27395          0.100585  ...            123.916363                     NaN
# 27396          0.100585  ...            123.926406                     NaN
# 27397          0.100585  ...            123.945400                     NaN
#
#        Avg_VW1_Z03D6945Tp_F  Avg_VW1_Z02D6982Ps_psi  Avg_VW1_Z02D6982Tp_F  \
# 0                121.361094             3184.043494            121.462733
# 1                121.360299             3184.060020            121.461173
# 2                121.352469             3184.060055            121.468179
# 3                121.352378             3184.031604            121.476759
# 4                121.346063             3184.019531            121.474419
# 27393                   NaN             3323.237008            123.410697
# 27394                   NaN             3323.269234            123.417552
# 27395                   NaN             3323.339665            123.417567
# 27396                   NaN             3323.353417            123.409700
# 27397                   NaN             3323.410433            123.439002
#
#        Avg_VW1_Z01D7061Ps_psi  Avg_VW1_Z01D7061Tp_F  Avg_VW1_Z0910D5482Ps_psi  \
# 0                 3216.464494            120.278862               2441.864587
# 1                 3216.520127            120.276792               2442.006201
# 2                 3216.510374            120.280932               2442.070968
# 3                 3216.479380            120.300598               2442.143066
# 4                 3216.436283            120.307843               2442.282528
# 27393             3320.264079            122.459648               2641.522160
# 27394             3320.271702            122.455598               2641.527275
# 27395             3320.266923            122.465723               2641.525834
# 27396             3320.181743            122.456771               2641.547556
# 27397             3320.304134            122.450874               2641.584741
#
#        Avg_VW1_Z0910D5482Tp_F  inj_diff
# 0                  111.881138       NaN
# 1                  111.891938  0.000000
# 2                  111.891218  0.000000
# 3                  111.899858  0.000000
# 4                  111.909219  0.000000
# 27393              110.559307 -0.031250
# 27394              110.556127 -0.091320
# 27395              110.557732 -0.137501
# 27396              110.557650  0.037290
# 27397              110.556937 -0.080345
#
# [10 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['SampleTimeUTC', 'Avg_PLT_CO2VentRate_TPH', 'Avg_CCS1_WHCO2InjPs_psi',
#        'Avg_CCS1_WHCO2InjTp_F', 'Avg_CCS1_ANPs_psi', 'Avg_CCS1_DH6325Ps_psi',
#        'Avg_CCS1_DH6325Tp_F', 'Avg_VW1_WBTbgPs_psi', 'Avg_VW1_WBTbgTp_F',
#        'Avg_VW1_ANPs_psi', 'Avg_VW1_Z11D4917Ps_psi', 'Avg_VW1_Z11D4917Tp_F',
#        'Avg_VW1_Z10D5001Ps_psi', 'Avg_VW1_Z10D5001Tp_F',
#        'Avg_VW1_Z09D5653Ps_psi', 'Avg_VW1_Z09D5653Tp_F',
#        'Avg_VW1_Z08D5840Ps_psi', 'Avg_VW1_Z08D5840Tp_F',
#        'Avg_VW1_Z07D6416Ps_psi', 'Avg_VW1_Z07D6416Tp_F',
#        'Avg_VW1_Z06D6632Ps_psi', 'Avg_VW1_Z06D6632Tp_F',
#        'Avg_VW1_Z05D6720Ps_psi', 'Avg_VW1_Z05D6720Tp_F',
#        'Avg_VW1_Z04D6837Ps_psi', 'Avg_VW1_Z04D6837Tp_F',
#        'Avg_VW1_Z03D6945Ps_psi', 'Avg_VW1_Z03D6945Tp_F',
#        'Avg_VW1_Z02D6982Ps_psi', 'Avg_VW1_Z02D6982Tp_F',
#        'Avg_VW1_Z01D7061Ps_psi', 'Avg_VW1_Z01D7061Tp_F',
#        'Avg_VW1_Z0910D5482Ps_psi', 'Avg_VW1_Z0910D5482Tp_F', 'inj_diff'],
#       dtype='object')

# %%
df1 = df.copy()

df1['SampleTimeUTC'] = pd.to_datetime(df1['SampleTimeUTC'])
df1 = df1.set_index("SampleTimeUTC")
idx = pd.date_range(df1.index[0], df1.index[-1])

#df1 = df1.reindex(idx, fill_value=np.nan).dropna()
df1.index.name = "SampleTimeUTC"

df1 = df1.asfreq('H')

#df1.index.freq = "H"
df1
# Out:
#                      Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00                20.543221                 1.880208
# 2009-10-01 01:00:00                20.543221                 1.374349
# 2009-10-01 02:00:00                20.543221                 1.315104
# 2009-10-01 03:00:00                20.543221                 1.255859
# 2009-10-01 04:00:00                20.543221                 1.342448
# ...                                      ...                      ...
# 2012-11-18 03:00:00                 0.408333              1409.701282
# 2012-11-18 04:00:00                 0.458333              1409.036129
# 2012-11-18 05:00:00                 0.508333              1408.648841
# 2012-11-18 06:00:00                 0.504202              1406.788722
# 2012-11-18 07:00:00                 0.616667              1407.204333
#
#                      Avg_CCS1_WHCO2InjTp_F  Avg_CCS1_ANPs_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00              59.400879          89.967778
# 2009-10-01 01:00:00              55.654541          89.825334
# 2009-10-01 02:00:00              53.661254          89.806754
# 2009-10-01 03:00:00              52.319824          89.806754
# 2009-10-01 04:00:00              48.994263          89.610633
# ...                                    ...                ...
# 2012-11-18 03:00:00              95.934610         530.799145
# 2012-11-18 04:00:00              95.722206         531.937228
# 2012-11-18 05:00:00              95.857338         526.400194
# 2012-11-18 06:00:00              95.681030         532.481976
# 2012-11-18 07:00:00              95.600624         517.267830
#
#                      Avg_CCS1_DH6325Ps_psi  Avg_CCS1_DH6325Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00            2893.787960           116.539694
# 2009-10-01 01:00:00            2893.793620           116.538811
# 2009-10-01 02:00:00            2893.791506           116.538623
# 2009-10-01 03:00:00            2893.786399           116.537392
# 2009-10-01 04:00:00            2893.774135           116.537714
# ...                                    ...                  ...
# 2012-11-18 03:00:00            3385.511261           129.515436
# 2012-11-18 04:00:00            3387.451438           129.559802
# 2012-11-18 05:00:00            3387.077108           129.559708
# 2012-11-18 06:00:00            3387.618129           129.578328
# 2012-11-18 07:00:00            3386.470343           129.565695
#
#                      Avg_VW1_WBTbgPs_psi  Avg_VW1_WBTbgTp_F  Avg_VW1_ANPs_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00          2173.710958         104.061007       1599.975952
# 2009-10-01 01:00:00          2173.762679         104.049292       1599.975952
# 2009-10-01 02:00:00          2173.754085         104.050357       1599.975952
# 2009-10-01 03:00:00          2173.734355         104.051422       1599.975952
# 2009-10-01 04:00:00          2173.738489         104.051422       1599.975952
# ...                                  ...                ...               ...
# 2012-11-18 03:00:00          2328.919804         104.920363               NaN
# 2012-11-18 04:00:00          2328.912415         104.911993          0.100585
# 2012-11-18 05:00:00          2328.921606         104.916643          0.100585
# 2012-11-18 06:00:00          2328.940994         104.911782          0.100585
# 2012-11-18 07:00:00          2328.994653         104.907342          0.100585
#
#                      Avg_VW1_Z11D4917Ps_psi  ...  Avg_VW1_Z04D6837Tp_F  \
# SampleTimeUTC                                ...
# 2009-10-01 00:00:00             2073.104972  ...            120.209798
# 2009-10-01 01:00:00             2073.109141  ...            120.211298
# 2009-10-01 02:00:00             2073.099392  ...            120.204548
# 2009-10-01 03:00:00             2073.094464  ...            120.209048
# 2009-10-01 04:00:00             2073.072345  ...            120.206798
# ...                                     ...  ...                   ...
# 2012-11-18 03:00:00             2069.883183  ...            123.910423
# 2012-11-18 04:00:00             2069.890177  ...            123.913723
# 2012-11-18 05:00:00             2069.875623  ...            123.916363
# 2012-11-18 06:00:00             2069.930707  ...            123.926406
# 2012-11-18 07:00:00             2069.903377  ...            123.945400
#
#                      Avg_VW1_Z03D6945Ps_psi  Avg_VW1_Z03D6945Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00             3164.194175            121.361094
# 2009-10-01 01:00:00             3164.154578            121.360299
# 2009-10-01 02:00:00             3164.142426            121.352469
# 2009-10-01 03:00:00             3164.138940            121.352378
# 2009-10-01 04:00:00             3164.143589            121.346063
# ...                                     ...                   ...
# 2012-11-18 03:00:00                     NaN                   NaN
# 2012-11-18 04:00:00                     NaN                   NaN
# 2012-11-18 05:00:00                     NaN                   NaN
# 2012-11-18 06:00:00                     NaN                   NaN
# 2012-11-18 07:00:00                     NaN                   NaN
#
#                      Avg_VW1_Z02D6982Ps_psi  Avg_VW1_Z02D6982Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00             3184.043494            121.462733
# 2009-10-01 01:00:00             3184.060020            121.461173
# 2009-10-01 02:00:00             3184.060055            121.468179
# 2009-10-01 03:00:00             3184.031604            121.476759
# 2009-10-01 04:00:00             3184.019531            121.474419
# ...                                     ...                   ...
# 2012-11-18 03:00:00             3323.237008            123.410697
# 2012-11-18 04:00:00             3323.269234            123.417552
# 2012-11-18 05:00:00             3323.339665            123.417567
# 2012-11-18 06:00:00             3323.353417            123.409700
# 2012-11-18 07:00:00             3323.410433            123.439002
#
#                      Avg_VW1_Z01D7061Ps_psi  Avg_VW1_Z01D7061Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00             3216.464494            120.278862
# 2009-10-01 01:00:00             3216.520127            120.276792
# 2009-10-01 02:00:00             3216.510374            120.280932
# 2009-10-01 03:00:00             3216.479380            120.300598
# 2009-10-01 04:00:00             3216.436283            120.307843
# ...                                     ...                   ...
# 2012-11-18 03:00:00             3320.264079            122.459648
# 2012-11-18 04:00:00             3320.271702            122.455598
# 2012-11-18 05:00:00             3320.266923            122.465723
# 2012-11-18 06:00:00             3320.181743            122.456771
# 2012-11-18 07:00:00             3320.304134            122.450874
#
#                      Avg_VW1_Z0910D5482Ps_psi  Avg_VW1_Z0910D5482Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00               2441.864587              111.881138
# 2009-10-01 01:00:00               2442.006201              111.891938
# 2009-10-01 02:00:00               2442.070968              111.891218
# 2009-10-01 03:00:00               2442.143066              111.899858
# 2009-10-01 04:00:00               2442.282528              111.909219
# ...                                       ...                     ...
# 2012-11-18 03:00:00               2641.522160              110.559307
# 2012-11-18 04:00:00               2641.527275              110.556127
# 2012-11-18 05:00:00               2641.525834              110.557732
# 2012-11-18 06:00:00               2641.547556              110.557650
# 2012-11-18 07:00:00               2641.584741              110.556937
#
#                      inj_diff
# SampleTimeUTC
# 2009-10-01 00:00:00       NaN
# 2009-10-01 01:00:00  0.000000
# 2009-10-01 02:00:00  0.000000
# 2009-10-01 03:00:00  0.000000
# 2009-10-01 04:00:00  0.000000
# ...                       ...
# 2012-11-18 03:00:00 -0.031250
# 2012-11-18 04:00:00 -0.091320
# 2012-11-18 05:00:00 -0.137501
# 2012-11-18 06:00:00  0.037290
# 2012-11-18 07:00:00 -0.080345
#
# [27464 rows x 34 columns]

# %%
df1.index
# Out:
# DatetimeIndex(['2009-10-01 00:00:00', '2009-10-01 01:00:00',
#                '2009-10-01 02:00:00', '2009-10-01 03:00:00',
#                '2009-10-01 04:00:00', '2009-10-01 05:00:00',
#                '2009-10-01 06:00:00', '2009-10-01 07:00:00',
#                '2009-10-01 08:00:00', '2009-10-01 09:00:00',
#                ...
#                '2012-11-17 22:00:00', '2012-11-17 23:00:00',
#                '2012-11-18 00:00:00', '2012-11-18 01:00:00',
#                '2012-11-18 02:00:00', '2012-11-18 03:00:00',
#                '2012-11-18 04:00:00', '2012-11-18 05:00:00',
#                '2012-11-18 06:00:00', '2012-11-18 07:00:00'],
#               dtype='datetime64[ns]', name='SampleTimeUTC', length=27464, freq='H')

# %%
# in pandas axis=0 represents rows (default) and axis=1 represents columns.
#df1.drop(['Avg_PLT_CO2InjRate_TPH'], axis=1, inplace=True)
df1.ends()
# Out:
#                      Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00                20.543221                 1.880208
# 2009-10-01 01:00:00                20.543221                 1.374349
# 2009-10-01 02:00:00                20.543221                 1.315104
# 2009-10-01 03:00:00                20.543221                 1.255859
# 2009-10-01 04:00:00                20.543221                 1.342448
# 2012-11-18 03:00:00                 0.408333              1409.701282
# 2012-11-18 04:00:00                 0.458333              1409.036129
# 2012-11-18 05:00:00                 0.508333              1408.648841
# 2012-11-18 06:00:00                 0.504202              1406.788722
# 2012-11-18 07:00:00                 0.616667              1407.204333
#
#                      Avg_CCS1_WHCO2InjTp_F  Avg_CCS1_ANPs_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00              59.400879          89.967778
# 2009-10-01 01:00:00              55.654541          89.825334
# 2009-10-01 02:00:00              53.661254          89.806754
# 2009-10-01 03:00:00              52.319824          89.806754
# 2009-10-01 04:00:00              48.994263          89.610633
# 2012-11-18 03:00:00              95.934610         530.799145
# 2012-11-18 04:00:00              95.722206         531.937228
# 2012-11-18 05:00:00              95.857338         526.400194
# 2012-11-18 06:00:00              95.681030         532.481976
# 2012-11-18 07:00:00              95.600624         517.267830
#
#                      Avg_CCS1_DH6325Ps_psi  Avg_CCS1_DH6325Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00            2893.787960           116.539694
# 2009-10-01 01:00:00            2893.793620           116.538811
# 2009-10-01 02:00:00            2893.791506           116.538623
# 2009-10-01 03:00:00            2893.786399           116.537392
# 2009-10-01 04:00:00            2893.774135           116.537714
# 2012-11-18 03:00:00            3385.511261           129.515436
# 2012-11-18 04:00:00            3387.451438           129.559802
# 2012-11-18 05:00:00            3387.077108           129.559708
# 2012-11-18 06:00:00            3387.618129           129.578328
# 2012-11-18 07:00:00            3386.470343           129.565695
#
#                      Avg_VW1_WBTbgPs_psi  Avg_VW1_WBTbgTp_F  Avg_VW1_ANPs_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00          2173.710958         104.061007       1599.975952
# 2009-10-01 01:00:00          2173.762679         104.049292       1599.975952
# 2009-10-01 02:00:00          2173.754085         104.050357       1599.975952
# 2009-10-01 03:00:00          2173.734355         104.051422       1599.975952
# 2009-10-01 04:00:00          2173.738489         104.051422       1599.975952
# 2012-11-18 03:00:00          2328.919804         104.920363               NaN
# 2012-11-18 04:00:00          2328.912415         104.911993          0.100585
# 2012-11-18 05:00:00          2328.921606         104.916643          0.100585
# 2012-11-18 06:00:00          2328.940994         104.911782          0.100585
# 2012-11-18 07:00:00          2328.994653         104.907342          0.100585
#
#                      Avg_VW1_Z11D4917Ps_psi  ...  Avg_VW1_Z04D6837Tp_F  \
# SampleTimeUTC                                ...
# 2009-10-01 00:00:00             2073.104972  ...            120.209798
# 2009-10-01 01:00:00             2073.109141  ...            120.211298
# 2009-10-01 02:00:00             2073.099392  ...            120.204548
# 2009-10-01 03:00:00             2073.094464  ...            120.209048
# 2009-10-01 04:00:00             2073.072345  ...            120.206798
# 2012-11-18 03:00:00             2069.883183  ...            123.910423
# 2012-11-18 04:00:00             2069.890177  ...            123.913723
# 2012-11-18 05:00:00             2069.875623  ...            123.916363
# 2012-11-18 06:00:00             2069.930707  ...            123.926406
# 2012-11-18 07:00:00             2069.903377  ...            123.945400
#
#                      Avg_VW1_Z03D6945Ps_psi  Avg_VW1_Z03D6945Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00             3164.194175            121.361094
# 2009-10-01 01:00:00             3164.154578            121.360299
# 2009-10-01 02:00:00             3164.142426            121.352469
# 2009-10-01 03:00:00             3164.138940            121.352378
# 2009-10-01 04:00:00             3164.143589            121.346063
# 2012-11-18 03:00:00                     NaN                   NaN
# 2012-11-18 04:00:00                     NaN                   NaN
# 2012-11-18 05:00:00                     NaN                   NaN
# 2012-11-18 06:00:00                     NaN                   NaN
# 2012-11-18 07:00:00                     NaN                   NaN
#
#                      Avg_VW1_Z02D6982Ps_psi  Avg_VW1_Z02D6982Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00             3184.043494            121.462733
# 2009-10-01 01:00:00             3184.060020            121.461173
# 2009-10-01 02:00:00             3184.060055            121.468179
# 2009-10-01 03:00:00             3184.031604            121.476759
# 2009-10-01 04:00:00             3184.019531            121.474419
# 2012-11-18 03:00:00             3323.237008            123.410697
# 2012-11-18 04:00:00             3323.269234            123.417552
# 2012-11-18 05:00:00             3323.339665            123.417567
# 2012-11-18 06:00:00             3323.353417            123.409700
# 2012-11-18 07:00:00             3323.410433            123.439002
#
#                      Avg_VW1_Z01D7061Ps_psi  Avg_VW1_Z01D7061Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00             3216.464494            120.278862
# 2009-10-01 01:00:00             3216.520127            120.276792
# 2009-10-01 02:00:00             3216.510374            120.280932
# 2009-10-01 03:00:00             3216.479380            120.300598
# 2009-10-01 04:00:00             3216.436283            120.307843
# 2012-11-18 03:00:00             3320.264079            122.459648
# 2012-11-18 04:00:00             3320.271702            122.455598
# 2012-11-18 05:00:00             3320.266923            122.465723
# 2012-11-18 06:00:00             3320.181743            122.456771
# 2012-11-18 07:00:00             3320.304134            122.450874
#
#                      Avg_VW1_Z0910D5482Ps_psi  Avg_VW1_Z0910D5482Tp_F  \
# SampleTimeUTC
# 2009-10-01 00:00:00               2441.864587              111.881138
# 2009-10-01 01:00:00               2442.006201              111.891938
# 2009-10-01 02:00:00               2442.070968              111.891218
# 2009-10-01 03:00:00               2442.143066              111.899858
# 2009-10-01 04:00:00               2442.282528              111.909219
# 2012-11-18 03:00:00               2641.522160              110.559307
# 2012-11-18 04:00:00               2641.527275              110.556127
# 2012-11-18 05:00:00               2641.525834              110.557732
# 2012-11-18 06:00:00               2641.547556              110.557650
# 2012-11-18 07:00:00               2641.584741              110.556937
#
#                      inj_diff
# SampleTimeUTC
# 2009-10-01 00:00:00       NaN
# 2009-10-01 01:00:00  0.000000
# 2009-10-01 02:00:00  0.000000
# 2009-10-01 03:00:00  0.000000
# 2009-10-01 04:00:00  0.000000
# 2012-11-18 03:00:00 -0.031250
# 2012-11-18 04:00:00 -0.091320
# 2012-11-18 05:00:00 -0.137501
# 2012-11-18 06:00:00  0.037290
# 2012-11-18 07:00:00 -0.080345
#
# [10 rows x 34 columns]

# %%
# Check for Missing Values

print("Column Names: ", df1.columns.values)
print("\n")
print("Information:", df1.info())
print("\n")
print("Descriptive Statistics: ")
df1.describe()
# Out:
# Column Names:  ['Avg_PLT_CO2VentRate_TPH' 'Avg_CCS1_WHCO2InjPs_psi'
#  'Avg_CCS1_WHCO2InjTp_F' 'Avg_CCS1_ANPs_psi' 'Avg_CCS1_DH6325Ps_psi'
#  'Avg_CCS1_DH6325Tp_F' 'Avg_VW1_WBTbgPs_psi' 'Avg_VW1_WBTbgTp_F'
#  'Avg_VW1_ANPs_psi' 'Avg_VW1_Z11D4917Ps_psi' 'Avg_VW1_Z11D4917Tp_F'
#  'Avg_VW1_Z10D5001Ps_psi' 'Avg_VW1_Z10D5001Tp_F' 'Avg_VW1_Z09D5653Ps_psi'
#  'Avg_VW1_Z09D5653Tp_F' 'Avg_VW1_Z08D5840Ps_psi' 'Avg_VW1_Z08D5840Tp_F'
#  'Avg_VW1_Z07D6416Ps_psi' 'Avg_VW1_Z07D6416Tp_F' 'Avg_VW1_Z06D6632Ps_psi'
#  'Avg_VW1_Z06D6632Tp_F' 'Avg_VW1_Z05D6720Ps_psi' 'Avg_VW1_Z05D6720Tp_F'
#  'Avg_VW1_Z04D6837Ps_psi' 'Avg_VW1_Z04D6837Tp_F' 'Avg_VW1_Z03D6945Ps_psi'
#  'Avg_VW1_Z03D6945Tp_F' 'Avg_VW1_Z02D6982Ps_psi' 'Avg_VW1_Z02D6982Tp_F'
#  'Avg_VW1_Z01D7061Ps_psi' 'Avg_VW1_Z01D7061Tp_F'
#  'Avg_VW1_Z0910D5482Ps_psi' 'Avg_VW1_Z0910D5482Tp_F' 'inj_diff']
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 27464 entries, 2009-10-01 00:00:00 to 2012-11-18 07:00:00
# Freq: H
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Avg_PLT_CO2VentRate_TPH   27398 non-null  float64
#  1   Avg_CCS1_WHCO2InjPs_psi   27270 non-null  float64
#  2   Avg_CCS1_WHCO2InjTp_F     27398 non-null  float64
#  3   Avg_CCS1_ANPs_psi         27304 non-null  float64
#  4   Avg_CCS1_DH6325Ps_psi     27398 non-null  float64
#  5   Avg_CCS1_DH6325Tp_F       27398 non-null  float64
#  6   Avg_VW1_WBTbgPs_psi       26127 non-null  float64
#  7   Avg_VW1_WBTbgTp_F         26061 non-null  float64
#  8   Avg_VW1_ANPs_psi          23487 non-null  float64
#  9   Avg_VW1_Z11D4917Ps_psi    26688 non-null  float64
#  10  Avg_VW1_Z11D4917Tp_F      26709 non-null  float64
#  11  Avg_VW1_Z10D5001Ps_psi    26688 non-null  float64
#  12  Avg_VW1_Z10D5001Tp_F      26709 non-null  float64
#  13  Avg_VW1_Z09D5653Ps_psi    26688 non-null  float64
#  14  Avg_VW1_Z09D5653Tp_F      26709 non-null  float64
#  15  Avg_VW1_Z08D5840Ps_psi    26189 non-null  float64
#  16  Avg_VW1_Z08D5840Tp_F      25878 non-null  float64
#  17  Avg_VW1_Z07D6416Ps_psi    25985 non-null  float64
#  18  Avg_VW1_Z07D6416Tp_F      25985 non-null  float64
#  19  Avg_VW1_Z06D6632Ps_psi    25500 non-null  float64
#  20  Avg_VW1_Z06D6632Tp_F      25500 non-null  float64
#  21  Avg_VW1_Z05D6720Ps_psi    23955 non-null  float64
#  22  Avg_VW1_Z05D6720Tp_F      23955 non-null  float64
#  23  Avg_VW1_Z04D6837Ps_psi    26600 non-null  float64
#  24  Avg_VW1_Z04D6837Tp_F      26600 non-null  float64
#  25  Avg_VW1_Z03D6945Ps_psi    24361 non-null  float64
#  26  Avg_VW1_Z03D6945Tp_F      25932 non-null  float64
#  27  Avg_VW1_Z02D6982Ps_psi    26423 non-null  float64
#  28  Avg_VW1_Z02D6982Tp_F      26423 non-null  float64
#  29  Avg_VW1_Z01D7061Ps_psi    25307 non-null  float64
#  30  Avg_VW1_Z01D7061Tp_F      25108 non-null  float64
#  31  Avg_VW1_Z0910D5482Ps_psi  26709 non-null  float64
#  32  Avg_VW1_Z0910D5482Tp_F    26709 non-null  float64
#  33  inj_diff                  27397 non-null  float64
# dtypes: float64(34)
# memory usage: 7.3 MB
# Information: None
#
#
# Descriptive Statistics:
#        Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# count             27398.000000             27270.000000
# mean                  2.122022              1239.861825
# std                 133.162146               817.740091
# min                   0.000000                 0.000000
# 25%                   0.000000              1235.469308
# 50%                   0.058333              1338.872024
# 75%                   0.150000              1361.045834
# max               18333.150000             39032.410160
#
#        Avg_CCS1_WHCO2InjTp_F  Avg_CCS1_ANPs_psi  Avg_CCS1_DH6325Ps_psi  \
# count           27398.000000       27304.000000           27398.000000
# mean               89.766221         560.862134            3244.168246
# std                48.287324         445.931405             173.471253
# min                 0.000000           0.000000               0.000000
# 25%                92.953925         523.536663            3233.023426
# 50%                96.268226         564.901591            3286.067870
# 75%                96.851236         604.763645            3324.735273
# max              2879.416016       24105.630860            3515.880615
#
#        Avg_CCS1_DH6325Tp_F  Avg_VW1_WBTbgPs_psi  Avg_VW1_WBTbgTp_F  \
# count         27398.000000         26127.000000       26061.000000
# mean            127.738740          1801.844864          80.794406
# std               7.167508           999.374082          44.286916
# min               0.000000             0.000000           0.000000
# 25%             127.166621          2173.526853         103.423346
# 50%             130.109008          2322.382139         104.196940
# 75%             131.082033          2379.839354         105.044018
# max             135.670399          4954.731745         120.056561
#
#        Avg_VW1_ANPs_psi  Avg_VW1_Z11D4917Ps_psi  ...  Avg_VW1_Z04D6837Tp_F  \
# count      23487.000000            26688.000000  ...          26600.000000
# mean         525.000311             1597.476442  ...             90.967574
# std         3988.707539              873.254402  ...             51.589928
# min            0.000000                0.000000  ...              0.000000
# 25%            0.452148             2070.333608  ...            118.813235
# 50%            4.656250             2073.364497  ...            119.543503
# 75%           16.900514             2074.094025  ...            119.852003
# max        31993.509770             2377.999424  ...            125.766369
#
#        Avg_VW1_Z03D6945Ps_psi  Avg_VW1_Z03D6945Tp_F  Avg_VW1_Z02D6982Ps_psi  \
# count            24361.000000          25932.000000            26423.000000
# mean              2350.941782            182.281703             2456.608853
# std               1495.701897            368.506491             1459.143450
# min                  0.000000              0.000000                0.000000
# 25%                  0.000000              0.000000                0.000000
# 50%               3299.938442            121.297661             3316.204091
# 75%               3320.609979            122.832244             3332.014610
# max               3457.878882           1602.857486             3499.615312
#
#        Avg_VW1_Z02D6982Tp_F  Avg_VW1_Z01D7061Ps_psi  Avg_VW1_Z01D7061Tp_F  \
# count          26423.000000            25307.000000          25108.000000
# mean              91.272574             2300.195377             85.859433
# std               52.699934             1521.416947             55.366988
# min                0.000000                0.000000              0.000000
# 25%               32.002941                0.000000              0.000000
# 50%              121.263339             3318.194554            121.362099
# 75%              122.027798             3327.320356            122.551008
# max              124.310501             3445.065566            133.912303
#
#        Avg_VW1_Z0910D5482Ps_psi  Avg_VW1_Z0910D5482Tp_F      inj_diff
# count              26709.000000            26709.000000  27397.000000
# mean                1855.603011               86.313992      0.001651
# std                 1017.588588               46.720937     82.690245
# min                    0.000000                0.000000 -11021.132640
# 25%                 2353.328436              110.492078     -0.072917
# 50%                 2374.948004              111.453740      0.000000
# 75%                 2416.106108              111.976222      0.074305
# max                 2758.334188              113.687965   7033.459028
#
# [8 rows x 34 columns]

# %%
print("Name of Columns that have Missing Values:\n", df1.columns[df1.isnull().any()])
# Out:
# Name of Columns that have Missing Values:
#  Index(['Avg_PLT_CO2VentRate_TPH', 'Avg_CCS1_WHCO2InjPs_psi',
#        'Avg_CCS1_WHCO2InjTp_F', 'Avg_CCS1_ANPs_psi', 'Avg_CCS1_DH6325Ps_psi',
#        'Avg_CCS1_DH6325Tp_F', 'Avg_VW1_WBTbgPs_psi', 'Avg_VW1_WBTbgTp_F',
#        'Avg_VW1_ANPs_psi', 'Avg_VW1_Z11D4917Ps_psi', 'Avg_VW1_Z11D4917Tp_F',
#        'Avg_VW1_Z10D5001Ps_psi', 'Avg_VW1_Z10D5001Tp_F',
#        'Avg_VW1_Z09D5653Ps_psi', 'Avg_VW1_Z09D5653Tp_F',
#        'Avg_VW1_Z08D5840Ps_psi', 'Avg_VW1_Z08D5840Tp_F',
#        'Avg_VW1_Z07D6416Ps_psi', 'Avg_VW1_Z07D6416Tp_F',
#        'Avg_VW1_Z06D6632Ps_psi', 'Avg_VW1_Z06D6632Tp_F',
#        'Avg_VW1_Z05D6720Ps_psi', 'Avg_VW1_Z05D6720Tp_F',
#        'Avg_VW1_Z04D6837Ps_psi', 'Avg_VW1_Z04D6837Tp_F',
#        'Avg_VW1_Z03D6945Ps_psi', 'Avg_VW1_Z03D6945Tp_F',
#        'Avg_VW1_Z02D6982Ps_psi', 'Avg_VW1_Z02D6982Tp_F',
#        'Avg_VW1_Z01D7061Ps_psi', 'Avg_VW1_Z01D7061Tp_F',
#        'Avg_VW1_Z0910D5482Ps_psi', 'Avg_VW1_Z0910D5482Tp_F', 'inj_diff'],
#       dtype='object')

# %%
df2 = df1.ffill(axis = 0) #Forward fill null or blank values
df3 = df2.backfill(axis = 0) #Back fill null or blank values

# %%
df3.isnull().sum()
# Out:
# Avg_PLT_CO2VentRate_TPH     0
# Avg_CCS1_WHCO2InjPs_psi     0
# Avg_CCS1_WHCO2InjTp_F       0
# Avg_CCS1_ANPs_psi           0
# Avg_CCS1_DH6325Ps_psi       0
# Avg_CCS1_DH6325Tp_F         0
# Avg_VW1_WBTbgPs_psi         0
# Avg_VW1_WBTbgTp_F           0
# Avg_VW1_ANPs_psi            0
# Avg_VW1_Z11D4917Ps_psi      0
# Avg_VW1_Z11D4917Tp_F        0
# Avg_VW1_Z10D5001Ps_psi      0
# Avg_VW1_Z10D5001Tp_F        0
# Avg_VW1_Z09D5653Ps_psi      0
# Avg_VW1_Z09D5653Tp_F        0
# Avg_VW1_Z08D5840Ps_psi      0
# Avg_VW1_Z08D5840Tp_F        0
# Avg_VW1_Z07D6416Ps_psi      0
# Avg_VW1_Z07D6416Tp_F        0
# Avg_VW1_Z06D6632Ps_psi      0
# Avg_VW1_Z06D6632Tp_F        0
# Avg_VW1_Z05D6720Ps_psi      0
# Avg_VW1_Z05D6720Tp_F        0
# Avg_VW1_Z04D6837Ps_psi      0
# Avg_VW1_Z04D6837Tp_F        0
# Avg_VW1_Z03D6945Ps_psi      0
# Avg_VW1_Z03D6945Tp_F        0
# Avg_VW1_Z02D6982Ps_psi      0
# Avg_VW1_Z02D6982Tp_F        0
# Avg_VW1_Z01D7061Ps_psi      0
# Avg_VW1_Z01D7061Tp_F        0
# Avg_VW1_Z0910D5482Ps_psi    0
# Avg_VW1_Z0910D5482Tp_F      0
# inj_diff                    0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis
#
# Viewing the data to make sense of trends

# %%
# sort by date
df3 = df3.sort_index()

# plot
df3.plot(figsize=(16, 30), subplots=True, sharex=True)
plt.title("Injection Data", size=fontsize)
plt.xlabel("Date", size=fontsize)
plt.ylabel("Inputs", size=fontsize)
plt.show()

# %%
df3.corr().style.background_gradient(cmap = "YlGnBu")
# Out:
# <style type="text/css">
# #T_852c3_row0_col0, #T_852c3_row1_col1, #T_852c3_row2_col2, #T_852c3_row3_col3, #T_852c3_row4_col4, #T_852c3_row5_col5, #T_852c3_row6_col6, #T_852c3_row7_col7, #T_852c3_row8_col8, #T_852c3_row9_col9, #T_852c3_row9_col11, #T_852c3_row9_col13, #T_852c3_row9_col31, #T_852c3_row10_col10, #T_852c3_row10_col12, #T_852c3_row10_col14, #T_852c3_row10_col32, #T_852c3_row11_col9, #T_852c3_row11_col11, #T_852c3_row11_col13, #T_852c3_row11_col31, #T_852c3_row12_col10, #T_852c3_row12_col12, #T_852c3_row12_col14, #T_852c3_row12_col32, #T_852c3_row13_col9, #T_852c3_row13_col11, #T_852c3_row13_col13, #T_852c3_row13_col31, #T_852c3_row14_col10, #T_852c3_row14_col12, #T_852c3_row14_col14, #T_852c3_row14_col32, #T_852c3_row15_col15, #T_852c3_row16_col16, #T_852c3_row17_col17, #T_852c3_row18_col18, #T_852c3_row19_col19, #T_852c3_row20_col20, #T_852c3_row21_col21, #T_852c3_row22_col22, #T_852c3_row23_col23, #T_852c3_row24_col24, #T_852c3_row25_col25, #T_852c3_row26_col26, #T_852c3_row27_col27, #T_852c3_row28_col28, #T_852c3_row29_col29, #T_852c3_row30_col30, #T_852c3_row31_col9, #T_852c3_row31_col11, #T_852c3_row31_col13, #T_852c3_row31_col31, #T_852c3_row32_col10, #T_852c3_row32_col12, #T_852c3_row32_col14, #T_852c3_row32_col32, #T_852c3_row33_col33 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_852c3_row0_col1, #T_852c3_row0_col19, #T_852c3_row4_col21, #T_852c3_row4_col25, #T_852c3_row6_col1, #T_852c3_row8_col6, #T_852c3_row33_col1 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_852c3_row0_col2, #T_852c3_row0_col6, #T_852c3_row0_col27, #T_852c3_row0_col28, #T_852c3_row1_col7, #T_852c3_row2_col19, #T_852c3_row2_col20, #T_852c3_row3_col7, #T_852c3_row3_col10, #T_852c3_row16_col4, #T_852c3_row26_col3 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_852c3_row0_col3, #T_852c3_row1_col23, #T_852c3_row1_col24, #T_852c3_row1_col27, #T_852c3_row1_col28, #T_852c3_row3_col24, #T_852c3_row12_col3, #T_852c3_row17_col3, #T_852c3_row18_col3, #T_852c3_row20_col3, #T_852c3_row23_col3, #T_852c3_row25_col26, #T_852c3_row33_col3, #T_852c3_row33_col9, #T_852c3_row33_col10, #T_852c3_row33_col11, #T_852c3_row33_col13, #T_852c3_row33_col14, #T_852c3_row33_col31 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_852c3_row0_col4, #T_852c3_row0_col15, #T_852c3_row3_col15, #T_852c3_row3_col16, #T_852c3_row3_col21, #T_852c3_row3_col22, #T_852c3_row4_col2, #T_852c3_row5_col2, #T_852c3_row8_col26, #T_852c3_row33_col22 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_852c3_row0_col5, #T_852c3_row7_col4, #T_852c3_row20_col4, #T_852c3_row32_col4 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_852c3_row0_col7, #T_852c3_row0_col10, #T_852c3_row0_col11, #T_852c3_row0_col13, #T_852c3_row3_col23, #T_852c3_row15_col4, #T_852c3_row16_col1, #T_852c3_row21_col3, #T_852c3_row22_col3, #T_852c3_row29_col3, #T_852c3_row30_col3, #T_852c3_row33_col32 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_852c3_row0_col8, #T_852c3_row33_col29 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_852c3_row0_col9, #T_852c3_row0_col14, #T_852c3_row0_col31, #T_852c3_row0_col32, #T_852c3_row15_col1, #T_852c3_row28_col3, #T_852c3_row33_col23, #T_852c3_row33_col24 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_852c3_row0_col12, #T_852c3_row1_col9, #T_852c3_row1_col10, #T_852c3_row1_col11, #T_852c3_row1_col13, #T_852c3_row1_col14, #T_852c3_row1_col31, #T_852c3_row1_col32, #T_852c3_row3_col9, #T_852c3_row3_col11, #T_852c3_row3_col13, #T_852c3_row3_col14, #T_852c3_row3_col27, #T_852c3_row3_col28, #T_852c3_row3_col31, #T_852c3_row3_col32, #T_852c3_row6_col3, #T_852c3_row7_col3, #T_852c3_row9_col3, #T_852c3_row10_col3, #T_852c3_row11_col3, #T_852c3_row13_col3, #T_852c3_row14_col3, #T_852c3_row19_col3, #T_852c3_row24_col3, #T_852c3_row31_col3, #T_852c3_row32_col3, #T_852c3_row33_col2, #T_852c3_row33_col7 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_852c3_row0_col16, #T_852c3_row1_col22, #T_852c3_row28_col8, #T_852c3_row33_col21 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_852c3_row0_col17, #T_852c3_row0_col18, #T_852c3_row3_col6, #T_852c3_row27_col2 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_852c3_row0_col20, #T_852c3_row4_col22 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_852c3_row0_col21, #T_852c3_row21_col5 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_852c3_row0_col22, #T_852c3_row22_col5, #T_852c3_row25_col8, #T_852c3_row33_col8 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_852c3_row0_col23, #T_852c3_row0_col24, #T_852c3_row16_col3 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_852c3_row0_col25, #T_852c3_row2_col8, #T_852c3_row17_col4, #T_852c3_row18_col4, #T_852c3_row26_col8 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_852c3_row0_col26, #T_852c3_row3_col29, #T_852c3_row5_col21, #T_852c3_row26_col5 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_852c3_row0_col29, #T_852c3_row3_col30, #T_852c3_row33_col26, #T_852c3_row33_col30 {
#   background-color: #d1edb3;
#   color: #000000;
# }
# #T_852c3_row0_col30, #T_852c3_row1_col5, #T_852c3_row5_col22 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_852c3_row0_col33 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_852c3_row1_col0, #T_852c3_row2_col12, #T_852c3_row3_col0, #T_852c3_row20_col2, #T_852c3_row23_col2, #T_852c3_row24_col2 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_852c3_row1_col2, #T_852c3_row16_col28 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_852c3_row1_col3 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_852c3_row1_col4, #T_852c3_row7_col8, #T_852c3_row10_col8 {
#   background-color: #c8e9b4;
#   color: #000000;
# }
# #T_852c3_row1_col6, #T_852c3_row4_col15, #T_852c3_row16_col26, #T_852c3_row33_col6, #T_852c3_row33_col12, #T_852c3_row33_col27, #T_852c3_row33_col28 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_852c3_row1_col8, #T_852c3_row29_col4 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_852c3_row1_col12, #T_852c3_row3_col12, #T_852c3_row5_col8, #T_852c3_row15_col26 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_852c3_row1_col15, #T_852c3_row1_col25, #T_852c3_row2_col21, #T_852c3_row3_col8, #T_852c3_row8_col20 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_852c3_row1_col16, #T_852c3_row4_col1, #T_852c3_row8_col19, #T_852c3_row9_col4, #T_852c3_row10_col4, #T_852c3_row11_col4, #T_852c3_row13_col4, #T_852c3_row14_col4, #T_852c3_row19_col4, #T_852c3_row31_col4 {
#   background-color: #e6f5b2;
#   color: #000000;
# }
# #T_852c3_row1_col17, #T_852c3_row1_col18, #T_852c3_row2_col7, #T_852c3_row2_col10, #T_852c3_row2_col11, #T_852c3_row2_col13, #T_852c3_row2_col27, #T_852c3_row2_col28, #T_852c3_row4_col16, #T_852c3_row4_col20, #T_852c3_row4_col28, #T_852c3_row7_col0, #T_852c3_row7_col2, #T_852c3_row8_col2, #T_852c3_row8_col27, #T_852c3_row9_col0, #T_852c3_row9_col2, #T_852c3_row10_col0, #T_852c3_row10_col2, #T_852c3_row11_col0, #T_852c3_row11_col2, #T_852c3_row12_col0, #T_852c3_row12_col2, #T_852c3_row13_col0, #T_852c3_row13_col2, #T_852c3_row14_col0, #T_852c3_row17_col0, #T_852c3_row18_col0, #T_852c3_row19_col0, #T_852c3_row20_col0, #T_852c3_row23_col0, #T_852c3_row24_col0, #T_852c3_row25_col0, #T_852c3_row29_col0, #T_852c3_row30_col0, #T_852c3_row31_col0, #T_852c3_row31_col2, #T_852c3_row32_col0 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_852c3_row1_col19, #T_852c3_row3_col19, #T_852c3_row29_col1, #T_852c3_row30_col1 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_852c3_row1_col20, #T_852c3_row3_col20, #T_852c3_row18_col1, #T_852c3_row20_col1, #T_852c3_row20_col5, #T_852c3_row23_col1, #T_852c3_row24_col1, #T_852c3_row26_col2, #T_852c3_row26_col23, #T_852c3_row29_col5, #T_852c3_row33_col19 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_852c3_row1_col21, #T_852c3_row27_col4, #T_852c3_row27_col8 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_852c3_row1_col26, #T_852c3_row6_col8, #T_852c3_row24_col26 {
#   background-color: #cdebb4;
#   color: #000000;
# }
# #T_852c3_row1_col29

# %%
cor_matrix = df3.corr()

filteredDf = cor_matrix[((cor_matrix >= .5) | (cor_matrix <= -.5)) & (cor_matrix !=1.000)]
plt.figure(figsize=(16,16))
sns.heatmap(filteredDf, annot=True, cmap="Reds")
plt.savefig('matrix.jpeg')
plt.show()

# %%
#Ranking the correlatable variables
cor_matrix = df3.corr()
cor_matrix[['Avg_CCS1_DH6325Tp_F']]

f, ax = plt.subplots(figsize=(25, 12))
sns.heatmap(cor_matrix[['Avg_CCS1_DH6325Tp_F']].sort_values(by=['Avg_CCS1_DH6325Tp_F'], 
                                                 ascending =False), annot=True, cmap="Blues")

plt.show()

# %%
drop_cols = [col for col in df3.columns if 'Tp_F' in col]
df4 = df3[df3.columns.drop(drop_cols)]
df5 = df4[['Avg_PLT_CO2VentRate_TPH', 
           'Avg_CCS1_WHCO2InjPs_psi', 
           'Avg_CCS1_ANPs_psi',
           'Avg_CCS1_DH6325Ps_psi', 
           'Avg_VW1_WBTbgPs_psi', 
           #'Avg_VW1_ANPs_psi', 
           'Avg_VW1_Z01D7061Ps_psi', 
           'inj_diff',
          ]]

df_clean = df5.copy()
df_clean.ends()
# Out:
#                      Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00                20.543221                 1.880208
# 2009-10-01 01:00:00                20.543221                 1.374349
# 2009-10-01 02:00:00                20.543221                 1.315104
# 2009-10-01 03:00:00                20.543221                 1.255859
# 2009-10-01 04:00:00                20.543221                 1.342448
# 2012-11-18 03:00:00                 0.408333              1409.701282
# 2012-11-18 04:00:00                 0.458333              1409.036129
# 2012-11-18 05:00:00                 0.508333              1408.648841
# 2012-11-18 06:00:00                 0.504202              1406.788722
# 2012-11-18 07:00:00                 0.616667              1407.204333
#
#                      Avg_CCS1_ANPs_psi  Avg_CCS1_DH6325Ps_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00          89.967778            2893.787960
# 2009-10-01 01:00:00          89.825334            2893.793620
# 2009-10-01 02:00:00          89.806754            2893.791506
# 2009-10-01 03:00:00          89.806754            2893.786399
# 2009-10-01 04:00:00          89.610633            2893.774135
# 2012-11-18 03:00:00         530.799145            3385.511261
# 2012-11-18 04:00:00         531.937228            3387.451438
# 2012-11-18 05:00:00         526.400194            3387.077108
# 2012-11-18 06:00:00         532.481976            3387.618129
# 2012-11-18 07:00:00         517.267830            3386.470343
#
#                      Avg_VW1_WBTbgPs_psi  Avg_VW1_Z01D7061Ps_psi  inj_diff
# SampleTimeUTC
# 2009-10-01 00:00:00          2173.710958             3216.464494  0.000000
# 2009-10-01 01:00:00          2173.762679             3216.520127  0.000000
# 2009-10-01 02:00:00          2173.754085             3216.510374  0.000000
# 2009-10-01 03:00:00          2173.734355             3216.479380  0.000000
# 2009-10-01 04:00:00          2173.738489             3216.436283  0.000000
# 2012-11-18 03:00:00          2328.919804             3320.264079 -0.031250
# 2012-11-18 04:00:00          2328.912415             3320.271702 -0.091320
# 2012-11-18 05:00:00          2328.921606             3320.266923 -0.137501
# 2012-11-18 06:00:00          2328.940994             3320.181743  0.037290
# 2012-11-18 07:00:00          2328.994653             3320.304134 -0.080345

# %%
cor_matrix = df_clean.corr()

filteredDf = cor_matrix[((cor_matrix >= .5) | (cor_matrix <= -.5)) & (cor_matrix !=1.000)]
plt.figure(figsize=(16,16))
sns.heatmap(filteredDf, annot=True, cmap="Reds")
plt.savefig('matrix2.jpeg')
plt.show()

# %%
# to remove outliers
# Based on https://stackoverflow.com/questions/59489073/how-to-not-remove-but-handle-outliers-by-transforming-using-pandas
def cap_outliers(series, zscore_threshold=3, verbose=False):
    '''Caps outliers to closest existing value within threshold (Modified Z-score).'''
    median_val = series.median()
    mad_val = series.mad() # Median absolute deviation

    z_score = (series - median_val) / mad_val
    outliers = abs(z_score) > zscore_threshold

    series = series.copy()
    series.loc[z_score > zscore_threshold] = series.loc[~outliers].max()
    series.loc[z_score < -zscore_threshold] = series.loc[~outliers].min() 

    # For comparison purposes.
    if verbose:
            lbound = median_val - zscore_threshold * mad_val
            ubound = median_val + zscore_threshold * mad_val
            print('\n'.join(
                ['Capping outliers by the Modified Z-score method:',
                 f'   Z-score threshold: {zscore_threshold}',
                 f'   Lower bound: {lbound}',
                 f'   Upper bound: {ubound}\n']))

    return series

# %%
# Use apply because it will take each row/column, works on both user defined 
# or pandas defined function. 

df_clean = df_clean.apply(cap_outliers)

for i in df_clean.columns:
    creating_box_hist(str(i), df_clean)

# %%
df_clean.plot(subplots=True, figsize=(25, 20))
plt.show()

# %%
base_filename = 'Cleaned_data'
csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
df_clean.to_csv(csvs_sht, index = True, header = True)
print ("File exported:", base_filename + "." + filename_suffix)
# Out:
# File exported: Cleaned_data.csv

# %% [markdown]
# The data cleaning has focused on removing outliers and also removing high correlation values. As can be seen above, a lot of the data from the observation well is highly correlatable and not very useful. It makes sense as there are sensors located at different depths, but essentially measuring the same thing. Therefore, only 1 piece of that data should be retained.
#
# There are also "red herring" data like temperature which is directly correltable to pressure. Again, it will not be very useful. Also, annulus pressure is not very helpful in prediciting the injection delta.
#
# Finally, we remove data that is outside the modified Z-score range (http://colingorrie.github.io/outlier-detection.html).

# %% [markdown]
# # Deployment of LSTM Model

# %% [markdown]
# LSTMs can be used to model univariate time series forecasting problems, where we have a single series of observations and a model is required to learn from the series of past observations to predict the next value in the sequence.

# %% [markdown]
# ### References
#
# 1. https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
# 2. https://towardsdatascience.com/dropout-in-neural-networks-47a162d621d9
# 3. https://machinelearningmastery.com/stacked-long-short-term-memory-networks/
# 4. https://machinelearningmastery.com/return-sequences-and-return-states-for-lstms-in-keras/
# 5. https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/
# 6. https://www.v7labs.com/blog/neural-networks-activation-functions

# %% [markdown]
# ### Libraries

# %%
# Sklearn Liraries
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error , mean_squared_error, r2_score
from sklearn.model_selection import TimeSeriesSplit

#Tensorflow Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential 
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense,LSTM,Activation

from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from tensorflow.keras.layers import Dense,LSTM,Activation, Dropout, Bidirectional, TimeDistributed

# Nueral Networks are stocastic; setting random seeds ensures we get the same output each time
SEED = 42
os.environ['PYTHONHASHSEED']=str(SEED)
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'  # TF 2.1
np.random.seed(SEED)
tf.random.set_seed(SEED)

print(tf.__version__)
# Out:
# 2.11.0

# %% [markdown]
# ### Functions

# %%
# normalization to ensure data is on same scale
scaler = MinMaxScaler(feature_range=(0, 1))

def reshape_data(train_x, train_y, test_x, test_y):
    # convert to [rows, columns] structure
    x_train = train_x.reshape((train_x.shape[0], train_x.shape[1]))
    y_train = train_y.reshape((train_y.shape[0], 1))
    
    x_test = test_x.reshape((test_x.shape[0], test_x.shape[1]))
    y_test = test_y.reshape((test_y.shape[0], 1))

    # normalization features
    x_scaled = scaler.fit_transform(x_train)
    testx_scaled = scaler.transform(x_test)
    
    y_scaled = scaler.fit_transform(y_train)
    testy_scaled = scaler.transform(y_test)
    
    # horizontally stack columns
    dataset_stacked_train = np.hstack((x_scaled, y_scaled))
    dataset_stacked_test = np.hstack((testx_scaled, testy_scaled))
    
    print ("train dataset_stacked.shape" , dataset_stacked_train.shape) 
    print ("test dataset_stacked.shape" , dataset_stacked_test.shape)
    return dataset_stacked_train, dataset_stacked_test

# %% [markdown]
# The LSTM model will learn a function that maps a sequence of past observations as input to an output observation. As such, the sequence of observations must be transformed into multiple examples from which the LSTM can learn.

# %%
# split sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out=1):
    
    """
    create lagged value sequence for time series data
    
    Parameters:
    ============
    
    Sequence:
    =========
    The dataset contain x and y values. x can be single column or mutliple columns. Y will be last column.
    
    n_steps_in:
    ===========
    The preferrable window size for past data (or lagged values). 
    
    n_steps_out:
    ============
    The default is 1.
    
    output:
    =======
    x: The independent variable array
    y: The y(dependent variable)
    
    """
    X, y = list(), list()
    for i in range(len(sequences)):
    # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
#loss plot to identify optimal model parameters from training
def loss_plot(history):
    
    plt.rcParams['figure.figsize'] = [24, 12]
    plt.plot(history.history['mse'])
    plt.plot(history.history['val_mse'])
    plt.title('model accuracy')
    plt.ylabel('Mean Square Error')
    plt.xlabel('epoch')
    plt.legend(['train MSE', 'val MSE'], loc='upper left')
    plt.show()
    
    plt.rcParams['figure.figsize'] = [24, 12]
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train loss', 'val loss'], loc='upper left')
    plt.show()

# %%
# To evaluate how well model predictions are doing
def evaluate_prediction(predictions, actual):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    r2 = r2_score(actual, predictions)
    print('Mean Square Error: {:.2f}'.format(mse))
    print('Mean Absolute Error: {:.2f}'.format(mae))
    print('Root Mean Square Error: {:.2f}'.format(rmse))
    print('R-Square: {:.2f}'.format(r2))
    print('')
    print('')
    
    list_df = [mse, rmse, mae, r2]
    df = pd.DataFrame(list_df, index=["MSE", "RMSE", "MAE", "R^2"])
    
    return df

# %% [markdown]
# #### The below function provides general LSTM model structure.

# %%
# To Note:
# 1. n-neurons: Using 50 neurons, which can increased or decreased to check if it affects model results.
# 2. lr = Learning rate: Very important parameter; smaller values decrease model overfitting but increase computation time
# 3. optimizer = Adam: Note that we have to use the .legacy as new version of tf has some conflict
# 4. Dropout: By dropping out the nodes (input and hidden layer) in a neural network, all the forward and backwards
#    connections with a dropped node are temporarily removed, thus creating a new network architecture out of the 
#    parent network. The nodes are dropped by a dropout probability of p. It is applied to reduce overfitting
# 5. Stacked LSTM: An LSTM layer provides a sequence output rather than a single value output to the LSTM layer. 
#    Specifically, one output per input time step (creating a 3D data set), rather than one output time step for all 
#    input time steps (i.e. 1 single value)

# The selected model is a 2 layer STACKED LSTM. This can also be increased by adding a new LSTM layer

def LSTM_model(opt, n_steps_in, n_features, n_steps_out, neurons, dropout, activation):
    
    """
    Parameters:
    ============
    
    opt:
    ====
    The learning rate for the model. default is 0.1
    
    n_steps_in:
    ===========
    The window size for past data(or lagged values), called samples.
    
    n_features:
    ============
    How many independent variables are used. 

    n_steps_out:
    =============
    The output size, which is 1 in this case
    
    output:
    =======
    compiled model
    
    """
    # define model
    model = Sequential()
    
    # add LSTM layer with tanh activation. return_sequences=True is used so we can feed another 
    # LSTM layer to model. default is false.
    model.add(LSTM(neurons, activation=activation, return_sequences=True, input_shape=(n_steps_in, n_features)))
    model.add(Dropout(dropout))
    # second layer of LSTM with tanh activation. Now return sequence is False, as there will be no other layer
    # except output layer.
    model.add(LSTM(neurons, activation=activation))
    model.add(Dropout(dropout))
    
    # final layer with output
    model.add(Dense(n_steps_out))
    
    # activation function of output layer
    model.add(Activation('tanh'))
    
    # compile model with loss funtion, optimizer and metrics
    model.compile(loss='mse' , optimizer=opt , metrics=['mse'])
    
    return model

# %%
data = df_clean.copy()
data.index
# Out:
# DatetimeIndex(['2009-10-01 00:00:00', '2009-10-01 01:00:00',
#                '2009-10-01 02:00:00', '2009-10-01 03:00:00',
#                '2009-10-01 04:00:00', '2009-10-01 05:00:00',
#                '2009-10-01 06:00:00', '2009-10-01 07:00:00',
#                '2009-10-01 08:00:00', '2009-10-01 09:00:00',
#                ...
#                '2012-11-17 22:00:00', '2012-11-17 23:00:00',
#                '2012-11-18 00:00:00', '2012-11-18 01:00:00',
#                '2012-11-18 02:00:00', '2012-11-18 03:00:00',
#                '2012-11-18 04:00:00', '2012-11-18 05:00:00',
#                '2012-11-18 06:00:00', '2012-11-18 07:00:00'],
#               dtype='datetime64[ns]', name='SampleTimeUTC', length=27464, freq='H')

# %%
# Create numpy array for further analysis
# choose a number of time steps - change this accordingly
n_steps_in = 50 # Smaller the value, more accurate, slower. Tested 30, 50, 100, with 100 being the worst, and 30 as best
n_steps_out = 1

train = data[:("2011")]
test = data[("2012"):]

x_train, y_train = train.drop("inj_diff", axis=1).values, train["inj_diff"].values
x_test, y_test = test.drop("inj_diff", axis=1).values, test["inj_diff"].values

train_data, test_data = reshape_data(x_train, y_train, x_test, y_test)

# covert into input/output
X, y = split_sequences(train_data, n_steps_in, n_steps_out)
x_test, y_test = split_sequences(test_data, n_steps_in, n_steps_out)
print ("X.shape" , X.shape) 
print ("y.shape" , y.shape)

n_features = X.shape[2]
# Out:
# train dataset_stacked.shape (19728, 7)
# test dataset_stacked.shape (7736, 7)
# X.shape (19679, 50, 6)
# y.shape (19679, 1)

# %%
# The following are input parameters that can be tweaked for nicer graphs if needed
# 1. n_splits - use larger values, which increases run time
# 2. lr - use smaller values which increases run time
# 3. epochs - use larger values which increases run time

data.index.name = "Time"
dd = data[(n_steps_in-1):]
d = dd.reset_index()

# split time series data in K-folds
# Tested 5 K-folds. Using n_splits=2 for speed.
tscv = TimeSeriesSplit(max_train_size=None, n_splits=5)

# Learning rate: Very important parameter; smaller values decrease model overfitting but increase computation time
# optimizer = Adam: Note that we have to use the .legacy as new version of tf has some conflict
# For lr, tested 0.001, but it takes a while to run. Using default of 0.1 for now
lr = 0.01

# Use 50 for ease of coding for now, but have tested 100 and 10. Epoch should be >100 for best fit
epochs = 50

# Use 20 as default. Can be increased at cost of time
neurons = 20

# Vary to test the goodness of fit
dropout = 0.25

# Other fucntions to consider
# https://www.v7labs.com/blog/neural-networks-activation-functions
activation = 'tanh'

opt = tf.keras.optimizers.legacy.Adam(learning_rate=lr)

val_pred = []

for train_index, test_index in tscv.split(X):
    
    # show date of train data: only for information
    print("Train Dates", d[d.index.isin(train_index)].Time[0],
          d[d.index.isin(train_index)].Time.iloc[-1])
    
    # show date of test data: only for information
    print("Test Dates", d[d.index.isin(test_index)].Time.iloc[0],
          d[d.index.isin(test_index)].Time.iloc[-1])
    
    # split data based on train and test index: X variable
    X_train, X_test = X[train_index], X[test_index]

    # split data based on train and test index: y variable
    y_train, y_test = y[train_index], y[test_index]   
    
    # caclulate steps based on legth of data and window size
    steps_per_epoch = len(X_train)//n_steps_in
    # start LSTM model
    model = LSTM_model(opt, n_steps_in, n_features, n_steps_out, neurons, dropout, activation)
    
    # In time series data shuffle will be false as order is important.
    hist = model.fit(X_train , y_train , epochs=epochs, steps_per_epoch=steps_per_epoch,
                    verbose=1 , validation_split=0.1, shuffle=False,
                        callbacks=[EarlyStopping('val_loss', mode='min', patience=20)])
    
    # plot Mean absolute error
    loss_plot(hist)
    
    # make predictions of test data length
    lstm_pr = model.predict(X_test)
    
    # reverse back to original scale
    pred = scaler.inverse_transform(lstm_pr)
    
    # create dataframe of predictions
    lstm1_predictions = pd.DataFrame(pred.reshape(pred.shape[1]*pred.shape[0]))

    # reverse back test values and create dataframe
    y_test = scaler.inverse_transform(y_test)
    y_test = pd.DataFrame(y_test.reshape(y_test.shape[1]*y_test.shape[0]))
    
    # New dataframe to save predictions and test data.
    results = pd.DataFrame()
    results["test"] = y_test
    results["LSTM_Predictions"] =lstm1_predictions
    
    # save each fold predictions in list outside of loop
    val_pred.append(results)
    
    # evaluate predictions accuracy
    evaluate_prediction(results["LSTM_Predictions"], results["test"])
    #print(df_error)
    # create index of each folder
    results["Date"] = pd.Series(d[d.index.isin(test_index)].Time.tolist())
    results.set_index("Date", inplace=True)
    
    # plot the predicions of each fold.
    results.plot(figsize=(20,7))
    plt.title('Model Accuracy')
    plt.ylabel('CO2 Injection')
    plt.xlabel('Date')
    plt.show()

    del model
# Out:
# Train Dates 2009-10-03 01:00:00 2010-02-16 20:00:00
# Test Dates 2010-02-16 21:00:00 2010-07-03 11:00:00
# Epoch 1/50
# 65/65 [==============================] - 6s 42ms/step - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 2/50
# 65/65 [==============================] - 2s 29ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 3/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 4/50
# 65/65 [==============================] - 2s 28ms/step - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 5/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 6/50
# 65/65 [==============================] - 2s 29ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 7/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 8/50
# 65/65 [==============================] - 2s 28ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 9/50
# 65/65 [==============================] - 2s 28ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 10/50
# 65/65 [==============================] - 2s 28ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 11/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 12/50
# 65/65 [==============================] - 2s 32ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 13/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 14/50
# 65/65 [==============================] - 2s 33ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 15/50
# 65/65 [==============================] - 2s 29ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 16/50
# 65/65 [==============================] - 2s 34ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 17/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 18/50
# 65/65 [==============================] - 2s 33ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 19/50
# 65/65 [==============================] - 2s 32ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 20/50
# 65/65 [==============================] - 2s 33ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 21/50
# 65/65 [==============================] - 2s 33ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 22/50
# 65/65 [==============================] - 2s 34ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 23/50
# 65/65 [==============================] - 2s 28ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 24/50
# 65/65 [==============================] - 2s 29ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 25/50
# 65/65 [==============================] - 2s 37ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 26/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 27/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 28/50
# 65/65 [==============================] - 2s 32ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 29/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 30/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 31/50
# 65/65 [==============================] - 2s 32ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 32/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 33/50
# 65/65 [==============================] - 2s 32ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 34/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 35/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 36/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 37/50
# 65/65 [==============================] - 2s 32ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 38/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 39/50
# 65/65 [==============================] - 2s 32ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 40/50
# 65/65 [==============================] - 2s 33ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 41/50
# 65/65 [==============================] - 2s 32ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 42/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 43/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 44/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 45/50
# 65/65 [==============================] - 2s 32ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 46/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 47/50
# 65/65 [==============================] - 2s 30ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 48/50
# 65/65 [==============================] - 2s 34ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 49/50
# 65/65 [==============================] - 2s 31ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 50/50
# 65/65 [==============================] - 2s 29ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0190 - val_mse: 0.0190
# 103/103 [==============================] - 2s 11ms/step
# Mean Square Error: 0.97
# Mean Absolute Error: 0.46
# Root Mean Square Error: 0.98
# R-Square: 0.06
# Train Dates 2009-10-03 01:00:00 2010-07-03 11:00:00
# Test Dates 2010-07-03 12:00:00 2010-11-17 02:00:00
# Epoch 1/50
#  53/131 [===========>..................] - ETA: 2s - loss: 0.0270 - mse: 0.0270
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31380/1257877197.py in <module>
#      56
#      57     # In time series data shuffle will be false as order is important.
# ---> 58     hist = model.fit(X_train , y_train , epochs=epochs, steps_per_epoch=steps_per_epoch,
#      59                     verbose=1 , validation_split=0.1, shuffle=False,
#      60                         callbacks=[EarlyStopping('val_loss', mode='min', patience=20)])
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
all_pred = pd.concat(val_pred, axis=0)
plt.rcParams['figure.figsize'] = [24, 12]
all_pred.plot()
plt.ylabel("Delta")
plt.xlabel("Date")
plt.title("Predictions with LSTM")
plt.show()

# %% [markdown]
# Based on the K-fold cross-validation, we are getting reasonable fits. Therefore, the LSTM archtecture above will be deployed to the entire data set now

# %% [markdown]
# ### Testing on the entire dataset.
# ##### Variables for sensitivity to be tested
# 1. Size of n_steps_in
# 2. Learning rate (lr)
# 3. Number of epochs
# 4. Size of steps_per_epoch
# 5. Number of neurons
# 6. Dropout size
# 7. Type of activation function

# %%
n_steps_in = 30
lr = 0.001
epochs = 500
neurons = 50
dropout = 0.2
activation = 'tanh'

opt = tf.keras.optimizers.legacy.Adam(learning_rate=lr)

train = data[:("2012")]
test = data[("2012"):]

x_train, y_train = train.drop("inj_diff", axis=1).values, train["inj_diff"].values
x_test, y_test = test.drop("inj_diff", axis=1).values, test["inj_diff"].values

train_data, test_data = reshape_data(x_train, y_train, x_test, y_test)

# covert into input/output
X, y = split_sequences(train_data, n_steps_in, n_steps_out)
x_test, y_test = split_sequences(test_data, n_steps_in, n_steps_out)
print ("X.shape" , X.shape) 
print ("y.shape" , y.shape)

n_features = X.shape[2]

# caclulate steps based on legth of data and window size
steps_per_epoch = len(X)//n_steps_in
model = LSTM_model(opt, n_steps_in, n_features, n_steps_out, neurons, dropout, activation)
History =  model.fit(X, y, epochs=epochs, steps_per_epoch=steps_per_epoch,
                    verbose=1 , validation_split=0.2, shuffle=False,
                        callbacks=[EarlyStopping('val_loss', mode='min', patience=20)])
# Out:
# train dataset_stacked.shape (27464, 7)
# test dataset_stacked.shape (7736, 7)
# X.shape (27435, 30, 6)
# y.shape (27435, 1)
# Epoch 1/500
# 914/914 [==============================] - 23s 21ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 2/500
# 914/914 [==============================] - 19s 21ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 3/500
# 914/914 [==============================] - 19s 21ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 4/500
# 914/914 [==============================] - 18s 20ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 5/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 6/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 7/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 8/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 9/500
# 914/914 [==============================] - 18s 20ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 10/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 11/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 12/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 13/500
# 914/914 [==============================] - 19s 20ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 14/500
# 914/914 [==============================] - 21s 23ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 15/500
# 914/914 [==============================] - 19s 21ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 16/500
# 914/914 [==============================] - 18s 20ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 17/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 18/500
# 914/914 [==============================] - 19s 20ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 19/500
# 914/914 [==============================] - 22s 24ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 20/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 21/500
# 914/914 [==============================] - 19s 21ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 22/500
# 914/914 [==============================] - 21s 23ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 23/500
# 914/914 [==============================] - 21s 22ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 24/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 25/500
# 914/914 [==============================] - 19s 21ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 26/500
# 914/914 [==============================] - 22s 24ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 27/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 28/500
# 914/914 [==============================] - 19s 21ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 29/500
# 914/914 [==============================] - 21s 23ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 30/500
# 914/914 [==============================] - 21s 23ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 31/500
# 914/914 [==============================] - 21s 22ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 32/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 33/500
# 914/914 [==============================] - 21s 23ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 34/500
# 914/914 [==============================] - 19s 20ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 35/500
# 914/914 [==============================] - 22s 24ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 36/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 37/500
# 914/914 [==============================] - 22s 24ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 38/500
# 914/914 [==============================] - 21s 23ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 39/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 40/500
# 914/914 [==============================] - 23s 25ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 41/500
# 914/914 [==============================] - 21s 23ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 42/500
# 914/914 [==============================] - 20s 22ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 43/500
# 914/914 [==============================] - 22s 24ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 44/500
# 914/914 [==============================] - 21s 23ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0029 - val_mse: 0.0029

# %%
# plot Mean absolute error
loss_plot(History)

# %%
# make predictions and transform
test_pred = scaler.inverse_transform(model.predict(x_test))

pred_test = test[(n_steps_in-1):].copy()
pred_test["LSTM Predictions"] = test_pred
pred_test = pred_test[["inj_diff", "LSTM Predictions"]]

# evaluate predictions accuracy
evaluate_prediction(pred_test["LSTM Predictions"], pred_test["inj_diff"])

pred_test.plot()
# Out:
# 241/241 [==============================] - 4s 15ms/step
# Mean Square Error: 0.23
# Mean Absolute Error: 0.20
# Root Mean Square Error: 0.48
# R-Square: 0.65
# <AxesSubplot:xlabel='Time'>

# %%
pred_test
# Out:
#                      inj_diff  LSTM Predictions
# Time
# 2012-01-02 05:00:00 -0.082985          0.073209
# 2012-01-02 06:00:00  0.017317          0.079612
# 2012-01-02 07:00:00 -0.199262          0.010331
# 2012-01-02 08:00:00 -0.119444          0.091193
# 2012-01-02 09:00:00 -0.073265          0.045212
# ...                       ...               ...
# 2012-11-18 03:00:00 -0.031250          0.011600
# 2012-11-18 04:00:00 -0.091320          0.053822
# 2012-11-18 05:00:00 -0.137501          0.001995
# 2012-11-18 06:00:00  0.037290          0.025733
# 2012-11-18 07:00:00 -0.080345          0.006965
#
# [7707 rows x 2 columns]

# %% [markdown]
# ### Deploy on Blind Data set

# %%
base_filename = 'illinois_basing_test_04112023'
csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
#df.to_csv(csvs_sht, index = True, header = True)
print ("File to be loaded:", csvs_sht)
# Out:
# File to be loaded: C:\Users\vasan\OneDrive - California Resources Corporation\01_Admin\07_MLChallenge\illinois_basing_test_04112023.csv

# %%
skiprows = 0
#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
df_blind = pd.read_csv(csvs_sht, thousands=',', skiprows = skiprows)
#df_blind.columns = df.columns.str.replace('\xa0', '')
df_blind["inj_diff"] = 0
df_blind.ends()
# Out:
#         SampleTimeUTC  Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# 0     11/18/2012 8:00                 0.825000              1406.469561
# 1     11/18/2012 9:00                 0.641667              1406.399989
# 2    11/18/2012 10:00                 0.633333              1406.588710
# 3    11/18/2012 11:00                 0.633333              1407.000806
# 4    11/18/2012 12:00                 0.458333              1406.682945
# 196  11/26/2012 12:00                 1.708333              1418.840352
# 197  11/26/2012 13:00                 1.708333              1418.537537
# 198  11/26/2012 14:00                 1.716667              1418.984295
# 199  11/26/2012 15:00                 1.566667              1419.207662
# 200  11/26/2012 16:00                 0.025000              1143.615576
#
#      Avg_CCS1_WHCO2InjTp_F  Avg_CCS1_ANPs_psi  Avg_CCS1_DH6325Ps_psi  \
# 0                95.529213         522.013451            3383.554036
# 1                95.191933         510.494516            3385.778632
# 2                95.546059         510.899432            3383.531185
# 3                95.382363         511.896438            3384.563845
# 4                95.643837         510.982277            3385.062998
# 196              96.514320         440.463678            3398.568276
# 197              96.197548         432.052225            3399.234914
# 198              96.460487         513.740069            3400.701626
# 199              96.425332         621.174498            3403.130627
# 200              89.688881         561.435533            3111.476807
#
#      Avg_CCS1_DH6325Tp_F  Avg_VW1_WBTbgPs_psi  Avg_VW1_WBTbgTp_F  \
# 0             129.535322          2329.030835         104.912923
# 1             129.518488          2329.015361         104.909203
# 2             129.466555          2329.055794         104.911063
# 3             129.481727          2329.133431         104.911993
# 4             129.459261          2329.147909         104.890602
# 196           129.185358          2327.606797         104.914033
# 197           129.200211          2327.799504         104.898972
# 198           129.224400          2327.909432         104.900832
# 199           129.259234          2327.912443         104.905483
# 200           128.116005          2327.892611         104.905483
#
#      Avg_VW1_ANPs_psi  ...  Avg_VW1_Z04D6837Tp_F  Avg_VW1_Z03D6945Ps_psi  \
# 0            0.100585  ...            123.950680                     NaN
# 1            0.100585  ...            123.953320                     NaN
# 2                 NaN  ...            123.950020                     NaN
# 3                 NaN  ...            123.955959                     NaN
# 4                 NaN  ...            123.952660                     NaN
# 196          2.644836  ...            124.241981                     0.0
# 197          2.620117  ...            124.245941                     0.0
# 198          2.648498  ...            124.251221                     0.0
# 199          2.674133  ...            124.245941                     0.0
# 200          2.670471  ...            124.254520                     0.0
#
#      Avg_VW1_Z03D6945Tp_F  Avg_VW1_Z02D6982Ps_psi  Avg_VW1_Z02D6982Tp_F  \
# 0                     NaN             3323.462998            123.443262
# 1                     NaN             3323.513243            123.453597
# 2                     NaN             3323.566427            123.445062
# 3                     NaN             3323.579193            123.442497
# 4                     NaN             3323.572024            123.448467
# 196                   0.0             3321.337750            123.516012
# 197                   0.0             3321.381618            123.511662
# 198                   0.0             3321.374638            123.516882
# 199                   0.0             3321.392446            123.513387
# 200                   0.0             3321.358042            123.512532
#
#      Avg_VW1_Z01D7061Ps_psi  Avg_VW1_Z01D7061Tp_F  Avg_VW1_Z0910D5482Ps_psi  \
# 0               3320.276693            122.462348               2641.618345
# 1               3320.269031            122.457593               2641.630886
# 2               3320.298985            122.453574               2641.633761
# 3               3320.306563            122.458973               2641.664410
# 4               3320.344305            122.463683               2641.688436
# 196             3321.700452            122.553698               2640.481917
# 197             3321.754409            122.555723               2640.675960
# 198             3321.721102            122.550998               2640.760974
# 199             3321.729205            122.554373               2640.762337
# 200             3321.724227            122.556398               2640.735295
#
#      Avg_VW1_Z0910D5482Tp_F  inj_diff
# 0                110.552962         0
# 1                110.550592         0
# 2                110.543437         0
# 3                110.546602         0
# 4                110.541832         0
# 196              110.566567         0
# 197              110.560132         0
# 198              110.560132         0
# 199              110.563312         0
# 200              110.562517         0
#
# [10 rows x 35 columns]

# %%
df_blind['SampleTimeUTC'] = pd.to_datetime(df_blind['SampleTimeUTC'])
df_blind = df_blind.set_index("SampleTimeUTC")
idx = pd.date_range(df_blind.index[0], df_blind.index[-1])

#df1 = df1.reindex(idx, fill_value=np.nan).dropna()
df_blind.index.name = "SampleTimeUTC"

df_blind = df_blind.asfreq('H')

#df1.index.freq = "H"
df_blind
# Out:
#                      Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# SampleTimeUTC
# 2012-11-18 08:00:00                 0.825000              1406.469561
# 2012-11-18 09:00:00                 0.641667              1406.399989
# 2012-11-18 10:00:00                 0.633333              1406.588710
# 2012-11-18 11:00:00                 0.633333              1407.000806
# 2012-11-18 12:00:00                 0.458333              1406.682945
# ...                                      ...                      ...
# 2012-11-26 12:00:00                 1.708333              1418.840352
# 2012-11-26 13:00:00                 1.708333              1418.537537
# 2012-11-26 14:00:00                 1.716667              1418.984295
# 2012-11-26 15:00:00                 1.566667              1419.207662
# 2012-11-26 16:00:00                 0.025000              1143.615576
#
#                      Avg_CCS1_WHCO2InjTp_F  Avg_CCS1_ANPs_psi  \
# SampleTimeUTC
# 2012-11-18 08:00:00              95.529213         522.013451
# 2012-11-18 09:00:00              95.191933         510.494516
# 2012-11-18 10:00:00              95.546059         510.899432
# 2012-11-18 11:00:00              95.382363         511.896438
# 2012-11-18 12:00:00              95.643837         510.982277
# ...                                    ...                ...
# 2012-11-26 12:00:00              96.514320         440.463678
# 2012-11-26 13:00:00              96.197548         432.052225
# 2012-11-26 14:00:00              96.460487         513.740069
# 2012-11-26 15:00:00              96.425332         621.174498
# 2012-11-26 16:00:00              89.688881         561.435533
#
#                      Avg_CCS1_DH6325Ps_psi  Avg_CCS1_DH6325Tp_F  \
# SampleTimeUTC
# 2012-11-18 08:00:00            3383.554036           129.535322
# 2012-11-18 09:00:00            3385.778632           129.518488
# 2012-11-18 10:00:00            3383.531185           129.466555
# 2012-11-18 11:00:00            3384.563845           129.481727
# 2012-11-18 12:00:00            3385.062998           129.459261
# ...                                    ...                  ...
# 2012-11-26 12:00:00            3398.568276           129.185358
# 2012-11-26 13:00:00            3399.234914           129.200211
# 2012-11-26 14:00:00            3400.701626           129.224400
# 2012-11-26 15:00:00            3403.130627           129.259234
# 2012-11-26 16:00:00            3111.476807           128.116005
#
#                      Avg_VW1_WBTbgPs_psi  Avg_VW1_WBTbgTp_F  Avg_VW1_ANPs_psi  \
# SampleTimeUTC
# 2012-11-18 08:00:00          2329.030835         104.912923          0.100585
# 2012-11-18 09:00:00          2329.015361         104.909203          0.100585
# 2012-11-18 10:00:00          2329.055794         104.911063               NaN
# 2012-11-18 11:00:00          2329.133431         104.911993               NaN
# 2012-11-18 12:00:00          2329.147909         104.890602               NaN
# ...                                  ...                ...               ...
# 2012-11-26 12:00:00          2327.606797         104.914033          2.644836
# 2012-11-26 13:00:00          2327.799504         104.898972          2.620117
# 2012-11-26 14:00:00          2327.909432         104.900832          2.648498
# 2012-11-26 15:00:00          2327.912443         104.905483          2.674133
# 2012-11-26 16:00:00          2327.892611         104.905483          2.670471
#
#                      Avg_VW1_Z11D4917Ps_psi  ...  Avg_VW1_Z04D6837Tp_F  \
# SampleTimeUTC                                ...
# 2012-11-18 08:00:00             2069.938165  ...            123.950680
# 2012-11-18 09:00:00             2069.942957  ...            123.953320
# 2012-11-18 10:00:00             2069.882166  ...            123.950020
# 2012-11-18 11:00:00             2069.932163  ...            123.955959
# 2012-11-18 12:00:00             2069.892961  ...            123.952660
# ...                                     ...  ...                   ...
# 2012-11-26 12:00:00             2069.778320  ...            124.241981
# 2012-11-26 13:00:00             2069.796224  ...            124.245941
# 2012-11-26 14:00:00             2069.795003  ...            124.251221
# 2012-11-26 15:00:00             2069.821212  ...            124.245941
# 2012-11-26 16:00:00             2069.826986  ...            124.254520
#
#                      Avg_VW1_Z03D6945Ps_psi  Avg_VW1_Z03D6945Tp_F  \
# SampleTimeUTC
# 2012-11-18 08:00:00                     NaN                   NaN
# 2012-11-18 09:00:00                     NaN                   NaN
# 2012-11-18 10:00:00                     NaN                   NaN
# 2012-11-18 11:00:00                     NaN                   NaN
# 2012-11-18 12:00:00                     NaN                   NaN
# ...                                     ...                   ...
# 2012-11-26 12:00:00                     0.0                   0.0
# 2012-11-26 13:00:00                     0.0                   0.0
# 2012-11-26 14:00:00                     0.0                   0.0
# 2012-11-26 15:00:00                     0.0                   0.0
# 2012-11-26 16:00:00                     0.0                   0.0
#
#                      Avg_VW1_Z02D6982Ps_psi  Avg_VW1_Z02D6982Tp_F  \
# SampleTimeUTC
# 2012-11-18 08:00:00             3323.462998            123.443262
# 2012-11-18 09:00:00             3323.513243            123.453597
# 2012-11-18 10:00:00             3323.566427            123.445062
# 2012-11-18 11:00:00             3323.579193            123.442497
# 2012-11-18 12:00:00             3323.572024            123.448467
# ...                                     ...                   ...
# 2012-11-26 12:00:00             3321.337750            123.516012
# 2012-11-26 13:00:00             3321.381618            123.511662
# 2012-11-26 14:00:00             3321.374638            123.516882
# 2012-11-26 15:00:00             3321.392446            123.513387
# 2012-11-26 16:00:00             3321.358042            123.512532
#
#                      Avg_VW1_Z01D7061Ps_psi  Avg_VW1_Z01D7061Tp_F  \
# SampleTimeUTC
# 2012-11-18 08:00:00             3320.276693            122.462348
# 2012-11-18 09:00:00             3320.269031            122.457593
# 2012-11-18 10:00:00             3320.298985            122.453574
# 2012-11-18 11:00:00             3320.306563            122.458973
# 2012-11-18 12:00:00             3320.344305            122.463683
# ...                                     ...                   ...
# 2012-11-26 12:00:00             3321.700452            122.553698
# 2012-11-26 13:00:00             3321.754409            122.555723
# 2012-11-26 14:00:00             3321.721102            122.550998
# 2012-11-26 15:00:00             3321.729205            122.554373
# 2012-11-26 16:00:00             3321.724227            122.556398
#
#                      Avg_VW1_Z0910D5482Ps_psi  Avg_VW1_Z0910D5482Tp_F  \
# SampleTimeUTC
# 2012-11-18 08:00:00               2641.618345              110.552962
# 2012-11-18 09:00:00               2641.630886              110.550592
# 2012-11-18 10:00:00               2641.633761              110.543437
# 2012-11-18 11:00:00               2641.664410              110.546602
# 2012-11-18 12:00:00               2641.688436              110.541832
# ...                                       ...                     ...
# 2012-11-26 12:00:00               2640.481917              110.566567
# 2012-11-26 13:00:00               2640.675960              110.560132
# 2012-11-26 14:00:00               2640.760974              110.560132
# 2012-11-26 15:00:00               2640.762337              110.563312
# 2012-11-26 16:00:00               2640.735295              110.562517
#
#                      inj_diff
# SampleTimeUTC
# 2012-11-18 08:00:00         0
# 2012-11-18 09:00:00         0
# 2012-11-18 10:00:00         0
# 2012-11-18 11:00:00         0
# 2012-11-18 12:00:00         0
# ...                       ...
# 2012-11-26 12:00:00         0
# 2012-11-26 13:00:00         0
# 2012-11-26 14:00:00         0
# 2012-11-26 15:00:00         0
# 2012-11-26 16:00:00         0
#
# [201 rows x 34 columns]

# %%
#base_filename2 = 'illinois_basing_train_04112023'
#csvs_sht = os.path.join(dir_name, base_filename2 + "." + filename_suffix)
#df.to_csv(csvs_sht, index = True, header = True)
#print ("File to be loaded:", csvs_sht)

# %%
#skiprows = 0
#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
#df_train2 = pd.read_csv(csvs_sht, thousands=',', skiprows = skiprows)
#df_blind.columns = df.columns.str.replace('\xa0', '')
#df_train2.ends()

# %%
#df_blind['SampleTimeUTC'] = pd.to_datetime(df_blind['SampleTimeUTC'])
#df_blind = df_blind.set_index("SampleTimeUTC")
#idx = pd.date_range(df_blind.index[0], df_blind.index[-1])
#df_blind.index.name = "SampleTimeUTC"
#df_blind = df_blind.asfreq('H')

# %%
df_blind_new = df_blind[['Avg_PLT_CO2VentRate_TPH',
                         'Avg_CCS1_WHCO2InjPs_psi',
                         'Avg_CCS1_ANPs_psi',
                         'Avg_CCS1_DH6325Ps_psi',
                         'Avg_VW1_WBTbgPs_psi',
                         'Avg_VW1_Z01D7061Ps_psi',
                         'inj_diff',
                        ]]

data2 = df_blind_new.copy()
data2.ends()
# Out:
#                      Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# SampleTimeUTC
# 2012-11-18 08:00:00                 0.825000              1406.469561
# 2012-11-18 09:00:00                 0.641667              1406.399989
# 2012-11-18 10:00:00                 0.633333              1406.588710
# 2012-11-18 11:00:00                 0.633333              1407.000806
# 2012-11-18 12:00:00                 0.458333              1406.682945
# 2012-11-26 12:00:00                 1.708333              1418.840352
# 2012-11-26 13:00:00                 1.708333              1418.537537
# 2012-11-26 14:00:00                 1.716667              1418.984295
# 2012-11-26 15:00:00                 1.566667              1419.207662
# 2012-11-26 16:00:00                 0.025000              1143.615576
#
#                      Avg_CCS1_ANPs_psi  Avg_CCS1_DH6325Ps_psi  \
# SampleTimeUTC
# 2012-11-18 08:00:00         522.013451            3383.554036
# 2012-11-18 09:00:00         510.494516            3385.778632
# 2012-11-18 10:00:00         510.899432            3383.531185
# 2012-11-18 11:00:00         511.896438            3384.563845
# 2012-11-18 12:00:00         510.982277            3385.062998
# 2012-11-26 12:00:00         440.463678            3398.568276
# 2012-11-26 13:00:00         432.052225            3399.234914
# 2012-11-26 14:00:00         513.740069            3400.701626
# 2012-11-26 15:00:00         621.174498            3403.130627
# 2012-11-26 16:00:00         561.435533            3111.476807
#
#                      Avg_VW1_WBTbgPs_psi  Avg_VW1_Z01D7061Ps_psi  inj_diff
# SampleTimeUTC
# 2012-11-18 08:00:00          2329.030835             3320.276693         0
# 2012-11-18 09:00:00          2329.015361             3320.269031         0
# 2012-11-18 10:00:00          2329.055794             3320.298985         0
# 2012-11-18 11:00:00          2329.133431             3320.306563         0
# 2012-11-18 12:00:00          2329.147909             3320.344305         0
# 2012-11-26 12:00:00          2327.606797             3321.700452         0
# 2012-11-26 13:00:00          2327.799504             3321.754409         0
# 2012-11-26 14:00:00          2327.909432             3321.721102         0
# 2012-11-26 15:00:00          2327.912443             3321.729205         0
# 2012-11-26 16:00:00          2327.892611             3321.724227         0

# %%
# Get last 30 rows of df_train
last_30_rows = df_clean.tail(29)

# Concatenate last_30_rows with df_test
data2 = pd.concat([last_30_rows, data2], axis=0)

# %%
data2.shape
# Out:
# (230, 7)

# %%
data2.shape
# Out:
# (230, 7)

# %%
df_clean2 = df_clean.copy()

# %%
df_clean2['LSTM Predictions'] = pred_test['LSTM Predictions']

# %%
df_clean2
# Out:
#                      Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00                11.108333               700.605639
# 2009-10-01 01:00:00                11.108333               700.605639
# 2009-10-01 02:00:00                11.108333               700.605639
# 2009-10-01 03:00:00                11.108333               700.605639
# 2009-10-01 04:00:00                11.108333               700.605639
# ...                                      ...                      ...
# 2012-11-18 03:00:00                 0.408333              1409.701282
# 2012-11-18 04:00:00                 0.458333              1409.036129
# 2012-11-18 05:00:00                 0.508333              1408.648841
# 2012-11-18 06:00:00                 0.504202              1406.788722
# 2012-11-18 07:00:00                 0.616667              1407.204333
#
#                      Avg_CCS1_ANPs_psi  Avg_CCS1_DH6325Ps_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00         149.097828            3005.665373
# 2009-10-01 01:00:00         149.097828            3005.665373
# 2009-10-01 02:00:00         149.097828            3005.665373
# 2009-10-01 03:00:00         149.097828            3005.665373
# 2009-10-01 04:00:00         149.097828            3005.665373
# ...                                ...                    ...
# 2012-11-18 03:00:00         530.799145            3385.511261
# 2012-11-18 04:00:00         531.937228            3387.451438
# 2012-11-18 05:00:00         526.400194            3387.077108
# 2012-11-18 06:00:00         532.481976            3387.618129
# 2012-11-18 07:00:00         517.267830            3386.470343
#
#                      Avg_VW1_WBTbgPs_psi  Avg_VW1_Z01D7061Ps_psi  inj_diff  \
# SampleTimeUTC
# 2009-10-01 00:00:00          2173.710958             3216.464494  0.000000
# 2009-10-01 01:00:00          2173.762679             3216.520127  0.000000
# 2009-10-01 02:00:00          2173.754085             3216.510374  0.000000
# 2009-10-01 03:00:00          2173.734355             3216.479380  0.000000
# 2009-10-01 04:00:00          2173.738489             3216.436283  0.000000
# ...                                  ...                     ...       ...
# 2012-11-18 03:00:00          2328.919804             3320.264079 -0.031250
# 2012-11-18 04:00:00          2328.912415             3320.271702 -0.091320
# 2012-11-18 05:00:00          2328.921606             3320.266923 -0.137501
# 2012-11-18 06:00:00          2328.940994             3320.181743  0.037290
# 2012-11-18 07:00:00          2328.994653             3320.304134 -0.080345
#
#                      LSTM Predictions
# SampleTimeUTC
# 2009-10-01 00:00:00               NaN
# 2009-10-01 01:00:00               NaN
# 2009-10-01 02:00:00               NaN
# 2009-10-01 03:00:00               NaN
# 2009-10-01 04:00:00               NaN
# ...                               ...
# 2012-11-18 03:00:00          0.011600
# 2012-11-18 04:00:00          0.053822
# 2012-11-18 05:00:00          0.001995
# 2012-11-18 06:00:00          0.025733
# 2012-11-18 07:00:00          0.006965
#
# [27464 rows x 8 columns]

# %%
#data.drop("inj_diff", axis=1, inplace=True)

# %%
train2 = data2
test2 = data2

x_train2, y_train2 = train2.drop("inj_diff", axis=1).values, train2["inj_diff"].values
x_test2, y_test2 = test2.drop("inj_diff", axis=1).values, test2["inj_diff"].values

train_data2, test_data2 = reshape_data(x_train2, y_train2, x_test2, y_test2)

n_steps_in = 30
# covert into input/output
X2, y2 = split_sequences(train_data2, n_steps_in, n_steps_out)
x_test2, y_test2 = split_sequences(test_data2, n_steps_in, n_steps_out)
print ("X2.shape" , X2.shape) 
print ("y2.shape" , y2.shape)

n_features = X2.shape[2]
# Out:
# train dataset_stacked.shape (230, 7)
# test dataset_stacked.shape (230, 7)
# X2.shape (201, 30, 6)
# y2.shape (201, 1)

# %%
x_test2.shape
# Out:
# (201, 30, 6)

# %%
# make predictions and transform
test_pred2 = scaler.inverse_transform(model.predict(x_test2))
#test_pred = model.predict(x_test)

pred_test2 = test2[(n_steps_in-1):].copy()
pred_test2["LSTM Predictions"] = test_pred2
pred_test2 = pred_test2[["inj_diff", "LSTM Predictions"]]

plot_pred_test2 = pred_test2[["LSTM Predictions"]]

plot_pred_test2.plot(linewidth = 3, fontsize = fontsize, color='red')
plt.xlabel("Time", size = fontsize)
plt.ylabel("Injection Delta", size = fontsize)
plt.legend(fontsize=fontsize, loc ="upper right")
# Out:
# 7/7 [==============================] - 0s 10ms/step

# %%
data2['inj_diff'] = pred_test2["LSTM Predictions"]

# %% [markdown]
# ### We have determined a prediction for the delta injection value

# %%
data2 = data2.drop(data2.index[:29])

data2
# Out:
#                      Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# SampleTimeUTC
# 2012-11-18 08:00:00                 0.825000              1406.469561
# 2012-11-18 09:00:00                 0.641667              1406.399989
# 2012-11-18 10:00:00                 0.633333              1406.588710
# 2012-11-18 11:00:00                 0.633333              1407.000806
# 2012-11-18 12:00:00                 0.458333              1406.682945
# ...                                      ...                      ...
# 2012-11-26 12:00:00                 1.708333              1418.840352
# 2012-11-26 13:00:00                 1.708333              1418.537537
# 2012-11-26 14:00:00                 1.716667              1418.984295
# 2012-11-26 15:00:00                 1.566667              1419.207662
# 2012-11-26 16:00:00                 0.025000              1143.615576
#
#                      Avg_CCS1_ANPs_psi  Avg_CCS1_DH6325Ps_psi  \
# SampleTimeUTC
# 2012-11-18 08:00:00         522.013451            3383.554036
# 2012-11-18 09:00:00         510.494516            3385.778632
# 2012-11-18 10:00:00         510.899432            3383.531185
# 2012-11-18 11:00:00         511.896438            3384.563845
# 2012-11-18 12:00:00         510.982277            3385.062998
# ...                                ...                    ...
# 2012-11-26 12:00:00         440.463678            3398.568276
# 2012-11-26 13:00:00         432.052225            3399.234914
# 2012-11-26 14:00:00         513.740069            3400.701626
# 2012-11-26 15:00:00         621.174498            3403.130627
# 2012-11-26 16:00:00         561.435533            3111.476807
#
#                      Avg_VW1_WBTbgPs_psi  Avg_VW1_Z01D7061Ps_psi  inj_diff
# SampleTimeUTC
# 2012-11-18 08:00:00          2329.030835             3320.276693  0.001340
# 2012-11-18 09:00:00          2329.015361             3320.269031  0.002648
# 2012-11-18 10:00:00          2329.055794             3320.298985  0.000938
# 2012-11-18 11:00:00          2329.133431             3320.306563  0.002184
# 2012-11-18 12:00:00          2329.147909             3320.344305  0.001438
# ...                                  ...                     ...       ...
# 2012-11-26 12:00:00          2327.606797             3321.700452  0.000046
# 2012-11-26 13:00:00          2327.799504             3321.754409  0.000027
# 2012-11-26 14:00:00          2327.909432             3321.721102  0.000677
# 2012-11-26 15:00:00          2327.912443             3321.729205  0.004331
# 2012-11-26 16:00:00          2327.892611             3321.724227 -0.061108
#
# [201 rows x 7 columns]

# %%
#df_clean = df_clean.rename(columns={'inj_diff': 'inj_diff'})
df_clean
# Out:
#                      Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00                11.108333               700.605639
# 2009-10-01 01:00:00                11.108333               700.605639
# 2009-10-01 02:00:00                11.108333               700.605639
# 2009-10-01 03:00:00                11.108333               700.605639
# 2009-10-01 04:00:00                11.108333               700.605639
# ...                                      ...                      ...
# 2012-11-18 03:00:00                 0.408333              1409.701282
# 2012-11-18 04:00:00                 0.458333              1409.036129
# 2012-11-18 05:00:00                 0.508333              1408.648841
# 2012-11-18 06:00:00                 0.504202              1406.788722
# 2012-11-18 07:00:00                 0.616667              1407.204333
#
#                      Avg_CCS1_ANPs_psi  Avg_CCS1_DH6325Ps_psi  \
# SampleTimeUTC
# 2009-10-01 00:00:00         149.097828            3005.665373
# 2009-10-01 01:00:00         149.097828            3005.665373
# 2009-10-01 02:00:00         149.097828            3005.665373
# 2009-10-01 03:00:00         149.097828            3005.665373
# 2009-10-01 04:00:00         149.097828            3005.665373
# ...                                ...                    ...
# 2012-11-18 03:00:00         530.799145            3385.511261
# 2012-11-18 04:00:00         531.937228            3387.451438
# 2012-11-18 05:00:00         526.400194            3387.077108
# 2012-11-18 06:00:00         532.481976            3387.618129
# 2012-11-18 07:00:00         517.267830            3386.470343
#
#                      Avg_VW1_WBTbgPs_psi  Avg_VW1_Z01D7061Ps_psi  inj_diff
# SampleTimeUTC
# 2009-10-01 00:00:00          2173.710958             3216.464494  0.000000
# 2009-10-01 01:00:00          2173.762679             3216.520127  0.000000
# 2009-10-01 02:00:00          2173.754085             3216.510374  0.000000
# 2009-10-01 03:00:00          2173.734355             3216.479380  0.000000
# 2009-10-01 04:00:00          2173.738489             3216.436283  0.000000
# ...                                  ...                     ...       ...
# 2012-11-18 03:00:00          2328.919804             3320.264079 -0.031250
# 2012-11-18 04:00:00          2328.912415             3320.271702 -0.091320
# 2012-11-18 05:00:00          2328.921606             3320.266923 -0.137501
# 2012-11-18 06:00:00          2328.940994             3320.181743  0.037290
# 2012-11-18 07:00:00          2328.994653             3320.304134 -0.080345
#
# [27464 rows x 7 columns]

# %%
dfmer = pd.concat([df_clean, data2], axis=0)

# %%
print(df_clean.shape)
print(data2.shape)
print(dfmer.shape)
# Out:
# (27464, 7)
# (201, 7)
# (27665, 7)

# %%
dfmer.index
# Out:
# DatetimeIndex(['2009-10-01 00:00:00', '2009-10-01 01:00:00',
#                '2009-10-01 02:00:00', '2009-10-01 03:00:00',
#                '2009-10-01 04:00:00', '2009-10-01 05:00:00',
#                '2009-10-01 06:00:00', '2009-10-01 07:00:00',
#                '2009-10-01 08:00:00', '2009-10-01 09:00:00',
#                ...
#                '2012-11-26 07:00:00', '2012-11-26 08:00:00',
#                '2012-11-26 09:00:00', '2012-11-26 10:00:00',
#                '2012-11-26 11:00:00', '2012-11-26 12:00:00',
#                '2012-11-26 13:00:00', '2012-11-26 14:00:00',
#                '2012-11-26 15:00:00', '2012-11-26 16:00:00'],
#               dtype='datetime64[ns]', name='SampleTimeUTC', length=27665, freq='H')

# %%
last_6_months = dfmer.tail(12*30)
last_6_months['inj_diff'].plot(linewidth=3, fontsize=fontsize, color='red')
plt.xlabel("Time", size=fontsize)
plt.ylabel("Injection Delta", size=fontsize)
plt.legend(fontsize=fontsize, loc="upper right")
# Set the y-axis limit
plt.ylim([-0.2, 0.2])

# Display the plot
plt.show()

# %%
last_6_months = dfmer.tail(12*30)
last_6_months['Avg_PLT_CO2VentRate_TPH'].plot(linewidth=3, fontsize=fontsize, color='red')
plt.xlabel("Time", size=fontsize)
plt.ylabel("Injection Delta", size=fontsize)
plt.legend(fontsize=fontsize, loc="upper right")

# %% [raw]
# # Conclusion

# %%
base_filename = 'Final_output'
csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
plot_pred_test2.to_csv(csvs_sht, index = True, header = True)
print ("File exported:", base_filename + "." + filename_suffix)
# Out:
# File exported: Final_output.csv

# %%
count = 'Completed Process'
elapsed = (time.time() - start)
print ("%s in %s seconds" % (count,elapsed))
# Out:
# Completed Process in 4868.76669883728 seconds

# %% [markdown]
# Submission
#
# Once the machine learning model is developed and evaluated, contestants submit the ML code to an SPEMLChallenge@gmail.com.  The results are submitted to the XEEK.org platform for preliminary scoring.
