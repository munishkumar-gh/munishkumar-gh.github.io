# %% [markdown]
# <a href="https://www.staatsolie.com/"><img src = "https://upload.wikimedia.org/wikipedia/commons/9/9e/Logo_-_Staatsolie_Maatschappij_Suriname.png" width = 400>
#
# <h1 align=center><font size = 5>Core Analysis - Prospect and Lead Inventory </font></h1>

# %% [markdown]
# <h1 align=center><font size = 4> Munish Kumar </font></h1>
# <h1 align=center><font size = 4> P5947_Lead_and_Prospect_Inventory_for_Staatsolie </font></h1>
# <h1 align=center><font size = 3> ERCE 2022 </font></h1>

# %% [markdown]
# #### Libraries

# %%
# Only install the following libraries if you dont have it, otherwise leave it commented out

#!conda install -c anaconda natsort --yes
#!conda install -c anaconda xlrd --yes
#!pip install sympy --user

# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
import time
import re
import requests
import pickle
import seaborn as sns
import os
import glob
import sys
from natsort import natsorted
sns.set()

# Sklearn Liraries
from sklearn import preprocessing

# For Latex style text
from sympy import S, symbols, printing

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

# Forces the print statement to show everything and not truncate
# np.set_printoptions(threshold=sys.maxsize) 
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# ###### Declare some global variables

# %%
dir_name = r'C:\Users\mkumar\Documents\GitHub\CoreData_Suriname'
filename_suffix = 'csv'

# Font, marker size and axis rotation
edgecolors = 'black'
markersize = 16
alpha = 0.5
size = 18
rotation = 0

# %% [markdown]
# ###### Series of Functions

# %%
# Function to look at first 5 and last 5 elements in a dataframe
def ends(df, x=5):
    return df.head(x).append(df.tail(x))
setattr(pd.DataFrame,'ends',ends)

# %%
# Function to read out file
def file_out(df, dir_name, base_filename, filename_suffix):
    try:
        csvs_sht = os.path.join(dir_name, base_filename + "." + filename_suffix)
        df.to_csv(csvs_sht, index = False, header=True)
        print ("Final File Extract Produced")
    except IOError:
        print("I/O error")
    return

# %%
# Function to search for a text string
def search_words(text):
    result = re.findall(r'\b[^\d\W]+\b', text)
    return " ".join(result)

# %%
# Function to plot grain density
def plot_grain_density(mod_df, title, bins, xmin, xmax, savefn):
    sns.set()
    sns.set_style("whitegrid")     
    sns.set_style("ticks", 
                  {"xtick.major.size":size,
                  "ytick.major.size":size}
                 )
    sns.axes_style("whitegrid")
    kwargs = {'cumulative': True}

    ax = sns.distplot(mod_df, 
                      bins = bins, 
                      kde=False, 
                      norm_hist=False, 
                      color = 'r',
                      #bw_adjust=.25,
                      #hist_kws=kwargs, 
                      #kde_kws=kwargs
                     )

    ax.set(ylabel='Frequency', 
           #xlabel='common ylabel',
           xlim = (xmin, xmax),
          )

    ax.legend(labels=['Histogram', 'Frequency'])
    plt.title(title)
    plt.grid(True)

    plt.savefig(savefn, transparent=True)
    return

# %%
# Plotting the effect of NOBP
def plot_NOBP(mod_df, df_sub, grouped, color, savefn):
    # Plot per group
    fig = plt.figure(figsize=(14, 8))
    ax = fig.add_subplot(121)

    for i, (name, group) in enumerate(grouped):
        sc = ax.scatter(
            group["NOB (psi)"],
            group["Porosity (%)"],
            s = markersize**2,
            alpha=0.5,
            label=name,
            edgecolors = edgecolors,
        )  

    # Add legends (one for gender, other for size)
    ax.add_artist(ax.legend(title='Well Name'))
    ax.legend(*sc.legend_elements("colors", num=6))
    ax.set_xlabel('Net Overburden Pressure (psi)', fontsize=size)
    ax.set_ylabel('Porosity (%)', fontsize=size)

    plt.xticks(rotation = rotation, fontsize=size)
    plt.yticks(rotation = rotation, fontsize=size)
    plt.ylim(0,20) 
    plt.grid(True)
    
    ax1 = fig.add_subplot(122)

    for i, (name, group) in enumerate(grouped):
        sc1 = ax1.scatter(
            group["NOB (psi)"],
            group["K_klin (mD)"],
            s = markersize**2,
            alpha=0.5,
            label=name,
            edgecolors = edgecolors,
        )  

    # Add legends 
    ax1.add_artist(ax1.legend(title='Well Name'))
    ax1.legend(*sc1.legend_elements("colors", num=6))
    ax1.set_xlabel('Net Overburden Pressure (psi)', fontsize=size)
    ax1.set_ylabel('Permeability (mD)', fontsize=size)

    plt.xticks(rotation = rotation, fontsize=size)
    plt.yticks(rotation = rotation, fontsize=size)
    #plt.ylim(0,20)

    plt.tight_layout()
    plt.grid(True)

    plt.savefig(savefn, transparent=True)
    return

# %%
def plot_PP(mod_df, df_sub, grouped, color, title, savefn, xint1, yint1, xint2, yint2):
    fig = plt.figure(figsize=(14, 8))
    ax = fig.add_subplot(111)

    for i, (name, group) in enumerate(grouped):
        sc = ax.scatter(
            group["Porosity (%)"],
            group["K_air (mD)"],
            s = markersize**2,
            alpha=0.5,
            label=name,
            edgecolors = edgecolors,
        )  

    # Add legends
    ax.add_artist(ax.legend(title='Well Name'))
    ax.legend(*sc.legend_elements("colors", num=6), prop={'size': 20})
    ax.set_xlabel('Porosity (%)', fontsize=size)
    ax.set_ylabel('Permeability (mD)', fontsize=size)

    plt.xticks(rotation = rotation, fontsize=size)
    plt.yticks(rotation = rotation, fontsize=size)
    plt.xlim(0,45)
    plt.ylim(0.001,10000)

    # Fit to linear-log
    y1 = df_sub["Porosity (%)"] # x-value
    y2 = df_sub["K_air (mD)"] #y-value
    
    # For fitting y = Ae^(Bx), log y = log A + Bx. So fit (log y) against x.
    #p = np.polyfit(y1, np.log(y2), 1, w=np.sqrt(y2)) # w is weight to bias against larger values of y
    #p = np.polyfit(y1, np.log(y2), 1)
    #f = np.poly1d(p)

    #ax.semilogy(y1, np.exp(p[0] * y1 + p[1]), 'k--', linewidth = 2.5)
    ax.set_yscale('log')

    #Display Equation
    #plt.text(16, 10, r'Equation ={}'.format(f), fontsize = size,bbox=dict(facecolor='white', alpha=0.25))
    #plt.title (title, fontsize = size)

    # here we add the vertical and horizontal line 1
    plt.axvline(x=xint1, color='darkorange',linestyle='--',linewidth=2)
    plt.axhline(y=yint1, color='darkorange',linestyle='--',linewidth=2)
    
    # here we add the horizontal and horizontal line 2
    plt.axvline(x=xint2, color='darkgreen',linestyle=':',linewidth=2)
    plt.axhline(y=yint2, color='darkgreen',linestyle=':',linewidth=2)

    plt.tight_layout()
    plt.grid(True)
    
    plt.savefig(savefn, transparent=True)
    return

# %% [markdown]
# ##### Read in the data and some preprocessing

# %%
# Header file comes preformatted as 1st row is variable name, 2nd row reads "Low, Best, High"
# Combines the first 2 rows of header into 1 header

df = pd.read_excel(
    'CoreData_Suriname.xlsx', 
    header=[0, 1], 
    sheet_name='MASTER', 
    keep_default_na=False,
    #usecols="A,C:AA"
)
df.columns=df.columns.to_flat_index()

# renaming the columns
df.columns = ['Well Name', 'Sample ID', 'Depth (m)', 'NOB (psi)', 'K_air (mD)', 'Porosity (%)', 'Grain Density (g/cc)', 'Core Type']
df.ends(10)
# Out:
# C:\Users\mkumar\AppData\Local\Temp\ipykernel_124764\3237448987.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return df.head(x).append(df.tail(x))
#    Well Name Sample ID  Depth (m)  NOB (psi)  K_air (mD)  Porosity (%)  \
# 0      CRC-1        1a    2747.00       14.7   2250.0000          25.1
# 1      CRC-1        2a    2817.00       14.7    353.0000          21.5
# 2      CRC-1        3a    2874.00       14.7    551.0000          23.6
# 3      CRC-1        4a    3075.00       14.7    285.0000          18.4
# 4      CRC-1        5a    3104.00       14.7    134.0000          23.6
# 5      CRC-1        6a    3174.00       14.7     22.9000          18.8
# 6      CRC-1        7a    3208.00       14.7    158.0000          14.6
# 7      CRC-1        8a    3254.00       14.7      0.0041           4.0
# 8      CRC-1        9a    3313.00       14.7   1970.0000          20.6
# 9      CRC-1       10a    3336.00       14.7      1.3200          15.1
# 55     ARA-1         4    2365.50       14.7      0.1600          29.8
# 56     ARA-1         5    2367.08       14.7      0.0001          28.4
# 57     ARA-1         6    2372.40       14.7      0.3400          32.4
# 58     ARA-1         7    2379.70       14.7      1.5000          27.5
# 59     ARA-1         8    2410.00       14.7      0.0001          23.1
# 60     ARA-1         9    2458.80       14.7      0.7200          29.8
# 61     ARA-1        10    2460.70       14.7      0.0001          26.8
# 62     ARA-1        11    2492.60       14.7      1.3000          40.5
# 63     ARA-1        14    2671.80       14.7      1.7000          15.7
# 64     ARA-1        15    2673.00       14.7      3.5000          12.0
#
#     Grain Density (g/cc)  Core Type
# 0                   0.00          0
# 1                   0.00          0
# 2                   0.00          0
# 3                   0.00          0
# 4                   0.00          0
# 5                   0.00          0
# 6                   0.00          0
# 7                   0.00          0
# 8                   0.00          0
# 9                   0.00          0
# 55                  2.18          0
# 56                  2.22          0
# 57                  2.18          0
# 58                  2.27          0
# 59                  2.36          0
# 60                  2.22          0
# 61                  2.26          0
# 62                  2.19          0
# 63                  2.69          0
# 64                  2.69          0

# %% [markdown]
# ##### Remove Missing Rows based on Missing Permeability and Porosity Values

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)

cols = ['K_air (mD)', 'Porosity (%)']

mod_df = df.dropna(how='any', subset=cols)
mod_df = df[df['K_air (mD)'] > 0.01]
mod_df
# Out:
#       Well Name Sample ID  Depth (m)  NOB (psi)  K_air (mD)  Porosity (%)  \
# 0         CRC-1        1a    2747.00       14.7    2250.000     25.100000
# 1         CRC-1        2a    2817.00       14.7     353.000     21.500000
# 2         CRC-1        3a    2874.00       14.7     551.000     23.600000
# 3         CRC-1        4a    3075.00       14.7     285.000     18.400000
# 4         CRC-1        5a    3104.00       14.7     134.000     23.600000
# 5         CRC-1        6a    3174.00       14.7      22.900     18.800000
# 6         CRC-1        7a    3208.00       14.7     158.000     14.600000
# 8         CRC-1        9a    3313.00       14.7    1970.000     20.600000
# 9         CRC-1       10a    3336.00       14.7       1.320     15.100000
# 11        CRC-1       12a    3486.00       14.7      81.300     16.300000
# 12        CRC-1       13a    3619.00       14.7     726.000     23.300000
# 13  Pontoenoe-1       1a1    5493.00       14.7       0.028     14.770000
# 15  Pontoenoe-1       3a1    5576.99       14.7       0.193     14.510000
# 23  Pontoenoe-1      11a1    6076.96       14.7       0.029     17.400000
# 29  Pontoenoe-1      17a1    6128.50       14.7      67.500     21.810000
# 31  Pontoenoe-1      19a1    6135.30       14.7       1.240     13.770000
# 34  Pontoenoe-1      22a1    6148.82       14.7    2310.000     29.240000
# 35  Pontoenoe-1      23a1    6155.00       14.7     210.000     24.590000
# 36  Pontoenoe-1      24a1    6160.02       14.7     583.000     24.250000
# 37  Pontoenoe-1      25a1    6163.00       14.7     296.000     23.370000
# 38  Pontoenoe-1      26a1    6177.50       14.7       0.016     14.810000
# 43    Popokai-1      1-6R    6132.20       14.7       0.040      4.858228
# 44    Popokai-1      1-7R    6152.20       14.7       0.918     17.350220
# 45    Popokai-1      1-8R    6228.30       14.7       1.000     15.985264
# 46    Popokai-1      1-9R    6288.50       14.7       0.023     10.049872
# 47    Popokai-1     1-10R    6337.70       14.7       0.074     11.009196
# 48    Popokai-1     1-11R    6338.00       14.7       0.274     15.360413
# 49    Popokai-1     1-12R    6338.90       14.7       0.037      9.125347
# 50    Popokai-1     1-14R    6344.70       14.7       0.195     14.208509
# 51    Popokai-1     1-15R    6347.90       14.7       0.539     16.697015
# 52    Popokai-1     1-16R    6387.00       14.7       0.269     13.095629
# 53        ARA-1         2    2360.80       14.7       2.100     27.000000
# 54        ARA-1         3    2362.26       14.7       0.220     28.300000
# 55        ARA-1         4    2365.50       14.7       0.160     29.800000
# 57        ARA-1         6    2372.40       14.7       0.340     32.400000
# 58        ARA-1         7    2379.70       14.7       1.500     27.500000
# 60        ARA-1         9    2458.80       14.7       0.720     29.800000
# 62        ARA-1        11    2492.60       14.7       1.300     40.500000
# 63        ARA-1        14    2671.80       14.7       1.700     15.700000
# 64        ARA-1        15    2673.00       14.7       3.500     12.000000
#
#     Grain Density (g/cc)  Core Type
# 0               0.000000          0
# 1               0.000000          0
# 2               0.000000          0
# 3               0.000000          0
# 4               0.000000          0
# 5               0.000000          0
# 6               0.000000          0
# 8               0.000000          0
# 9               0.000000          0
# 11              0.000000          0
# 12              0.000000          0
# 13              2.708000          0
# 15              2.700000          0
# 23              2.693000          0
# 29              2.642000          0
# 31              2.723000          0
# 34              2.635000          0
# 35              2.637000          0
# 36              2.639000          0
# 37              2.640000          0
# 38              2.741000          0
# 43              2.664322          0
# 44              2.627235          0
# 45              2.641432          0
# 46              2.637619          0
# 47              2.635149          0
# 48              2.637713          0
# 49              2.649801          0
# 50              2.626870          0
# 51              2.633881          0
# 52              2.649880          0
# 53              2.200000          0
# 54              2.190000          0
# 55              2.180000          0
# 57              2.180000          0
# 58              2.270000          0
# 60              2.220000          0
# 62              2.190000          0
# 63              2.690000          0
# 64              2.690000          0

# %% [markdown]
# ###### Mapping each well to a colour

# %%
df_colors = pd.read_csv('https://raw.githubusercontent.com/codebrainz/color-names/master/output/colors.csv',header=None)
df_colors.columns = ['color_name', 'color_description', 'hex_value', 'r', 'g','b']

names = mod_df['Well Name'].unique()
c = df_colors[['hex_value']].astype(str).agg(','.join,axis=1).tolist()
colors = dict(zip(names,c))

mod_df['color'] = mod_df['Well Name'].apply(lambda x: colors[x])
mod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 64
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             40 non-null     object
#  1   Sample ID             40 non-null     object
#  2   Depth (m)             40 non-null     float64
#  3   NOB (psi)             40 non-null     float64
#  4   K_air (mD)            40 non-null     float64
#  5   Porosity (%)          40 non-null     float64
#  6   Grain Density (g/cc)  40 non-null     float64
#  7   Core Type             40 non-null     int64
#  8   color                 40 non-null     object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 3.1+ KB
# C:\Users\mkumar\AppData\Local\Temp\ipykernel_124764\949046389.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mod_df['color'] = mod_df['Well Name'].apply(lambda x: colors[x])

# %%
for well in mod_df['Well Name'].unique():
        print(mod_df[mod_df['Well Name'] == well].info())      
        print(mod_df[mod_df['Well Name'] == well].describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             11 non-null     object
#  1   Sample ID             11 non-null     object
#  2   Depth (m)             11 non-null     float64
#  3   NOB (psi)             11 non-null     float64
#  4   K_air (mD)            11 non-null     float64
#  5   Porosity (%)          11 non-null     float64
#  6   Grain Density (g/cc)  11 non-null     float64
#  7   Core Type             11 non-null     int64
#  8   color                 11 non-null     object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 880.0+ bytes
# None
#        Well Name Sample ID    Depth (m)     NOB (psi)   K_air (mD)  \
# count         11        11    11.000000  1.100000e+01    11.000000
# unique         1        11          NaN           NaN          NaN
# top        CRC-1        1a          NaN           NaN          NaN
# freq          11         1          NaN           NaN          NaN
# mean         NaN       NaN  3159.363636  1.470000e+01   593.865455
# std          NaN       NaN   274.629304  3.726118e-15   784.253077
# min          NaN       NaN  2747.000000  1.470000e+01     1.320000
# 25%          NaN       NaN  2974.500000  1.470000e+01   107.650000
# 50%          NaN       NaN  3174.000000  1.470000e+01   285.000000
# 75%          NaN       NaN  3324.500000  1.470000e+01   638.500000
# max          NaN       NaN  3619.000000  1.470000e+01  2250.000000
#
#         Porosity (%)  Grain Density (g/cc)  Core Type    color
# count      11.000000                  11.0       11.0       11
# unique           NaN                   NaN        NaN        1
# top              NaN                   NaN        NaN  #5d8aa8
# freq             NaN                   NaN        NaN       11
# mean       20.081818                   0.0        0.0      NaN
# std         3.690750                   0.0        0.0      NaN
# min        14.600000                   0.0        0.0      NaN
# 25%        17.350000                   0.0        0.0      NaN
# 50%        20.600000                   0.0        0.0      NaN
# 75%        23.450000                   0.0        0.0      NaN
# max        25.100000                   0.0        0.0      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 13 to 38
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             10 non-null     object
#  1   Sample ID             10 non-null     object
#  2   Depth (m)             10 non-null     float64
#  3   NOB (psi)             10 non-null     float64
#  4   K_air (mD)            10 non-null     float64
#  5   Porosity (%)          10 non-null     float64
#  6   Grain Density (g/cc)  10 non-null     float64
#  7   Core Type             10 non-null     int64
#  8   color                 10 non-null     object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 800.0+ bytes
# None
#           Well Name Sample ID    Depth (m)     NOB (psi)   K_air (mD)  \
# count            10        10    10.000000  1.000000e+01    10.000000
# unique            1        10          NaN           NaN          NaN
# top     Pontoenoe-1       1a1          NaN           NaN          NaN
# freq             10         1          NaN           NaN          NaN
# mean            NaN       NaN  6021.509000  1.470000e+01   346.800600
# std             NaN       NaN   258.619264  1.872445e-15   715.662573
# min             NaN       NaN  5493.000000  1.470000e+01     0.016000
# 25%             NaN       NaN  6089.845000  1.470000e+01     0.070000
# 50%             NaN       NaN  6142.060000  1.470000e+01    34.370000
# 75%             NaN       NaN  6158.765000  1.470000e+01   274.500000
# max             NaN       NaN  6177.500000  1.470000e+01  2310.000000
#
#         Porosity (%)  Grain Density (g/cc)  Core Type    color
# count      10.000000             10.000000       10.0       10
# unique           NaN                   NaN        NaN        1
# top              NaN                   NaN        NaN  #00308f
# freq             NaN                   NaN        NaN       10
# mean       19.852000              2.675800        0.0      NaN
# std         5.466302              0.041292        0.0      NaN
# min        13.770000              2.635000        0.0      NaN
# 25%        14.780000              2.639250        0.0      NaN
# 50%        19.605000              2.667500        0.0      NaN
# 75%        24.030000              2.706000        0.0      NaN
# max        29.240000              2.741000        0.0      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 43 to 52
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             10 non-null     object
#  1   Sample ID             10 non-null     object
#  2   Depth (m)             10 non-null     float64
#  3   NOB (psi)             10 non-null     float64
#  4   K_air (mD)            10 non-null     float64
#  5   Porosity (%)          10 non-null     float64
#  6   Grain Density (g/cc)  10 non-null     float64
#  7   Core Type             10 non-null     int64
#  8   color                 10 non-null     object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 800.0+ bytes
# None
#         Well Name Sample ID    Depth (m)     NOB (psi)  K_air (mD)  \
# count          10        10    10.000000  1.000000e+01   10.000000
# unique          1        10          NaN           NaN         NaN
# top     Popokai-1      1-6R          NaN           NaN         NaN
# freq           10         1          NaN           NaN         NaN
# mean          NaN       NaN  6289.540000  1.470000e+01    0.336900
# std           NaN       NaN    88.456332  1.872445e-15    0.364031
# min           NaN       NaN  6132.200000  1.470000e+01    0.023000
# 25%           NaN       NaN  6243.350000  1.470000e+01    0.048500
# 50%           NaN       NaN  6337.850000  1.470000e+01    0.232000
# 75%           NaN       NaN  6343.250000  1.470000e+01    0.472750
# max           NaN       NaN  6387.000000  1.470000e+01    1.000000
#
#         Porosity (%)  Grain Density (g/cc)  Core Type    color
# count      10.000000             10.000000       10.0       10
# unique           NaN                   NaN        NaN        1
# top              NaN                   NaN        NaN  #72a0c1
# freq             NaN                   NaN        NaN       10
# mean       12.773969              2.640390        0.0      NaN
# std         3.972158              0.011513        0.0      NaN
# min         4.858228              2.626870        0.0      NaN
# 25%        10.289703              2.634198        0.0      NaN
# 50%        13.652069              2.637666        0.0      NaN
# 75%        15.829051              2.647709        0.0      NaN
# max        17.350220              2.664322        0.0      NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 53 to 64
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             9 non-null      object
#  1   Sample ID             9 non-null      object
#  2   Depth (m)             9 non-null      float64
#  3   NOB (psi)             9 non-null      float64
#  4   K_air (mD)            9 non-null      float64
#  5   Porosity (%)          9 non-null      float64
#  6   Grain Density (g/cc)  9 non-null      float64
#  7   Core Type             9 non-null      int64
#  8   color                 9 non-null      object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 720.0+ bytes
# None
#        Well Name  Sample ID    Depth (m)     NOB (psi)  K_air (mD)  \
# count          9        9.0     9.000000  9.000000e+00    9.000000
# unique         1        9.0          NaN           NaN         NaN
# top        ARA-1        2.0          NaN           NaN         NaN
# freq           9        1.0          NaN           NaN         NaN
# mean         NaN        NaN  2459.651111  1.470000e+01    1.282222
# std          NaN        NaN   129.294814  1.884111e-15    1.084041
# min          NaN        NaN  2360.800000  1.470000e+01    0.160000
# 25%          NaN        NaN  2365.500000  1.470000e+01    0.340000
# 50%          NaN        NaN  2379.700000  1.470000e+01    1.300000
# 75%          NaN        NaN  2492.600000  1.470000e+01    1.700000
# max          NaN        NaN  2673.000000  1.470000e+01    3.500000
#
#         Porosity (%)  Grain Density (g/cc)  Core Type    color
# count       9.000000              9.000000        9.0        9
# unique           NaN                   NaN        NaN        1
# top              NaN                   NaN        NaN  #a32638
# freq             NaN                   NaN        NaN        9
# mean       27.000000              2.312222        0.0      NaN
# std         8.527309              0.215973        0.0      NaN
# min        12.000000              2.180000        0.0      NaN
# 25%        27.000000              2.190000        0.0      NaN
# 50%        28.300000              2.200000        0.0      NaN
# 75%        29.800000              2.270000        0.0      NaN
# max        40.500000              2.690000        0.0      NaN

# %%
print(mod_df.info())
print(mod_df.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 64
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Well Name             40 non-null     object
#  1   Sample ID             40 non-null     object
#  2   Depth (m)             40 non-null     float64
#  3   NOB (psi)             40 non-null     float64
#  4   K_air (mD)            40 non-null     float64
#  5   Porosity (%)          40 non-null     float64
#  6   Grain Density (g/cc)  40 non-null     float64
#  7   Core Type             40 non-null     int64
#  8   color                 40 non-null     object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 3.1+ KB
# None
#        Well Name Sample ID   Depth (m)  NOB (psi)   K_air (mD)  Porosity (%)  \
# count         40        40    40.00000       40.0    40.000000     40.000000
# unique         4        40         NaN        NaN          NaN           NaN
# top        CRC-1        1a         NaN        NaN          NaN           NaN
# freq          11         1         NaN        NaN          NaN           NaN
# mean         NaN       NaN  4500.00875       14.7   250.385875     19.753992
# std          NaN       NaN  1709.49335        0.0   584.731644      7.320309
# min          NaN       NaN  2360.80000       14.7     0.016000      4.858228
# 25%          NaN       NaN  2799.50000       14.7     0.213750     14.727500
# 50%          NaN       NaN  4556.00000       14.7     1.310000     17.900000
# 75%          NaN       NaN  6160.76500       14.7   171.000000     24.335000
# max          NaN       NaN  6387.00000       14.7  2310.000000     40.500000
#
#         Grain Density (g/cc)  Core Type    color
# count              40.000000       40.0       40
# unique                   NaN        NaN        4
# top                      NaN        NaN  #5d8aa8
# freq                     NaN        NaN       11
# mean                1.849298        0.0      NaN
# std                 1.166044        0.0      NaN
# min                 0.000000        0.0      NaN
# 25%                 0.000000        0.0      NaN
# 50%                 2.630558        0.0      NaN
# 75%                 2.643950        0.0      NaN
# max                 2.741000        0.0      NaN

# %% [markdown]
# ## Determine Properties based on a particular Net Overburden Pressure (NOBP) value

# %%
a = mod_df['NOB (psi)'].unique()
print(sorted(a))
# Out:
# [14.7]

# %% [markdown]
# Some of the net overburden values are missing. It will be assumed that these are ambient values i.e. 800 psi

# %%
mod_df['NOB (psi)'].fillna(14.7, inplace=True)
mod_df['NOB (psi)'].isnull().values.any()
# Out:
# C:\Users\mkumar\AppData\Local\Temp\ipykernel_124764\374934801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mod_df['NOB (psi)'].fillna(14.7, inplace=True)
# False

# %%
NOBP = 800

df_sub = mod_df[mod_df['NOB (psi)'] <= NOBP]
grouped = df_sub.groupby("Well Name")
color = df_sub['color']

# %% [markdown]
# #### Histogram - Plotting the Grain Density, Porosity and Permeability at Ambient (800 psi)

# %%
savefn = "Hist_GD_800.png"

# fuction to plot - usage
# plot_grain_density (dataframe_column, plot_title, number_bins, x-axis_min, x_axis_max savefile_name)

plot_grain_density(df_sub['Grain Density (g/cc)'], "Grain Density (Ambient)", 100, 2, 3, savefn)
# Out:
# C:\Users\mkumar\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
savefn = "Hist_Poro_800.png"
plot_grain_density(df_sub["Porosity (%)"], "Porosity (%) (Ambient)", 20, 0, 35, savefn)

# %%
savefn = "Hist_Perm_800.png"

x= df_sub["K_air (mD)"]

logbins = np.geomspace(x.min(), x.max(), 20)
plot_grain_density(df_sub["K_air (mD)"], "Permeability (mD) (Ambient)", logbins, 0.01, x.max()+1000, savefn)
plt.xscale('log')

# %% [markdown]
# #### Plot cross-plot of Porosity-Permeability

# %%
savefn = "Poro_Perm_800.png"

#Cutoff intercept
yint1 = 1
xint1 = 14

yint2 = 0.1
xint2 = 11

plot_PP(mod_df, df_sub, grouped, color, "Ambient Porosity vs Permeability", savefn, xint1, yint1, xint2, yint2)
# Out:
# C:\Users\mkumar\Anaconda3\lib\site-packages\matplotlib\collections.py:1039: UserWarning: Collection without array used. Make sure to specify the values to be colormapped via the `c` argument.
#   warnings.warn("Collection without array used. Make sure to "

# %% [markdown]
# ##### Cross-plot for values not at NOBP of 800 psi

# %%
# df_sub = mod_df[mod_df['NOB (psi)'] > NOBP]
# grouped = df_sub.groupby("Well Name")
# color = df_sub['color']

# %%
# savefn = "Hist_GD_not_800.png"

# # fuction to plot - usage
# # plot_grain_density (dataframe_column, plot_title, number_bins, x-axis_min, x_axis_max savefile_name)

# plot_grain_density(df_sub['Grain Density (g/cc)'], "Grain Density (>800 psi)", 20, 2.6, 2.8, savefn)

# %%
# savefn = "Hist_Poro_not_800.png"
# plot_grain_density(df_sub["Porosity (%)"], "Porosity (%) (>800 psi)", 20, 0, 30, savefn)

# %%
# savefn = "Hist_Perm_not_800.png"
# plot_grain_density(df_sub["K_klin (mD)"], "Permeability (mD) (>800 psi)", 100, 0, 50, savefn)

# %%
# savefn = "Poro_Perm_not_800.png"

# #Cutoff intercept
# yint1 = 1
# xint1 = 6.498/0.5204

# yint2 = 0.1
# xint2 = (np.log(0.1)+6.498)/0.5204

# plot_PP(mod_df, df_sub, grouped, color, "Overburden Porosity vs Permeability", savefn, xint1, yint1, xint2, yint2)
