# %% [markdown]
# <a href="https://www.spe.org/events/en/2022/conference/22apog/asia-pacific-oil-and-gas-conference-and-exhibition.html"><img src = "https://www.spe.org/binaries/content/gallery/specms/speevents/organization-logos/spe-logo-2020.png" width = 200>
#
# <h1 align=center><font size = 5>Prediction of Recovery Factor using Machine Learning Methods</font></h1>

# %% [markdown]
# <h1 align=center><font size = 4> Munish Kumar, Kannapan Swaminathan</font></h1>
# <h1 align=center><font size = 4> Part 4: Modelling of Recovery Factor</font></h1>
# <h1 align=center><font size = 3> ERCE 2022 </font></h1>

# %% [markdown]
# ###### References

# %% [markdown]
# 1. https://www.kaggle.com/code/kkhandekar/an-introduction-to-pycaret/notebook.
# 2. https://towardsdatascience.com/5-things-you-dont-know-about-pycaret-528db0436eec
# 3. https://www.dataquest.io/blog/understanding-regression-error-metrics/
# 4. https://www.analyticsvidhya.com/blog/2021/07/automl-using-pycaret-with-a-regression-use-case/
# 5. https://www.datacamp.com/community/tutorials/guide-for-automating-ml-workflows-using-pycaret
# 6. https://pycaret.readthedocs.io/en/latest/api/regression.html
# 7. http://www.pycaret.org/tutorials/html/REG102.html
# 8. https://githubhelp.com/ray-project/tune-sklearn

# %% [markdown]
# #### Libraries

# %%
# Only install the following libraries if you dont have it, otherwise leave it commented out

#!conda install -c anaconda natsort --yes
#!conda install -c anaconda xlrd --yes

#!pip install natsort --user
#!pip install xlrd --user
#!pip install pycaret[full] --user
#!pip install mlflow --user
#!pip install tune-sklearn ray[tune] --user
#!pip install optuna -- user
#!pip install hyperopt --user
#!pip install redis --user

# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
import time
import re
import requests
import pickle
import seaborn as sns
import os
import glob
import sys
from natsort import natsorted
sns.set()

import plotly.graph_objects as go
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# Sklearn Liraries
from sklearn import preprocessing

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

import ray
from ray import tune

# Forces the print statement to show everything and not truncate
# np.set_printoptions(threshold=sys.maxsize) 
print('Libraries imported')
# Out:
# Libraries imported

# %%
#Receive Data
#dir_name = r'C:\Users\kswaminathan\OneDrive\01_KannaLibrary\15_Analogs'
dir_name = r'C:\Users\mkumar\Documents\GitHub\SPE_Paper\Final'
filename_suffix = 'csv'

# %% [markdown]
# ##### Read in the data

# %%
skiprows = 0
#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
df = pd.read_excel("dfssoil.xlsx", thousands=',', skiprows = skiprows)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')] 
df.head()
# Out:
#      10_Region      11_Basin name  52_Well spacing (average) (ac)  \
# 0       AFRICA       ABU GHARADIG                           140.0
# 1       AFRICA       ABU GHARADIG                           140.0
# 2  MIDDLE EAST             ZAGROS                             0.0
# 3  MIDDLE EAST    SOUTH OMAN SALT                            62.0
# 4       EUROPE  NORTH SEA CENTRAL                             0.0
#
#   72_Onshore or offshore  75_Temperature (original) (deg. F)  \
# 0                ONSHORE                               232.0
# 1                ONSHORE                               250.0
# 2                ONSHORE                               190.0
# 3                ONSHORE                               212.0
# 4               OFFSHORE                               172.0
#
#    77_Pressure (original) (psi) 82_Drive mechanism (main)  \
# 0                   4500.000000                 GAS DRIVE
# 1                   4600.000000                 GAS DRIVE
# 2                   4452.278385             AQUIFER DRIVE
# 3                  11600.000000                 GAS DRIVE
# 4                   2850.000000                 GAS DRIVE
#
#    117_Reservoir top subsea depth (ft TVDSS)  \
# 0                                     9350.0
# 1                                     9650.0
# 2                                     7500.0
# 3                                    12140.0
# 4                                     6102.0
#
#    118_Structural flank dip (average) (deg.)  149_Reservoir period  ...  \
# 0                                       15.0            CRETACEOUS  ...
# 1                                       15.0            CRETACEOUS  ...
# 2                                       20.0     NEOGENE/PALEOGENE  ...
# 3                                       10.0  CAMBRIAN/PROTEROZOIC  ...
# 4                                        1.5             PALEOGENE  ...
#
#   161_Reservoir architecture (main) 176_Net/gross ratio (average)  \
# 0                     JIGSAW-PUZZLE                          0.10
# 1                     JIGSAW-PUZZLE                          0.07
# 2                        LAYER-CAKE                          0.36
# 3                        LAYER-CAKE                          0.68
# 4                         TANK LIKE                          0.80
#
#    204_Porosity (matrix average) (%)  210_Permeability (air average) (mD)  \
# 0                               21.0                               140.00
# 1                               16.0                               140.00
# 2                               19.0                               385.00
# 3                               17.0                                 0.01
# 4                               35.0                              3000.00
#
#    218_API gravity (average) (deg. API)  225_Viscosity (oil average) (cp)  \
# 0                                  40.5                         13.810000
# 1                                  40.0                          4.740000
# 2                                  32.6                          0.580000
# 3                                  48.0                          0.135469
# 4                                  19.5                          7.000000
#
#    252_GOR (initial average) (SCF/STB)  \
# 0                                850.0
# 1                                800.0
# 2                                950.0
# 3                                410.0
# 4                                246.0
#
#    293_Original in-place oil equivalent (MMBOE)  \
# 0                                         166.0
# 1                                         214.0
# 2                                       57300.0
# 3                                        1321.0
# 4                                        1000.0
#
#    307_Recovery factor (ultimate oil) (%)  EORIOR
# 0                                    19.0       2
# 1                                    14.0       2
# 2                                    44.3       3
# 3                                     7.0       4
# 4                                    44.0       7
#
# [5 rows x 21 columns]

# %%
# Plot as Heat map to check for highly correlated variables
plt.figure(figsize=(10, 10))
ax = sns.heatmap(df.corr(), annot=True, fmt=".2f")

# %% [markdown]
# In observing the heat map above, I define highly correlated variables as having collinearity coeeficients of > 0.7. Therefore,
#
# 1. 75_ Temperature is highly correlatable to 117_Reservoir top subsea depth
# 2. 77_Pressure is highly correlatable to  117_Reservoir top subsea depth
#
# As high collinear variables do not add any additional information when it comes to predictive modelling, I will drop "117_Reservoir top subsea depth" and recreate the heat map to check for correlation.
#
# Note that dropping the variables makes sense, as reservoir top subsea depth should be physically linked to pressure and temperature in a reservoir

# %%
df_drop = df.drop(['117_Reservoir top subsea depth (ft TVDSS)',
                  ], axis = 1)
plt.figure(figsize=(10, 10))
ax = sns.heatmap(df_drop.corr(), annot=True, fmt=".2f")

# %% [markdown]
# ##### Drop Structural Flank Dip - does not make much difference to the results and is a difficult input to find for fields

# %%
df_drop = df_drop.drop(['118_Structural flank dip (average) (deg.)',
                  ], axis = 1)
plt.figure(figsize=(10, 10))
ax = sns.heatmap(df_drop.corr(), annot=True, fmt=".2f")

# %% [markdown]
# ##### Convert EORIOR to float - to ensure it is a numerical feature

# %%
df_drop['EORIOR'] = df_drop['EORIOR'].astype(float)

# Confirm properties of final dataframe
print(len(df_drop))
print(df_drop.info())
print(df_drop.describe(include='all'))
print(df_drop.columns.values)
# Out:
# 436
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436 entries, 0 to 435
# Data columns (total 19 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   10_Region                                     436 non-null    object
#  1   11_Basin name                                 436 non-null    object
#  2   52_Well spacing (average) (ac)                436 non-null    float64
#  3   72_Onshore or offshore                        436 non-null    object
#  4   75_Temperature (original) (deg. F)            436 non-null    float64
#  5   77_Pressure (original) (psi)                  436 non-null    float64
#  6   82_Drive mechanism (main)                     436 non-null    object
#  7   149_Reservoir period                          436 non-null    object
#  8   153_Depositional system (main)                436 non-null    object
#  9   161_Reservoir architecture (main)             436 non-null    object
#  10  176_Net/gross ratio (average)                 436 non-null    float64
#  11  204_Porosity (matrix average) (%)             436 non-null    float64
#  12  210_Permeability (air average) (mD)           436 non-null    float64
#  13  218_API gravity (average) (deg. API)          436 non-null    float64
#  14  225_Viscosity (oil average) (cp)              436 non-null    float64
#  15  252_GOR (initial average) (SCF/STB)           436 non-null    float64
#  16  293_Original in-place oil equivalent (MMBOE)  436 non-null    float64
#  17  307_Recovery factor (ultimate oil) (%)        436 non-null    float64
#  18  EORIOR                                        436 non-null    float64
# dtypes: float64(12), object(7)
# memory usage: 64.8+ KB
# None
#             10_Region       11_Basin name  52_Well spacing (average) (ac)  \
# count             436                 436                      436.000000
# unique              7                 111                             NaN
# top     NORTH AMERICA  NORTH SEA NORTHERN                             NaN
# freq              101                  27                             NaN
# mean              NaN                 NaN                       82.987683
# std               NaN                 NaN                      217.616551
# min               NaN                 NaN                        0.000000
# 25%               NaN                 NaN                        0.000000
# 50%               NaN                 NaN                       30.000000
# 75%               NaN                 NaN                       89.250000
# max               NaN                 NaN                     3700.000000
#
#        72_Onshore or offshore  75_Temperature (original) (deg. F)  \
# count                     436                          436.000000
# unique                      3                                 NaN
# top                   ONSHORE                                 NaN
# freq                      270                                 NaN
# mean                      NaN                          174.952730
# std                       NaN                           54.010637
# min                       NaN                           31.000000
# 25%                       NaN                          138.750000
# 50%                       NaN                          173.512904
# 75%                       NaN                          208.055632
# max                       NaN                          334.000000
#
#         77_Pressure (original) (psi) 82_Drive mechanism (main)  \
# count                     436.000000                       436
# unique                           NaN                         4
# top                              NaN             AQUIFER DRIVE
# freq                             NaN                       245
# mean                     3514.688179                       NaN
# std                      2314.090794                       NaN
# min                        50.000000                       NaN
# 25%                      1825.750000                       NaN
# 50%                      3205.000000                       NaN
# 75%                      4479.000000                       NaN
# max                     13288.000000                       NaN
#
#        149_Reservoir period 153_Depositional system (main)  \
# count                   436                            436
# unique                   23                              6
# top              CRETACEOUS                     24:COASTAL
# freq                    124                            199
# mean                    NaN                            NaN
# std                     NaN                            NaN
# min                     NaN                            NaN
# 25%                     NaN                            NaN
# 50%                     NaN                            NaN
# 75%                     NaN                            NaN
# max                     NaN                            NaN
#
#        161_Reservoir architecture (main)  176_Net/gross ratio (average)  \
# count                                436                     436.000000
# unique                                 7                            NaN
# top                           LAYER-CAKE                            NaN
# freq                                 261                            NaN
# mean                                 NaN                       0.526927
# std                                  NaN                       0.231470
# min                                  NaN                       0.020000
# 25%                                  NaN                       0.350000
# 50%                                  NaN                       0.520000
# 75%                                  NaN                       0.700000
# max                                  NaN                       1.000000
#
#         204_Porosity (matrix average) (%)  \
# count                          436.000000
# unique                                NaN
# top                                   NaN
# freq                                  NaN
# mean                            21.562385
# std                              6.354179
# min                              5.000000
# 25%                             17.000000
# 50%                             21.650000
# 75%                             25.625000
# max                             38.000000
#
#         210_Permeability (air average) (mD)  \
# count                            436.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                             758.015739
# std                             1305.758823
# min                                0.010000
# 25%                               95.250000
# 50%                              300.000000
# 75%                              842.082500
# max                             9000.000000
#
#         218_API gravity (average) (deg. API)  \
# count                             436.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                               32.515619
# std                                 8.891754
# min                                 7.100000
# 25%                                27.975000
# 50%                                34.000000
# 75%                                39.000000
# max                                56.000000
#
#         225_Viscosity (oil average) (cp)  252_GOR (initial average) (SCF/STB)  \
# count                         436.000000                           436.000000
# unique                               NaN                                  NaN
# top                                  NaN                                  NaN
# freq                                 NaN                                  NaN
# mean                          719.906690                           587.607951
# std                          7770.510190                           668.679593
# min                             0.089754                             0.000000
# 25%                             0.590000                           177.750000
# 50%                             1.780000                           393.000000
# 75%                             6.740000                           750.000000
# max                        150000.000000                          5019.000000
#
#         293_Original in-place oil equivalent (MMBOE)  \
# count                                     436.000000
# unique                                           NaN
# top                                              NaN
# freq                                             NaN
# mean                                     4296.730835
# std                                     16570.397736
# min                                         5.000000
# 25%                                       239.750000
# 50%                                       848.000000
# 75%                                      2705.000000
# max                                    213000.000000
#
#         307_Recovery factor (ultimate oil) (%)      EORIOR
# count                               436.000000  436.000000
# unique                                     NaN         NaN
# top                                        NaN         NaN
# freq                                       NaN         NaN
# mean                                 39.093716    4.853211
# std                                  15.033174    1.971408
# min                                   5.500000    0.000000
# 25%                                  29.000000    4.000000
# 50%                                  38.950000    5.000000
# 75%                                  49.000000    6.000000
# max                                  78.400000    9.000000
# ['10_Region' '11_Basin name' '52_Well spacing (average) (ac)'
#  '72_Onshore or offshore' '75_Temperature (original) (deg. F)'
#  '77_Pressure (original) (psi)' '82_Drive mechanism (main)'
#  '149_Reservoir period' '153_Depositional system (main)'
#  '161_Reservoir architecture (main)' '176_Net/gross ratio (average)'
#  '204_Porosity (matrix average) (%)' '210_Permeability (air average) (mD)'
#  '218_API gravity (average) (deg. API)' '225_Viscosity (oil average) (cp)'
#  '252_GOR (initial average) (SCF/STB)'
#  '293_Original in-place oil equivalent (MMBOE)'
#  '307_Recovery factor (ultimate oil) (%)' 'EORIOR']

# %% [markdown]
# Final Data set has 436 rows and 19 columns.

# %% [markdown]
# ## 1. Pycaret Implementation

# %% [markdown]
# Pycaret will be used in the machine learning portion. Pycaret is a low-code machine learning library in Python that automates machine learning workflows. One of its key benefits is its ability to run a large number of differnt machine learning algorithms, but with only a few lines of code

# %%
from pycaret.regression import *

#Create a copy
model_df = df_drop.copy()
target = '307_Recovery factor (ultimate oil) (%)'

# no resampling
clf_none = setup(
            data=model_df,
            target=target,
            session_id=42,
            normalize=True,
            ignore_low_variance=True,
            train_size=0.7)
# Out:
# <style type="text/css">
# #T_1bbd7_row27_col1, #T_1bbd7_row34_col1, #T_1bbd7_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1bbd7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bbd7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bbd7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1bbd7_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1bbd7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1bbd7_row1_col1" class="data row1 col1" >307_Recovery factor (ultimate oil) (%)</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1bbd7_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_1bbd7_row2_col1" class="data row2 col1" >(436, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1bbd7_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_1bbd7_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1bbd7_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_1bbd7_row4_col1" class="data row4 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1bbd7_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_1bbd7_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1bbd7_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_1bbd7_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1bbd7_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_1bbd7_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1bbd7_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_1bbd7_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1bbd7_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_1bbd7_row9_col1" class="data row9 col1" >(305, 154)</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1bbd7_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_1bbd7_row10_col1" class="data row10 col1" >(131, 154)</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1bbd7_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_1bbd7_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1bbd7_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_1bbd7_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1bbd7_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_1bbd7_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1bbd7_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_1bbd7_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1bbd7_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_1bbd7_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1bbd7_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_1bbd7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1bbd7_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_1bbd7_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1bbd7_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_1bbd7_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1bbd7_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_1bbd7_row19_col1" class="data row19 col1" >03bc</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1bbd7_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_1bbd7_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1bbd7_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_1bbd7_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1bbd7_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_1bbd7_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1bbd7_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_1bbd7_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1bbd7_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_1bbd7_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1bbd7_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_1bbd7_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_1bbd7_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_1bbd7_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_1bbd7_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_1bbd7_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_1bbd7_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_1bbd7_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_1bbd7_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_1bbd7_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd7_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_1bbd7_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_28178_ th {
#   text-align: left;
# }
# #T_28178_row0_col0, #T_28178_row1_col0, #T_28178_row1_col1, #T_28178_row1_col2, #T_28178_row1_col3, #T_28178_row1_col4, #T_28178_row1_col5, #T_28178_row1_col6, #T_28178_row2_col0, #T_28178_row2_col1, #T_28178_row2_col2, #T_28178_row2_col3, #T_28178_row2_col4, #T_28178_row2_col5, #T_28178_row2_col6, #T_28178_row3_col0, #T_28178_row3_col1, #T_28178_row3_col2, #T_28178_row3_col3, #T_28178_row3_col4, #T_28178_row3_col5, #T_28178_row3_col6, #T_28178_row4_col0, #T_28178_row4_col1, #T_28178_row4_col2, #T_28178_row4_col3, #T_28178_row4_col4, #T_28178_row4_col5, #T_28178_row4_col6, #T_28178_row5_col0, #T_28178_row5_col1, #T_28178_row5_col2, #T_28178_row5_col3, #T_28178_row5_col4, #T_28178_row5_col5, #T_28178_row5_col6, #T_28178_row6_col0, #T_28178_row6_col1, #T_28178_row6_col2, #T_28178_row6_col3, #T_28178_row6_col4, #T_28178_row6_col5, #T_28178_row6_col6, #T_28178_row7_col0, #T_28178_row7_col1, #T_28178_row7_col2, #T_28178_row7_col3, #T_28178_row7_col4, #T_28178_row7_col5, #T_28178_row7_col6, #T_28178_row8_col0, #T_28178_row8_col1, #T_28178_row8_col2, #T_28178_row8_col3, #T_28178_row8_col4, #T_28178_row8_col5, #T_28178_row8_col6, #T_28178_row9_col0, #T_28178_row9_col1, #T_28178_row9_col2, #T_28178_row9_col3, #T_28178_row9_col4, #T_28178_row9_col5, #T_28178_row9_col6, #T_28178_row10_col0, #T_28178_row10_col1, #T_28178_row10_col2, #T_28178_row10_col3, #T_28178_row10_col4, #T_28178_row10_col5, #T_28178_row10_col6, #T_28178_row11_col0, #T_28178_row11_col1, #T_28178_row11_col2, #T_28178_row11_col3, #T_28178_row11_col4, #T_28178_row11_col5, #T_28178_row11_col6, #T_28178_row12_col0, #T_28178_row12_col1, #T_28178_row12_col2, #T_28178_row12_col3, #T_28178_row12_col4, #T_28178_row12_col5, #T_28178_row12_col6, #T_28178_row13_col0, #T_28178_row13_col1, #T_28178_row13_col2, #T_28178_row13_col3, #T_28178_row13_col4, #T_28178_row13_col5, #T_28178_row13_col6, #T_28178_row14_col0, #T_28178_row14_col1, #T_28178_row14_col2, #T_28178_row14_col3, #T_28178_row14_col4, #T_28178_row14_col5, #T_28178_row14_col6, #T_28178_row15_col0, #T_28178_row15_col1, #T_28178_row15_col2, #T_28178_row15_col3, #T_28178_row15_col4, #T_28178_row15_col5, #T_28178_row15_col6, #T_28178_row16_col0, #T_28178_row16_col1, #T_28178_row16_col2, #T_28178_row16_col3, #T_28178_row16_col4, #T_28178_row16_col5, #T_28178_row16_col6, #T_28178_row17_col0, #T_28178_row17_col1, #T_28178_row17_col2, #T_28178_row17_col3, #T_28178_row17_col4, #T_28178_row17_col5, #T_28178_row17_col6, #T_28178_row18_col0, #T_28178_row18_col1, #T_28178_row18_col2, #T_28178_row18_col3, #T_28178_row18_col4, #T_28178_row18_col5, #T_28178_row18_col6, #T_28178_row19_col0, #T_28178_row19_col1, #T_28178_row19_col2, #T_28178_row19_col3, #T_28178_row19_col4, #T_28178_row19_col5, #T_28178_row19_col6 {
#   text-align: left;
# }
# #T_28178_row0_col1, #T_28178_row0_col2, #T_28178_row0_col3, #T_28178_row0_col4, #T_28178_row0_col5, #T_28178_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_28178_row0_col7, #T_28178_row1_col7, #T_28178_row2_col7, #T_28178_row3_col7, #T_28178_row4_col7, #T_28178_row5_col7, #T_28178_row6_col7, #T_28178_row7_col7, #T_28178_row8_col7, #T_28178_row9_col7, #T_28178_row11_col7, #T_28178_row12_col7, #T_28178_row14_col7, #T_28178_row15_col7, #T_28178_row16_col7, #T_28178_row17_col7, #T_28178_row18_col7, #T_28178_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_28178_row10_col7, #T_28178_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_28178_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28178_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_28178_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_28178_row0_col1" class="data row0 col1" >8.8658</td>
#       <td id="T_28178_row0_col2" class="data row0 col2" >125.0359</td>
#       <td id="T_28178_row0_col3" class="data row0 col3" >11.1468</td>
#       <td id="T_28178_row0_col4" class="data row0 col4" >0.4177</td>
#       <td id="T_28178_row0_col5" class="data row0 col5" >0.3442</td>
#       <td id="T_28178_row0_col6" class="data row0 col6" >0.3201</td>
#       <td id="T_28178_row0_col7" class="data row0 col7" >1.1950</td>
#     </tr>
#     <tr>
#       <th id="T_28178_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_28178_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_28178_row1_col1" class="data row1 col1" >9.3928</td>
#       <td id="T_28178_row1_col2" class="data row1 col2" >135.1021</td>
#       <td id="T_28178_row1_col3" class="data row1 col3" >11.6123</td>
#       <td id="T_28178_row1_col4" class="data row1 col4" >0.3694</td>
#       <td id="T_28178_row1_col5" class="data row1 col5" >0.3576</td>
#       <td id="T_28178_row1_col6" class="data row1 col6" >0.3371</td>
#       <td id="T_28178_row1_col7" class="data row1 col7" >0.1750</td>
#     </tr>
#     <tr>
#       <th id="T_28178_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_28178_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_28178_row2_col1" class="data row2 col1" >9.6589</td>
#       <td id="T_28178_row2_col2" class="data row2 col2" >141.3729</td>
#       <td id="T_28178_row2_col3" class="data row2 col3" >11.8708</td>
#       <td id="T_28178_row2_col4" class="data row2 col4" >0.3378</td>
#       <td id="T_28178_row2_col5" class="data row2 col5" >0.3638</td>
#       <td id="T_28178_row2_col6" class="data row2 col6" >0.3435</td>
#       <td id="T_28178_row2_col7" class="data row2 col7" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_28178_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_28178_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_28178_row3_col1" class="data row3 col1" >9.4470</td>
#       <td id="T_28178_row3_col2" class="data row3 col2" >144.1076</td>
#       <td id="T_28178_row3_col3" class="data row3 col3" >11.9662</td>
#       <td id="T_28178_row3_col4" class="data row3 col4" >0.3202</td>
#       <td id="T_28178_row3_col5" class="data row3 col5" >0.3627</td>
#       <td id="T_28178_row3_col6" class="data row3 col6" >0.3234</td>
#       <td id="T_28178_row3_col7" class="data row3 col7" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_28178_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_28178_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_28178_row4_col1" class="data row4 col1" >9.8921</td>
#       <td id="T_28178_row4_col2" class="data row4 col2" >146.6899</td>
#       <td id="T_28178_row4_col3" class="data row4 col3" >12.0955</td>
#       <td id="T_28178_row4_col4" class="data row4 col4" >0.3127</td>
#       <td id="T_28178_row4_col5" class="data row4 col5" >0.3761</td>
#       <td id="T_28178_row4_col6" class="data row4 col6" >0.3683</td>
#       <td id="T_28178_row4_col7" class="data row4 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_28178_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_28178_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_28178_row5_col1" class="data row5 col1" >9.9070</td>
#       <td id="T_28178_row5_col2" class="data row5 col2" >147.3030</td>
#       <td id="T_28178_row5_col3" class="data row5 col3" >12.1090</td>
#       <td id="T_28178_row5_col4" class="data row5 col4" >0.3106</td>
#       <td id="T_28178_row5_col5" class="data row5 col5" >0.3633</td>
#       <td id="T_28178

# %%
top3_fold_5 = compare_models(include=['rf', 'gbr', 'catboost'], fold = 5, sort='MAE')
# Out:
# <style type="text/css">
# #T_fd46e_ th {
#   text-align: left;
# }
# #T_fd46e_row0_col0, #T_fd46e_row1_col0, #T_fd46e_row1_col1, #T_fd46e_row1_col2, #T_fd46e_row1_col3, #T_fd46e_row1_col4, #T_fd46e_row1_col5, #T_fd46e_row1_col6, #T_fd46e_row2_col0, #T_fd46e_row2_col1, #T_fd46e_row2_col2, #T_fd46e_row2_col3, #T_fd46e_row2_col4, #T_fd46e_row2_col5, #T_fd46e_row2_col6 {
#   text-align: left;
# }
# #T_fd46e_row0_col1, #T_fd46e_row0_col2, #T_fd46e_row0_col3, #T_fd46e_row0_col4, #T_fd46e_row0_col5, #T_fd46e_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fd46e_row0_col7, #T_fd46e_row1_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fd46e_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fd46e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd46e_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_fd46e_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_fd46e_row0_col1" class="data row0 col1" >9.0604</td>
#       <td id="T_fd46e_row0_col2" class="data row0 col2" >129.4306</td>
#       <td id="T_fd46e_row0_col3" class="data row0 col3" >11.3588</td>
#       <td id="T_fd46e_row0_col4" class="data row0 col4" >0.4025</td>
#       <td id="T_fd46e_row0_col5" class="data row0 col5" >0.3551</td>
#       <td id="T_fd46e_row0_col6" class="data row0 col6" >0.3319</td>
#       <td id="T_fd46e_row0_col7" class="data row0 col7" >0.9880</td>
#     </tr>
#     <tr>
#       <th id="T_fd46e_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_fd46e_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_fd46e_row1_col1" class="data row1 col1" >9.2614</td>
#       <td id="T_fd46e_row1_col2" class="data row1 col2" >133.3879</td>
#       <td id="T_fd46e_row1_col3" class="data row1 col3" >11.5406</td>
#       <td id="T_fd46e_row1_col4" class="data row1 col4" >0.3836</td>
#       <td id="T_fd46e_row1_col5" class="data row1 col5" >0.3562</td>
#       <td id="T_fd46e_row1_col6" class="data row1 col6" >0.3344</td>
#       <td id="T_fd46e_row1_col7" class="data row1 col7" >0.1820</td>
#     </tr>
#     <tr>
#       <th id="T_fd46e_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_fd46e_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_fd46e_row2_col1" class="data row2 col1" >9.7232</td>
#       <td id="T_fd46e_row2_col2" class="data row2 col2" >142.6388</td>
#       <td id="T_fd46e_row2_col3" class="data row2 col3" >11.9330</td>
#       <td id="T_fd46e_row2_col4" class="data row2 col4" >0.3415</td>
#       <td id="T_fd46e_row2_col5" class="data row2 col5" >0.3681</td>
#       <td id="T_fd46e_row2_col6" class="data row2 col6" >0.3474</td>
#       <td id="T_fd46e_row2_col7" class="data row2 col7" >0.0280</td>
#     </tr>
#   </tbody>
# </table>

# %%
top3 = compare_models(include=['rf', 'gbr', 'catboost'], fold = 10, sort='MAE')
# Out:
# <style type="text/css">
# #T_8836c_ th {
#   text-align: left;
# }
# #T_8836c_row0_col0, #T_8836c_row1_col0, #T_8836c_row1_col1, #T_8836c_row1_col2, #T_8836c_row1_col3, #T_8836c_row1_col4, #T_8836c_row1_col5, #T_8836c_row1_col6, #T_8836c_row2_col0, #T_8836c_row2_col1, #T_8836c_row2_col2, #T_8836c_row2_col3, #T_8836c_row2_col4, #T_8836c_row2_col5, #T_8836c_row2_col6 {
#   text-align: left;
# }
# #T_8836c_row0_col1, #T_8836c_row0_col2, #T_8836c_row0_col3, #T_8836c_row0_col4, #T_8836c_row0_col5, #T_8836c_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8836c_row0_col7, #T_8836c_row1_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8836c_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8836c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8836c_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_8836c_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_8836c_row0_col1" class="data row0 col1" >8.8658</td>
#       <td id="T_8836c_row0_col2" class="data row0 col2" >125.0359</td>
#       <td id="T_8836c_row0_col3" class="data row0 col3" >11.1468</td>
#       <td id="T_8836c_row0_col4" class="data row0 col4" >0.4177</td>
#       <td id="T_8836c_row0_col5" class="data row0 col5" >0.3442</td>
#       <td id="T_8836c_row0_col6" class="data row0 col6" >0.3201</td>
#       <td id="T_8836c_row0_col7" class="data row0 col7" >0.9670</td>
#     </tr>
#     <tr>
#       <th id="T_8836c_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_8836c_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_8836c_row1_col1" class="data row1 col1" >9.3928</td>
#       <td id="T_8836c_row1_col2" class="data row1 col2" >135.1021</td>
#       <td id="T_8836c_row1_col3" class="data row1 col3" >11.6123</td>
#       <td id="T_8836c_row1_col4" class="data row1 col4" >0.3694</td>
#       <td id="T_8836c_row1_col5" class="data row1 col5" >0.3576</td>
#       <td id="T_8836c_row1_col6" class="data row1 col6" >0.3371</td>
#       <td id="T_8836c_row1_col7" class="data row1 col7" >0.1790</td>
#     </tr>
#     <tr>
#       <th id="T_8836c_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_8836c_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_8836c_row2_col1" class="data row2 col1" >9.6589</td>
#       <td id="T_8836c_row2_col2" class="data row2 col2" >141.3729</td>
#       <td id="T_8836c_row2_col3" class="data row2 col3" >11.8708</td>
#       <td id="T_8836c_row2_col4" class="data row2 col4" >0.3378</td>
#       <td id="T_8836c_row2_col5" class="data row2 col5" >0.3638</td>
#       <td id="T_8836c_row2_col6" class="data row2 col6" >0.3435</td>
#       <td id="T_8836c_row2_col7" class="data row2 col7" >0.0310</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There is a performance improvement in going from 5 folds to 10 folds for catboost and gbr. However, for rf, 5 folds performs better. However, the improvement is marginal so for simplicity, and to keep computation time reasonable, folds is kept at 10.

# %% [markdown]
# ## 2. Plot each Model and Check Features

# %% [markdown]
# ##### Category Boosting (CatBoost)

# %%
cb = create_model('catboost')
cb_results = pull()
#print(cb_results)

import pandas as pd
cb_feature_imp = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value' : abs(cb.feature_importances_)}).sort_values(by='Value', ascending=False)
#print(cb_feature_imp)
cb_feature_imp.to_csv('Featue_importance_CATBOOST.csv')
# Out:
# <style type="text/css">
# #T_6e0e3_row10_col0, #T_6e0e3_row10_col1, #T_6e0e3_row10_col2, #T_6e0e3_row10_col3, #T_6e0e3_row10_col4, #T_6e0e3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6e0e3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e0e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e0e3_row0_col0" class="data row0 col0" >8.7774</td>
#       <td id="T_6e0e3_row0_col1" class="data row0 col1" >143.7698</td>
#       <td id="T_6e0e3_row0_col2" class="data row0 col2" >11.9904</td>
#       <td id="T_6e0e3_row0_col3" class="data row0 col3" >0.3290</td>
#       <td id="T_6e0e3_row0_col4" class="data row0 col4" >0.4423</td>
#       <td id="T_6e0e3_row0_col5" class="data row0 col5" >0.4321</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e0e3_row1_col0" class="data row1 col0" >7.1289</td>
#       <td id="T_6e0e3_row1_col1" class="data row1 col1" >96.1058</td>
#       <td id="T_6e0e3_row1_col2" class="data row1 col2" >9.8034</td>
#       <td id="T_6e0e3_row1_col3" class="data row1 col3" >0.5254</td>
#       <td id="T_6e0e3_row1_col4" class="data row1 col4" >0.2974</td>
#       <td id="T_6e0e3_row1_col5" class="data row1 col5" >0.2469</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e0e3_row2_col0" class="data row2 col0" >9.7137</td>
#       <td id="T_6e0e3_row2_col1" class="data row2 col1" >139.7118</td>
#       <td id="T_6e0e3_row2_col2" class="data row2 col2" >11.8200</td>
#       <td id="T_6e0e3_row2_col3" class="data row2 col3" >0.3389</td>
#       <td id="T_6e0e3_row2_col4" class="data row2 col4" >0.4119</td>
#       <td id="T_6e0e3_row2_col5" class="data row2 col5" >0.4119</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e0e3_row3_col0" class="data row3 col0" >9.4459</td>
#       <td id="T_6e0e3_row3_col1" class="data row3 col1" >162.8558</td>
#       <td id="T_6e0e3_row3_col2" class="data row3 col2" >12.7615</td>
#       <td id="T_6e0e3_row3_col3" class="data row3 col3" >0.3031</td>
#       <td id="T_6e0e3_row3_col4" class="data row3 col4" >0.3707</td>
#       <td id="T_6e0e3_row3_col5" class="data row3 col5" >0.3206</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e0e3_row4_col0" class="data row4 col0" >8.1459</td>
#       <td id="T_6e0e3_row4_col1" class="data row4 col1" >113.1566</td>
#       <td id="T_6e0e3_row4_col2" class="data row4 col2" >10.6375</td>
#       <td id="T_6e0e3_row4_col3" class="data row4 col3" >0.4653</td>
#       <td id="T_6e0e3_row4_col4" class="data row4 col4" >0.2931</td>
#       <td id="T_6e0e3_row4_col5" class="data row4 col5" >0.2522</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e0e3_row5_col0" class="data row5 col0" >8.5145</td>
#       <td id="T_6e0e3_row5_col1" class="data row5 col1" >101.7543</td>
#       <td id="T_6e0e3_row5_col2" class="data row5 col2" >10.0873</td>
#       <td id="T_6e0e3_row5_col3" class="data row5 col3" >0.5682</td>
#       <td id="T_6e0e3_row5_col4" class="data row5 col4" >0.3716</td>
#       <td id="T_6e0e3_row5_col5" class="data row5 col5" >0.3609</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6e0e3_row6_col0" class="data row6 col0" >8.7495</td>
#       <td id="T_6e0e3_row6_col1" class="data row6 col1" >122.0168</td>
#       <td id="T_6e0e3_row6_col2" class="data row6 col2" >11.0461</td>
#       <td id="T_6e0e3_row6_col3" class="data row6 col3" >0.4718</td>
#       <td id="T_6e0e3_row6_col4" class="data row6 col4" >0.2692</td>
#       <td id="T_6e0e3_row6_col5" class="data row6 col5" >0.2302</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6e0e3_row7_col0" class="data row7 col0" >8.7297</td>
#       <td id="T_6e0e3_row7_col1" class="data row7 col1" >110.2910</td>
#       <td id="T_6e0e3_row7_col2" class="data row7 col2" >10.5020</td>
#       <td id="T_6e0e3_row7_col3" class="data row7 col3" >0.3684</td>
#       <td id="T_6e0e3_row7_col4" class="data row7 col4" >0.3032</td>
#       <td id="T_6e0e3_row7_col5" class="data row7 col5" >0.2768</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6e0e3_row8_col0" class="data row8 col0" >9.4621</td>
#       <td id="T_6e0e3_row8_col1" class="data row8 col1" >121.1993</td>
#       <td id="T_6e0e3_row8_col2" class="data row8 col2" >11.0091</td>
#       <td id="T_6e0e3_row8_col3" class="data row8 col3" >0.4277</td>
#       <td id="T_6e0e3_row8_col4" class="data row8 col4" >0.3276</td>
#       <td id="T_6e0e3_row8_col5" class="data row8 col5" >0.3173</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6e0e3_row9_col0" class="data row9 col0" >9.9906</td>
#       <td id="T_6e0e3_row9_col1" class="data row9 col1" >139.4974</td>
#       <td id="T_6e0e3_row9_col2" class="data row9 col2" >11.8109</td>
#       <td id="T_6e0e3_row9_col3" class="data row9 col3" >0.3789</td>
#       <td id="T_6e0e3_row9_col4" class="data row9 col4" >0.3553</td>
#       <td id="T_6e0e3_row9_col5" class="data row9 col5" >0.3518</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6e0e3_row10_col0" class="data row10 col0" >8.8658</td>
#       <td id="T_6e0e3_row10_col1" class="data row10 col1" >125.0359</td>
#       <td id="T_6e0e3_row10_col2" class="data row10 col2" >11.1468</td>
#       <td id="T_6e0e3_row10_col3" class="data row10 col3" >0.4177</td>
#       <td id="T_6e0e3_row10_col4" class="data row10 col4" >0.3442</td>
#       <td id="T_6e0e3_row10_col5" class="data row10 col5" >0.3201</td>
#     </tr>
#     <tr>
#       <th id="T_6e0e3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6e0e3_row11_col0" class="data row11 col0" >0.7984</td>
#       <td id="T_6e0e3_row11_col1" class="data row11 col1" >19.9177</td>
#       <td id="T_6e0e3_row11_col2" class="data row11 col2" >0.8857</td>
#       <td id="T_6e0e3_row11_col3" class="data row11 col3" >0.0841</td>
#       <td id="T_6e0e3_row11_col4" class="data row11 col4" >0.0531</td>
#       <td id="T_6e0e3_row11_col5" class="data row11 col5" >0.0660</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Given the sheer number of variables, will only plot the first 10
# 'feature_all' will plot everything
plot_model(cb, plot = 'feature')

# %% [markdown]
# ##### Random Forest (RFR)

# %%
rfr = create_model('rf')
rfr_results = pull()

import pandas as pd
rfr_feature_imp = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value' : abs(rfr.feature_importances_)}).sort_values(by='Value', ascending=False)
rfr_feature_imp.to_csv('Feature_importance_RFR.csv')
# Out:
# <style type="text/css">
# #T_f1453_row10_col0, #T_f1453_row10_col1, #T_f1453_row10_col2, #T_f1453_row10_col3, #T_f1453_row10_col4, #T_f1453_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f1453_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1453_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1453_row0_col0" class="data row0 col0" >9.1114</td>
#       <td id="T_f1453_row0_col1" class="data row0 col1" >135.2387</td>
#       <td id="T_f1453_row0_col2" class="data row0 col2" >11.6292</td>
#       <td id="T_f1453_row0_col3" class="data row0 col3" >0.3689</td>
#       <td id="T_f1453_row0_col4" class="data row0 col4" >0.4158</td>
#       <td id="T_f1453_row0_col5" class="data row0 col5" >0.3989</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1453_row1_col0" class="data row1 col0" >9.0111</td>
#       <td id="T_f1453_row1_col1" class="data row1 col1" >130.6803</td>
#       <td id="T_f1453_row1_col2" class="data row1 col2" >11.4316</td>
#       <td id="T_f1453_row1_col3" class="data row1 col3" >0.3546</td>
#       <td id="T_f1453_row1_col4" class="data row1 col4" >0.3296</td>
#       <td id="T_f1453_row1_col5" class="data row1 col5" >0.2945</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f1453_row2_col0" class="data row2 col0" >9.6606</td>
#       <td id="T_f1453_row2_col1" class="data row2 col1" >141.5488</td>
#       <td id="T_f1453_row2_col2" class="data row2 col2" >11.8974</td>
#       <td id="T_f1453_row2_col3" class="data row2 col3" >0.3302</td>
#       <td id="T_f1453_row2_col4" class="data row2 col4" >0.4234</td>
#       <td id="T_f1453_row2_col5" class="data row2 col5" >0.4284</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f1453_row3_col0" class="data row3 col0" >9.1564</td>
#       <td id="T_f1453_row3_col1" class="data row3 col1" >140.8654</td>
#       <td id="T_f1453_row3_col2" class="data row3 col2" >11.8687</td>
#       <td id="T_f1453_row3_col3" class="data row3 col3" >0.3972</td>
#       <td id="T_f1453_row3_col4" class="data row3 col4" >0.3636</td>
#       <td id="T_f1453_row3_col5" class="data row3 col5" >0.3357</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f1453_row4_col0" class="data row4 col0" >8.8310</td>
#       <td id="T_f1453_row4_col1" class="data row4 col1" >130.1396</td>
#       <td id="T_f1453_row4_col2" class="data row4 col2" >11.4079</td>
#       <td id="T_f1453_row4_col3" class="data row4 col3" >0.3850</td>
#       <td id="T_f1453_row4_col4" class="data row4 col4" >0.3148</td>
#       <td id="T_f1453_row4_col5" class="data row4 col5" >0.2785</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f1453_row5_col0" class="data row5 col0" >9.7976</td>
#       <td id="T_f1453_row5_col1" class="data row5 col1" >124.7850</td>
#       <td id="T_f1453_row5_col2" class="data row5 col2" >11.1707</td>
#       <td id="T_f1453_row5_col3" class="data row5 col3" >0.4705</td>
#       <td id="T_f1453_row5_col4" class="data row5 col4" >0.3944</td>
#       <td id="T_f1453_row5_col5" class="data row5 col5" >0.4059</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f1453_row6_col0" class="data row6 col0" >9.0411</td>
#       <td id="T_f1453_row6_col1" class="data row6 col1" >132.9739</td>
#       <td id="T_f1453_row6_col2" class="data row6 col2" >11.5314</td>
#       <td id="T_f1453_row6_col3" class="data row6 col3" >0.4243</td>
#       <td id="T_f1453_row6_col4" class="data row6 col4" >0.2734</td>
#       <td id="T_f1453_row6_col5" class="data row6 col5" >0.2265</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f1453_row7_col0" class="data row7 col0" >8.6972</td>
#       <td id="T_f1453_row7_col1" class="data row7 col1" >114.5386</td>
#       <td id="T_f1453_row7_col2" class="data row7 col2" >10.7023</td>
#       <td id="T_f1453_row7_col3" class="data row7 col3" >0.3441</td>
#       <td id="T_f1453_row7_col4" class="data row7 col4" >0.3180</td>
#       <td id="T_f1453_row7_col5" class="data row7 col5" >0.2870</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f1453_row8_col0" class="data row8 col0" >10.9339</td>
#       <td id="T_f1453_row8_col1" class="data row8 col1" >162.7236</td>
#       <td id="T_f1453_row8_col2" class="data row8 col2" >12.7563</td>
#       <td id="T_f1453_row8_col3" class="data row8 col3" >0.2316</td>
#       <td id="T_f1453_row8_col4" class="data row8 col4" >0.3677</td>
#       <td id="T_f1453_row8_col5" class="data row8 col5" >0.3542</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f1453_row9_col0" class="data row9 col0" >9.6878</td>
#       <td id="T_f1453_row9_col1" class="data row9 col1" >137.5266</td>
#       <td id="T_f1453_row9_col2" class="data row9 col2" >11.7272</td>
#       <td id="T_f1453_row9_col3" class="data row9 col3" >0.3877</td>
#       <td id="T_f1453_row9_col4" class="data row9 col4" >0.3748</td>
#       <td id="T_f1453_row9_col5" class="data row9 col5" >0.3617</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f1453_row10_col0" class="data row10 col0" >9.3928</td>
#       <td id="T_f1453_row10_col1" class="data row10 col1" >135.1021</td>
#       <td id="T_f1453_row10_col2" class="data row10 col2" >11.6123</td>
#       <td id="T_f1453_row10_col3" class="data row10 col3" >0.3694</td>
#       <td id="T_f1453_row10_col4" class="data row10 col4" >0.3576</td>
#       <td id="T_f1453_row10_col5" class="data row10 col5" >0.3371</td>
#     </tr>
#     <tr>
#       <th id="T_f1453_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f1453_row11_col0" class="data row11 col0" >0.6246</td>
#       <td id="T_f1453_row11_col1" class="data row11 col1" >11.9232</td>
#       <td id="T_f1453_row11_col2" class="data row11 col2" >0.5073</td>
#       <td id="T_f1453_row11_col3" class="data row11 col3" >0.0600</td>
#       <td id="T_f1453_row11_col4" class="data row11 col4" >0.0456</td>
#       <td id="T_f1453_row11_col5" class="data row11 col5" >0.0615</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(rfr, plot = 'feature')

# %% [markdown]
# ##### Gradient Boosting (GBR)

# %%
gbr = create_model('gbr')
gbr_results = pull()
#print(gbr_results)

import pandas as pd
gbr_feature_imp = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value' : abs(gbr.feature_importances_)}).sort_values(by='Value', ascending=False)
gbr_feature_imp.to_csv('Feature_importance_GBR.csv')
# Out:
# <style type="text/css">
# #T_dc500_row10_col0, #T_dc500_row10_col1, #T_dc500_row10_col2, #T_dc500_row10_col3, #T_dc500_row10_col4, #T_dc500_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_dc500_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc500_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc500_row0_col0" class="data row0 col0" >9.5535</td>
#       <td id="T_dc500_row0_col1" class="data row0 col1" >151.0181</td>
#       <td id="T_dc500_row0_col2" class="data row0 col2" >12.2889</td>
#       <td id="T_dc500_row0_col3" class="data row0 col3" >0.2952</td>
#       <td id="T_dc500_row0_col4" class="data row0 col4" >0.4355</td>
#       <td id="T_dc500_row0_col5" class="data row0 col5" >0.4276</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dc500_row1_col0" class="data row1 col0" >8.7608</td>
#       <td id="T_dc500_row1_col1" class="data row1 col1" >115.4462</td>
#       <td id="T_dc500_row1_col2" class="data row1 col2" >10.7446</td>
#       <td id="T_dc500_row1_col3" class="data row1 col3" >0.4299</td>
#       <td id="T_dc500_row1_col4" class="data row1 col4" >0.3173</td>
#       <td id="T_dc500_row1_col5" class="data row1 col5" >0.2912</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dc500_row2_col0" class="data row2 col0" >9.6868</td>
#       <td id="T_dc500_row2_col1" class="data row2 col1" >152.7776</td>
#       <td id="T_dc500_row2_col2" class="data row2 col2" >12.3603</td>
#       <td id="T_dc500_row2_col3" class="data row2 col3" >0.2771</td>
#       <td id="T_dc500_row2_col4" class="data row2 col4" >0.4282</td>
#       <td id="T_dc500_row2_col5" class="data row2 col5" >0.4189</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dc500_row3_col0" class="data row3 col0" >8.5895</td>
#       <td id="T_dc500_row3_col1" class="data row3 col1" >148.1668</td>
#       <td id="T_dc500_row3_col2" class="data row3 col2" >12.1724</td>
#       <td id="T_dc500_row3_col3" class="data row3 col3" >0.3659</td>
#       <td id="T_dc500_row3_col4" class="data row3 col4" >0.3530</td>
#       <td id="T_dc500_row3_col5" class="data row3 col5" >0.2850</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dc500_row4_col0" class="data row4 col0" >8.6990</td>
#       <td id="T_dc500_row4_col1" class="data row4 col1" >126.0041</td>
#       <td id="T_dc500_row4_col2" class="data row4 col2" >11.2252</td>
#       <td id="T_dc500_row4_col3" class="data row4 col3" >0.4045</td>
#       <td id="T_dc500_row4_col4" class="data row4 col4" >0.3112</td>
#       <td id="T_dc500_row4_col5" class="data row4 col5" >0.2778</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dc500_row5_col0" class="data row5 col0" >9.4480</td>
#       <td id="T_dc500_row5_col1" class="data row5 col1" >121.1348</td>
#       <td id="T_dc500_row5_col2" class="data row5 col2" >11.0061</td>
#       <td id="T_dc500_row5_col3" class="data row5 col3" >0.4860</td>
#       <td id="T_dc500_row5_col4" class="data row5 col4" >0.3828</td>
#       <td id="T_dc500_row5_col5" class="data row5 col5" >0.3834</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dc500_row6_col0" class="data row6 col0" >9.8464</td>
#       <td id="T_dc500_row6_col1" class="data row6 col1" >130.8128</td>
#       <td id="T_dc500_row6_col2" class="data row6 col2" >11.4373</td>
#       <td id="T_dc500_row6_col3" class="data row6 col3" >0.4337</td>
#       <td id="T_dc500_row6_col4" class="data row6 col4" >0.2900</td>
#       <td id="T_dc500_row6_col5" class="data row6 col5" >0.2636</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dc500_row7_col0" class="data row7 col0" >10.3484</td>
#       <td id="T_dc500_row7_col1" class="data row7 col1" >145.2470</td>
#       <td id="T_dc500_row7_col2" class="data row7 col2" >12.0518</td>
#       <td id="T_dc500_row7_col3" class="data row7 col3" >0.1682</td>
#       <td id="T_dc500_row7_col4" class="data row7 col4" >0.3548</td>
#       <td id="T_dc500_row7_col5" class="data row7 col5" >0.3374</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dc500_row8_col0" class="data row8 col0" >11.3218</td>
#       <td id="T_dc500_row8_col1" class="data row8 col1" >161.8410</td>
#       <td id="T_dc500_row8_col2" class="data row8 col2" >12.7217</td>
#       <td id="T_dc500_row8_col3" class="data row8 col3" >0.2358</td>
#       <td id="T_dc500_row8_col4" class="data row8 col4" >0.3671</td>
#       <td id="T_dc500_row8_col5" class="data row8 col5" >0.3651</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dc500_row9_col0" class="data row9 col0" >10.3350</td>
#       <td id="T_dc500_row9_col1" class="data row9 col1" >161.2802</td>
#       <td id="T_dc500_row9_col2" class="data row9 col2" >12.6996</td>
#       <td id="T_dc500_row9_col3" class="data row9 col3" >0.2819</td>
#       <td id="T_dc500_row9_col4" class="data row9 col4" >0.3983</td>
#       <td id="T_dc500_row9_col5" class="data row9 col5" >0.3846</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_dc500_row10_col0" class="data row10 col0" >9.6589</td>
#       <td id="T_dc500_row10_col1" class="data row10 col1" >141.3729</td>
#       <td id="T_dc500_row10_col2" class="data row10 col2" >11.8708</td>
#       <td id="T_dc500_row10_col3" class="data row10 col3" >0.3378</td>
#       <td id="T_dc500_row10_col4" class="data row10 col4" >0.3638</td>
#       <td id="T_dc500_row10_col5" class="data row10 col5" >0.3435</td>
#     </tr>
#     <tr>
#       <th id="T_dc500_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_dc500_row11_col0" class="data row11 col0" >0.8161</td>
#       <td id="T_dc500_row11_col1" class="data row11 col1" >15.9028</td>
#       <td id="T_dc500_row11_col2" class="data row11 col2" >0.6760</td>
#       <td id="T_dc500_row11_col3" class="data row11 col3" >0.0963</td>
#       <td id="T_dc500_row11_col4" class="data row11 col4" >0.0463</td>
#       <td id="T_dc500_row11_col5" class="data row11 col5" >0.0578</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(gbr, plot = 'feature')

# %% [markdown]
# ## 3a. Testing for Optimisation - Not necessary to run
# -----------------------------------------------------------------------------------

# %% [markdown]
# One of the important parameters in the hyperparameters is the number of iterations over which the K fold cross validation is done.
#
# 2 checks are done for this. The first scenario is over the range(0, 1000, 50). The optimisation ran overnight and showed that the ML algorithm did not see much improvement past 50.

# %%
elapsed = []
MAE_mean_iter = []
MSE_mean_iter = []
RMSE_mean_iter = []

# The output from the (0, 1000, 50) is saved; there is no need to run this again. 
# Line has been modified just so the code can run.
for i in range(0, 51, 50):
    start = time.time()
    if i == 0:
        i += 1    
    tuned_cb = tune_model(cb, optimize = 'MSE', n_iter = i)
    #print(tuned_cb)
    MAE_mean_iter.append(pull()['MAE']['Mean'])
    MSE_mean_iter.append(pull()['MSE']['Mean'])
    RMSE_mean_iter.append(pull()['RMSE']['Mean'])
    elapsed.append((time.time() - start))

MAE_Mean = pd.DataFrame(MAE_mean_iter, index = elapsed, columns=['MAE Mean Error'])
MAE_Mean.index.name = 'Elapsed Time'

MSE_Mean = pd.DataFrame(MSE_mean_iter, index = elapsed, columns=['MSE Mean Error']) 
MSE_Mean.index.name = 'Elapsed Time'

RMSE_Mean = pd.DataFrame(RMSE_mean_iter, index = elapsed, columns=['RMSE Mean Error'])
RMSE_Mean.index.name = 'Elapsed Time'

res_50_iter = pd.concat([MAE_Mean, MSE_Mean, RMSE_Mean], axis=1)

print(res_50_iter)

# %%
b = sns.lineplot(data=res_50_iter)
b.axes.set_title("Error as function of Elapsed Time",fontsize=20)
b.set_xlabel("Elapsed Time",fontsize=20)
b.set_ylabel("Error",fontsize=20)
#b.set_yscale('log')
b.tick_params(labelsize=18)

# %%
#res.to_csv('Run_Catboost_1000_Itr.csv')

# %%
elapsed = []
MAE_mean_iter = []
MSE_mean_iter = []
RMSE_mean_iter = []

# This was run at (1, 51, 1) to get increments of 1
# Right now, this is changed to (1, 51, 50) to allow the code to run efficiently
for i in range(1, 51, 50):
    start = time.time()
    tuned_cb = tune_model(cb, optimize = 'MSE', n_iter = i)
    MAE_mean_iter.append(pull()['MAE']['Mean'])
    MSE_mean_iter.append(pull()['MSE']['Mean'])
    RMSE_mean_iter.append(pull()['RMSE']['Mean'])
    elapsed.append((time.time() - start))

MAE_Mean = pd.DataFrame(MAE_mean_iter, index = elapsed, columns=['MAE Mean Error'])
MAE_Mean.index.name = 'Elapsed Time'

MSE_Mean = pd.DataFrame(MSE_mean_iter, index = elapsed, columns=['MSE Mean Error']) 
MSE_Mean.index.name = 'Elapsed Time'

RMSE_Mean = pd.DataFrame(RMSE_mean_iter, index = elapsed, columns=['RMSE Mean Error'])
RMSE_Mean.index.name = 'Elapsed Time'

res_1_iter = pd.concat([MAE_Mean, MSE_Mean, RMSE_Mean], axis=1)

print(res_1_iter)

res_1_iter.to_csv('Run_Catboost_50_Itr.csv')

# %%
b = sns.lineplot(data=res_1_iter)
b.axes.set_title("Error as function of Elapsed Time",fontsize=20)
b.set_xlabel("Elapsed Time",fontsize=20)
b.set_ylabel("Error",fontsize=20)
#b.set_yscale('log')
b.tick_params(labelsize=18)

# %%
tuned_cb3 = tune_model(cb, optimize = 'RMSE', n_iter = 10)

# %%
plot_model(tuned_cb3, plot = 'parameter')

# %% [markdown]
# ##### Gradient Boosting Regression

# %%
gbr = create_model('gbr')
print(gbr)

# %%
tuned_gbr = tune_model(gbr, search_library = "tune-sklearn", search_algorithm="hyperopt", optimize="RMSE", n_iter=50)
print(tuned_gbr)

# %%
#tuned_gbr1 = tune_model(gbr, search_library = "tune-sklearn", search_algorithm="hyperopt", optimize="RMSE", n_iter=50)
#print(tuned_gbr1)

# %%
#tuned_gbr4 = tune_model(gbr, search_library = "tune-sklearn", search_algorithm="optuna", optimize="RMSE", n_iter=50)
#print(tuned_gbr4)

# %%
#tuned_gbr5 = tune_model(gbr, search_library = "tune-sklearn", search_algorithm="bayesian", optimize="RMSE", n_iter=50)
#print(tuned_gbr5)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3. Optimisation

# %% [markdown]
# ### a. Tune the Model

# %% [markdown]
# The earlier experiments allow one to determine which model performs efficiently, and the tuning needed to arrive at the answer. Here, we will create the 3 specific models , which we will than blend, and than finally produce a "tuned" blended model based on earlier optimised parameters

# %% [markdown]
# from pycaret.distributions import UniformDistribution, CategoricalDistribution
#
# catboost_param_dists = {
#     'iterations': CategoricalDistribution([500,100,300]),
#     'colsample_bylevel': UniformDistribution(0.5, 1.0),
#     'random_strength': CategoricalDistribution([0,0.1,0.2,1,10]),
#     'max_depth' : CategoricalDistribution([5,6,7,8,9])
# }

# %%
tuned_models = []

# %% [markdown]
# cb = create_model('catboost', fold = 10)
# cb_opt = tune_model(cb,
#                 optimize = 'RMSE',
#                 n_iter = 50,
#                 choose_better = True,
#                 search_library = "optuna",
#                 #custom_grid = catboost_param_dists ,
#                 #early_stopping = "asha",
#                 #early_stopping_max_iters = 10,
#                 #return_tuner = False ,
#                )

# %% [markdown]
# cb = create_model('catboost', fold = 10)
# cb_hyp = tune_model(cb,
#                 optimize = 'RMSE',
#                 n_iter = 50,
#                 choose_better = True,
#                 #search_library = "optuna",
#                 search_library = "tune-sklearn",
#                 search_algorithm="hyperopt",
#                 #custom_grid = catboost_param_dists ,
#                 #early_stopping = "asha",
#                 #early_stopping_max_iters = 10,
#                 #return_tuner = False ,
#                )

# %% [markdown]
# cb = create_model('catboost', fold = 10)
# cb_ran = tune_model(cb,
#                 optimize = 'RMSE',
#                 n_iter = 50,
#                 choose_better = True,
#                 #search_library = "optuna",
#                 #search_library = "tune-sklearn",
#                 #search_algorithm="bayesian",
#                 #custom_grid = catboost_param_dists ,
#                 #early_stopping = "asha",
#                 #early_stopping_max_iters = 10,
#                 #return_tuner = False ,
#                )

# %%
cb = create_model('catboost', fold = 10)
cb = tune_model(cb, 
                optimize = 'RMSE', 
                n_iter = 50, 
                choose_better = True,
                search_library = "tune-sklearn", 
                search_algorithm="bayesian",              
               )

tuned_models.append(cb)
# Out:
# == Status ==<br>Current time: 2022-04-21 22:01:10 (running for 00:00:10.45)<br>Memory usage on this node: 3.6/3.8 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/6 CPUs, 0/0 GPUs, 0.0/0.16 GiB heap, 0.0/0.08 GiB objects<br>Result logdir: C:\Users\quant\ray_results\_Trainable_2022-04-21_22-00-57<br>Number of trials: 1/50 (1 RUNNING)<br><br>
# (_Trainable pid=9672) 2022-04-21 22:01:10,059	ERROR worker.py:449 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::_Inner.__init__() (pid=9672, ip=127.0.0.1, repr=<ray.tune.utils.trainable._Trainable object at 0x0000029209835308>)
# (_Trainable pid=9672)   File "python\ray\_raylet.pyx", line 621, in ray._raylet.execute_task
# (_Trainable pid=9672)   File "C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray\_private\memory_monitor.py", line 164, in raise_if_low_memory
# (_Trainable pid=9672)     used_gb, total_gb, self.error_threshold
# (_Trainable pid=9672) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node Family is used (3.65 / 3.83 GB). The top 10 memory consumers are:
# (_Trainable pid=9672)
# (_Trainable pid=9672) PID	MEM	COMMAND
# (_Trainable pid=9672) 7460	0.22GiB	C:\Program Files\Common Files\McAfee\AMCore\mcshield.exe
# (_Trainable pid=9672) 9672	0.2GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# (_Trainable pid=9672) 13608	0.15GiB	C:\Users\quant\Anaconda3\python.exe -m ipykernel_launcher -f C:\Users\quant\AppData\Roaming\jupyter\
# (_Trainable pid=9672) 9316	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# (_Trainable pid=9672) 7504	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# (_Trainable pid=9672) 11184	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# (_Trainable pid=9672) 2912	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# (_Trainable pid=9672) 8052	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# (_Trainable pid=9672) 10648	0.08GiB	C:\Users\quant\Anaconda3\python.exe -u C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\
# (_Trainable pid=9672) 16048	0.08GiB	C:\Users\quant\Anaconda3\python.exe -u C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\
# (_Trainable pid=9672)
# (_Trainable pid=9672) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (_Trainable pid=9672) ---
# (_Trainable pid=9672) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (_Trainable pid=9672) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (_Trainable pid=9672) ---
# 2022-04-21 22:01:10,179	ERROR trial_runner.py:872 -- Trial _Trainable_78f6b324: Error processing event.
# (pid=) 2022-04-21 22:01:14,113	INFO context.py:67 -- Exec'ing worker with command: "C:\Users\quant\Anaconda3\python.exe" C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray\workers/default_worker.py --node-ip-address=127.0.0.1 --node-manager-port=50925 --object-store-name=tcp://127.0.0.1:51286 --raylet-name=tcp://127.0.0.1:63027 --redis-address=None --storage=None --temp-dir=C:\Users\quant\AppData\Local\Temp\ray --metrics-agent-port=55385 --logging-rotate-bytes=536870912 --logging-rotate-backup-count=5 --gcs-address=127.0.0.1:54538 --redis-password=5241590000000000 --startup-token=6 --runtime-env-hash=1516020270
# ---------------------------------------------------------------------------
# RayActorError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13608\1608573644.py in <module>
#       5                 choose_better = True,
#       6                 search_library = "tune-sklearn",
# ----> 7                 search_algorithm="bayesian",
#       8                )
#       9
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\regression.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1168         tuner_verbose=tuner_verbose,
#    1169         return_train_score=return_train_score,
# -> 1170         **kwargs,
#    1171     )
#    1172
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\internal\tabular.py in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, return_train_score, **kwargs)
#    4679                 model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4680         else:
# -> 4681             model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4682         best_params = model_grid.best_params_
#    4683         logger.info(f"best_params: {best_params}")
#
# ~\AppData\Roaming\Python\Python37\site-packages\tune_sklearn\tune_basesearch.py in fit(self, X, y, groups, tune_params, **fit_params)
#     620
#     621         """
# --> 622         return self._fit(X, y, groups, tune_params, **fit_params)
#     623
#     624     def score(self, X, y=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tune_sklearn\tune_basesearch.py in _fit(self, X, y, groups, tune_params, **fit_params)
#     532         self._fill_config_hyperparam(config)
#     533         self.analysis_ = self._tune_run(X, y, config, resources_per_trial,
# --> 534                                         tune_params)
#     535
#     536         self.cv_results_ = self._format_results(self.n_splits, self.analysis_)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tune_sklearn\tune_search.py in _tune_run(self, X, y, config, resources_per_trial, tune_params)
#     806                 "ignore", message="fail_fast='raise' "
#     807                 "detected.")
# --> 808             analysis = tune.run(trainable, **run_args)
#     809         return analysis
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, max_concurrent_trials, _experiment_checkpoint_dir, queue_trials, loggers, _remote)
#     670     progress_reporter.set_start_time(tune_start)
#     671     while not runner.is_finished() and not state[signal.SIGINT]:
# --> 672         runner.step()
#     673         if has_verbosity(Verbosity.V1_EXPERIMENT):
#     674             _report_progress(runner, progress_reporter)
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\trial_runner.py in step(self)
#     765         next_trial = self._update_trial_queue_and_get_next_trial()
#     766
# --> 767         self._wait_and_handle_event(next_trial)
#     768
#     769         self._stop_experiment_if_needed()
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\trial_runner.py in _wait_and_handle_event(self, next_trial)
#     743         except Exception as e:
#     744             if e is TuneError or self._fail_fast == TrialRunner.RAISE:
# --> 745                 raise e
#     746             else:
#     747                 raise TuneError(traceback.format_exc())
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\trial_runner.py in _wait_and_handle_event(self, next_trial)
#     728                 result = future_result.result
#     729                 if future_result.type == ExecutorEventType.ERROR:
# --> 730                     self._on_executor_error(trial, result)
#     731                 elif future_result.type == ExecutorEventType.RESTORING_RESULT:
#     732                     self._on_restoring_result(trial)
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\trial_runner.py in _on_executor_error(self, trial, result)
#     872             logger.error(error_msg)
#     873             assert isinstance(result[0], Exception)
# --> 874             raise result[0]
#     875         else:
#     876             logger.exception(error_msg)
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\ray_trial_executor.py in get_next_executor_event(self, live_trials, next_trial_exists)
#     899                 assert isinstance(trial, Trial)
#     900                 try:
# --> 901                     future_result = ray.get(ready_future)
#     902                     # For local mode
#     903                     if isinstance(future_result, _LocalWrapper):
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\_private\client_mode_hook.py in wrapper(*args, **kwargs)
#     103             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105         return func(*args, **kwargs)
#     106
#     107     return wrapper
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\worker.py in get(object_refs, timeout)
#    1809                     raise value.as_instanceof_cause()
#    1810                 else:
# -> 1811                     raise value
#    1812
#    1813         if is_individual_id:
#
# RayActorError: The actor died because of an error raised in its creation task, ray::_Inner.__init__() (pid=9672, ip=127.0.0.1, repr=<ray.tune.utils.trainable._Trainable object at 0x0000029209835308>)
#   File "python\ray\_raylet.pyx", line 621, in ray._raylet.execute_task
#   File "C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray\_private\memory_monitor.py", line 164, in raise_if_low_memory
#     used_gb, total_gb, self.error_threshold
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node Family is used (3.65 / 3.83 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 7460	0.22GiB	C:\Program Files\Common Files\McAfee\AMCore\mcshield.exe
# 9672	0.2GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 13608	0.15GiB	C:\Users\quant\Anaconda3\python.exe -m ipykernel_launcher -f C:\Users\quant\AppData\Roaming\jupyter\
# 9316	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 7504	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 11184	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 2912	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 8052	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 10648	0.08GiB	C:\Users\quant\Anaconda3\python.exe -u C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\
# 16048	0.08GiB	C:\Users\quant\Anaconda3\python.exe -u C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---

# %% [markdown]
# gbr = create_model('gbr', fold = 10)
# gbr = tune_model(gbr,
#                  optimize = 'RMSE',
#                  n_iter = 50,
#                  choose_better = True,
#                  search_library = "tune-sklearn",
#                  search_algorithm="Hyperopt")
# tuned_models.append(gbr)

# %% [markdown]
# gbr = create_model('gbr', fold = 10)
# gbr = tune_model(gbr,
#                  optimize = 'RMSE',
#                  n_iter = 50,
#                  choose_better = True,
#                  search_library = "tune-sklearn",
#                  search_algorithm="Optuna")
# tuned_models.append(gbr)

# %%
gbr = create_model('gbr', fold = 10)
gbr = tune_model(gbr, 
                 optimize = 'RMSE', 
                 n_iter = 50, 
                 choose_better = True, 
                 search_library = "tune-sklearn", 
                 search_algorithm="bayesian",
                )
tuned_models.append(gbr)
# Out:
# == Status ==<br>Current time: 2022-04-21 22:05:52 (running for 00:00:14.30)<br>Memory usage on this node: 3.6/3.8 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/6 CPUs, 0/0 GPUs, 0.0/0.16 GiB heap, 0.0/0.08 GiB objects<br>Result logdir: C:\Users\quant\ray_results\_Trainable_2022-04-21_22-05-38<br>Number of trials: 3/50 (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# 2022-04-21 22:05:52,812	INFO trial_runner.py:803 -- starting _Trainable_27a18f46
# 2022-04-21 22:05:53,858	ERROR worker.py:93 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::bundle_reservation_check_func() (pid=9316, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 621, in ray._raylet.execute_task
#   File "C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray\_private\memory_monitor.py", line 164, in raise_if_low_memory
#     used_gb, total_gb, self.error_threshold
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node Family is used (3.64 / 3.83 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 13608	0.25GiB	C:\Users\quant\Anaconda3\python.exe -m ipykernel_launcher -f C:\Users\quant\AppData\Roaming\jupyter\
# 2868	0.24GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 16208	0.18GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 2344	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 9972	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 10860	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 5528	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 15212	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 14756	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 14256	0.11GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# (pid=) 2022-04-21 22:05:53,921	INFO context.py:67 -- Exec'ing worker with command: "C:\Users\quant\Anaconda3\python.exe" C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray\workers/default_worker.py --node-ip-address=127.0.0.1 --node-manager-port=50925 --object-store-name=tcp://127.0.0.1:51286 --raylet-name=tcp://127.0.0.1:63027 --redis-address=None --storage=None --temp-dir=C:\Users\quant\AppData\Local\Temp\ray --metrics-agent-port=55385 --logging-rotate-bytes=536870912 --logging-rotate-backup-count=5 --gcs-address=127.0.0.1:54538 --redis-password=5241590000000000 --startup-token=8 --runtime-env-hash=1516020270
# 2022-04-21 22:05:54,094	WARNING util.py:171 -- The `reset` operation took 1.281 s, which may be a performance bottleneck.
# 2022-04-21 22:05:54,095	ERROR worker.py:93 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_Inner.get_auto_filled_metrics() (pid=2868, ip=127.0.0.1, repr=<ray.tune.utils.trainable._Trainable object at 0x00000269755E14C8>)
#   File "python\ray\_raylet.pyx", line 621, in ray._raylet.execute_task
#   File "C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray\_private\memory_monitor.py", line 164, in raise_if_low_memory
#     used_gb, total_gb, self.error_threshold
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node Family is used (3.64 / 3.83 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 13608	0.25GiB	C:\Users\quant\Anaconda3\python.exe -m ipykernel_launcher -f C:\Users\quant\AppData\Roaming\jupyter\
# 2868	0.24GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 2344	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 9972	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 10860	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 5528	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 15212	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 14756	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 14256	0.11GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
# 14788	0.08GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --display-capture-permis
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
# 2022-04-21 22:05:54,106	WARNING util.py:171 -- The `start_trial` operation took 1.293 s, which may be a performance bottleneck.
# 2022-04-21 22:05:54,113	ERROR trial_runner.py:872 -- Trial _Trainable_238807d0: Error processing event.
# ---------------------------------------------------------------------------
# RayActorError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13608\2082013344.py in <module>
#       5                  choose_better = True,
#       6                  search_library = "tune-sklearn",
# ----> 7                  search_algorithm="bayesian",
#       8                 )
#       9 tuned_models.append(gbr)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\regression.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1168         tuner_verbose=tuner_verbose,
#    1169         return_train_score=return_train_score,
# -> 1170         **kwargs,
#    1171     )
#    1172
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\internal\tabular.py in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, return_train_score, **kwargs)
#    4679                 model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4680         else:
# -> 4681             model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4682         best_params = model_grid.best_params_
#    4683         logger.info(f"best_params: {best_params}")
#
# ~\AppData\Roaming\Python\Python37\site-packages\tune_sklearn\tune_basesearch.py in fit(self, X, y, groups, tune_params, **fit_params)
#     620
#     621         """
# --> 622         return self._fit(X, y, groups, tune_params, **fit_params)
#     623
#     624     def score(self, X, y=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tune_sklearn\tune_basesearch.py in _fit(self, X, y, groups, tune_params, **fit_params)
#     532         self._fill_config_hyperparam(config)
#     533         self.analysis_ = self._tune_run(X, y, config, resources_per_trial,
# --> 534                                         tune_params)
#     535
#     536         self.cv_results_ = self._format_results(self.n_splits, self.analysis_)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tune_sklearn\tune_search.py in _tune_run(self, X, y, config, resources_per_trial, tune_params)
#     806                 "ignore", message="fail_fast='raise' "
#     807                 "detected.")
# --> 808             analysis = tune.run(trainable, **run_args)
#     809         return analysis
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, reuse_actors, trial_executor, raise_on_failed_trial, callbacks, max_concurrent_trials, _experiment_checkpoint_dir, queue_trials, loggers, _remote)
#     670     progress_reporter.set_start_time(tune_start)
#     671     while not runner.is_finished() and not state[signal.SIGINT]:
# --> 672         runner.step()
#     673         if has_verbosity(Verbosity.V1_EXPERIMENT):
#     674             _report_progress(runner, progress_reporter)
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\trial_runner.py in step(self)
#     765         next_trial = self._update_trial_queue_and_get_next_trial()
#     766
# --> 767         self._wait_and_handle_event(next_trial)
#     768
#     769         self._stop_experiment_if_needed()
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\trial_runner.py in _wait_and_handle_event(self, next_trial)
#     743         except Exception as e:
#     744             if e is TuneError or self._fail_fast == TrialRunner.RAISE:
# --> 745                 raise e
#     746             else:
#     747                 raise TuneError(traceback.format_exc())
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\trial_runner.py in _wait_and_handle_event(self, next_trial)
#     728                 result = future_result.result
#     729                 if future_result.type == ExecutorEventType.ERROR:
# --> 730                     self._on_executor_error(trial, result)
#     731                 elif future_result.type == ExecutorEventType.RESTORING_RESULT:
#     732                     self._on_restoring_result(trial)
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\trial_runner.py in _on_executor_error(self, trial, result)
#     872             logger.error(error_msg)
#     873             assert isinstance(result[0], Exception)
# --> 874             raise result[0]
#     875         else:
#     876             logger.exception(error_msg)
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\tune\ray_trial_executor.py in get_next_executor_event(self, live_trials, next_trial_exists)
#     899                 assert isinstance(trial, Trial)
#     900                 try:
# --> 901                     future_result = ray.get(ready_future)
#     902                     # For local mode
#     903                     if isinstance(future_result, _LocalWrapper):
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\_private\client_mode_hook.py in wrapper(*args, **kwargs)
#     103             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105         return func(*args, **kwargs)
#     106
#     107     return wrapper
#
# ~\AppData\Roaming\Python\Python37\site-packages\ray\worker.py in get(object_refs, timeout)
#    1809                     raise value.as_instanceof_cause()
#    1810                 else:
# -> 1811                     raise value
#    1812
#    1813         if is_individual_id:
#
# RayActorError: The actor died because of an error raised in its creation task, ray::_Inner.__init__() (pid=16208, ip=127.0.0.1, repr=<ray.tune.utils.trainable._Trainable object at 0x0000022636CAB708>)
#   File "python\ray\_raylet.pyx", line 621, in ray._raylet.execute_task
#   File "C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray\_private\memory_monitor.py", line 164, in raise_if_low_memory
#     used_gb, total_gb, self.error_threshold
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node Family is used (3.64 / 3.83 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 13608	0.26GiB	C:\Users\quant\Anaconda3\python.exe -m ipykernel_launcher -f C:\Users\quant\AppData\Roaming\jupyter\
# 2868	0.24GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 16208	0.21GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 2344	0.14GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 10860	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 15212	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 5528	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 14756	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 9972	0.13GiB	C:\Users\quant\Anaconda3\python.exe -c from joblib.externals.loky.backend.popen_loky_win32 import ma
# 14256	0.11GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---

# %% [markdown]
# gbr = create_model('gbr', fold = 10)
# gbr = tune_model(gbr,
#                  optimize = 'RMSE',
#                  n_iter = 50,
#                  choose_better = True,
#                  #search_library = "tune-sklearn",
#                  #search_algorithm="bayesian"
#                 )

# %%
rf = create_model('rf', fold = 10)
rf = tune_model(rf, 
                optimize = 'RMSE', 
                n_iter = 50, 
                choose_better = True, 
                search_library = "tune-sklearn", 
                search_algorithm="bayesian")
tuned_models.append(rf)
# Out:
# 2022-04-21 22:01:16,398	ERROR worker.py:93 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::bundle_reservation_check_func() (pid=9316, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 621, in ray._raylet.execute_task
#   File "C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray\_private\memory_monitor.py", line 164, in raise_if_low_memory
#     used_gb, total_gb, self.error_threshold
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node Family is used (3.64 / 3.83 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 7460	0.22GiB	C:\Program Files\Common Files\McAfee\AMCore\mcshield.exe
# 9672	0.19GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 13608	0.17GiB	C:\Users\quant\Anaconda3\python.exe -m ipykernel_launcher -f C:\Users\quant\AppData\Roaming\jupyter\
# 14788	0.09GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --display-capture-permis
# 9316	0.09GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 7504	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 11184	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 2912	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 8052	0.08GiB	C:\Users\quant\Anaconda3\python.exe C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\ray
# 10648	0.08GiB	C:\Users\quant\Anaconda3\python.exe -u C:\Users\quant\AppData\Roaming\Python\Python37\site-packages\
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---

# %% [markdown]
# ### b. Ensemble the Model

# %% [markdown]
# pycaret.regression.ensemble_model(estimator, method: str = 'Bagging', fold: Optional[Union[int, Any]] = None, n_estimators: int = 10, round: int = 4, choose_better: bool = False, optimize: str = 'R2', fit_kwargs: Optional[dict] = None, groups: Optional[Union[str, Any]] = None, verbose: bool = True, return_train_score: bool = False)

# %%
prediction_model = []

tuned_bagged_cb = ensemble_model(estimator = cb, method = 'Bagging', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_bagged_cb)

# %%
tuned_boosted_cb = ensemble_model(estimator = cb, method = 'Boosting', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_boosted_cb)

# %% [markdown]
# Based on the output here, the 'boosting' method has dropped the MAE, MSE and RMSE from 9.03, 128.5 & 11.32 to 8.89, 122.7 and 11.06 respectively

# %%
tuned_bagged_gbr = ensemble_model(estimator = gbr, method = 'Bagging', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_bagged_gbr)

# %%
tuned_boosted_gbr = ensemble_model(estimator = gbr, method = 'Boosting', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_boosted_gbr)

# %% [markdown]
# Based on the output here, none of the methods have improved the MAE, MSE and RMSE

# %%
tuned_bagged_rf = ensemble_model(estimator = rf, method = 'Bagging', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_bagged_rf)

# %%
tuned_boosted_rf = ensemble_model(estimator = rf, method = 'Boosting', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_boosted_rf)

# %% [markdown]
# Based on the output here, the 'boosting' method has improved the statistics.

# %% [markdown]
# ### c. Blending all Models

# %% [markdown]
# pycaret.regression.blend_models(
# estimator_list: list, fold: Optional[Union[int, Any]] = None, round: int = 4, choose_better: bool = False, optimize: str = 'R2', weights: Optional[List[float]] = None, fit_kwargs: Optional[dict] = None, groups: Optional[Union[str, Any]] = None, verbose: bool = True, return_train_score: bool = False )

# %%
blend_5_soft = blend_models(estimator_list = tuned_models, fold=5, optimize = 'RMSE', choose_better = True)
prediction_model.append(blend_5_soft)

# %%
blend_10_soft = blend_models(estimator_list = tuned_models, fold=10, optimize = 'RMSE', choose_better = True)
prediction_model.append(blend_10_soft)

# %% [markdown]
# ### d. Stacking all Models

# %% [markdown]
# pycaret.regression.stack_models(estimator_list: list, meta_model=None, meta_model_fold: Optional[Union[int, Any]] = 5, fold: Optional[Union[int, Any]] = None, round: int = 4, restack: bool = True, choose_better: bool = False, optimize: str = 'R2', fit_kwargs: Optional[dict] = None, groups: Optional[Union[str, Any]] = None, verbose: bool = True, return_train_score: bool = False)

# %%
stack_5 = stack_models(estimator_list = tuned_models, meta_model = cb, fold = 5, optimize = 'RMSE', choose_better= True)
prediction_model.append(stack_5)

# %%
stack_10 = stack_models(estimator_list = tuned_models, meta_model = cb, fold = 10, optimize = 'RMSE', choose_better= True)
prediction_model.append(stack_10)

# %%
prediction_model

# %%
for model in prediction_model:
    print(model.__class__.__name__)
    display(predict_model(model))

# %% [markdown]
# ## 4. Save the Model

# %% [markdown]
# #### Lowest Mean RMSE = 10.99 is "blend_10_soft" which is the blending of all models with 10 K-folds

# %%
save_model(blend_10_soft, 'Blended_model_21042022')

# %% [markdown]
# #### 2nd Lowest Mean RMSE = 11.06 is "tuned_boosted_cb" which is the boosted cat boost

# %%
save_model(tuned_boosted_cb, 'Boosted_CatBoost_21042022')

# %% [markdown]
# #### 3rd Lowest Mean RMSE = 11.15 is "blend_10_soft" which is the boosted Random Forest

# %%
save_model(tuned_boosted_rf, 'Boosted_RF_21042022')

# %% [markdown]
# #### 4th Lowest Mean RMSE = 11.19 is "tuned_boosted_gbr" which is the boosted gradient boost

# %%
save_model(tuned_boosted_gbr, 'Boosted_GBR_21042022')

# %% [markdown]
# ## 5. Finalise the model

# %%
final_blend = finalize_model(blend_10_soft)

# %%
final_db = finalize_model(tuned_boosted_cb)

# %%
final_gbr = finalize_model(tuned_boosted_gbr)

# %%
final_rf = finalize_model(tuned_boosted_rf)

# %%
predict_model(final_blend)

# %%
plot_model(final_blend)

# %%
plot_model(final_blend, plot = 'error')

# %%
#https://towardsdatascience.com/easy-mlops-with-pycaret-mlflow-7fbcbf1e38c6
plot_model(final_blend, plot = 'residuals_interactive')

# %% [markdown]
# ## 6. Blind Test

# %%
dfblind = pd.read_excel("BlindTest_SSOIL.xlsx", thousands=',', skiprows = skiprows)
#dfblind = dfblind.loc[:, ~df.columns.str.contains('^Unnamed')] 
dfblind.head()

# %%
BlindPredict = predict_model(final_blend, data=dfblind, round=0)

# %%
BlindPredict
