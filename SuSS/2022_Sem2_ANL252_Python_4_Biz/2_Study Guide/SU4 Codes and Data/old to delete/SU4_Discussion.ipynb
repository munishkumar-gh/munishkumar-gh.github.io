# %%
import pandas as pd
car_price_model = pd.read_csv("C:/Users/alfredkohpy/car_price_model.csv")

# %%
car_price_model = car_price_model.dropna(axis=0, how='any')

# %%
car_price_model['SGD Price'] = car_price_model['Price']*1.5

# %%
car_price_model
# Out:
#       Year        Make    Model Category    Price  SGD Price
# 9581  2021       Acura      ILX    Sedan  26100.0    39150.0
# 9582  2021       Acura      RDX      SUV  38400.0    57600.0
# 9583  2021       Acura      TLX    Sedan  37500.0    56250.0
# 9584  2021  Alfa Romeo   Giulia    Sedan  40350.0    60525.0
# 9585  2021  Alfa Romeo  Stelvio      SUV  42350.0    63525.0
# ...    ...         ...      ...      ...      ...        ...
# 9816  2021       Volvo      V60    Wagon  40950.0    61425.0
# 9815  2021       Volvo      V90    Wagon  51800.0    77700.0
# 9818  2021       Volvo     XC40      SUV  33700.0    50550.0
# 9819  2021       Volvo     XC60      SUV  41700.0    62550.0
# 9820  2021       Volvo     XC90      SUV  49000.0    73500.0
#
# [240 rows x 6 columns]

# %%
car_price_model.groupby('Make')['SGD Price'].mean()
# Out:
# Make
# Acura             51000.000000
# Alfa Romeo        62025.000000
# Audi              87321.428571
# BMW               76185.000000
# Buick             44812.500000
# Cadillac          75774.642857
# Chevrolet         52144.875000
# Chrysler          47525.000000
# Dodge             46005.000000
# FIAT              38722.500000
# Ford              51438.750000
# GMC               54516.666667
# Genesis           77081.250000
# Honda             43070.625000
# Hyundai           37393.392857
# INFINITI          71950.000000
# Jaguar            83133.750000
# Jeep              44734.687500
# Kia               36940.500000
# Land Rover       102112.500000
# Lexus             81964.500000
# Lincoln           87792.000000
# MAZDA             38881.875000
# Mercedes-Benz    101105.625000
# Mitsubishi        31492.500000
# Nissan            42888.750000
# Polestar          89850.000000
# Porsche          113600.000000
# Ram               52771.250000
# Rivian           114375.000000
# ...
