# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('TMA_Data.csv')
unit = df["Unit"]
unit.value_counts()
# Out:
# Manufacturing    169
# IT                41
# Sales             22
# Engineering       10
# Admin              7
# C-Level            1
# Name: Unit, dtype: int64

# %%
sizes = [68, 16, 9, 4, 3, 0.04]
labels = 'Manufacturing', 'IT', 'Sales', 'Engineering', 'Admin', 'C-Level'

plt.pie(sizes,
       labels = labels,
       autopct='%1.1f%%')

plt.title('% of Employees in Each Department')
plt.axis('equal')

plt.show()
