# %% [markdown]
# # TMA

# %%
import pandas as pd

data = pd.read_excel (r'TMA.xlsx', sheet_name='TMA_Data')
print (data)
# Out:
#       ID             Staff            BirthYear Gender   Marital  \
# 0      1   Aairah Hastings  1986-07-10 00:00:00      F    Single
# 1      2  Aaminah Mcmillan             05/25/86      F   Married
# 2      3      Aamna Howell             04/20/85      F    Single
# 3      4     Aayan Ferrell  1984-10-06 00:00:00     M    Married
# 4      5        Ace Potter  1989-08-09 00:00:00      F  Divorced
# ..   ...               ...                  ...    ...       ...
# 245  246     Zaina Parrish  1981-11-10 00:00:00      F   Married
# 246  247       Zane Downes             10/24/87     M    Married
# 247  248       Zayd Farley  1970-09-07 00:00:00     M     Single
# 248  249       Zoya Easton  1980-02-08 00:00:00      F    Single
# 249  250    Zuzanna Pruitt             05/21/87      F    Single
#
#       Citizenship Minority             JoinDate             LeftDate  \
# 0         Citizen      Yes  2012-02-04 00:00:00                  NaN
# 1         Citizen       No  2014-12-05 00:00:00                  NaN
# 2         Citizen       No            9/29/2014                  NaN
# 3         Citizen       No  2016-05-01 00:00:00                  NaN
# 4         Citizen       No  2011-11-07 00:00:00  2020-06-09 00:00:00
# ..            ...      ...                  ...                  ...
# 245  Non-Resident       No            2/16/2015                  NaN
# 246  Non-Resident       No            4/20/2017                  NaN
# 247  Non-Resident       No  2014-05-01 00:00:00                  NaN
# 248  Non-Resident       No            8/13/2012  2015-01-09 00:00:00
# 249  Non-Resident       No            3/30/2015                  NaN
#
#               Unit  Salary PerformanceScore  Survey  Satisfaction  Absence
# 0    Manufacturing   46335             Meet    3.40             5       15
# 1    Manufacturing   66825             Meet    4.60             3       20
# 2    Manufacturing   60446             Meet    3.40             4       14
# 3           Admin    93046             Meet    4.10             4       20
# 4    Manufacturing   50825             Meet    5.00             4        2
# ..             ...     ...              ...     ...           ...      ...
# 245             IT   89883             Meet    3.69             5       15
# 246             IT   90100             Meet    3.40             3       14
# 247             IT  138888           Exceed    4.30             5        4
# 248  Manufacturing   50274       To Improve    2.50             3       13
# 249  Manufacturing   55315             Meet    5.00             5       16
#
# [250 rows x 15 columns]

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data)
df[[ 'Staff','Marital', 'Citizenship', 'Minority', 'Unit', 'PerformanceScore', 'in Company']] = df[['Staff','Marital', 'Citizenship', 'Minority', 'Unit', 'PerformanceScore', 'in Company']].astype(str)
print(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 df = pd.DataFrame(data)
# ----> 2 df[[ 'Staff','Marital', 'Citizenship', 'Minority', 'Unit', 'PerformanceScore', 'in Company']] = df[['Staff','Marital', 'Citizenship', 'Minority', 'Unit', 'PerformanceScore', 'in Company']].astype(str)
#       3 print(data)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['in Company'] not in index"

# %% [markdown]
# ___________

# %% [markdown]
# # b)

# %%
# importing the required module
import matplotlib.pyplot as plt
  
# x axis values
x = ['Divorced','Married','Others','Single']
# corresponding y axis values
y = [13,56,13,83]
  
# plotting the points 
plt.plot(x, y)
  
# naming the x axis
plt.xlabel('Marital Status')
# naming the y axis
plt.ylabel('Current Employee')
  
# giving a title to my graph
plt.title('Employment Status By Marital Status - Current')
  
# function to show the plot
plt.show()

# %%
# importing the required module
import matplotlib.pyplot as plt

# x axis values
x = ['Divorced','Married','Others','Single']
# corresponding y axis values
y = [13,38,3,31]
  
# plotting the points 
plt.plot(x, y)
  
# naming the x axis
plt.xlabel('Marital Status')
# naming the y axis
plt.ylabel('Former Employee')
  
# giving a title to my graph
plt.title('Employment Status By Marital Status - Former')
  
# function to show the plot
plt.show()

# %%
# importing the required module
import matplotlib.pyplot as plt
  
# x axis values
x = [1,2,3,4,5]
# corresponding y axis values
y = [1,1,45,48,49]
  
# plotting the points 
plt.plot(x, y)
  
# naming the x axis
plt.xlabel('Satisfaction Score')
# naming the y axis
plt.ylabel('No. of Female Employee')
  
# giving a title to my graph
plt.title('Employee Satisifaction Level By Gender (Female)')
  
# function to show the plot
plt.show()

# %%
# importing the required module
import matplotlib.pyplot as plt
  

# x axis values
x = [1,2,3,4,5]
# corresponding y axis values
y = [0,3,39,32,32]
  
# plotting the points 
plt.plot(x, y)
  
# naming the x axis
plt.xlabel('Satisfaction Score')
# naming the y axis
plt.ylabel('No. of Female Employee')
  
# giving a title to my graph
plt.title('Employee Satisifaction Level By Gender (Male)')
  
# function to show the plot
plt.show()

# %% [markdown]
# # c)

# %%
import pandas as pd
import numpy as np


Ldata = pd.read_excel (r'TMA.xlsx', sheet_name='Left Date')
print (Ldata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 5>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 5 Ldata = pd.read_excel (r'TMA.xlsx', sheet_name='Left Date')
#       6 print (Ldata)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py:465, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#     464 try:
# --> 465     data = io.parse(
#     466         sheet_name=sheet_name,
#     467         header=header,
#     468         names=names,
#     469         index_col=index_col,
#     470         usecols=usecols,
#     471         squeeze=squeeze,
#     472         dtype=dtype,
#     473         converters=converters,
#     474         true_values=true_values,
#     475         false_values=false_values,
#     476         skiprows=skiprows,
#     477         nrows=nrows,
#     478         na_values=na_values,
#     479         keep_default_na=keep_default_na,
#     480         na_filter=na_filter,
#     481         verbose=verbose,
#     482         parse_dates=parse_dates,
#     483         date_parser=date_parser,
#     484         thousands=thousands,
#     485         decimal=decimal,
#     486         comment=comment,
#     487         skipfooter=skipfooter,
#     488         convert_float=convert_float,
#     489         mangle_dupe_cols=mangle_dupe_cols,
#     490     )
#     491 finally:
#     492     # make sure to close opened file handles
#     493     if should_close:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py:1458, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1424 def parse(
#    1425     self,
#    1426     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1445     **kwds,
#    1446 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1447     """
#    1448     Parse specified sheet(s) into a DataFrame.
#    1449
#    (...)
#    1456         DataFrame from the passed in Excel file.
#    1457     """
# -> 1458     return self._reader.parse(
#    1459         sheet_name=sheet_name,
#    1460         header=header,
#    1461         names=names,
#    1462         index_col=index_col,
#    1463         usecols=usecols,
#    1464         squeeze=squeeze,
#    1465         converters=converters,
#    1466         true_values=true_values,
#    1467         false_values=false_values,
#    1468         skiprows=skiprows,
#    1469         nrows=nrows,
#    1470         na_values=na_values,
#    1471         parse_dates=parse_dates,
#    1472         date_parser=date_parser,
#    1473         thousands=thousands,
#    1474         comment=comment,
#    1475         skipfooter=skipfooter,
#    1476         convert_float=convert_float,
#    1477         mangle_dupe_cols=mangle_dupe_cols,
#    1478         **kwds,
#    1479     )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py:634, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     631     print(f"Reading sheet {asheetname}")
#     633 if isinstance(asheetname, str):
# --> 634     sheet = self.get_sheet_by_name(asheetname)
#     635 else:  # assume an integer if not a string
#     636     sheet = self.get_sheet_by_index(asheetname)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:545, in OpenpyxlReader.get_sheet_by_name(self, name)
#     544 def get_sheet_by_name(self, name: str):
# --> 545     self.raise_if_bad_sheet_by_name(name)
#     546     return self.book[name]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py:570, in BaseExcelReader.raise_if_bad_sheet_by_name(self, name)
#     568 def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     569     if name not in self.sheet_names:
# --> 570         raise ValueError(f"Worksheet named '{name}' not found")
#
# ValueError: Worksheet named 'Left Date' not found

# %%
df = pd.DataFrame(Ldata, columns= ['JoinDate','LeftDate'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 df = pd.DataFrame(Ldata, columns= ['JoinDate','LeftDate'])
#       2 print(df)
#
# NameError: name 'Ldata' is not defined

# %%
import numpy as np
import pandas as pd
import datetime as datetime

data = pd.DataFrame({'p1': Param1,'p2': Param2})
startDT = data['p1']
endDT = data['p2']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 5>()
#       2 import pandas as pd
#       3 import datetime as datetime
# ----> 5 data = pd.DataFrame({'p1': Param1,'p2': Param2})
#       6 startDT = data['p1']
#       7 endDT = data['p2']
#
# NameError: name 'Param1' is not defined

# %% [markdown]
# # d)

# %%
name = pd.DataFrame(data, columns= [('Staff')])
print(name)
# Out:
#                 Staff
# 0     Aairah Hastings
# 1    Aaminah Mcmillan
# 2        Aamna Howell
# 3       Aayan Ferrell
# 4          Ace Potter
# ..                ...
# 245     Zaina Parrish
# 246       Zane Downes
# 247       Zayd Farley
# 248       Zoya Easton
# 249    Zuzanna Pruitt
#
# [250 rows x 1 columns]

# %%
name = ("Aairah Hastings","Aaminah Mcmillan","Aamna Howell")
employment_status = ("employed")

while True:
        user_input = input("What is the name of the employee?")
        if user_input in name:
            name_index = name.index(user_input)
            employment_status = employment_status
            print(f"The staff of name {user_input} is {employment_status} by the company.")
            break
        else:
            user_input = input("Invalid input. Please try again.")
# Out:
# What is the name of the employee?Ashleigh Mccabe

# %% [markdown]
# # Other working

# %%
Marital_InCompany = pd.DataFrame(data, columns= [('Marital'),('in Company')])
print(Marital_InCompany)

# %%
# the histogram of the data

#for y in data.ndim: 
#    print(data[:,in Company]
print(data.shape)
print(data.size)
print(data.ndim) #ndim = 2 because this is a 2D table
feature_names = ['Single', 'Married', 'Divorced', 'Others']

# %%
y = pd.DataFrame(data, columns= ['in Company N'])
print(y)

# %%
Divorced = [13,13]
Married = [56,58]
Others = [13,3]
Single = [83,31]

Marital_Status = ["Divorced,Married,Others,Single"]
