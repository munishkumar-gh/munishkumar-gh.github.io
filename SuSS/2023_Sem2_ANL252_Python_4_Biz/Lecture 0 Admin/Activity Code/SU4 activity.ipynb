# %% [markdown]
# # First activity

# %%
import pandas as pd
car_model = pd.read_csv("car_model.csv")

# %%
print(car_model)
# Out:
#      Year        Make    Model Category
# 0    2021       Acura      ILX    Sedan
# 1    2021       Acura      RDX      SUV
# 2    2021       Acura      TLX    Sedan
# 3    2021  Alfa Romeo   Giulia    Sedan
# 4    2021  Alfa Romeo  Stelvio      SUV
# ..    ...         ...      ...      ...
# 235  2021       Volvo      V60    Wagon
# 236  2021  Volkswagen   Tiguan      SUV
# 237  2021       Volvo     XC40      SUV
# 238  2021       Volvo     XC60      SUV
# 239  2021       Volvo     XC90      SUV
#
# [240 rows x 4 columns]

# %%
display(car_model)
# Out:
#      Year        Make    Model Category
# 0    2021       Acura      ILX    Sedan
# 1    2021       Acura      RDX      SUV
# 2    2021       Acura      TLX    Sedan
# 3    2021  Alfa Romeo   Giulia    Sedan
# 4    2021  Alfa Romeo  Stelvio      SUV
# ..    ...         ...      ...      ...
# 235  2021       Volvo      V60    Wagon
# 236  2021  Volkswagen   Tiguan      SUV
# 237  2021       Volvo     XC40      SUV
# 238  2021       Volvo     XC60      SUV
# 239  2021       Volvo     XC90      SUV
#
# [240 rows x 4 columns]

# %%
car_model.tail(10)
# Out:
#      Year        Make   Model   Category
# 230  2021  Volkswagen   Jetta      Sedan
# 231  2021  Volkswagen    Golf  Hatchback
# 232  2021  Volkswagen  Passat      Sedan
# 233  2021       Volvo     S90      Sedan
# 234  2021       Volvo     V90      Wagon
# 235  2021       Volvo     V60      Wagon
# 236  2021  Volkswagen  Tiguan        SUV
# 237  2021       Volvo    XC40        SUV
# 238  2021       Volvo    XC60        SUV
# 239  2021       Volvo    XC90        SUV

# %%
car_model.head(20)
# Out:
#     Year        Make       Model                 Category
# 0   2021       Acura         ILX                    Sedan
# 1   2021       Acura         RDX                      SUV
# 2   2021       Acura         TLX                    Sedan
# 3   2021  Alfa Romeo      Giulia                    Sedan
# 4   2021  Alfa Romeo     Stelvio                      SUV
# 5   2021        Audi  A6 allroad                    Wagon
# 6   2021        Audi          A7                    Sedan
# 7   2021        Audi          Q3                      SUV
# 8   2021        Audi          Q5                      SUV
# 9   2021        Audi          Q8                      SUV
# 10  2021        Audi          S5  Convertible,Sedan,Coupe
# 11  2021        Audi          S6                    Sedan
# 12  2021         BMW    3 Series                    Sedan
# 13  2021         BMW          X1                      SUV
# 14  2021         BMW          X3                      SUV
# 15  2021         BMW          X5                      SUV
# 16  2021         BMW          X7                      SUV
# 17  2021       Buick     Enclave                      SUV
# 18  2021       Buick      Encore                      SUV
# 19  2021       Buick   Encore GX                      SUV

# %%
#check the number of rows
len(car_model)
# Out:
# 240

# %%
#check the number of columns
len(car_model.columns)
# Out:
# 4

# %%
car_model.shape
# Out:
# (240, 4)

# %% [markdown]
# # Second activity

# %%
car_model["Make"]
# Out:
# 0           Acura
# 1           Acura
# 2           Acura
# 3      Alfa Romeo
# 4      Alfa Romeo
#           ...
# 235         Volvo
# 236    Volkswagen
# 237         Volvo
# 238         Volvo
# 239         Volvo
# Name: Make, Length: 240, dtype: object

# %%
car_model.loc[:, 'Make']  #how to use loc to pick "Make" column?
# Out:
# 0           Acura
# 1           Acura
# 2           Acura
# 3      Alfa Romeo
# 4      Alfa Romeo
#           ...
# 235         Volvo
# 236    Volkswagen
# 237         Volvo
# 238         Volvo
# 239         Volvo
# Name: Make, Length: 240, dtype: object

# %%
car_model[car_model['Make'] == 'Audi']
# Out:
#     Year  Make       Model                 Category
# 5   2021  Audi  A6 allroad                    Wagon
# 6   2021  Audi          A7                    Sedan
# 7   2021  Audi          Q3                      SUV
# 8   2021  Audi          Q5                      SUV
# 9   2021  Audi          Q8                      SUV
# 10  2021  Audi          S5  Convertible,Sedan,Coupe
# 11  2021  Audi          S6                    Sedan

# %%
car_model.tail(10)["Year"]
# Out:
# 230    2021
# 231    2021
# 232    2021
# 233    2021
# 234    2021
# 235    2021
# 236    2021
# 237    2021
# 238    2021
# 239    2021
# Name: Year, dtype: int64

# %%
car_model["Year"].tail(10)
# Out:
# 230    2021
# 231    2021
# 232    2021
# 233    2021
# 234    2021
# 235    2021
# 236    2021
# 237    2021
# 238    2021
# 239    2021
# Name: Year, dtype: int64

# %% [markdown]
# # Thrid Activity

# %%
# check for nulls in the Price field
import pandas as pd
car_price_model = pd.read_csv("car_price_model.csv")
car_price_model['Price'].isnull()
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# Name: Price, Length: 240, dtype: bool

# %%
clean = car_price_model.dropna(subset=['Price']) # only do dropna() on Price column's missing values
# save clean data in a new dataframe, car_joined_model stays the same
clean
# Out:
#      Year        Make       Model    Price
# 2    2021       Acura         TLX  37500.0
# 3    2021  Alfa Romeo      Giulia  40350.0
# 4    2021  Alfa Romeo     Stelvio  42350.0
# 5    2021        Audi  A6 allroad  65900.0
# 6    2021        Audi          A7  69200.0
# ..    ...         ...         ...      ...
# 235  2021       Volvo         V60  40950.0
# 236  2021  Volkswagen      Tiguan  25245.0
# 237  2021       Volvo        XC40  33700.0
# 238  2021       Volvo        XC60  41700.0
# 239  2021       Volvo        XC90  49000.0
#
# [238 rows x 4 columns]

# %%
#confirm no missing values in Price column
clean['Price'].isnull().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
plt.boxplot(clean['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20ca37edf10>,
#   <matplotlib.lines.Line2D at 0x20ca580c220>],
#  'caps': [<matplotlib.lines.Line2D at 0x20ca580c4f0>,
#   <matplotlib.lines.Line2D at 0x20ca580c7c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20ca37edc40>],
#  'medians': [<matplotlib.lines.Line2D at 0x20ca580ca90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20ca580cd60>],
#  'means': []}

# %%
# get the 25th percentile, and the 75th percentile
q1 = clean['Price'].quantile(.25)
q3 = clean['Price'].quantile(.75)

# %%
# get the interquartile range
iqr = q3 - q1
iqr
# Out:
# 19090.0

# %%
# list statuses of all prices: True means not an oulier
# note: & is a bitwise AND operator
~((clean['Price'] < q1 - 1.5*iqr) | (clean['Price'] > q3 + 1.5*iqr))
# Out:
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
#        ...
# 235    True
# 236    True
# 237    True
# 238    True
# 239    True
# Name: Price, Length: 238, dtype: bool

# %%
# show records with normal prices (there are 216 records)
clean[~((clean['Price'] < q1 - 1.5*iqr) | (clean['Price'] > q3 + 1.5*iqr))]
# Out:
#      Year        Make       Model    Price
# 2    2021       Acura         TLX  37500.0
# 3    2021  Alfa Romeo      Giulia  40350.0
# 4    2021  Alfa Romeo     Stelvio  42350.0
# 5    2021        Audi  A6 allroad  65900.0
# 6    2021        Audi          A7  69200.0
# ..    ...         ...         ...      ...
# 235  2021       Volvo         V60  40950.0
# 236  2021  Volkswagen      Tiguan  25245.0
# 237  2021       Volvo        XC40  33700.0
# 238  2021       Volvo        XC60  41700.0
# 239  2021       Volvo        XC90  49000.0
#
# [216 rows x 4 columns]

# %%
# show records outside normal prices
# Python's Tilde ~n operator is the bitwise negation operator: 
# it takes the number n as binary number and “flips” all bits 0 to 1 and 1 to 0 to obtain the complement binary number.
# For example, the tilde operation ~1 becomes 0 and ~0 becomes 1 and ~101 becomes 010

clean[(clean['Price'] < q1 - 1.5*iqr) | (clean['Price'] > q3 + 1.5*iqr)]
# Out:
#      Year           Make                       Model     Price
# 11   2021           Audi                          S6   74400.0
# 16   2021            BMW                          X7   74900.0
# 23   2021       Cadillac                    Escalade   76195.0
# 24   2021       Cadillac                Escalade ESV   79195.0
# 41   2021      Chevrolet  Silverado 3500 HD Crew Cab   80000.0
# 130  2021     Land Rover                 Range Rover   92000.0
# 136  2021          Lexus                          LC   93050.0
# 137  2021          Lexus                          LS   76000.0
# 138  2021          Lexus                          LX   86830.0
# 146  2021        Lincoln                   Navigator   76750.0
# 147  2021        Lincoln                 Navigator L   85715.0
# 159  2021  Mercedes-Benz                     G-Class  131750.0
# 164  2021  Mercedes-Benz        Mercedes-AMG G-Class  160000.0
# 181  2021        Porsche                  718 Spyder   97300.0
# 182  2021        Porsche                         911   99200.0
# 184  2021        Porsche                      Taycan   79900.0
# 185  2021        Porsche                    Panamera   87200.0
# 186  2021        Porsche               Cayenne Coupe   76500.0
# 192  2021         Rivian                         R1S   77500.0
# 194  2021         Rivian                         R1T   75000.0
# 202  2021          Tesla                     Model X   79990.0
# 215  2021         Toyota                Land Cruiser   85665.0

# %% [markdown]
# #### Discussion
# Discuss whether the models with extraordinarily high/low selling prices should be excluded from the DataFrame.

# %% [markdown]
# # Fourth Activity

# %%
car_price_model = pd.read_csv("car_price_model.csv")
car_price_model
# Out:
#      Year        Make    Model    Price
# 0    2021       Acura      ILX      NaN
# 1    2021       Acura      RDX      NaN
# 2    2021       Acura      TLX  37500.0
# 3    2021  Alfa Romeo   Giulia  40350.0
# 4    2021  Alfa Romeo  Stelvio  42350.0
# ..    ...         ...      ...      ...
# 235  2021       Volvo      V60  40950.0
# 236  2021  Volkswagen   Tiguan  25245.0
# 237  2021       Volvo     XC40  33700.0
# 238  2021       Volvo     XC60  41700.0
# 239  2021       Volvo     XC90  49000.0
#
# [240 rows x 4 columns]

# %%
# Drop the rows where at least one element is missing.
car_price_model = car_price_model.dropna()
car_price_model
# Out:
#      Year        Make       Model    Price
# 2    2021       Acura         TLX  37500.0
# 3    2021  Alfa Romeo      Giulia  40350.0
# 4    2021  Alfa Romeo     Stelvio  42350.0
# 5    2021        Audi  A6 allroad  65900.0
# 6    2021        Audi          A7  69200.0
# ..    ...         ...         ...      ...
# 235  2021       Volvo         V60  40950.0
# 236  2021  Volkswagen      Tiguan  25245.0
# 237  2021       Volvo        XC40  33700.0
# 238  2021       Volvo        XC60  41700.0
# 239  2021       Volvo        XC90  49000.0
#
# [238 rows x 4 columns]

# %%
# Add a new column named SGD Price 1.5 times of the Price
car_price_model['SGD Price'] = car_price_model['Price']*1.5   
car_price_model
# Out:
# C:\Users\siyingzhu\AppData\Local\Temp\ipykernel_18104\2935792358.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_price_model['SGD Price'] = car_price_model['Price']*1.5
#      Year        Make       Model    Price  SGD Price
# 2    2021       Acura         TLX  37500.0    56250.0
# 3    2021  Alfa Romeo      Giulia  40350.0    60525.0
# 4    2021  Alfa Romeo     Stelvio  42350.0    63525.0
# 5    2021        Audi  A6 allroad  65900.0    98850.0
# 6    2021        Audi          A7  69200.0   103800.0
# ..    ...         ...         ...      ...        ...
# 235  2021       Volvo         V60  40950.0    61425.0
# 236  2021  Volkswagen      Tiguan  25245.0    37867.5
# 237  2021       Volvo        XC40  33700.0    50550.0
# 238  2021       Volvo        XC60  41700.0    62550.0
# 239  2021       Volvo        XC90  49000.0    73500.0
#
# [238 rows x 5 columns]

# %%
car_price_model.sort_values(by = ['SGD Price'], ascending=True)
# Out:
#      Year           Make                 Model     Price  SGD Price
# 42   2021      Chevrolet                 Spark   13600.0    20400.0
# 176  2021         Nissan                 Versa   14980.0    22470.0
# 92   2021        Hyundai                Accent   15395.0    23092.5
# 121  2021            Kia                   Rio   16050.0    24075.0
# 124  2021            Kia                  Soul   17590.0    26385.0
# ..    ...            ...                   ...       ...        ...
# 136  2021          Lexus                    LC   93050.0   139575.0
# 181  2021        Porsche            718 Spyder   97300.0   145950.0
# 182  2021        Porsche                   911   99200.0   148800.0
# 159  2021  Mercedes-Benz               G-Class  131750.0   197625.0
# 164  2021  Mercedes-Benz  Mercedes-AMG G-Class  160000.0   240000.0
#
# [238 rows x 5 columns]

# %%
car_price_model.groupby(by = ['Make']).mean()
# Out:
#                  Year         Price      SGD Price
# Make
# Acura          2021.0  37500.000000   56250.000000
# Alfa Romeo     2021.0  41350.000000   62025.000000
# Audi           2021.0  58214.285714   87321.428571
# BMW            2021.0  50790.000000   76185.000000
# Buick          2021.0  29875.000000   44812.500000
# Cadillac       2021.0  50516.428571   75774.642857
# Chevrolet      2021.0  34763.250000   52144.875000
# Chrysler       2021.0  31683.333333   47525.000000
# Dodge          2021.0  30670.000000   46005.000000
# FIAT           2021.0  25815.000000   38722.500000
# Ford           2021.0  34292.500000   51438.750000
# GMC            2021.0  36344.444444   54516.666667
# Genesis        2021.0  51387.500000   77081.250000
# Honda          2021.0  28713.750000   43070.625000
# Hyundai        2021.0  24928.928571   37393.392857
# INFINITI       2021.0  47966.666667   71950.000000
# Jaguar         2021.0  55422.500000   83133.750000
# Jeep           2021.0  29823.125000   44734.687500
# Kia            2021.0  24627.000000   36940.500000
# Land Rover     2021.0  68075.000000  102112.500000
# Lexus          2021.0  54643.000000   81964.500000
# Lincoln        2021.0  58528.000000   87792.000000
# MAZDA          2021.0  25921.250000   38881.875000
# Mercedes-Benz  2021.0  67403.750000  101105.625000
# Mitsubishi     2021.0  20995.000000   31492.500000
# Nissan         2021.0  28592.500000   42888.750000
# Polestar       2021.0  59900.000000   89850.000000
# Porsche        2021.0  75733.333333  113600.000000
# Ram            2021.0  35180.833333   52771.250000
# Rivian         2021.0  76250.000000  114375.000000
# Subaru         2021.0  24636.666667   36955.000000
# Tesla          2021.0  74705.000000  112057.500000
# Toyota         2021.0  33598.600000   50397.900000
# Volkswagen     2021.0  25638.333333   38457.500000
# Volvo          2021.0  46200.000000   69300.000000
