# %% [markdown]
# # ANL252 Python for Data Analytics
# ## Jupyter Notebook Demo File
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Study Unit 1
# ## We will begin by using the Boston housing data from sklearn libary. You will learn more about this library later.

# %%
import pandas as pd
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"

###The following pd.read_csv function is for read data. 
###If you want to read data from some other url link, just replace the data_url above
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)


data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
# print the data content. Note: the three dots in the middle of the output means values in the middle of each row are omitted

print(data)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
# print the target content, which is the MEDV field (Median value of owner-occupied homes in $1000's)
# Target contains a set of values used for predictive modelling, which we will not worry about for now.
print(target)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
# the target contains a set of values (i.e., median house prices) stored in a data format called "array"
# you will learn more about arracy later
# here are some simple operations we can do about the access
# assign the values housing.target to another array named housing_price"
housing_price = target

# %%
# we can print the content of the first entry in the array
print(housing_price[0])
# Out:
# 24.0

# %%
# we can print the first ten values of the median house prices
print(housing_price[0:10])
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9]

# %%
# we can also use a for loop to print the first ten values of the median house prices
for x in housing_price:
 print(x)
# Out:
# 24.0
# 21.6
# 34.7
# 33.4
# 36.2
# 28.7
# 22.9
# 27.1
# 16.5
# 18.9
# 15.0
# 18.9
# 21.7
# 20.4
# 18.2
# 19.9
# 23.1
# 17.5
# 20.2
# 18.2
# 13.6
# 19.6
# 15.2
# 14.5
# 15.6
# 13.9
# 16.6
# 14.8
# 18.4
# 21.0
# 12.7
# 14.5
# 13.2
# 13.1
# 13.5
# 18.9
# 20.0
# 21.0
# 24.7
# 30.8
# 34.9
# 26.6
# 25.3
# 24.7
# 21.2
# 19.3
# 20.0
# 16.6
# 14.4
# 19.4
# 19.7
# 20.5
# 25.0
# 23.4
# 18.9
# 35.4
# 24.7
# 31.6
# 23.3
# 19.6
# 18.7
# 16.0
# 22.2
# 25.0
# 33.0
# 23.5
# 19.4
# 22.0
# 17.4
# 20.9
# 24.2
# 21.7
# 22.8
# 23.4
# 24.1
# 21.4
# 20.0
# 20.8
# 21.2
# 20.3
# 28.0
# 23.9
# 24.8
# 22.9
# 23.9
# 26.6
# 22.5
# 22.2
# 23.6
# 28.7
# 22.6
# 22.0
# 22.9
# 25.0
# 20.6
# 28.4
# 21.4
# 38.7
# 43.8
# 33.2
# 27.5
# 26.5
# 18.6
# 19.3
# 20.1
# 19.5
# 19.5
# 20.4
# 19.8
# 19.4
# 21.7
# 22.8
# 18.8
# 18.7
# 18.5
# 18.3
# 21.2
# 19.2
# 20.4
# 19.3
# 22.0
# 20.3
# 20.5
# 17.3
# 18.8
# 21.4
# 15.7
# 16.2
# 18.0
# 14.3
# 19.2
# 19.6
# 23.0
# 18.4
# 15.6
# 18.1
# 17.4
# 17.1
# 13.3
# 17.8
# 14.0
# 14.4
# ...

# %%
# we can also use a for loop to print the first ten values of the median house prices
for x in housing_price:
 print(x)
 if x == 18.9:
        break
# Out:
# 24.0
# 21.6
# 34.7
# 33.4
# 36.2
# 28.7
# 22.9
# 27.1
# 16.5
# 18.9

# %%
# Previous example is not elegant in two ways:
# You need to know that the 10th value is 18.9
# It is generally not a good practice to use break unless there is no other option
# following is a more elegant code to print the first ten values of the median house prices
for x in housing_price[0:10]:
 print(x)
# Out:
# 24.0
# 21.6
# 34.7
# 33.4
# 36.2
# 28.7
# 22.9
# 27.1
# 16.5
# 18.9

# %%
# Let's find the average price of the first ten vmedian house prices
avg = 0
for x in housing_price[0:10]:
 avg = avg + x
print("Average of first ten median house prices = ", avg/10)
# Out:
# Average of first ten median house prices =  26.4

# %%
# you can do some plots using matplotlib
# we will cover matplotlib in details later
# we will just use it for now

import matplotlib.pyplot as plt

plt.boxplot(housing_price)
plt.ylabel('Housing Price')
plt.xlabel('Box Plot of Housing Price')
plt.show()

# %%
# you can do some plots using matplotlib
# we will cover matplotlib in details later
# we will just use it for now

import matplotlib.pyplot as plt

# the histogram of the data
n, bins, patches = plt.hist(housing_price, 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Housing Price')
plt.ylabel('Probability')
plt.title('Histogram of Housing Price')
plt.text(25, .04, r'$\mu=26.4$')
plt.xlim(0, 60)
plt.ylim(0, 0.1)
plt.grid(True)
plt.show()

# %% [markdown]
# # Study Unit 2
# ## We will using tuples, list and array data structures to manage and plot data...

# %%
# the data contains a set of values related housing features stored in a data format called "array"
# you will learn more about array later
# here are some simple operations we can do about the access
# assign the values housing.data to another array named features_data"
features_data = data

for x in features_data:
 print(x,'\n')
 for y in x:
   print(y, end=', ')
 print('\n')
# Out:
# [6.320e-03 1.800e+01 2.310e+00 0.000e+00 5.380e-01 6.575e+00 6.520e+01
#  4.090e+00 1.000e+00 2.960e+02 1.530e+01 3.969e+02 4.980e+00]
#
# 0.00632, 18.0, 2.31, 0.0, 0.538, 6.575, 65.2, 4.09, 1.0, 296.0, 15.3, 396.9, 4.98,
#
# [2.7310e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 6.4210e+00
#  7.8900e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9690e+02
#  9.1400e+00]
#
# 0.02731, 0.0, 7.07, 0.0, 0.469, 6.421, 78.9, 4.9671, 2.0, 242.0, 17.8, 396.9, 9.14,
#
# [2.7290e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 7.1850e+00
#  6.1100e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9283e+02
#  4.0300e+00]
#
# 0.02729, 0.0, 7.07, 0.0, 0.469, 7.185, 61.1, 4.9671, 2.0, 242.0, 17.8, 392.83, 4.03,
#
# [3.2370e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 6.9980e+00
#  4.5800e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9463e+02
#  2.9400e+00]
#
# 0.03237, 0.0, 2.18, 0.0, 0.458, 6.998, 45.8, 6.0622, 3.0, 222.0, 18.7, 394.63, 2.94,
#
# ...

# %%
# the data contains a set of values related housing features stored in a data format called "array"
# we will convert it to another data format called tuple

housing_data = data

# Method 1
#tuple_data = tuple([tuple(e) for e in housing_data])

#Method 2
tuple_data = tuple(map(tuple, housing_data))

#print(tuple_data)

# Use While loop to print the tuple contents
i = 0
while i < len(tuple_data):
 print(tuple_data[i])
 i = i+ 1
# Out:
# (0.00632, 18.0, 2.31, 0.0, 0.538, 6.575, 65.2, 4.09, 1.0, 296.0, 15.3, 396.9, 4.98)
# (0.02731, 0.0, 7.07, 0.0, 0.469, 6.421, 78.9, 4.9671, 2.0, 242.0, 17.8, 396.9, 9.14)
# (0.02729, 0.0, 7.07, 0.0, 0.469, 7.185, 61.1, 4.9671, 2.0, 242.0, 17.8, 392.83, 4.03)
# (0.03237, 0.0, 2.18, 0.0, 0.458, 6.998, 45.8, 6.0622, 3.0, 222.0, 18.7, 394.63, 2.94)
# (0.06905, 0.0, 2.18, 0.0, 0.458, 7.147, 54.2, 6.0622, 3.0, 222.0, 18.7, 396.9, 5.33)
# (0.02985, 0.0, 2.18, 0.0, 0.458, 6.43, 58.7, 6.0622, 3.0, 222.0, 18.7, 394.12, 5.21)
# (0.08829, 12.5, 7.87, 0.0, 0.524, 6.012, 66.6, 5.5605, 5.0, 311.0, 15.2, 395.6, 12.43)
# (0.14455, 12.5, 7.87, 0.0, 0.524, 6.172, 96.1, 5.9505, 5.0, 311.0, 15.2, 396.9, 19.15)
# (0.21124, 12.5, 7.87, 0.0, 0.524, 5.631, 100.0, 6.0821, 5.0, 311.0, 15.2, 386.63, 29.93)
# (0.17004, 12.5, 7.87, 0.0, 0.524, 6.004, 85.9, 6.5921, 5.0, 311.0, 15.2, 386.71, 17.1)
# (0.22489, 12.5, 7.87, 0.0, 0.524, 6.377, 94.3, 6.3467, 5.0, 311.0, 15.2, 392.52, 20.45)
# ...

# %%
# print the first two columns of each tuple
# Use While loop to print the tuple contents
i = 0
while i < len(tuple_data):
  print(tuple_data[i][0:2])
  i = i+ 1
# Out:
# (0.00632, 18.0)
# (0.02731, 0.0)
# (0.02729, 0.0)
# (0.03237, 0.0)
# (0.06905, 0.0)
# (0.02985, 0.0)
# (0.08829, 12.5)
# (0.14455, 12.5)
# (0.21124, 12.5)
# (0.17004, 12.5)
# (0.22489, 12.5)
# (0.11747, 12.5)
# (0.09378, 12.5)
# (0.62976, 0.0)
# (0.63796, 0.0)
# (0.62739, 0.0)
# (1.05393, 0.0)
# (0.7842, 0.0)
# (0.80271, 0.0)
# (0.7258, 0.0)
# (1.25179, 0.0)
# (0.85204, 0.0)
# (1.23247, 0.0)
# (0.98843, 0.0)
# (0.75026, 0.0)
# (0.84054, 0.0)
# (0.67191, 0.0)
# (0.95577, 0.0)
# (0.77299, 0.0)
# (1.00245, 0.0)
# (1.13081, 0.0)
# (1.35472, 0.0)
# (1.38799, 0.0)
# (1.15172, 0.0)
# (1.61282, 0.0)
# (0.06417, 0.0)
# (0.09744, 0.0)
# (0.08014, 0.0)
# (0.17505, 0.0)
# (0.02763, 75.0)
# (0.03359, 75.0)
# (0.12744, 0.0)
# (0.1415, 0.0)
# (0.15936, 0.0)
# (0.12269, 0.0)
# (0.17142, 0.0)
# (0.18836, 0.0)
# (0.22927, 0.0)
# (0.25387, 0.0)
# (0.21977, 0.0)
# (0.08873, 21.0)
# (0.04337, 21.0)
# (0.0536, 21.0)
# (0.04981, 21.0)
# (0.0136, 75.0)
# (0.01311, 90.0)
# (0.02055, 85.0)
# (0.01432, 100.0)
# ...

# %%
# the data contains a set of values related housing features stored in a data format called "array"
# we will convert it to another data format called list
# you will learn more about array later
housing_data = data.tolist()
#print(housing_data)
# Use While loop to print the list contents
i = 0
while i < len(housing_data):
  print(housing_data[i])
  i = i+ 1
# Out:
# [0.00632, 18.0, 2.31, 0.0, 0.538, 6.575, 65.2, 4.09, 1.0, 296.0, 15.3, 396.9, 4.98]
# [0.02731, 0.0, 7.07, 0.0, 0.469, 6.421, 78.9, 4.9671, 2.0, 242.0, 17.8, 396.9, 9.14]
# [0.02729, 0.0, 7.07, 0.0, 0.469, 7.185, 61.1, 4.9671, 2.0, 242.0, 17.8, 392.83, 4.03]
# [0.03237, 0.0, 2.18, 0.0, 0.458, 6.998, 45.8, 6.0622, 3.0, 222.0, 18.7, 394.63, 2.94]
# [0.06905, 0.0, 2.18, 0.0, 0.458, 7.147, 54.2, 6.0622, 3.0, 222.0, 18.7, 396.9, 5.33]
# [0.02985, 0.0, 2.18, 0.0, 0.458, 6.43, 58.7, 6.0622, 3.0, 222.0, 18.7, 394.12, 5.21]
# [0.08829, 12.5, 7.87, 0.0, 0.524, 6.012, 66.6, 5.5605, 5.0, 311.0, 15.2, 395.6, 12.43]
# [0.14455, 12.5, 7.87, 0.0, 0.524, 6.172, 96.1, 5.9505, 5.0, 311.0, 15.2, 396.9, 19.15]
# [0.21124, 12.5, 7.87, 0.0, 0.524, 5.631, 100.0, 6.0821, 5.0, 311.0, 15.2, 386.63, 29.93]
# [0.17004, 12.5, 7.87, 0.0, 0.524, 6.004, 85.9, 6.5921, 5.0, 311.0, 15.2, 386.71, 17.1]
# [0.22489, 12.5, 7.87, 0.0, 0.524, 6.377, 94.3, 6.3467, 5.0, 311.0, 15.2, 392.52, 20.45]
# ...

# %%
# print the first two columns of each list
# Use While loop to print the list contents
i = 0
while i < len(housing_data):
  print(housing_data[i][0:2])
  i = i+ 1
# Out:
# [0.00632, 18.0]
# [0.02731, 0.0]
# [0.02729, 0.0]
# [0.03237, 0.0]
# [0.06905, 0.0]
# [0.02985, 0.0]
# [0.08829, 12.5]
# [0.14455, 12.5]
# [0.21124, 12.5]
# [0.17004, 12.5]
# [0.22489, 12.5]
# [0.11747, 12.5]
# [0.09378, 12.5]
# [0.62976, 0.0]
# [0.63796, 0.0]
# [0.62739, 0.0]
# [1.05393, 0.0]
# [0.7842, 0.0]
# [0.80271, 0.0]
# [0.7258, 0.0]
# [1.25179, 0.0]
# [0.85204, 0.0]
# [1.23247, 0.0]
# [0.98843, 0.0]
# [0.75026, 0.0]
# [0.84054, 0.0]
# [0.67191, 0.0]
# [0.95577, 0.0]
# [0.77299, 0.0]
# [1.00245, 0.0]
# [1.13081, 0.0]
# [1.35472, 0.0]
# [1.38799, 0.0]
# [1.15172, 0.0]
# [1.61282, 0.0]
# [0.06417, 0.0]
# [0.09744, 0.0]
# [0.08014, 0.0]
# [0.17505, 0.0]
# [0.02763, 75.0]
# [0.03359, 75.0]
# [0.12744, 0.0]
# [0.1415, 0.0]
# [0.15936, 0.0]
# [0.12269, 0.0]
# [0.17142, 0.0]
# [0.18836, 0.0]
# [0.22927, 0.0]
# [0.25387, 0.0]
# [0.21977, 0.0]
# [0.08873, 21.0]
# [0.04337, 21.0]
# [0.0536, 21.0]
# [0.04981, 21.0]
# [0.0136, 75.0]
# [0.01311, 90.0]
# [0.02055, 85.0]
# [0.01432, 100.0]
# ...

# %%
# the target contains a set of values (i.e., median house prices) stored in a data format called "array"
# you will learn more about array later
# here are some simple operations we can do about the access
# assign the values housing.target to another array named housing_price"

housing_price = target

# compute min and max of house prices
print("minimum =", min(housing_price), "maximum =", max(housing_price))

tuple_price = tuple(housing_price) #no need to use map since this is only one dimension
print("minimum =", min(tuple_price), "maximum =", max(tuple_price))

list_price = housing_price.tolist()
print("minimum =", min(list_price), "maximum =", max(list_price))
# Out:
# minimum = 5.0 maximum = 50.0
# minimum = 5.0 maximum = 50.0
# minimum = 5.0 maximum = 50.0

# %%
# the target contains a set of values (i.e., median house prices) stored in a data format called "array"
# you will learn more about array later
# here are some simple operations we can do about the access
# assign the values housing.target to another array named housing_price"
# find the sum, count, average values in the array, tuple, and list

# create a user-defined function
def average(total, number_of_items):
 return total/number_of_items

housing_price = target
print(sum(housing_price))
print(len(housing_price))
print(average(sum(housing_price),len(housing_price)))
print()

tuple_price = tuple(housing_price) #no need to use map since this is only one dimension
print(sum(tuple_price))
print(len(tuple_price))
print(average(sum(tuple_price),len(tuple_price)))
print()

list_price = housing_price.tolist()
print(sum(list_price))
print(len(list_price))
print(average(sum(list_price),len(list_price)))
print()
# Out:
# 11401.600000000013
# 506
# 22.532806324110698
#
# 11401.600000000013
# 506
# 22.532806324110698
#
# 11401.600000000013
# 506
# 22.532806324110698

# %%
# the target contains a set of values (i.e., median house prices) stored in a data format called "array"
# you will learn more about array later
# here are some simple operations we can do about the access
# assign the values target to another array named housing_price"
housing_price = target
print(min(housing_price))

tuple_price = tuple(housing_price) #no need to use map since this is only one dimension
print(max(tuple_price))

list_price = housing_price.tolist()
print(max(list_price))
# Out:
# 5.0
# 50.0
# 50.0

# %% [markdown]
# # Study Unit 3
# ## We will using numpy array and functions to manage and plot data...

# %%
# use data from Study Unit 2

import math
import numpy as numpy

housing_data = data
features_data = data
#for y in housing_data.ndim: 
#    print(housing_data[:,y])
print(housing_data.shape)
print(housing_data.size)
print(housing_data.ndim) #ndim = 2 because this is a 2D table
feature_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

#compute the statistics for each column of the housing data
i = 0
while i < housing_data.shape[1]: 
 x = housing_data[:, i]
 print(feature_names[i], "\t\t min = ", numpy.min(x), \
       ", max =", numpy.max(x), ", std = ", round(numpy.std(x),3), \
       ", mean=", round(numpy.mean(x),3), ", median = ", round(numpy.median(x),3))
 i = i + 1
# Out:
# (506, 13)
# 6578
# 2
# CRIM 		 min =  0.00632 , max = 88.9762 , std =  8.593 , mean= 3.614 , median =  0.257
# ZN 		 min =  0.0 , max = 100.0 , std =  23.299 , mean= 11.364 , median =  0.0
# INDUS 		 min =  0.46 , max = 27.74 , std =  6.854 , mean= 11.137 , median =  9.69
# CHAS 		 min =  0.0 , max = 1.0 , std =  0.254 , mean= 0.069 , median =  0.0
# NOX 		 min =  0.385 , max = 0.871 , std =  0.116 , mean= 0.555 , median =  0.538
# RM 		 min =  3.561 , max = 8.78 , std =  0.702 , mean= 6.285 , median =  6.208
# AGE 		 min =  2.9 , max = 100.0 , std =  28.121 , mean= 68.575 , median =  77.5
# DIS 		 min =  1.1296 , max = 12.1265 , std =  2.104 , mean= 3.795 , median =  3.207
# RAD 		 min =  1.0 , max = 24.0 , std =  8.699 , mean= 9.549 , median =  5.0
# TAX 		 min =  187.0 , max = 711.0 , std =  168.37 , mean= 408.237 , median =  330.0
# PTRATIO 		 min =  12.6 , max = 22.0 , std =  2.163 , mean= 18.456 , median =  19.05
# ...

# %%
import matplotlib.pyplot as plt

plt.bar(feature_names, housing_data.mean(axis=0), color ='maroon',
        width = 0.4)
 
plt.xlabel("Housing features")
plt.ylabel("Mean values")
plt.title("Mean values in different housing features")
plt.show()

# %%
import matplotlib.pyplot as plt
housing_data = data
housing_price = target

# LSTAT    % lower status of the population
# MEDV     Median value of owner-occupied homes in $1000's

plt.scatter(housing_data[:,12], housing_price)
plt.xlabel(" % lower status of the population (LSTAT)")
plt.ylabel("Median value of owner-occupied homes in $1000's (MEDV)")
plt.title("Scatter Plot of MEDV and LSTAT")
plt.show()
