# %% [markdown]
# #### install and import pandas

# %%
# !pip install pandas
import pandas as pd
# Out:
# /bin/bash: /Library/Frameworks/Python.framework/Versions/3.10/bin/pip: /Library/Frameworks/Python.framework/Versions/3.10/bin/python: bad interpreter: No such file or directory

# %% [markdown]
# # First activity

# %%
import pandas as pd
car_model = pd.read_csv("car_model.csv")

# %%
print(car_model)
# Out:
#      Year        Make    Model Category
# 0    2021       Acura      ILX    Sedan
# 1    2021       Acura      RDX      SUV
# 2    2021       Acura      TLX    Sedan
# 3    2021  Alfa Romeo   Giulia    Sedan
# 4    2021  Alfa Romeo  Stelvio      SUV
# ..    ...         ...      ...      ...
# 235  2021       Volvo      V60    Wagon
# 236  2021  Volkswagen   Tiguan      SUV
# 237  2021       Volvo     XC40      SUV
# 238  2021       Volvo     XC60      SUV
# 239  2021       Volvo     XC90      SUV
#
# [240 rows x 4 columns]

# %%
display(car_model)
# Out:
#      Year        Make    Model Category
# 0    2021       Acura      ILX    Sedan
# 1    2021       Acura      RDX      SUV
# 2    2021       Acura      TLX    Sedan
# 3    2021  Alfa Romeo   Giulia    Sedan
# 4    2021  Alfa Romeo  Stelvio      SUV
# ..    ...         ...      ...      ...
# 235  2021       Volvo      V60    Wagon
# 236  2021  Volkswagen   Tiguan      SUV
# 237  2021       Volvo     XC40      SUV
# 238  2021       Volvo     XC60      SUV
# 239  2021       Volvo     XC90      SUV
#
# [240 rows x 4 columns]

# %%
car_model.tail(10)
# Out:
#      Year        Make   Model   Category
# 230  2021  Volkswagen   Jetta      Sedan
# 231  2021  Volkswagen    Golf  Hatchback
# 232  2021  Volkswagen  Passat      Sedan
# 233  2021       Volvo     S90      Sedan
# 234  2021       Volvo     V90      Wagon
# 235  2021       Volvo     V60      Wagon
# 236  2021  Volkswagen  Tiguan        SUV
# 237  2021       Volvo    XC40        SUV
# 238  2021       Volvo    XC60        SUV
# 239  2021       Volvo    XC90        SUV

# %%
car_model.head(20)
# Out:
#     Year        Make       Model                 Category
# 0   2021       Acura         ILX                    Sedan
# 1   2021       Acura         RDX                      SUV
# 2   2021       Acura         TLX                    Sedan
# 3   2021  Alfa Romeo      Giulia                    Sedan
# 4   2021  Alfa Romeo     Stelvio                      SUV
# 5   2021        Audi  A6 allroad                    Wagon
# 6   2021        Audi          A7                    Sedan
# 7   2021        Audi          Q3                      SUV
# 8   2021        Audi          Q5                      SUV
# 9   2021        Audi          Q8                      SUV
# 10  2021        Audi          S5  Convertible,Sedan,Coupe
# 11  2021        Audi          S6                    Sedan
# 12  2021         BMW    3 Series                    Sedan
# 13  2021         BMW          X1                      SUV
# 14  2021         BMW          X3                      SUV
# ...

# %%
#check the number of rows
len(car_model)
# Out:
# 240

# %%
#check the number of columns
len(car_model.columns)
# Out:
# 4

# %%
car_model.shape
# Out:
# (240, 4)

# %% [markdown]
# # Second activity

# %%
car_model["Make"]
# Out:
# 0           Acura
# 1           Acura
# 2           Acura
# 3      Alfa Romeo
# 4      Alfa Romeo
#           ...
# 235         Volvo
# 236    Volkswagen
# 237         Volvo
# 238         Volvo
# 239         Volvo
# Name: Make, Length: 240, dtype: object

# %%
car_model.loc[: , 'Make']  #how to use loc to pick "Make" column?
# Out:
# 0           Acura
# 1           Acura
# 2           Acura
# 3      Alfa Romeo
# 4      Alfa Romeo
#           ...
# 235         Volvo
# 236    Volkswagen
# 237         Volvo
# 238         Volvo
# 239         Volvo
# Name: Make, Length: 240, dtype: object

# %%
car_model[car_model['Make'] == 'Audi']
# Out:
#     Year  Make       Model                 Category
# 5   2021  Audi  A6 allroad                    Wagon
# 6   2021  Audi          A7                    Sedan
# 7   2021  Audi          Q3                      SUV
# 8   2021  Audi          Q5                      SUV
# 9   2021  Audi          Q8                      SUV
# 10  2021  Audi          S5  Convertible,Sedan,Coupe
# 11  2021  Audi          S6                    Sedan

# %%
car_model.tail(10)["Year"]
# Out:
# 230    2021
# 231    2021
# 232    2021
# 233    2021
# 234    2021
# 235    2021
# 236    2021
# 237    2021
# 238    2021
# 239    2021
# Name: Year, dtype: int64

# %%
car_model["Year"].tail(10)
# Out:
# 230    2021
# 231    2021
# 232    2021
# 233    2021
# 234    2021
# 235    2021
# 236    2021
# 237    2021
# 238    2021
# 239    2021
# Name: Year, dtype: int64

# %% [markdown]
# # Merge DataFrames
# This section on data frames is optional! Only third activity is briefly explained as a demo
#
# # Third activity

# %%
car_model = pd.read_csv('./car_model.csv')
car_model
# Out:
#      Year        Make    Model Category
# 0    2021       Acura      ILX    Sedan
# 1    2021       Acura      RDX      SUV
# 2    2021       Acura      TLX    Sedan
# 3    2021  Alfa Romeo   Giulia    Sedan
# 4    2021  Alfa Romeo  Stelvio      SUV
# ..    ...         ...      ...      ...
# 235  2021       Volvo      V60    Wagon
# 236  2021  Volkswagen   Tiguan      SUV
# 237  2021       Volvo     XC40      SUV
# 238  2021       Volvo     XC60      SUV
# 239  2021       Volvo     XC90      SUV
#
# [240 rows x 4 columns]

# %%
car_price_model = pd.read_csv('./car_price_model.csv')
car_price_model
# Out:
#      Year        Make    Model    Price
# 0    2021       Acura      ILX      NaN
# 1    2021       Acura      RDX      NaN
# 2    2021       Acura      TLX  37500.0
# 3    2021  Alfa Romeo   Giulia  40350.0
# 4    2021  Alfa Romeo  Stelvio  42350.0
# ..    ...         ...      ...      ...
# 235  2021       Volvo      V60  40950.0
# 236  2021  Volkswagen   Tiguan  25245.0
# 237  2021       Volvo     XC40  33700.0
# 238  2021       Volvo     XC60  41700.0
# 239  2021       Volvo     XC90  49000.0
#
# [240 rows x 4 columns]

# %%
car_joined_model = pd.concat([car_model, car_price_model], axis=0, join='inner')
# only shared columns (variables) stay
car_joined_model
# Out:
#      Year        Make    Model
# 0    2021       Acura      ILX
# 1    2021       Acura      RDX
# 2    2021       Acura      TLX
# 3    2021  Alfa Romeo   Giulia
# 4    2021  Alfa Romeo  Stelvio
# ..    ...         ...      ...
# 235  2021       Volvo      V60
# 236  2021  Volkswagen   Tiguan
# 237  2021       Volvo     XC40
# 238  2021       Volvo     XC60
# 239  2021       Volvo     XC90
#
# [480 rows x 3 columns]

# %%
car_joined_model = pd.concat([car_model, car_price_model], axis=0, join='outer')
# try 'outer' and see the difference. 
car_joined_model
# Out:
#      Year        Make    Model Category    Price
# 0    2021       Acura      ILX    Sedan      NaN
# 1    2021       Acura      RDX      SUV      NaN
# 2    2021       Acura      TLX    Sedan      NaN
# 3    2021  Alfa Romeo   Giulia    Sedan      NaN
# 4    2021  Alfa Romeo  Stelvio      SUV      NaN
# ..    ...         ...      ...      ...      ...
# 235  2021       Volvo      V60      NaN  40950.0
# 236  2021  Volkswagen   Tiguan      NaN  25245.0
# 237  2021       Volvo     XC40      NaN  33700.0
# 238  2021       Volvo     XC60      NaN  41700.0
# 239  2021       Volvo     XC90      NaN  49000.0
#
# [480 rows x 5 columns]

# %% [markdown]
# # Fourth Activity

# %%
# check for nulls in the Price field
car_joined_model['Price'].isnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# Name: Price, Length: 480, dtype: bool

# %%
clean = car_joined_model.dropna(subset=['Price']) # only do dropna() on Price column's missing values
# save clean data in a new dataframe, car_joined_model stays the same
clean
# Out:
#      Year        Make       Model Category    Price
# 2    2021       Acura         TLX      NaN  37500.0
# 3    2021  Alfa Romeo      Giulia      NaN  40350.0
# 4    2021  Alfa Romeo     Stelvio      NaN  42350.0
# 5    2021        Audi  A6 allroad      NaN  65900.0
# 6    2021        Audi          A7      NaN  69200.0
# ..    ...         ...         ...      ...      ...
# 235  2021       Volvo         V60      NaN  40950.0
# 236  2021  Volkswagen      Tiguan      NaN  25245.0
# 237  2021       Volvo        XC40      NaN  33700.0
# 238  2021       Volvo        XC60      NaN  41700.0
# 239  2021       Volvo        XC90      NaN  49000.0
#
# [238 rows x 5 columns]

# %%
#confirm no missing values in Price column
clean['Price'].isnull().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
plt.boxplot(clean['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x117b0cc10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x117b0d270>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x117b0c940>],
#  'medians': [<matplotlib.lines.Line2D at 0x117b0d750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x117b0da20>],
#  'means': []}

# %%
# get the 25th percentile, and the 75th percentile
q1 = clean['Price'].quantile(.25)
q3 = clean['Price'].quantile(.75)

# %%
# get the interquartile range
iqr = q3 - q1
iqr
# Out:
# 19090.0

# %%
# list statuses of all prices: True means not an oulier
# note: & is a bitwise AND operator
~((clean['Price'] < q1 - 1.5*iqr) | (clean['Price'] > q3 + 1.5*iqr))
# Out:
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
#        ...
# 235    True
# 236    True
# 237    True
# 238    True
# 239    True
# Name: Price, Length: 238, dtype: bool

# %%
# show records with normal prices (there are 216 records)
clean[~((clean['Price'] < q1 - 1.5*iqr) | (clean['Price'] > q3 + 1.5*iqr))]
# Out:
#      Year        Make       Model Category    Price
# 2    2021       Acura         TLX      NaN  37500.0
# 3    2021  Alfa Romeo      Giulia      NaN  40350.0
# 4    2021  Alfa Romeo     Stelvio      NaN  42350.0
# 5    2021        Audi  A6 allroad      NaN  65900.0
# 6    2021        Audi          A7      NaN  69200.0
# ..    ...         ...         ...      ...      ...
# 235  2021       Volvo         V60      NaN  40950.0
# 236  2021  Volkswagen      Tiguan      NaN  25245.0
# 237  2021       Volvo        XC40      NaN  33700.0
# 238  2021       Volvo        XC60      NaN  41700.0
# 239  2021       Volvo        XC90      NaN  49000.0
#
# [216 rows x 5 columns]

# %%
# show records outside normal prices
# Python's Tilde ~n operator is the bitwise negation operator: 
# it takes the number n as binary number and “flips” all bits 0 to 1 and 1 to 0 to obtain the complement binary number.
# For example, the tilde operation ~1 becomes 0 and ~0 becomes 1 and ~101 becomes 010

clean[(clean['Price'] < q1 - 1.5*iqr) | (clean['Price'] > q3 + 1.5*iqr)]
# Out:
#      Year           Make                       Model Category     Price
# 11   2021           Audi                          S6      NaN   74400.0
# 16   2021            BMW                          X7      NaN   74900.0
# 23   2021       Cadillac                    Escalade      NaN   76195.0
# 24   2021       Cadillac                Escalade ESV      NaN   79195.0
# 41   2021      Chevrolet  Silverado 3500 HD Crew Cab      NaN   80000.0
# 130  2021     Land Rover                 Range Rover      NaN   92000.0
# 136  2021          Lexus                          LC      NaN   93050.0
# 137  2021          Lexus                          LS      NaN   76000.0
# 138  2021          Lexus                          LX      NaN   86830.0
# 146  2021        Lincoln                   Navigator      NaN   76750.0
# 147  2021        Lincoln                 Navigator L      NaN   85715.0
# 159  2021  Mercedes-Benz                     G-Class      NaN  131750.0
# ...

# %% [markdown]
# #### Discussion
# Discuss whether the models with extraordinarily high/low selling prices should be excluded from the DataFrame.

# %% [markdown]
# # Data Modification
# # Activity 5

# %% [markdown]
# # Fifth Activity

# %%
car_price_model = pd.read_csv("car_price_model.csv")
car_price_model
# Out:
#      Year        Make    Model    Price
# 0    2021       Acura      ILX      NaN
# 1    2021       Acura      RDX      NaN
# 2    2021       Acura      TLX  37500.0
# 3    2021  Alfa Romeo   Giulia  40350.0
# 4    2021  Alfa Romeo  Stelvio  42350.0
# ..    ...         ...      ...      ...
# 235  2021       Volvo      V60  40950.0
# 236  2021  Volkswagen   Tiguan  25245.0
# 237  2021       Volvo     XC40  33700.0
# 238  2021       Volvo     XC60  41700.0
# 239  2021       Volvo     XC90  49000.0
#
# [240 rows x 4 columns]

# %%
# Drop the rows where at least one element is missing.
car_price_model = car_price_model.dropna()
car_price_model
# Out:
#      Year        Make       Model    Price
# 2    2021       Acura         TLX  37500.0
# 3    2021  Alfa Romeo      Giulia  40350.0
# 4    2021  Alfa Romeo     Stelvio  42350.0
# 5    2021        Audi  A6 allroad  65900.0
# 6    2021        Audi          A7  69200.0
# ..    ...         ...         ...      ...
# 235  2021       Volvo         V60  40950.0
# 236  2021  Volkswagen      Tiguan  25245.0
# 237  2021       Volvo        XC40  33700.0
# 238  2021       Volvo        XC60  41700.0
# 239  2021       Volvo        XC90  49000.0
#
# [238 rows x 4 columns]

# %%
# Add a new column named SGD Price 1.5 times of the Price
car_price_model['SGD Price'] = car_price_model['Price']*1.5   
car_price_model
# Out:
# /var/folders/sw/ynbq3xcx5dd2tmnt7_scg1y80000gn/T/ipykernel_892/2935792358.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_price_model['SGD Price'] = car_price_model['Price']*1.5
#      Year        Make       Model    Price  SGD Price
# 2    2021       Acura         TLX  37500.0    56250.0
# 3    2021  Alfa Romeo      Giulia  40350.0    60525.0
# 4    2021  Alfa Romeo     Stelvio  42350.0    63525.0
# 5    2021        Audi  A6 allroad  65900.0    98850.0
# 6    2021        Audi          A7  69200.0   103800.0
# ..    ...         ...         ...      ...        ...
# 235  2021       Volvo         V60  40950.0    61425.0
# 236  2021  Volkswagen      Tiguan  25245.0    37867.5
# 237  2021       Volvo        XC40  33700.0    50550.0
# ...

# %%
# compute the mean SGD price for each make

car_price_model.groupby('Make')['SGD Price'].mean()
# Out:
# Make
# Acura             56250.000000
# Alfa Romeo        62025.000000
# Audi              87321.428571
# BMW               76185.000000
# Buick             44812.500000
# Cadillac          75774.642857
# Chevrolet         52144.875000
# Chrysler          47525.000000
# Dodge             46005.000000
# FIAT              38722.500000
# Ford              51438.750000
# GMC               54516.666667
# Genesis           77081.250000
# Honda             43070.625000
# Hyundai           37393.392857
# INFINITI          71950.000000
# Jaguar            83133.750000
# Jeep              44734.687500
# Kia               36940.500000
# Land Rover       102112.500000
# Lexus             81964.500000
# Lincoln           87792.000000
# MAZDA             38881.875000
# Mercedes-Benz    101105.625000
# Mitsubishi        31492.500000
# Nissan            42888.750000
# Polestar          89850.000000
# Porsche          113600.000000
# Ram               52771.250000
# Rivian           114375.000000
# ...
