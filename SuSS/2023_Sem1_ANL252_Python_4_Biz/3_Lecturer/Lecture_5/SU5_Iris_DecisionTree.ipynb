# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 

# %matplotlib inline

# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()

# %%
iris = pd.DataFrame(iris_dataset.data, columns=iris_dataset.feature_names)
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris['Class'] = iris_dataset.target

# %%
#check for missing values
iris.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Class                0
# dtype: int64

# %%
# Extracting the dependent and independent variables
#X = pd.DataFrame(np.c_[boston['LSTAT'], boston['RM']], columns = ['LSTAT','RM'])
#X = data[:, [1, 9]]
#X = pd.DataFrame(iris['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)'])
#X = pd.DataFrame(iris[['sepal length (cm)'],['sepal width (cm)']])
#X = iris['sepal length (cm)']
X =  pd.DataFrame(iris_dataset.data, columns=iris_dataset.feature_names)
Y = iris['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
from sklearn import tree
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import classification_report

# a classifier works for categorical target values
dtc = tree.DecisionTreeClassifier()

# %%
# fit decision tree on training data
dtc.fit(X_train, Y_train)
# then use the fitted decision tree to predict on test data
# if decision tree learnt the true relationships, it should do well on test data
Y_predict = dtc.predict(X_test)

# %%
# also, print classification report
print(classification_report(Y_predict,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       0.82      0.90      0.86        10
#            2       0.91      0.83      0.87        12
#
#     accuracy                           0.90        30
#    macro avg       0.91      0.91      0.91        30
# weighted avg       0.90      0.90      0.90        30

# %%
# from sklearn import plot_tree
# control the plotting size 
plt.figure(figsize=(15, 8))
# plot the decision tree
tree.plot_tree(dtc)
plt.show()

# if you encounter error with plot_tree, try the updates in the next cell

# %%
# if you encounter error with plot_tree, try the following:

# what I did was then I when the Anaconda powershell and run:
# pip install -U scikit-learn

# another possible source in the url below, I suspect the last line should be the same as 
# pip install -U scikit-learn 


# see https://blog.actorsfit.com/a?ID=01200-fbbd0d11-ea27-47f1-adbe-d34f91a2a13e#_scikitlearn__16
# Activate the required virtual environment
# conda activate virtual environment name
# Update using conda 
# conda update scikit-learn
# You can also use pip to update 
# pip install --upgrade scikit-learn
