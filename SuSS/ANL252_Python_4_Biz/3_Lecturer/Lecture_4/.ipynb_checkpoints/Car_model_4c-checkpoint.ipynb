# %% [markdown]
# ### Car sales program:
# #### Carry out the following tasks in JupyterLab:
#
# ##### Read in the data file “car_price.csv” into Python. The data file contains 4 variables: Year, Make, Model, and Price (in USD).
# ##### Outer join the “car_model” and “car_price” data by their “year”, “make” and “model”.
# ##### Print the merged DataFrame and check on its dimension.
# ##### Delete duplicate columns from the DataFrame.

# %%
import pandas as pd

car_model = pd.read_csv("car_model.csv")
car_price = pd.read_csv("car_price.csv")

# %%
car_model.head()
# Out:
#    Year    Make                                   Model Category
# 0  2000    Ford                                    E350   Family
# 1  2001   Chevy              Venture "Extended Edition"    Sedan
# 2  2002   Chevy  Venture "Extended Edition, Very Large"   Sports
# 3  2003    Jeep                          Grand Cherokee  Unknown
# 4  2004  Toyota                                    Wish      SUV

# %%
car_price.head()
# Out:
#    Year    Make                                   Model         Price
# 0  2000    Ford                                    E350  31489.586290
# 1  2001   Chevy              Venture "Extended Edition"  54967.447750
# 2  2002   Chevy  Venture "Extended Edition, Very Large"  55448.315530
# 3  2003    Jeep                          Grand Cherokee  50508.905890
# 4  2004  Toyota                                    Wish   3647.208496

# %%
car_model_price = pd.concat([car_model, car_price], axis = 1, join = "outer")
car_model_price.head()
# Out:
#    Year    Make                                   Model Category  Year  \
# 0  2000    Ford                                    E350   Family  2000
# 1  2001   Chevy              Venture "Extended Edition"    Sedan  2001
# 2  2002   Chevy  Venture "Extended Edition, Very Large"   Sports  2002
# 3  2003    Jeep                          Grand Cherokee  Unknown  2003
# 4  2004  Toyota                                    Wish      SUV  2004
#
#      Make                                   Model         Price
# 0    Ford                                    E350  31489.586290
# 1   Chevy              Venture "Extended Edition"  54967.447750
# 2   Chevy  Venture "Extended Edition, Very Large"  55448.315530
# 3    Jeep                          Grand Cherokee  50508.905890
# 4  Toyota                                    Wish   3647.208496

# %%
car_model_price.shape
# Out:
# (21, 8)

# %% [markdown]
# ##### But how do we drop duplicated columns?

# %%
# How many duplicated coumns are there?
car_model_price.columns.duplicated()
# Out:
# array([False, False, False, False,  True,  True,  True, False])

# %% [markdown]
# The above line returns a boolean array: a True or False for each column. If it is False then the column name is unique up to that point, if it is True then the column name is duplicated earlier.

# %% [markdown]
# Pandas allows one to index using boolean values whereby it selects only the True values.
#
# Since we want to keep the unduplicated columns, we need the above boolean array to be flipped i.e. we want to convert the False to True

# %%
~car_model_price.columns.duplicated()
# Out:
# array([ True,  True,  True,  True, False, False, False,  True])

# %%
car_model_price = car_model_price.loc[:, ~car_model_price.columns.duplicated()]
car_model_price
# Out:
#     Year           Make                                   Model  \
# 0   2000           Ford                                    E350
# 1   2001          Chevy              Venture "Extended Edition"
# 2   2002          Chevy  Venture "Extended Edition, Very Large"
# 3   2003           Jeep                          Grand Cherokee
# 4   2004         Toyota                                    Wish
# 5   2005          Honda                                    Jaxx
# 6   2006         Nissan                                 Skyline
# 7   2007           Ford                                 Mustang
# 8   2008    Range Rover                              Pathfinder
# 9   2009          Volvo                                      X6
# 10  2010            BMW                                      i3
# 11  2011  Mercedes Benz                                 C cLass
# 12  2012         Subaru                                     BRZ
# 13  2013           Audi                                      R8
# 14  2014  Mercedes Benz                                     G50
# 15  2015           Ford                                    F450
# 16  2016         Ferrai                                  Spider
# 17  2017      American                                  Chopper
# 18  2018       Kawasaki                                   Ninja
# 19  2019       Daihatsu                                   Super
# 20  2020          Tesla                                 Model S
#
#              Category         Price
# 0              Family  31489.586290
# 1               Sedan  54967.447750
# 2              Sports  55448.315530
# 3             Unknown  50508.905890
# 4                 SUV   3647.208496
# 5                 SUV  29106.682640
# 6                 SUV  47948.167620
# 7               Sedan  39035.069340
# 8                 SUV  17960.838230
# 9               Sedan  81874.540180
# 10                SUV  51615.344490
# 11                SUV   7522.392529
# 12              Sedan  21631.666240
# 13              Sedan  38356.588750
# 14                SUV  65594.423910
# 15  TeasportTransport   2899.589514
# 16             Sports  69035.947650
# 17           Personal  79667.596120
# 18             Luxury  94841.274830
# 19              Sedan  99393.880830
# 20              Sedan  14426.696630

# %%
car_model_price.shape
# Out:
# (21, 5)
