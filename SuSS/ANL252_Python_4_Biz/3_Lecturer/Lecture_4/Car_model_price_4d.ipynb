# %% [markdown]
# ### Car sales program:
#
# ##### Carry out the following tasks in JupyterLab:
#
# ##### Remove all the rows with missing data in “price” from the merged DataFrame created in the previous chapter.

# %%
import pandas as pd

car_model_price = pd.read_csv("car_model_price.csv")
car_model_price
# Out:
#       Year        Make              Model            Category    Price
# 0     2020        Audi                 Q3                 SUV  26100.0
# 1     2020   Chevrolet             Malibu               Sedan  38400.0
# 2     2020    Cadillac       Escalade ESV                 SUV  37500.0
# 3     2020   Chevrolet           Corvette  Coupe, Convertible  40350.0
# 4     2020       Acura                RLX               Sedan  42350.0
# ...    ...         ...                ...                 ...      ...
# 9831  2022  Mitsubishi      Eclipse Cross                 SUV      NaN
# 9832  2022      Nissan  Frontier Crew Cab              Pickup      NaN
# 9833  2022      Nissan         Pathfinder                 SUV      NaN
# 9834  2022      Subaru                BRZ               Coupe      NaN
# 9835  2022  Volkswagen             Tiguan                 SUV      NaN
#
# [9836 rows x 5 columns]

# %%
car_model_price_clean = car_model_price.dropna(axis = 0, how = 'any')
car_model_price_clean
# Out:
#      Year       Make         Model                   Category    Price
# 0    2020       Audi            Q3                        SUV  26100.0
# 1    2020  Chevrolet        Malibu                      Sedan  38400.0
# 2    2020   Cadillac  Escalade ESV                        SUV  37500.0
# 3    2020  Chevrolet      Corvette         Coupe, Convertible  40350.0
# 4    2020      Acura           RLX                      Sedan  42350.0
# ..    ...        ...           ...                        ...      ...
# 235  2019        BMW      4 Series  Convertible, Sedan, Coupe  40950.0
# 236  2019      Acura           TLX                      Sedan  51800.0
# 237  2019      Acura           ILX                      Sedan  33700.0
# 238  2019        BMW      2 Series         Coupe, Convertible  41700.0
# 239  2019       Audi            A3         Convertible, Sedan  49000.0
#
# [240 rows x 5 columns]

# %% [markdown]
# ##### Detect car models that can be considered as outliers in terms of their selling price.
#
# ##### Discuss whether the models with extraordinarily high/low selling prices should be excluded from the DataFrame.

# %%
q1 = car_model_price_clean['Price'].quantile(q = 0.4)
q3 = car_model_price_clean['Price'].quantile(q = 0.5)
iqr = q3-q1

y1 = q1 - 1.5*iqr
y2 = q3 + 1.5*iqr

print(f"Lower Bound:\n {y1}")
print(f"Upper Bound:\n {y2}")
# Out:
# Lower Bound:
#  28396.25
# Upper Bound:
#  36598.25

# %%
car_outlier = car_model_price_clean[~( 
    (car_model_price_clean["Price"]< y1) | (car_model_price_clean["Price"]> y2)
)]

car_outlier
# Out:
#      Year           Make                    Model  \
# 7    2020       Chrysler                 Pacifica
# 13   2020           Ford                   Fusion
# 20   2020          Buick                   Encore
# 21   2020            GMC  Sierra 2500 HD Crew Cab
# 25   2020       Cadillac                      XT4
# 28   2020        Hyundai                 Santa Fe
# 29   2020           Ford                 EcoSport
# 37   2020            GMC  Sierra 3500 HD Crew Cab
# 38   2020           Jeep                Gladiator
# 40   2020       Cadillac                    CT6-V
# 46   2020           Jeep                  Compass
# 48   2020       Chrysler                  Voyager
# 49   2020          Honda            Accord Hybrid
# 51   2020      Chevrolet                    Spark
# 52   2020            GMC     Sierra 1500 Crew Cab
# 53   2020        Hyundai                     NEXO
# 57   2020       Cadillac                      CT5
# 61   2020            GMC                 Yukon XL
# 67   2020            GMC                    Yukon
# 71   2020      Chevrolet                  Bolt EV
# 72   2020           Ford               Expedition
# 74   2020          Honda                 Passport
# 85   2020            BMW                       X5
# 88   2020      Chevrolet                     Trax
# 89   2020        Hyundai     Ioniq Plug-in Hybrid
# 90   2020         Jaguar                   E-PACE
# 91   2020        Hyundai                   Tucson
# 94   2020         Jaguar                   I-PACE
# 99   2020        Hyundai                   Accent
# 113  2020           Jeep       Wrangler Unlimited
# 114  2020            Kia                     Soul
# 118  2020     Land Rover                Discovery
# 122  2020          Lexus                       LX
# 124  2020          Lexus                       GX
# 127  2020          Lexus                       LS
# 128  2020          Lexus                       UX
# 142  2020        Lincoln                  Corsair
# 144  2020  Mercedes-Benz                  G-Class
# 151  2020         Nissan      NV3500 HD Passenger
# 155  2020  Mercedes-Benz                  E-Class
# 156  2020           MINI               Countryman
# 159  2020         Nissan                     370Z
# 169  2020         Nissan               Pathfinder
# 171  2020         Nissan                    NV200
# 172  2020        Porsche                      911
# 187  2020         Subaru                   Legacy
# 190  2020         Toyota                  Corolla
# 192  2020         Subaru                 Forester
# 195  2020         Toyota                  4Runner
# 204  2020         Toyota                     RAV4
# 213  2020         Toyota        Tacoma Double Cab
# 219  2019           Audi                       A6
# 222  2019           Audi                       A4
# 226  2019          Acura                      MDX
# 227  2019          Acura                      NSX
# 228  2019           Audi                       A7
# 229  2019     Alfa Romeo                4C Spider
# 237  2019          Acura                      ILX
#
#                              Category    Price
# 7                         Van/Minivan  34000.0
# 13                              Sedan  35400.0
# 20                                SUV  31800.0
# 21                             Pickup  33395.0
# 25                                SUV  35795.0
# 28                                SUV  28800.0
# 29                                SUV  36500.0
# 37                             Pickup  33200.0
# 38                             Pickup  34900.0
# 40                              Sedan  35300.0
# 46                                SUV  29800.0
# 48                        Van/Minivan  31370.0
# 49                              Sedan  35820.0
# 51                          Hatchback  28870.0
# 52                             Pickup  30570.0
# 53                                SUV  32570.0
# 57                              Sedan  32750.0
# 61                                SUV  32675.0
# 67                                SUV  36000.0
# 71                          Hatchback  29800.0
# 72                                SUV  28700.0
# 74                                SUV  29700.0
# 85                                SUV  30560.0
# 88                                SUV  31790.0
# 89                          Hatchback  32790.0
# 90                                SUV  32550.0
# 91                                SUV  36490.0
# 94                                SUV  33245.0
# 99                              Sedan  32675.0
# 113                               SUV  34040.0
# 114                             Wagon  33120.0
# 118                               SUV  31975.0
# 122                               SUV  30400.0
# 124                               SUV  29390.0
# 127                             Sedan  33090.0
# 128                               SUV  32190.0
# 142                               SUV  33000.0
# 144                               SUV  36105.0
# 151                       Van/Minivan  34160.0
# 155  Coupe, Wagon, Sedan, Convertible  33045.0
# 156                               SUV  33650.0
# 159                             Coupe  36230.0
# 169                               SUV  31670.0
# 171                       Van/Minivan  32810.0
# 172                       Convertible  36330.0
# 187                             Sedan  35645.0
# 190                             Sedan  32385.0
# 192                               SUV  31540.0
# 195                               SUV  32295.0
# 204                               SUV  36125.0
# 213                            Pickup  35085.0
# 219                             Sedan  28500.0
# 222                             Sedan  34460.0
# 226                               SUV  34025.0
# 227                             Coupe  32570.0
# 228                             Sedan  31545.0
# 229                       Convertible  30855.0
# 237                             Sedan  33700.0

# %%
car_outlier.to_csv("car_outlier.csv", index = False)
