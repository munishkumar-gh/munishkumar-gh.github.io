# %% [markdown]
# <h1 align=center><font size = 5>SPE Europe Energy GeoHackathon</font></h1>
#
# Society of Petroleum Engieers|  ERCE Equipoise | Geothermal Challenge
# :-------------------------:|:-------------------------:|:-------------------------:
# <a href="https://www.spehackathon-eu.com"> <img src = "https://upload.wikimedia.org/wikipedia/en/thumb/4/42/Society_of_Petroleum_Engineers_Logo.svg/1200px-Society_of_Petroleum_Engineers_Logo.svg.png" width = 200 /> | <a href="https://www.erce.energy/"> <img src = "https://energycouncil.com/wp-content/uploads/ERCE.png" width = 200/> | <img src = "https://solutions.vallourec.com/-/media/Solutions-img/Low-Carbon-Energy/Medias/Geothermal-energy/Header-Corner_Geothermal.ashx" width = 200/>

# %% [markdown]
# <h1 align=center><font size = 4> Team ERCE - Munish Kumar, Kanna Swaminathan & Ivan Maulana </font></h1>
# <h1 align=center><font size = 3> 2021 </font></h1>

# %%
# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
from matplotlib.ticker import FormatStrFormatter

from numpy import sqrt 

import seaborn as sns
import math

import time
import re
import requests
import pickle
import os
import glob
import scipy
import sys
import warnings

import plotly.express as px
import plotly.graph_objects as go 

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

warnings.filterwarnings('ignore')
sns.set()

from sklearn.linear_model import LinearRegression

# Forces the print statement to show everything and not truncate
# np.set_printoptions(threshold=sys.maxsize) 
print('Libraries imported')
# Out:
# Libraries imported

# %% [markdown]
# ###### Declare some global variables

# %%
dir_name = r'C:\Users\vasan\OneDrive\02_Impact_Petroleum\09_GeoHackathon_2021\00_Hackathon'
filename_suffix = 'txt'
filename_suffix2 = 'csv'
filename_suffix3 = 'xlsx'

font = {'family': 'arial',
    'color':  'blue',
    'weight': 'normal',
    'size': 16,
   }

# %%
#conversion factors
kJ_day_MW = 1/3.6e6/24
m3_day_m3_sec = 1 / (24 * 60 * 60)
pump_efficiency = 0.5
electricity_price = 100 # euro/MWh

# %%
#inputs

existingwells = 10 
newwells = 6

#location of demand point 1
d1x = 94 
d1y = 65

#location of demand point 2
d2x = 125
d2y = 170


doublets = ["01", "02", "03", "04", "05", "06", "09", "10"] #"07", "08"] #Define number of doublets

# %%
#define costs and discount rate

periodic_discount_rate = 0.05

drilling = 4113000
ESP = 400000
VSD = 300000
xmastree = 250000
degasser = 1000000
filters = 4500
heatxchanger = 2000000
injpump = 300000
CHP = 1000000

# %%
# read wells summary and location 
wells = pd.read_excel('WellsInput.xlsx')

# %%
def crossplot(data):
    # overview plot of data
    fig, ax = plt.subplots(2,2, figsize=(12,6), dpi=150, sharex=True)
    # get plot axes
    ax_list = fig.axes

    # plot a few keywords in pairs for both wells
    for i, key in enumerate(['temperature (k)', 'bhp (bar)','energy (kj/day)','water rate (m3/day)']):
        data.plot(x='time (yrs)',
                 y=data.filter(like=key).columns.tolist(), 
                 ax=ax_list[i], 
                 linestyle='-', 
                 style=['x', 'o'])
        ax_list[i].legend(fontsize=6)
        ax_list[i].grid(alpha=0.3)

    plt.show()
    return

# %%
#function that computes energy per producer

def EnergyProd2(data):
    
    for i in doublets:
        prodE = abs(data['p' + str(i) + ' : energy (kj/day)'])
        injE = abs(data['i' + str(i) + ' : energy (kj/day)'])
        data['System power (MW)' + '_' + str(i)] = (prodE - injE)* kJ_day_MW
        
        data['Produced Energy (MWh)' + '_' + str(i)] = data['System power (MW)' + '_' + str(i)] * data['deltahours']
        
    data['System power (MW) Sum'] = data.filter(regex='^System').sum(1)
    data['Produced Energy (MWh) Sum'] = data.filter(regex='^Produced Energy').sum(1)
    
    data.plot('econ_periods', 'System power (MW) Sum')
    
    fig, ax = plt.subplots(2,2, figsize=(12,6), dpi=150, sharex=True)
    # get plot axes
    ax_list = fig.axes
    
    for i, key in enumerate(['System power (MW)', 'bhp (bar)','temperature (k)', 'water rate (m3/day)']):
        dfBase600.plot(x='time (yrs)',
                 y=dfBase600.filter(like=key).columns.tolist(), 
                 ax=ax_list[i], 
                 linestyle='-', 
                 style=['x', 'o'])
        ax_list[i].legend(fontsize=6)
        ax_list[i].grid(alpha=0.3)
       
    return data.head()

# %%
#Function computes opex of pump
def pumpopex(data, doublets):
    
#    for i in doublets:
#        data = data.filter(like=i)
#        data = data.filter(like=("bhp"))
        
#    pumprate = data.filter(like=("water"))
    
    for i in doublets:
        pumpdp = abs(data['p' + str(i) + ' : bhp (bar)']) - abs(data['i' + str(i) + ' : bhp (bar)'])
        data['Pump dp (MPa)' + '_' + str(i)] = pumpdp 
    
        pumppower = abs(data['Pump dp (MPa)' + '_' + str(i)]) * abs(data['p' + str(i) + ' : water rate (m3/day)']) * m3_day_m3_sec * pump_efficiency
        data['Pump power (MW)' + '_' + str(i)] = pumppower
    
        data['OpEx_pump (\u20ac)' + '_' + str(i)] = data['Pump power (MW)' + '_' + str(i)]* data['deltahours'] * electricity_price
       
    return data

# %%
#this function returns a datafram with existing well doublets and their cumulative distance from demand locations

def doubletsfn (data):
    data['d1dist (m)'] = (sqrt( (d1x - wells['x_coord'])**2 + (d1y - wells['y_coord'])**2 ))*50
    data['d2dist (m)'] = (sqrt( (d2x - wells['x_coord'])**2 + (d2y - wells['y_coord'])**2 ))*50
    
    d1dist = wells.groupby(wells.Well.str[1:])['d1dist (m)'].sum().to_frame('d1dist').reset_index()
    d2dist = wells.groupby(wells.Well.str[1:])['d2dist (m)'].sum().to_frame('d2dist').reset_index()
    
    data2=pd.merge(d1dist, d2dist, on=['Well'])
    
    return data2

# %%
#This functionsretrives power on year 1 for each doublets

def doubletsPow (data, wells):
    dfPow = data.filter(regex='^System')
    dfPow.drop(['System power (MW) Sum'], axis=1, inplace=True)
    dfPow = dfPow.iloc[[49]]
    dfPow = dfPow.T
    dfPow = dfPow.reset_index()
    dfPow[['Power','Well']] = dfPow['index'].str.split("_",expand=True)
    
    result=pd.merge(wells, dfPow, on=['Well'])
    result.drop(['index', 'Power',], axis=1, inplace=True)
    result = result.rename({1: 'Power (MW)'}, axis=1)
    
    return result

# %%
# this function computes the capex for pipeline

def capexpl(data):
    data['demandloc'] = np.where(data['d1dist'] < data['d2dist'], 0, 1) 
    dfdemand = data.groupby(['demandloc']).sum()
    dfdemand = dfdemand.reset_index()
    dfdemand['demandreq'] = np.where(dfdemand['demandloc'] == 0, 80, 100) 
    
    dfdemand['dfplcost'] = np.where(dfdemand['demandloc'] == 0, (dfdemand['d1dist']/1000)*600000,(dfdemand['d2dist']/1000)*600000 ) 
    
    return dfdemand

# %%
#this function computes the capex 

def capex(data, wells, PL):
    count = newwells/2
    countproxy = existingwells/2
    
    Capex = drilling*count + (ESP + VSD + xmastree + degasser + filters + heatxchanger + injpump + CHP)*countproxy + PL
    CapexTemp = drilling*countproxy*2
    
    # assign the CapEx
    data['CapEx (\u20ac)'] = 0
    data.loc[dfBase600.index == data.index[0], 'CapEx (\u20ac)'] = Capex
    data['CapexTemp (\u20ac)'] = 0
    data.loc[dfBase600.index == data.index[0], 'CapexTemp (\u20ac)'] = CapexTemp
    
    return data

# %%
#this function computes the Levelaized Cost of Heat 
#periodic_discount_rate = 0.05
def LCOH (data):
    # compute the LCOH costs
    data['LCOH costs'] = data['CapEx (\u20ac)'].fillna(0) + data['OpEx (\u20ac)'] + data['OpEx_pump (\u20ac)'].fillna(0)
    
    # discount LCOH costs
    data['discounted LCOH costs'] = (data['LCOH costs'] /
                                      (1 + periodic_discount_rate) ** data['econ_periods']).cumsum()
    
    data['discounted LCOH energy'] = (data['Produced Energy (MWh) Sum'].cumsum() /
                                        (1 + periodic_discount_rate) ** data[
                                            'econ_periods']).cumsum()
    data[r'LCOH (€/MWh)'] = data['discounted LCOH costs'] / data['discounted LCOH energy']
    
    dfBase600.plot('econ_periods', 'LCOH (€/MWh)')
    
    return data

# %%
#function that return final econ plots
def plotecon(data): 
    fig, ax = plt.subplots(2,3, figsize=(12,8), dpi=150, sharex=True)
    # get plot axes
    ax_list = fig.axes
    
    # plot a few keywords in pairs for both wells
    
    for i, key in enumerate(['temperature', 'bhp','water rate (m3/day)',
                             'power', 'Ex','LCOH (€/MWh)']):
        data.plot(x='econ_periods',
                  y=data.filter(like=key).columns.tolist(),
                  ax=ax_list[i],
                  linestyle='-',
                  style=['x', 'o'])
        ax_list[i].legend(fontsize=6)
        ax_list[i].grid(alpha=0.3)
        if key == 'LCOH (€/MWh)':
            ax_list[i].annotate('%0.2f @ time: %.2f yrs' % (data[key].iloc[-1], dfBase600['econ_periods'].iloc[-1]),
                                xy=(0.5, 0.5), va='center', ha='center',
                                xycoords=('axes fraction'))

# %%
#function computes the economic parameters
def netpv(data):
    data['CapEx (MM€)'] = data['CapEx (€)']/1000000
    data['OpEx (MM€)'] = data['OpEx (€)']/1000000
    data['OpEx_pump (MM€)'] = data['OpEx_pump (€)']/1000000
    
    data['Revenue (MM€)'] = (data['System power (MW) Sum'] * data['deltahours'] * electricity_price)/1000000
    data['NCF (MM€)'] = data['Revenue (MM€)'] - data['CapEx (MM€)'].fillna(0) - data['OpEx (MM€)']  - data['OpEx_pump (MM€)'].fillna(0)
    data['pv (MM€)'] = data['NCF (MM€)'] / (1 + periodic_discount_rate) ** data['econ_periods']
    
    return data

# %%
#function plots econ parameters

def plotecon2(data): 
    fig, ax = plt.subplots(2,3, figsize=(12,8), dpi=150, sharex=True)
    # get plot axes
    ax_list = fig.axes
    
    # plot a few keywords in pairs for both wells
    
    npv = data['pv (MM€)'].sum()
    
    for i, key in enumerate(['pv (MM€)', 'Revenue (MM€)','NCF (MM€)',
                             'OpEx (MM€)', 'CapEx (MM€)','LCOH (€/MWh)']):
        data.plot(x='econ_periods',
                  y=data.filter(like=key).columns.tolist(),
                  ax=ax_list[i],
                  linestyle='-',
                  style=['x', 'o'])
        ax_list[i].legend(fontsize=6)
        ax_list[i].grid(alpha=0.3)
        if key == 'LCOH (€/MWh)':
            ax_list[i].annotate('%0.2f @ time: %.2f yrs' % (data[key].iloc[-1], data['econ_periods'].iloc[-1]),
                                xy=(0.5, 0.5), va='center', ha='center',
                                xycoords=('axes fraction'))
        elif key == 'pv (MM€)':
            ax_list[i].annotate('NPV is €' + str(npv),
                                xy=(0.8, 0.7), va='center', ha='center',
                                xycoords=('axes fraction'))

# %%
dfBase600 = pd.read_csv('R49_8Db_R24dup_Db04_935_05_650_10_06_815_SouthB2_2000_E01b_lowerPrates3_mod.csv')

# %%
dfBase600.isna().sum()
# Out:
# unnamed: 0                   0
# p10 : energy (kj/day)        0
# i10 : bhp (bar)              0
# i01 : energy (kj/day)        0
# p03 : energy (kj/day)        0
#                             ..
# i09 : bhp (bar)              0
# i10 : water rate (m3/day)    0
# time (yrs)                   0
# econ_periods                 0
# deltahours                   1
# Length: 68, dtype: int64

# %%
dfBase600 = dfBase600.fillna(0)

# %%
dfBase600.head()
# Out:
#    unnamed: 0  p10 : energy (kj/day)  i10 : bhp (bar)  i01 : energy (kj/day)  \
# 0         0.0          -3.846149e-01       229.153509           1.784336e-02
# 1         8.0          -3.266210e+09       233.107548           8.319519e+08
# 2         9.0          -3.289996e+09       233.663961           8.318782e+08
# 3        10.0          -3.313559e+09       234.351557           8.321687e+08
# 4        11.0          -3.336524e+09       234.902401           8.324277e+08
#
#    p03 : energy (kj/day)  i05 : energy (kj/day)  i05 : temperature (k)  \
# 0          -1.842289e+00          -6.206008e-02             349.132467
# 1          -1.835441e+09           2.043695e+09             298.150000
# 2          -1.832828e+09           2.046026e+09             298.150000
# 3          -1.830979e+09           2.048099e+09             298.150000
# 4          -1.829313e+09           2.049681e+09             298.150000
#
#    i05 : water rate (m3/day)  i04 : water rate (m3/day)  \
# 0              -1.877777e-07                  -0.000024
# 1               1.560000e+04               22440.000000
# 2               1.560000e+04               22440.000000
# 3               1.560000e+04               22440.000000
# 4               1.560000e+04               22440.000000
#
#    i02 : temperature (k)  ...  p05 : water rate (m3/day)  \
# 0             343.624054  ...                  -0.000002
# 1             298.150000  ...              -15600.000000
# 2             298.150000  ...              -15600.000000
# 3             298.150000  ...              -15600.000000
# 4             298.150000  ...              -15600.000000
#
#    i09 : temperature (k)  i09 : energy (kj/day)  i01 : bhp (bar)  \
# 0             342.532734          -2.090775e-03       227.560093
# 1             298.150000           1.086763e+09       221.497323
# 2             298.150000           1.087806e+09       221.371905
# 3             298.150000           1.088781e+09       221.866135
# 4             298.150000           1.089538e+09       222.307082
#
#    i05 : bhp (bar)  i09 : bhp (bar)  i10 : water rate (m3/day)  time (yrs)  \
# 0       219.645628       204.063927               1.793024e-07         0.0
# 1       269.423266       253.545732               1.080000e+04         1.0
# 2       270.890575       254.747018               1.080000e+04         2.0
# 3       272.197555       255.871907               1.080000e+04         3.0
# 4       273.195420       256.746418               1.080000e+04         4.0
#
#    econ_periods  deltahours
# 0             0         0.0
# 1             1      8760.0
# 2             2      8760.0
# 3             3      8760.0
# 4             4      8760.0
#
# [5 rows x 68 columns]

# %%
WaterTotal = dfBase600.filter(like='(m3/day)')

WaterTotalP = WaterTotal.filter(regex='^p')
WaterTotalP = WaterTotalP.reindex(sorted(WaterTotalP.columns), axis=1)

WaterTotali = WaterTotal.filter(regex='^i')
WaterTotali = WaterTotali.reindex(sorted(WaterTotali.columns), axis=1)

WaterTotalP['PTotal'] = WaterTotalP.sum(axis=1)
WaterTotali['iTotal'] = WaterTotali.sum(axis=1)
#WaterTotalisum = WaterTotali.sum() 
#df['Total'] = df.sum(axis=1)

# %%
Total = WaterTotalP['PTotal'].sum()
print (Total)
# Out:
# -4773599.999750994

# %%
WaterTotalP.head(3)
# Out:
#    p01 : water rate (m3/day)  p02 : water rate (m3/day)  \
# 0              -1.617861e-07              -6.055927e-08
# 1              -6.600000e+03              -4.800000e+03
# 2              -6.600000e+03              -4.800000e+03
#
#    p03 : water rate (m3/day)  p04 : water rate (m3/day)  \
# 0                  -0.000005                  -0.000008
# 1               -5400.000000              -22440.000000
# 2               -5400.000000              -22440.000000
#
#    p05 : water rate (m3/day)  p06 : water rate (m3/day)  \
# 0                  -0.000002                  -0.000002
# 1              -15600.000000              -19560.000000
# 2              -15600.000000              -19560.000000
#
#    p09 : water rate (m3/day)  p10 : water rate (m3/day)        PTotal
# 0              -1.204592e-07                  -0.000001     -0.000019
# 1              -8.400000e+03              -10800.000000 -93600.000000
# 2              -8.400000e+03              -10800.000000 -93600.000000

# %%
WaterTotali.head(3)
# Out:
#    i01 : water rate (m3/day)  i02 : water rate (m3/day)  \
# 0               1.408770e-07                        0.0
# 1               6.600000e+03                     4800.0
# 2               6.600000e+03                     4800.0
#
#    i03 : water rate (m3/day)  i04 : water rate (m3/day)  \
# 0              -1.372648e-08                  -0.000024
# 1               5.400000e+03               22440.000000
# 2               5.400000e+03               22440.000000
#
#    i05 : water rate (m3/day)  i06 : water rate (m3/day)  \
# 0              -1.877777e-07                  -0.000014
# 1               1.560000e+04               19560.000000
# 2               1.560000e+04               19560.000000
#
#    i09 : water rate (m3/day)  i10 : water rate (m3/day)        iTotal
# 0              -6.894559e-09               1.793024e-07     -0.000038
# 1               8.400000e+03               1.080000e+04  93600.000000
# 2               8.400000e+03               1.080000e+04  93600.000000

# %%
(WaterTotalP['PTotal'] + WaterTotali['iTotal']).head()
# Out:
# 0   -5.697587e-05
# 1   -2.924935e-09
# 2   -1.236913e-09
# 3    1.575972e-08
# 4    4.496542e-09
# dtype: float64

# %%
(WaterTotali['i09 : water rate (m3/day)']/24).mean()
# Out:
# 328.57448777489475

# %%
# visualize data initially from input
#crossplot(dfBase600)

# %%
# compute energy produced
EnergyProd2(dfBase600)
# Out:
#    unnamed: 0  p10 : energy (kj/day)  i10 : bhp (bar)  i01 : energy (kj/day)  \
# 0         0.0          -3.846149e-01       229.153509           1.784336e-02
# 1         8.0          -3.266210e+09       233.107548           8.319519e+08
# 2         9.0          -3.289996e+09       233.663961           8.318782e+08
# 3        10.0          -3.313559e+09       234.351557           8.321687e+08
# 4        11.0          -3.336524e+09       234.902401           8.324277e+08
#
#    p03 : energy (kj/day)  i05 : energy (kj/day)  i05 : temperature (k)  \
# 0          -1.842289e+00          -6.206008e-02             349.132467
# 1          -1.835441e+09           2.043695e+09             298.150000
# 2          -1.832828e+09           2.046026e+09             298.150000
# 3          -1.830979e+09           2.048099e+09             298.150000
# 4          -1.829313e+09           2.049681e+09             298.150000
#
#    i05 : water rate (m3/day)  i04 : water rate (m3/day)  \
# 0              -1.877777e-07                  -0.000024
# 1               1.560000e+04               22440.000000
# 2               1.560000e+04               22440.000000
# 3               1.560000e+04               22440.000000
# 4               1.560000e+04               22440.000000
#
#    i02 : temperature (k)  ...  System power (MW)_05  Produced Energy (MWh)_05  \
# 0             343.624054  ...          6.612173e-09                  0.000000
# 1             298.150000  ...          2.738529e+01             239895.108103
# 2             298.150000  ...          2.803112e+01             245552.648166
# 3             298.150000  ...          2.859566e+01             250497.999905
# 4             298.150000  ...          2.910105e+01             254925.240804
#
#    System power (MW)_06  Produced Energy (MWh)_06  System power (MW)_09  \
# 0         -5.371874e-08                 -0.000000          4.347682e-10
# 1          4.999229e+01             437932.485156          1.886540e+01
# 2          4.984492e+01             436641.536481          1.891359e+01
# 3          4.980539e+01             436295.178854          1.896104e+01
# 4          4.980924e+01             436328.910219          1.900162e+01
#
#    Produced Energy (MWh)_09  System power (MW)_10  Produced Energy (MWh)_10  \
# 0                  0.000000          4.188361e-09                  0.000000
# 1             165260.907087          2.189778e+01             191824.512042
# 2             165683.031354          2.216576e+01             194172.069220
# 3             166098.727730          2.242945e+01             196481.947669
# 4             166454.177127          2.268800e+01             198746.917240
#
#    System power (MW) Sum  Produced Energy (MWh) Sum
# 0          -9.384810e-08               0.000000e+00
# 1           2.124527e+02               1.861086e+06
# 2           2.135783e+02               1.870946e+06
# 3           2.147514e+02               1.881222e+06
# 4           2.158973e+02               1.891261e+06
#
# [5 rows x 86 columns]

# %%
# compute opex due to pumping
df2 = pumpopex(dfBase600,doublets)
dfBase600['OpEx_pump (\u20ac)'] = df2.filter(regex='^OpEx').sum(1)
dfBase600['Pump power (MW)_total'] = df2.filter(regex='^Pump power').sum(1)

# %%
#compute power produced per doublet
dfdist = doubletsfn(wells)
dfWells = doubletsPow (dfBase600, dfdist)

# %%
dfdist
# Out:
#   Well        d1dist        d2dist
# 0   01   9269.889823   8354.301426
# 1   02   5732.216992   9325.413012
# 2   03   5701.562119   5760.629430
# 3   04   7091.725104  16674.450035
# 4   05   5399.426034  14200.552400
# 5   06   3682.270685   9783.975764
# 6   07   4486.925451   2798.660394
# 7   08   5056.184332   6103.277808
# 8   09  12295.785250   3200.000000
# 9   10   3863.495984  14749.626709

# %%
dfWells
# Out:
#   Well        d1dist        d2dist         49
# 0   01   9269.889823   8354.301426  15.149467
# 1   02   5732.216992   9325.413012   8.863192
# 2   03   5701.562119   5760.629430  11.204417
# 3   04   7091.725104  16674.450035  44.928557
# 4   05   5399.426034  14200.552400  24.148804
# 5   06   3682.270685   9783.975764  43.901141
# 6   09  12295.785250   3200.000000  12.362886
# 7   10   3863.495984  14749.626709  22.793579

# %%
#assign doublets to demand locations and compute capex due to pipelines
dfdemand = capexpl(dfWells)

# %%
dfdemand
# Out:
#    demandloc        d1dist        d2dist  Power (MW)  demandreq      dfplcost
# 0          0  31470.696917  70494.647348  176.974460         80  1.888242e+07
# 1          1  21565.675073  11554.301426   35.478263        100  6.932581e+06

# %%
#compute total cost due to pipeline
PL = dfdemand['dfplcost'].sum()

# %%
#compute Capex
dfBase600 = capex(dfBase600, dfWells, PL)

# %%
#compute Opex
periodic_OpEx_rate = 0.07
# calculate variable OpEx costs
dfBase600['OpexTemp1 (\u20ac)'] = dfBase600['CapEx (\u20ac)'].cumsum() * periodic_OpEx_rate
dfBase600['OpexTemp2 (\u20ac)'] = dfBase600['CapexTemp (\u20ac)'].cumsum() * periodic_OpEx_rate
dfBase600['OpEx (\u20ac)'] =dfBase600['OpexTemp1 (\u20ac)'] + dfBase600['OpexTemp2 (\u20ac)']

# %%
#compute LCOH
dfBase600 = LCOH (dfBase600)

# %%
#see head of final df
dfBase600['System power (MW) Sum'].tail()
# Out:
# 47    187.755722
# 48    185.559919
# 49    183.352044
# 50    181.132291
# 51    181.132291
# Name: System power (MW) Sum, dtype: float64

# %%
dfBase600['System power (MW) Sum'].mean()
# Out:
# 208.22391102820635

# %%
dfBase600['System power (MW) Sum'].head()
# Out:
# 0   -9.384810e-08
# 1    2.124527e+02
# 2    2.135783e+02
# 3    2.147514e+02
# 4    2.158973e+02
# Name: System power (MW) Sum, dtype: float64

# %%
dfBase600['System power (MW) Sum'].max()
# Out:
# 225.04118743787916

# %%
dfBase600['System power (MW) Sum'].nsmallest(2)
# Out:
# 0    -9.384810e-08
# 51    1.811323e+02
# Name: System power (MW) Sum, dtype: float64

# %%
#visualise final econ plots
plotecon(dfBase600)

# %%
dfBase600.head()
# Out:
#    unnamed: 0  p10 : energy (kj/day)  i10 : bhp (bar)  i01 : energy (kj/day)  \
# 0         0.0          -3.846149e-01       229.153509           1.784336e-02
# 1         8.0          -3.266210e+09       233.107548           8.319519e+08
# 2         9.0          -3.289996e+09       233.663961           8.318782e+08
# 3        10.0          -3.313559e+09       234.351557           8.321687e+08
# 4        11.0          -3.336524e+09       234.902401           8.324277e+08
#
#    p03 : energy (kj/day)  i05 : energy (kj/day)  i05 : temperature (k)  \
# 0          -1.842289e+00          -6.206008e-02             349.132467
# 1          -1.835441e+09           2.043695e+09             298.150000
# 2          -1.832828e+09           2.046026e+09             298.150000
# 3          -1.830979e+09           2.048099e+09             298.150000
# 4          -1.829313e+09           2.049681e+09             298.150000
#
#    i05 : water rate (m3/day)  i04 : water rate (m3/day)  \
# 0              -1.877777e-07                  -0.000024
# 1               1.560000e+04               22440.000000
# 2               1.560000e+04               22440.000000
# 3               1.560000e+04               22440.000000
# 4               1.560000e+04               22440.000000
#
#    i02 : temperature (k)  ...  Pump power (MW)_total     CapEx (€)  \
# 0             343.624054  ...           2.563519e-09  6.442650e+07
# 1             298.150000  ...           4.433304e+01  0.000000e+00
# 2             298.150000  ...           4.534314e+01  0.000000e+00
# 3             298.150000  ...           4.588478e+01  0.000000e+00
# 4             298.150000  ...           4.624756e+01  0.000000e+00
#
#    CapexTemp (€)  OpexTemp1 (€)  OpexTemp2 (€)      OpEx (€)    LCOH costs  \
# 0       41130000   4.509855e+06      2879100.0  7.388955e+06  7.181545e+07
# 1              0   4.509855e+06      2879100.0  7.388955e+06  4.622470e+07
# 2              0   4.509855e+06      2879100.0  7.388955e+06  4.710955e+07
# 3              0   4.509855e+06      2879100.0  7.388955e+06  4.758402e+07
# 4              0   4.509855e+06      2879100.0  7.388955e+06  4.790182e+07
#
#    discounted LCOH costs  discounted LCOH energy  LCOH (€/MWh)
# 0           7.181545e+07            0.000000e+00           inf
# 1           1.158390e+08            1.772463e+06     65.354818
# 2           1.585687e+08            5.157526e+06     30.745117
# 3           1.996736e+08            1.000647e+07     19.954458
# 4           2.390825e+08            1.618045e+07     14.776014
#
# [5 rows x 121 columns]

# %%
dfBase600 = netpv(dfBase600)

# %%
npv = dfBase600['pv (MM€)'].sum()
npv
# Out:
# 2518.1376784236986

# %%
dfBase600.head()
# Out:
#    unnamed: 0  p10 : energy (kj/day)  i10 : bhp (bar)  i01 : energy (kj/day)  \
# 0         0.0          -3.846149e-01       229.153509           1.784336e-02
# 1         8.0          -3.266210e+09       233.107548           8.319519e+08
# 2         9.0          -3.289996e+09       233.663961           8.318782e+08
# 3        10.0          -3.313559e+09       234.351557           8.321687e+08
# 4        11.0          -3.336524e+09       234.902401           8.324277e+08
#
#    p03 : energy (kj/day)  i05 : energy (kj/day)  i05 : temperature (k)  \
# 0          -1.842289e+00          -6.206008e-02             349.132467
# 1          -1.835441e+09           2.043695e+09             298.150000
# 2          -1.832828e+09           2.046026e+09             298.150000
# 3          -1.830979e+09           2.048099e+09             298.150000
# 4          -1.829313e+09           2.049681e+09             298.150000
#
#    i05 : water rate (m3/day)  i04 : water rate (m3/day)  \
# 0              -1.877777e-07                  -0.000024
# 1               1.560000e+04               22440.000000
# 2               1.560000e+04               22440.000000
# 3               1.560000e+04               22440.000000
# 4               1.560000e+04               22440.000000
#
#    i02 : temperature (k)  ...    LCOH costs  discounted LCOH costs  \
# 0             343.624054  ...  7.181545e+07           7.181545e+07
# 1             298.150000  ...  4.622470e+07           1.158390e+08
# 2             298.150000  ...  4.710955e+07           1.585687e+08
# 3             298.150000  ...  4.758402e+07           1.996736e+08
# 4             298.150000  ...  4.790182e+07           2.390825e+08
#
#    discounted LCOH energy  LCOH (€/MWh)  CapEx (MM€)  OpEx (MM€)  \
# 0            0.000000e+00           inf    64.426499    7.388955
# 1            1.772463e+06     65.354818     0.000000    7.388955
# 2            5.157526e+06     30.745117     0.000000    7.388955
# 3            1.000647e+07     19.954458     0.000000    7.388955
# 4            1.618045e+07     14.776014     0.000000    7.388955
#
#    OpEx_pump (MM€)  Revenue (MM€)   NCF (MM€)    pv (MM€)
# 0         0.000000      -0.000000  -71.815454  -71.815454
# 1        38.835744     186.108585  139.883886  133.222748
# 2        39.720594     187.094596  139.985047  126.970564
# 3        40.195066     188.122216  140.538195  121.402177
# 4        40.512861     189.126057  141.224241  116.185533
#
# [5 rows x 127 columns]

# %%
plotecon2(dfBase600)

# %%
#figure, axis = plt.subplots(2, 2)
fig, axis = plt.subplots(2,2, figsize=(12,6), dpi=150, sharex=True)

X = dfBase600['econ_periods'] 
Y1 = dfBase600['p02 : bhp (bar)']
Y2 = dfBase600['p02 : water rate (m3/day)']
Y3 = dfBase600['p02 : temperature (k)']
Y4 = dfBase600['p02 : energy (kj/day)']

Y5 = dfBase600['i02 : bhp (bar)']
Y6 = dfBase600['i02 : water rate (m3/day)']
Y7 = dfBase600['i02 : temperature (k)']
Y8 = dfBase600['i02 : energy (kj/day)']

axis[0, 0].plot(X, Y1)
axis[0, 0].plot(X, Y5)
axis[0, 0].set_title("BHP (bar)")
  
axis[0, 1].plot(X, Y2)
axis[0, 1].plot(X, Y6)
axis[0, 1].set_title("water rate (m3/d)")
  
axis[1, 0].plot(X, Y3)
axis[1, 0].plot(X, Y7)
axis[1, 0].set_title("Temp (Kelvin)")
  
axis[1, 1].plot(X, Y4)
axis[1, 1].plot(X, Y8)
axis[1, 1].set_title("Energy (kj/d")
  
# Combine all the operations and display
#plt.title("P01 - I01")
#plt.figure(figsize=(20,4))
plt.show()

# %%
wells
# Out:
#    Well  x_coord  y_coord   d1dist (m)   d2dist (m)
# 0   I01      190      100  5109.060579  4776.243294
# 1   I02      136       75  2158.703314  4781.736086
# 2   I03      108      113  2500.000000  2974.054472
# 3   P01      164      110  4160.829244  3578.058133
# 4   P02      162       87  3573.513677  4543.676925
# 5   P03      134      115  3201.562119  2786.574959
# 6   I08      195       70  5056.184332  6103.277808
# 7   I05      145       41  2818.244134  6527.059062
# 8   I04       46       46  2581.181900  7351.360418
# 9   I06       52      100  2733.587387  5056.925944
# 10  I07       72      152  4486.925451  2798.660394
# 11  I09      170      170  6480.933575  2250.000000
# 12  P04       17       18  4510.543205  9323.089617
# 13  P05      113       17  2581.181900  7673.493337
# 14  P06       88       83   948.683298  4727.049820
# 15  P09      144      170  5814.851675   950.000000
# 16  P10       65       17  2804.014979  8217.207555
# 17  I10       87       45  1059.481005  6532.419154

# %%
pos = [6,10,15,16]
wells23 = wells.drop(wells.index[pos])

# %%
wells['group'] = wells['Well'].str[:1]

# %%
wells2 = wells.groupby(['group'])

# %%
wellsI = wells2.get_group('I')

# %%
wellsP = wells2.get_group('P')

# %%
x1 = wellsP['x_coord']
x2 = wellsI['x_coord']

y1 = wellsP['y_coord']
y2 = wellsI['y_coord']


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(x1, y1, color='black', label='P')
ax1.scatter(x2, y2, color='green', label='I')

plt.legend()
plt.show()

# %%
dfWells
# Out:
#   Well        d1dist        d2dist  Power (MW)  demandloc
# 0   01   9269.889823   8354.301426   16.612862          1
# 1   02   5732.216992   9325.413012   10.988259          0
# 2   03   5701.562119   5760.629430   13.382777          0
# 3   04   7091.725104  16674.450035   53.328069          0
# 4   05   5399.426034  14200.552400   27.385286          0
# 5   06   3682.270685   9783.975764   49.992293          0
# 6   09  12295.785250   3200.000000   18.865400          1
# 7   10   3863.495984  14749.626709   21.897775          0

# %%
# Output
dfBase600.to_excel("R49.xlsx")
