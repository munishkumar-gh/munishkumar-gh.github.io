# %% [markdown]
# <a href="https://www.spe.org/events/en/2022/conference/22apog/asia-pacific-oil-and-gas-conference-and-exhibition.html"><img src = "https://www.spe.org/binaries/content/gallery/specms/speevents/organization-logos/spe-logo-2020.png" width = 200>
#
# <h1 align=center><font size = 5>Prediction of Recovery Factor using Machine Learning Methods</font></h1>

# %% [markdown]
# <h1 align=center><font size = 4> Munish Kumar, Kannapan Swaminathan</font></h1>
# <h1 align=center><font size = 4> Part 4: Modelling of Recovery Factor</font></h1>
# <h1 align=center><font size = 3> ERCE 2022 </font></h1>

# %% [markdown]
# ###### References

# %% [markdown]
# 1. https://www.kaggle.com/code/kkhandekar/an-introduction-to-pycaret/notebook.
# 2. https://towardsdatascience.com/5-things-you-dont-know-about-pycaret-528db0436eec
# 3. https://www.dataquest.io/blog/understanding-regression-error-metrics/
# 4. https://www.analyticsvidhya.com/blog/2021/07/automl-using-pycaret-with-a-regression-use-case/
# 5. https://www.datacamp.com/community/tutorials/guide-for-automating-ml-workflows-using-pycaret
# 6. https://pycaret.readthedocs.io/en/latest/api/regression.html
# 7. http://www.pycaret.org/tutorials/html/REG102.html
# 8. https://githubhelp.com/ray-project/tune-sklearn

# %% [markdown]
# ## Check PyCaret Version

# %%
from pycaret.utils import version

# %%
version()
# Out:
# '2.3.6'

# %% [markdown]
# #### Libraries

# %%
# Only install the following libraries if you dont have it, otherwise leave it commented out

#!conda install -c anaconda natsort --yes
#!conda install -c anaconda xlrd --yes

#!pip install natsort --user
#!pip install xlrd --user
#!pip install pycaret[full] --user
#!pip install mlflow --user
#!pip install tune-sklearn ray[tune] --user
#!pip install optuna -- user
#!pip install hyperopt --user
#!pip install redis --user

# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
import time
import re
import requests
import pickle
import seaborn as sns
import os
import glob
import sys
from natsort import natsorted
sns.set()

import plotly.graph_objects as go
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# Sklearn Liraries
from sklearn import preprocessing

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

import ray
from ray import tune

# Forces the print statement to show everything and not truncate
# np.set_printoptions(threshold=sys.maxsize) 
print('Libraries imported')
# Out:
# Libraries imported

# %%
#Receive Data
#dir_name = r'C:\Users\kswaminathan\OneDrive\01_KannaLibrary\15_Analogs'
dir_name = r'C:\Users\mkumar\Documents\GitHub\@Papers\SPE2022\Final'
filename_suffix = 'csv'

# %% [markdown]
# ##### Read in the data

# %%
skiprows = 0
#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
df = pd.read_excel("dftorisv2.xlsx", thousands=',', skiprows = skiprows)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')] 
df.head()
# Out:
#    Lithology Code  Well Spacing  Net Pay Pay  Gross Pay  Porosity      Swi  \
# 0               1         120.0        320.0      600.0      14.0  40.0000
# 1               1         160.0        100.0      160.0      18.1  35.0000
# 2               1         160.0        100.0      300.0      15.7  51.6333
# 3               1          80.0        350.0     1400.0      13.0  30.0000
# 4               1         160.0        194.0      550.0      23.0  35.0000
#
#    Oil FVFi  Temp  Permeability  API Gravity  ...  Fractured Faulted  \
# 0     1.586   153          10.0         41.0  ...                  0
# 1     1.230   163          65.0         35.6  ...                  0
# 2     1.190   185         102.0         32.9  ...                  0
# 3     1.230   153           3.0         35.0  ...                  1
# 4     1.380   200         450.0         27.0  ...                  1
#
#    Shale Breaks  Major Gas Cap  Geologic Play  Deposition System  \
# 0             0              0            303                132
# 1             0              0            303                132
# 2             1              0            303                132
# 3             1              0            303                131
# 4             1              1            302                131
#
#    Diagenetic Overprint  Structural Comp  Heterogeniety  Trap Type       URF
# 0                     1               10              1          2  0.352836
# 1                     1               10              1          2  0.321570
# 2                     1               10              1          2  0.277514
# 3                     1               10              1          2  0.380000
# 4                     7               10              1          3  0.425909
#
# [5 rows x 24 columns]

# %%
# Plot as Heat map to check for highly correlated variables
plt.figure(figsize=(15, 15))
ax = sns.heatmap(df.corr(), annot=True, fmt=".2f")

# %% [markdown]
# In observing the heat map above, I define highly correlated variables as having collinearity coeeficients of > 0.7. There was no highly correlated values

# %% [markdown]
# ##### Convert to float - to ensure it is a numerical feature

# %%
df_drop = df.copy()
df_drop = df_drop.astype(float)

# Confirm properties of final dataframe
print(len(df_drop))
print(df_drop.info())
print(df_drop.describe(include='all'))
print(df_drop.columns.values)
# Out:
# 449
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Lithology Code        449 non-null    float64
#  1   Well Spacing          449 non-null    float64
#  2   Net Pay Pay           449 non-null    float64
#  3   Gross Pay             449 non-null    float64
#  4   Porosity              449 non-null    float64
#  5   Swi                   449 non-null    float64
#  6   Oil FVFi              449 non-null    float64
#  7   Temp                  449 non-null    float64
#  8   Permeability          449 non-null    float64
#  9   API Gravity           449 non-null    float64
#  10  Viscosity             449 non-null    float64
#  11  OOIP                  449 non-null    float64
#  12  Initial GOR           449 non-null    float64
#  13  Pressure Initial      449 non-null    float64
#  14  Fractured Faulted     449 non-null    float64
#  15  Shale Breaks          449 non-null    float64
#  16  Major Gas Cap         449 non-null    float64
#  17  Geologic Play         449 non-null    float64
#  18  Deposition System     449 non-null    float64
#  19  Diagenetic Overprint  449 non-null    float64
#  20  Structural Comp       449 non-null    float64
#  21  Heterogeniety         449 non-null    float64
#  22  Trap Type             449 non-null    float64
#  23  URF                   449 non-null    float64
# dtypes: float64(24)
# memory usage: 84.3 KB
# None
#        Lithology Code  Well Spacing  Net Pay Pay    Gross Pay    Porosity  \
# count      449.000000    449.000000   449.000000   449.000000  449.000000
# mean         1.356347     35.315705   102.768909   273.681710   19.442494
# std          0.544830     46.152618   161.329359   428.565109    8.602036
# min          1.000000      0.888626     5.000000    10.000000    3.000000
# 25%          1.000000     10.000000    23.500000    50.000000   12.000000
# 50%          1.000000     20.000000    50.000000   140.000000   18.000000
# 75%          2.000000     40.000000   120.000000   300.000000   27.000000
# max          3.000000    640.000000  2300.000000  5500.000000   51.000000
#
#               Swi    Oil FVFi        Temp  Permeability  API Gravity  ...  \
# count  449.000000  449.000000  449.000000    449.000000   449.000000  ...
# mean    30.419584    1.254460  138.792873    442.745214    32.212071  ...
# std      9.744284    0.205802   43.183985   1436.765362     8.845767  ...
# min      7.000000    1.000000   63.000000      0.100000     6.000000  ...
# 25%     24.600000    1.100000  105.000000     11.000000    27.000000  ...
# 50%     30.000000    1.200000  130.000000     63.000000    34.000000  ...
# 75%     35.000000    1.342000  166.000000    400.000000    39.000000  ...
# max     68.000000    2.127000  266.000000  26816.500000    52.000000  ...
#
#        Fractured Faulted  Shale Breaks  Major Gas Cap  Geologic Play  \
# count         449.000000    449.000000     449.000000     449.000000
# mean            0.336303      0.592428       3.064588     640.538976
# std             0.472971      0.491931      42.737757     750.138448
# min             0.000000      0.000000       0.000000       5.000000
# 25%             0.000000      0.000000       0.000000      44.000000
# 50%             0.000000      1.000000       0.000000     414.000000
# 75%             1.000000      1.000000       0.000000     831.000000
# max             1.000000      1.000000     680.000000    2417.000000
#
#        Deposition System  Diagenetic Overprint  Structural Comp  \
# count         449.000000            449.000000       449.000000
# mean          183.020045              2.155902        13.643653
# std            37.944121              2.091163         8.544132
# min           110.000000              1.000000        10.000000
# 25%           152.000000              1.000000        10.000000
# 50%           181.000000              1.000000        10.000000
# 75%           222.000000              3.000000        10.000000
# max           270.000000              9.000000        50.000000
#
#        Heterogeniety   Trap Type         URF
# count     449.000000  449.000000  449.000000
# mean        1.389755    2.211581    0.351592
# std         0.635260    0.662954    0.136395
# min         1.000000    1.000000    0.024000
# 25%         1.000000    2.000000    0.251808
# 50%         1.000000    2.000000    0.340000
# 75%         2.000000    3.000000    0.445000
# max         3.000000    3.000000    0.698300
#
# [8 rows x 24 columns]
# ['Lithology Code' 'Well Spacing' 'Net Pay Pay' 'Gross Pay' 'Porosity'
#  'Swi' 'Oil FVFi' 'Temp' 'Permeability' 'API Gravity' 'Viscosity' 'OOIP'
#  'Initial GOR' 'Pressure Initial' 'Fractured Faulted' 'Shale Breaks'
#  'Major Gas Cap' 'Geologic Play' 'Deposition System'
#  'Diagenetic Overprint' 'Structural Comp' 'Heterogeniety' 'Trap Type'
#  'URF']

# %% [markdown]
# Final Data set has 450 rows and 24 columns.

# %% [markdown]
# ### Train, Validation, and Test Split

# %%
# Creates a mask where values that are true go into the training/test set
# Note that I done it so that the random number is predictable

msk = np.random.seed(0)
msk = np.random.rand(len(df_drop))<0.8

raw_train_validate_set = df_drop[msk]
raw_test_set = df_drop[~msk]

print(raw_train_validate_set.shape)
print(raw_test_set.shape)
# Out:
# (364, 24)
# (85, 24)

# %%
raw_train_validate_set.to_excel(r'dfssoil.xlsx', index = False, header=True)
raw_test_set.to_excel(r'BlindTest_SSOIL.xlsx', index = False, header=True)

# %% [markdown]
# We split the data set 80-20 into a "train-validate" set and a "test" set. The test set is external asn will never be seen by the model.

# %% [markdown]
# ## 1. Pycaret Implementation

# %% [markdown]
# Pycaret will be used in the machine learning portion. Pycaret is a low-code machine learning library in Python that automates machine learning workflows. One of its key benefits is its ability to run a large number of differnt machine learning algorithms, but with only a few lines of code

# %%
skiprows = 0
#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
df = pd.read_excel("dfssoil.xlsx", thousands=',', skiprows = skiprows)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')] 
df.head()
# Out:
#    Lithology Code  Well Spacing  Net Pay Pay  Gross Pay  Porosity      Swi  \
# 0               1         120.0        320.0      600.0      14.0  40.0000
# 1               1         160.0        100.0      160.0      18.1  35.0000
# 2               1         160.0        100.0      300.0      15.7  51.6333
# 3               1          80.0        350.0     1400.0      13.0  30.0000
# 4               1         160.0        194.0      550.0      23.0  35.0000
#
#    Oil FVFi  Temp  Permeability  API Gravity  ...  Fractured Faulted  \
# 0     1.586   153          10.0         41.0  ...                  0
# 1     1.230   163          65.0         35.6  ...                  0
# 2     1.190   185         102.0         32.9  ...                  0
# 3     1.230   153           3.0         35.0  ...                  1
# 4     1.380   200         450.0         27.0  ...                  1
#
#    Shale Breaks  Major Gas Cap  Geologic Play  Deposition System  \
# 0             0              0            303                132
# 1             0              0            303                132
# 2             1              0            303                132
# 3             1              0            303                131
# 4             1              1            302                131
#
#    Diagenetic Overprint  Structural Comp  Heterogeniety  Trap Type       URF
# 0                     1               10              1          2  0.352836
# 1                     1               10              1          2  0.321570
# 2                     1               10              1          2  0.277514
# 3                     1               10              1          2  0.380000
# 4                     7               10              1          3  0.425909
#
# [5 rows x 24 columns]

# %%
from pycaret.regression import *

#Create a copy
model_df = df_drop.copy()
target = 'URF'

# no resampling
clf_none = setup(
            data=model_df,
            target=target,
            session_id=42,
            normalize=True,
            transformation = True,
            ignore_low_variance=True,
            remove_outliers = True, outliers_threshold = 0.1,
            remove_multicollinearity = True, multicollinearity_threshold = 0.7,
            train_size=0.7)
# Out:
# <style type="text/css">
# #T_8aa02_row27_col1, #T_8aa02_row29_col1, #T_8aa02_row34_col1, #T_8aa02_row38_col1, #T_8aa02_row40_col1, #T_8aa02_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8aa02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8aa02_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8aa02_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8aa02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8aa02_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_8aa02_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8aa02_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8aa02_row1_col1" class="data row1 col1" >URF</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8aa02_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_8aa02_row2_col1" class="data row2 col1" >(449, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8aa02_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_8aa02_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8aa02_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_8aa02_row4_col1" class="data row4 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8aa02_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_8aa02_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8aa02_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_8aa02_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8aa02_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_8aa02_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8aa02_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_8aa02_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8aa02_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_8aa02_row9_col1" class="data row9 col1" >(282, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8aa02_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_8aa02_row10_col1" class="data row10 col1" >(135, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8aa02_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_8aa02_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8aa02_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_8aa02_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8aa02_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_8aa02_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8aa02_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_8aa02_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8aa02_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_8aa02_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8aa02_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_8aa02_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8aa02_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_8aa02_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8aa02_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_8aa02_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8aa02_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_8aa02_row19_col1" class="data row19 col1" >f8c6</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8aa02_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_8aa02_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8aa02_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_8aa02_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8aa02_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_8aa02_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_8aa02_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_8aa02_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_8aa02_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_8aa02_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_8aa02_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_8aa02_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_8aa02_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_8aa02_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_8aa02_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_8aa02_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_8aa02_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_8aa02_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_8aa02_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_8aa02_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8aa02_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_8aa02_row30_

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_99957 th {
#   text-align: left;
# }
# #T_99957_row0_col0, #T_99957_row0_col6, #T_99957_row1_col0, #T_99957_row1_col1, #T_99957_row1_col3, #T_99957_row1_col4, #T_99957_row1_col5, #T_99957_row1_col6, #T_99957_row2_col0, #T_99957_row2_col1, #T_99957_row2_col2, #T_99957_row2_col3, #T_99957_row2_col4, #T_99957_row2_col5, #T_99957_row2_col6, #T_99957_row3_col0, #T_99957_row3_col1, #T_99957_row3_col2, #T_99957_row3_col3, #T_99957_row3_col4, #T_99957_row3_col5, #T_99957_row3_col6, #T_99957_row4_col0, #T_99957_row4_col1, #T_99957_row4_col2, #T_99957_row4_col3, #T_99957_row4_col4, #T_99957_row4_col5, #T_99957_row4_col6, #T_99957_row5_col0, #T_99957_row5_col1, #T_99957_row5_col2, #T_99957_row5_col3, #T_99957_row5_col4, #T_99957_row5_col5, #T_99957_row5_col6, #T_99957_row6_col0, #T_99957_row6_col1, #T_99957_row6_col2, #T_99957_row6_col3, #T_99957_row6_col4, #T_99957_row6_col5, #T_99957_row6_col6, #T_99957_row7_col0, #T_99957_row7_col1, #T_99957_row7_col2, #T_99957_row7_col3, #T_99957_row7_col4, #T_99957_row7_col5, #T_99957_row8_col0, #T_99957_row8_col1, #T_99957_row8_col2, #T_99957_row8_col3, #T_99957_row8_col4, #T_99957_row8_col5, #T_99957_row8_col6, #T_99957_row9_col0, #T_99957_row9_col1, #T_99957_row9_col2, #T_99957_row9_col3, #T_99957_row9_col4, #T_99957_row9_col5, #T_99957_row9_col6, #T_99957_row10_col0, #T_99957_row10_col1, #T_99957_row10_col2, #T_99957_row10_col3, #T_99957_row10_col4, #T_99957_row10_col5, #T_99957_row10_col6, #T_99957_row11_col0, #T_99957_row11_col1, #T_99957_row11_col2, #T_99957_row11_col3, #T_99957_row11_col4, #T_99957_row11_col5, #T_99957_row11_col6, #T_99957_row12_col0, #T_99957_row12_col1, #T_99957_row12_col2, #T_99957_row12_col3, #T_99957_row12_col4, #T_99957_row12_col5, #T_99957_row12_col6, #T_99957_row13_col0, #T_99957_row13_col1, #T_99957_row13_col2, #T_99957_row13_col3, #T_99957_row13_col4, #T_99957_row13_col5, #T_99957_row13_col6, #T_99957_row14_col0, #T_99957_row14_col1, #T_99957_row14_col2, #T_99957_row14_col3, #T_99957_row14_col4, #T_99957_row14_col5, #T_99957_row14_col6, #T_99957_row15_col0, #T_99957_row15_col1, #T_99957_row15_col2, #T_99957_row15_col3, #T_99957_row15_col4, #T_99957_row15_col5, #T_99957_row15_col6, #T_99957_row16_col0, #T_99957_row16_col1, #T_99957_row16_col2, #T_99957_row16_col3, #T_99957_row16_col4, #T_99957_row16_col5, #T_99957_row16_col6, #T_99957_row17_col0, #T_99957_row17_col1, #T_99957_row17_col2, #T_99957_row17_col3, #T_99957_row17_col4, #T_99957_row17_col5, #T_99957_row17_col6, #T_99957_row18_col0, #T_99957_row18_col1, #T_99957_row18_col2, #T_99957_row18_col3, #T_99957_row18_col4, #T_99957_row18_col5, #T_99957_row18_col6, #T_99957_row19_col0, #T_99957_row19_col1, #T_99957_row19_col2, #T_99957_row19_col3, #T_99957_row19_col4, #T_99957_row19_col5, #T_99957_row19_col6 {
#   text-align: left;
# }
# #T_99957_row0_col1, #T_99957_row0_col2, #T_99957_row0_col3, #T_99957_row0_col4, #T_99957_row0_col5, #T_99957_row1_col2, #T_99957_row7_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_99957_row0_col7, #T_99957_row1_col7, #T_99957_row2_col7, #T_99957_row3_col7, #T_99957_row4_col7, #T_99957_row5_col7, #T_99957_row6_col7, #T_99957_row7_col7, #T_99957_row8_col7, #T_99957_row9_col7, #T_99957_row10_col7, #T_99957_row11_col7, #T_99957_row13_col7, #T_99957_row14_col7, #T_99957_row15_col7, #T_99957_row16_col7, #T_99957_row17_col7, #T_99957_row18_col7, #T_99957_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_99957_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_99957">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99957_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_99957_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_99957_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_99957_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_99957_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_99957_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_99957_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_99957_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99957_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_99957_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_99957_row0_col1" class="data row0 col1" >0.0950</td>
#       <td id="T_99957_row0_col2" class="data row0 col2" >0.0154</td>
#       <td id="T_99957_row0_col3" class="data row0 col3" >0.1227</td>
#       <td id="T_99957_row0_col4" class="data row0 col4" >0.0841</td>
#       <td id="T_99957_row0_col5" class="data row0 col5" >0.0904</td>
#       <td id="T_99957_row0_col6" class="data row0 col6" >0.3603</td>
#       <td id="T_99957_row0_col7" class="data row0 col7" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_99957_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_99957_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_99957_row1_col1" class="data row1 col1" >0.0962</td>
#       <td id="T_99957_row1_col2" class="data row1 col2" >0.0154</td>
#       <td id="T_99957_row1_col3" class="data row1 col3" >0.1232</td>
#       <td id="T_99957_row1_col4" class="data row1 col4" >0.0820</td>
#       <td id="T_99957_row1_col5" class="data row1 col5" >0.0908</td>
#       <td id="T_99957_row1_col6" class="data row1 col6" >0.3723</td>
#       <td id="T_99957_row1_col7" class="data row1 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_99957_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_99957_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_99957_row2_col1" class="data row2 col1" >0.0958</td>
#       <td id="T_99957_row2_col2" class="data row2 col2" >0.0157</td>
#       <td id="T_99957_row2_col3" class="data row2 col3" >0.1242</td>
#       <td id="T_99957_row2_col4" class="data row2 col4" >0.0655</td>
#       <td id="T_99957_row2_col5" class="data row2 col5" >0.0917</td>
#       <td id="T_99957_row2_col6" class="data row2 col6" >0.3719</td>
#       <td id="T_99957_row2_col7" class="data row2 col7" >0.0390</td>
#     </tr>
#     <tr>
#       <th id="T_99957_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_99957_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_99957_row3_col1" class="data row3 col1" >0.0979</td>
#       <td id="T_99957_row3_col2" class="data row3 col2" >0.0157</td>
#       <td id="T_99957_row3_col3" class="data row3 col3" >0.1242</td>
#       <td id="T_99957_row3_col4" class="data row3 col4" >0.0587</td>
#       <td id="T_99957_row3_col5" class="data row3 col5" >0.0918</td>
#       <td id="T_99957_row3_col6" class="data row3 col6" >0.3724</td>
#       <td id="T_99957_row3_col7" class="data row3 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_99957_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_99957_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_99957_row4_col1" class="data row4 col1" >0.0980</td>
#       <td id="T_99957_row4_col2" class="data row4 col2" >0.0157</td>
#       <td id="T_99957_row4_col3" class="data row4 col3" >0.1243</td>
#       <td id="T_99957_row4_col4" class="data row4 col4" >0.0570</td>
#       <td id="T_99957_row4_col5" class="data row4 col5" >0.0918</td>
#       <td id="T_99957_row4_col6" class="data row4 col6" >0.3726</td>
#       <td id="T_99957_row4_col7" class="data row4 col7" >0.3900</td>
#     </tr>
#     <tr>
#       <th id="T_99957_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_99957_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_99957_row5_col1" class="data row5 col1" >0.0980</td>
#       <td id="T_99957_row5_col2" class="data row5 col2" >0.0157</td>
#       <td id="T_99957_row5_col3" class="data row5 col3" >0.1243</td>
#       <td id="T_99957_r

# %%
top3_fold_5 = compare_models(include=['rf', 'catboost', 'knn'], fold = 5, sort='MAE')
# Out:
# <style type="text/css">
# #T_4dbbe th {
#   text-align: left;
# }
# #T_4dbbe_row0_col0, #T_4dbbe_row0_col6, #T_4dbbe_row1_col0, #T_4dbbe_row1_col1, #T_4dbbe_row1_col2, #T_4dbbe_row1_col3, #T_4dbbe_row1_col4, #T_4dbbe_row1_col5, #T_4dbbe_row1_col6, #T_4dbbe_row2_col0, #T_4dbbe_row2_col1, #T_4dbbe_row2_col2, #T_4dbbe_row2_col3, #T_4dbbe_row2_col4, #T_4dbbe_row2_col5 {
#   text-align: left;
# }
# #T_4dbbe_row0_col1, #T_4dbbe_row0_col2, #T_4dbbe_row0_col3, #T_4dbbe_row0_col4, #T_4dbbe_row0_col5, #T_4dbbe_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4dbbe_row0_col7, #T_4dbbe_row1_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4dbbe_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4dbbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4dbbe_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4dbbe_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4dbbe_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4dbbe_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4dbbe_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4dbbe_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4dbbe_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4dbbe_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4dbbe_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_4dbbe_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_4dbbe_row0_col1" class="data row0 col1" >0.0958</td>
#       <td id="T_4dbbe_row0_col2" class="data row0 col2" >0.0155</td>
#       <td id="T_4dbbe_row0_col3" class="data row0 col3" >0.1241</td>
#       <td id="T_4dbbe_row0_col4" class="data row0 col4" >0.1013</td>
#       <td id="T_4dbbe_row0_col5" class="data row0 col5" >0.0918</td>
#       <td id="T_4dbbe_row0_col6" class="data row0 col6" >0.3725</td>
#       <td id="T_4dbbe_row0_col7" class="data row0 col7" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_4dbbe_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_4dbbe_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_4dbbe_row1_col1" class="data row1 col1" >0.0969</td>
#       <td id="T_4dbbe_row1_col2" class="data row1 col2" >0.0162</td>
#       <td id="T_4dbbe_row1_col3" class="data row1 col3" >0.1270</td>
#       <td id="T_4dbbe_row1_col4" class="data row1 col4" >0.0632</td>
#       <td id="T_4dbbe_row1_col5" class="data row1 col5" >0.0937</td>
#       <td id="T_4dbbe_row1_col6" class="data row1 col6" >0.3678</td>
#       <td id="T_4dbbe_row1_col7" class="data row1 col7" >0.3920</td>
#     </tr>
#     <tr>
#       <th id="T_4dbbe_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_4dbbe_row2_col0" class="data row2 col0" >K Neighbors Regressor</td>
#       <td id="T_4dbbe_row2_col1" class="data row2 col1" >0.0988</td>
#       <td id="T_4dbbe_row2_col2" class="data row2 col2" >0.0164</td>
#       <td id="T_4dbbe_row2_col3" class="data row2 col3" >0.1279</td>
#       <td id="T_4dbbe_row2_col4" class="data row2 col4" >0.0435</td>
#       <td id="T_4dbbe_row2_col5" class="data row2 col5" >0.0939</td>
#       <td id="T_4dbbe_row2_col6" class="data row2 col6" >0.3567</td>
#       <td id="T_4dbbe_row2_col7" class="data row2 col7" >0.0060</td>
#     </tr>
#   </tbody>
# </table>

# %%
top3 = compare_models(include=['rf', 'catboost', 'knn'], fold = 10, sort='MAE')
# Out:
# <style type="text/css">
# #T_1465a th {
#   text-align: left;
# }
# #T_1465a_row0_col0, #T_1465a_row0_col6, #T_1465a_row1_col0, #T_1465a_row1_col1, #T_1465a_row1_col2, #T_1465a_row1_col3, #T_1465a_row1_col4, #T_1465a_row1_col5, #T_1465a_row1_col6, #T_1465a_row2_col0, #T_1465a_row2_col1, #T_1465a_row2_col2, #T_1465a_row2_col3, #T_1465a_row2_col4, #T_1465a_row2_col5 {
#   text-align: left;
# }
# #T_1465a_row0_col1, #T_1465a_row0_col2, #T_1465a_row0_col3, #T_1465a_row0_col4, #T_1465a_row0_col5, #T_1465a_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1465a_row0_col7, #T_1465a_row1_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1465a_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1465a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1465a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1465a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1465a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1465a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1465a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1465a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1465a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1465a_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1465a_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_1465a_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_1465a_row0_col1" class="data row0 col1" >0.0958</td>
#       <td id="T_1465a_row0_col2" class="data row0 col2" >0.0157</td>
#       <td id="T_1465a_row0_col3" class="data row0 col3" >0.1242</td>
#       <td id="T_1465a_row0_col4" class="data row0 col4" >0.0655</td>
#       <td id="T_1465a_row0_col5" class="data row0 col5" >0.0917</td>
#       <td id="T_1465a_row0_col6" class="data row0 col6" >0.3719</td>
#       <td id="T_1465a_row0_col7" class="data row0 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_1465a_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_1465a_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_1465a_row1_col1" class="data row1 col1" >0.0964</td>
#       <td id="T_1465a_row1_col2" class="data row1 col2" >0.0163</td>
#       <td id="T_1465a_row1_col3" class="data row1 col3" >0.1266</td>
#       <td id="T_1465a_row1_col4" class="data row1 col4" >0.0162</td>
#       <td id="T_1465a_row1_col5" class="data row1 col5" >0.0934</td>
#       <td id="T_1465a_row1_col6" class="data row1 col6" >0.3700</td>
#       <td id="T_1465a_row1_col7" class="data row1 col7" >0.4260</td>
#     </tr>
#     <tr>
#       <th id="T_1465a_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_1465a_row2_col0" class="data row2 col0" >K Neighbors Regressor</td>
#       <td id="T_1465a_row2_col1" class="data row2 col1" >0.0977</td>
#       <td id="T_1465a_row2_col2" class="data row2 col2" >0.0164</td>
#       <td id="T_1465a_row2_col3" class="data row2 col3" >0.1273</td>
#       <td id="T_1465a_row2_col4" class="data row2 col4" >0.0166</td>
#       <td id="T_1465a_row2_col5" class="data row2 col5" >0.0934</td>
#       <td id="T_1465a_row2_col6" class="data row2 col6" >0.3536</td>
#       <td id="T_1465a_row2_col7" class="data row2 col7" >0.0050</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There is a performance improvement in going from 5 folds to 10 folds for all 3 models. To keep computation time reasonable, folds is kept at 10.

# %% [markdown]
# ## 2. Plot each Model and Check Features

# %% [markdown]
# ##### Random Forest (RFR)

# %%
rfr = create_model('rf')
rfr_results = pull()

rfr_feature_imp = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value' : abs(rfr.feature_importances_)}).sort_values(by='Value', ascending=False)
rfr_feature_imp.to_csv('Feature_importance_RFR.csv')
# Out:
# <style type="text/css">
# #T_a5e7a_row10_col0, #T_a5e7a_row10_col1, #T_a5e7a_row10_col2, #T_a5e7a_row10_col3, #T_a5e7a_row10_col4, #T_a5e7a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a5e7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5e7a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a5e7a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a5e7a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a5e7a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a5e7a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a5e7a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5e7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5e7a_row0_col0" class="data row0 col0" >0.0757</td>
#       <td id="T_a5e7a_row0_col1" class="data row0 col1" >0.0091</td>
#       <td id="T_a5e7a_row0_col2" class="data row0 col2" >0.0956</td>
#       <td id="T_a5e7a_row0_col3" class="data row0 col3" >-0.1306</td>
#       <td id="T_a5e7a_row0_col4" class="data row0 col4" >0.0722</td>
#       <td id="T_a5e7a_row0_col5" class="data row0 col5" >0.2783</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5e7a_row1_col0" class="data row1 col0" >0.1168</td>
#       <td id="T_a5e7a_row1_col1" class="data row1 col1" >0.0199</td>
#       <td id="T_a5e7a_row1_col2" class="data row1 col2" >0.1411</td>
#       <td id="T_a5e7a_row1_col3" class="data row1 col3" >0.1817</td>
#       <td id="T_a5e7a_row1_col4" class="data row1 col4" >0.1069</td>
#       <td id="T_a5e7a_row1_col5" class="data row1 col5" >0.5418</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5e7a_row2_col0" class="data row2 col0" >0.0933</td>
#       <td id="T_a5e7a_row2_col1" class="data row2 col1" >0.0160</td>
#       <td id="T_a5e7a_row2_col2" class="data row2 col2" >0.1264</td>
#       <td id="T_a5e7a_row2_col3" class="data row2 col3" >0.0228</td>
#       <td id="T_a5e7a_row2_col4" class="data row2 col4" >0.0920</td>
#       <td id="T_a5e7a_row2_col5" class="data row2 col5" >0.3429</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5e7a_row3_col0" class="data row3 col0" >0.1195</td>
#       <td id="T_a5e7a_row3_col1" class="data row3 col1" >0.0246</td>
#       <td id="T_a5e7a_row3_col2" class="data row3 col2" >0.1569</td>
#       <td id="T_a5e7a_row3_col3" class="data row3 col3" >-0.1516</td>
#       <td id="T_a5e7a_row3_col4" class="data row3 col4" >0.1178</td>
#       <td id="T_a5e7a_row3_col5" class="data row3 col5" >0.5814</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5e7a_row4_col0" class="data row4 col0" >0.0839</td>
#       <td id="T_a5e7a_row4_col1" class="data row4 col1" >0.0127</td>
#       <td id="T_a5e7a_row4_col2" class="data row4 col2" >0.1128</td>
#       <td id="T_a5e7a_row4_col3" class="data row4 col3" >0.1185</td>
#       <td id="T_a5e7a_row4_col4" class="data row4 col4" >0.0813</td>
#       <td id="T_a5e7a_row4_col5" class="data row4 col5" >0.2646</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a5e7a_row5_col0" class="data row5 col0" >0.1085</td>
#       <td id="T_a5e7a_row5_col1" class="data row5 col1" >0.0180</td>
#       <td id="T_a5e7a_row5_col2" class="data row5 col2" >0.1343</td>
#       <td id="T_a5e7a_row5_col3" class="data row5 col3" >-0.1106</td>
#       <td id="T_a5e7a_row5_col4" class="data row5 col4" >0.0984</td>
#       <td id="T_a5e7a_row5_col5" class="data row5 col5" >0.3624</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a5e7a_row6_col0" class="data row6 col0" >0.0991</td>
#       <td id="T_a5e7a_row6_col1" class="data row6 col1" >0.0170</td>
#       <td id="T_a5e7a_row6_col2" class="data row6 col2" >0.1305</td>
#       <td id="T_a5e7a_row6_col3" class="data row6 col3" >0.2027</td>
#       <td id="T_a5e7a_row6_col4" class="data row6 col4" >0.0957</td>
#       <td id="T_a5e7a_row6_col5" class="data row6 col5" >0.3876</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a5e7a_row7_col0" class="data row7 col0" >0.0755</td>
#       <td id="T_a5e7a_row7_col1" class="data row7 col1" >0.0094</td>
#       <td id="T_a5e7a_row7_col2" class="data row7 col2" >0.0970</td>
#       <td id="T_a5e7a_row7_col3" class="data row7 col3" >0.3514</td>
#       <td id="T_a5e7a_row7_col4" class="data row7 col4" >0.0730</td>
#       <td id="T_a5e7a_row7_col5" class="data row7 col5" >0.2873</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a5e7a_row8_col0" class="data row8 col0" >0.0901</td>
#       <td id="T_a5e7a_row8_col1" class="data row8 col1" >0.0148</td>
#       <td id="T_a5e7a_row8_col2" class="data row8 col2" >0.1219</td>
#       <td id="T_a5e7a_row8_col3" class="data row8 col3" >0.2436</td>
#       <td id="T_a5e7a_row8_col4" class="data row8 col4" >0.0883</td>
#       <td id="T_a5e7a_row8_col5" class="data row8 col5" >0.3545</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a5e7a_row9_col0" class="data row9 col0" >0.0951</td>
#       <td id="T_a5e7a_row9_col1" class="data row9 col1" >0.0156</td>
#       <td id="T_a5e7a_row9_col2" class="data row9 col2" >0.1249</td>
#       <td id="T_a5e7a_row9_col3" class="data row9 col3" >-0.0731</td>
#       <td id="T_a5e7a_row9_col4" class="data row9 col4" >0.0916</td>
#       <td id="T_a5e7a_row9_col5" class="data row9 col5" >0.3179</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a5e7a_row10_col0" class="data row10 col0" >0.0958</td>
#       <td id="T_a5e7a_row10_col1" class="data row10 col1" >0.0157</td>
#       <td id="T_a5e7a_row10_col2" class="data row10 col2" >0.1242</td>
#       <td id="T_a5e7a_row10_col3" class="data row10 col3" >0.0655</td>
#       <td id="T_a5e7a_row10_col4" class="data row10 col4" >0.0917</td>
#       <td id="T_a5e7a_row10_col5" class="data row10 col5" >0.3719</td>
#     </tr>
#     <tr>
#       <th id="T_a5e7a_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_a5e7a_row11_col0" class="data row11 col0" >0.0147</td>
#       <td id="T_a5e7a_row11_col1" class="data row11 col1" >0.0044</td>
#       <td id="T_a5e7a_row11_col2" class="data row11 col2" >0.0179</td>
#       <td id="T_a5e7a_row11_col3" class="data row11 col3" >0.1692</td>
#       <td id="T_a5e7a_row11_col4" class="data row11 col4" >0.0135</td>
#       <td id="T_a5e7a_row11_col5" class="data row11 col5" >0.1023</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(rfr, plot = 'feature')

# %% [markdown]
# ##### Catboost Regressor (catboost)

# %%
cb = create_model('catboost')
cb_results = pull()
#print(gbr_results)

cb_feature_imp = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value' : abs(cb.feature_importances_)}).sort_values(by='Value', ascending=False)
cb_feature_imp.to_csv('Feature_importance_CatBoost.csv')
# Out:
# <style type="text/css">
# #T_548df_row10_col0, #T_548df_row10_col1, #T_548df_row10_col2, #T_548df_row10_col3, #T_548df_row10_col4, #T_548df_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_548df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_548df_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_548df_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_548df_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_548df_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_548df_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_548df_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_548df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_548df_row0_col0" class="data row0 col0" >0.0780</td>
#       <td id="T_548df_row0_col1" class="data row0 col1" >0.0108</td>
#       <td id="T_548df_row0_col2" class="data row0 col2" >0.1038</td>
#       <td id="T_548df_row0_col3" class="data row0 col3" >-0.3321</td>
#       <td id="T_548df_row0_col4" class="data row0 col4" >0.0782</td>
#       <td id="T_548df_row0_col5" class="data row0 col5" >0.2905</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_548df_row1_col0" class="data row1 col0" >0.1157</td>
#       <td id="T_548df_row1_col1" class="data row1 col1" >0.0202</td>
#       <td id="T_548df_row1_col2" class="data row1 col2" >0.1422</td>
#       <td id="T_548df_row1_col3" class="data row1 col3" >0.1694</td>
#       <td id="T_548df_row1_col4" class="data row1 col4" >0.1076</td>
#       <td id="T_548df_row1_col5" class="data row1 col5" >0.5433</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_548df_row2_col0" class="data row2 col0" >0.0944</td>
#       <td id="T_548df_row2_col1" class="data row2 col1" >0.0174</td>
#       <td id="T_548df_row2_col2" class="data row2 col2" >0.1317</td>
#       <td id="T_548df_row2_col3" class="data row2 col3" >-0.0616</td>
#       <td id="T_548df_row2_col4" class="data row2 col4" >0.0961</td>
#       <td id="T_548df_row2_col5" class="data row2 col5" >0.3491</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_548df_row3_col0" class="data row3 col0" >0.1241</td>
#       <td id="T_548df_row3_col1" class="data row3 col1" >0.0268</td>
#       <td id="T_548df_row3_col2" class="data row3 col2" >0.1637</td>
#       <td id="T_548df_row3_col3" class="data row3 col3" >-0.2533</td>
#       <td id="T_548df_row3_col4" class="data row3 col4" >0.1230</td>
#       <td id="T_548df_row3_col5" class="data row3 col5" >0.5945</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_548df_row4_col0" class="data row4 col0" >0.0888</td>
#       <td id="T_548df_row4_col1" class="data row4 col1" >0.0140</td>
#       <td id="T_548df_row4_col2" class="data row4 col2" >0.1184</td>
#       <td id="T_548df_row4_col3" class="data row4 col3" >0.0303</td>
#       <td id="T_548df_row4_col4" class="data row4 col4" >0.0852</td>
#       <td id="T_548df_row4_col5" class="data row4 col5" >0.2761</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_548df_row5_col0" class="data row5 col0" >0.1100</td>
#       <td id="T_548df_row5_col1" class="data row5 col1" >0.0177</td>
#       <td id="T_548df_row5_col2" class="data row5 col2" >0.1331</td>
#       <td id="T_548df_row5_col3" class="data row5 col3" >-0.0905</td>
#       <td id="T_548df_row5_col4" class="data row5 col4" >0.0975</td>
#       <td id="T_548df_row5_col5" class="data row5 col5" >0.3667</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_548df_row6_col0" class="data row6 col0" >0.0926</td>
#       <td id="T_548df_row6_col1" class="data row6 col1" >0.0152</td>
#       <td id="T_548df_row6_col2" class="data row6 col2" >0.1233</td>
#       <td id="T_548df_row6_col3" class="data row6 col3" >0.2889</td>
#       <td id="T_548df_row6_col4" class="data row6 col4" >0.0897</td>
#       <td id="T_548df_row6_col5" class="data row6 col5" >0.3502</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_548df_row7_col0" class="data row7 col0" >0.0789</td>
#       <td id="T_548df_row7_col1" class="data row7 col1" >0.0108</td>
#       <td id="T_548df_row7_col2" class="data row7 col2" >0.1038</td>
#       <td id="T_548df_row7_col3" class="data row7 col3" >0.2569</td>
#       <td id="T_548df_row7_col4" class="data row7 col4" >0.0775</td>
#       <td id="T_548df_row7_col5" class="data row7 col5" >0.2805</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_548df_row8_col0" class="data row8 col0" >0.0868</td>
#       <td id="T_548df_row8_col1" class="data row8 col1" >0.0138</td>
#       <td id="T_548df_row8_col2" class="data row8 col2" >0.1177</td>
#       <td id="T_548df_row8_col3" class="data row8 col3" >0.2947</td>
#       <td id="T_548df_row8_col4" class="data row8 col4" >0.0847</td>
#       <td id="T_548df_row8_col5" class="data row8 col5" >0.3227</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_548df_row9_col0" class="data row9 col0" >0.0946</td>
#       <td id="T_548df_row9_col1" class="data row9 col1" >0.0166</td>
#       <td id="T_548df_row9_col2" class="data row9 col2" >0.1288</td>
#       <td id="T_548df_row9_col3" class="data row9 col3" >-0.1402</td>
#       <td id="T_548df_row9_col4" class="data row9 col4" >0.0947</td>
#       <td id="T_548df_row9_col5" class="data row9 col5" >0.3260</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_548df_row10_col0" class="data row10 col0" >0.0964</td>
#       <td id="T_548df_row10_col1" class="data row10 col1" >0.0163</td>
#       <td id="T_548df_row10_col2" class="data row10 col2" >0.1266</td>
#       <td id="T_548df_row10_col3" class="data row10 col3" >0.0162</td>
#       <td id="T_548df_row10_col4" class="data row10 col4" >0.0934</td>
#       <td id="T_548df_row10_col5" class="data row10 col5" >0.3700</td>
#     </tr>
#     <tr>
#       <th id="T_548df_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_548df_row11_col0" class="data row11 col0" >0.0146</td>
#       <td id="T_548df_row11_col1" class="data row11 col1" >0.0045</td>
#       <td id="T_548df_row11_col2" class="data row11 col2" >0.0170</td>
#       <td id="T_548df_row11_col3" class="data row11 col3" >0.2166</td>
#       <td id="T_548df_row11_col4" class="data row11 col4" >0.0132</td>
#       <td id="T_548df_row11_col5" class="data row11 col5" >0.1042</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(cb, plot = 'feature')

# %% [markdown]
# ##### Gradient Boost Regressor (gbr)

# %%
gbr = create_model('gbr')
gbr_results = pull()
#print(cb_results)

gbr_feature_imp = pd.DataFrame({'Feature': get_config('X_train').columns, 'Value' : abs(gbr.feature_importances_)}).sort_values(by='Value', ascending=False)
gbr_feature_imp.to_csv('Feature_importance_GBR.csv')
# Out:
# <style type="text/css">
# #T_85f55_row10_col0, #T_85f55_row10_col1, #T_85f55_row10_col2, #T_85f55_row10_col3, #T_85f55_row10_col4, #T_85f55_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_85f55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85f55_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_85f55_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_85f55_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_85f55_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_85f55_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_85f55_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85f55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85f55_row0_col0" class="data row0 col0" >0.0920</td>
#       <td id="T_85f55_row0_col1" class="data row0 col1" >0.0134</td>
#       <td id="T_85f55_row0_col2" class="data row0 col2" >0.1156</td>
#       <td id="T_85f55_row0_col3" class="data row0 col3" >-0.6519</td>
#       <td id="T_85f55_row0_col4" class="data row0 col4" >0.0860</td>
#       <td id="T_85f55_row0_col5" class="data row0 col5" >0.3297</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85f55_row1_col0" class="data row1 col0" >0.1236</td>
#       <td id="T_85f55_row1_col1" class="data row1 col1" >0.0232</td>
#       <td id="T_85f55_row1_col2" class="data row1 col2" >0.1524</td>
#       <td id="T_85f55_row1_col3" class="data row1 col3" >0.0452</td>
#       <td id="T_85f55_row1_col4" class="data row1 col4" >0.1146</td>
#       <td id="T_85f55_row1_col5" class="data row1 col5" >0.5777</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85f55_row2_col0" class="data row2 col0" >0.1021</td>
#       <td id="T_85f55_row2_col1" class="data row2 col1" >0.0203</td>
#       <td id="T_85f55_row2_col2" class="data row2 col2" >0.1425</td>
#       <td id="T_85f55_row2_col3" class="data row2 col3" >-0.2425</td>
#       <td id="T_85f55_row2_col4" class="data row2 col4" >0.1046</td>
#       <td id="T_85f55_row2_col5" class="data row2 col5" >0.3824</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85f55_row3_col0" class="data row3 col0" >0.1224</td>
#       <td id="T_85f55_row3_col1" class="data row3 col1" >0.0275</td>
#       <td id="T_85f55_row3_col2" class="data row3 col2" >0.1657</td>
#       <td id="T_85f55_row3_col3" class="data row3 col3" >-0.2844</td>
#       <td id="T_85f55_row3_col4" class="data row3 col4" >0.1244</td>
#       <td id="T_85f55_row3_col5" class="data row3 col5" >0.5776</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85f55_row4_col0" class="data row4 col0" >0.0957</td>
#       <td id="T_85f55_row4_col1" class="data row4 col1" >0.0160</td>
#       <td id="T_85f55_row4_col2" class="data row4 col2" >0.1266</td>
#       <td id="T_85f55_row4_col3" class="data row4 col3" >-0.1094</td>
#       <td id="T_85f55_row4_col4" class="data row4 col4" >0.0922</td>
#       <td id="T_85f55_row4_col5" class="data row4 col5" >0.2921</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_85f55_row5_col0" class="data row5 col0" >0.1160</td>
#       <td id="T_85f55_row5_col1" class="data row5 col1" >0.0186</td>
#       <td id="T_85f55_row5_col2" class="data row5 col2" >0.1363</td>
#       <td id="T_85f55_row5_col3" class="data row5 col3" >-0.1448</td>
#       <td id="T_85f55_row5_col4" class="data row5 col4" >0.0997</td>
#       <td id="T_85f55_row5_col5" class="data row5 col5" >0.3841</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_85f55_row6_col0" class="data row6 col0" >0.0844</td>
#       <td id="T_85f55_row6_col1" class="data row6 col1" >0.0119</td>
#       <td id="T_85f55_row6_col2" class="data row6 col2" >0.1090</td>
#       <td id="T_85f55_row6_col3" class="data row6 col3" >0.4437</td>
#       <td id="T_85f55_row6_col4" class="data row6 col4" >0.0800</td>
#       <td id="T_85f55_row6_col5" class="data row6 col5" >0.3213</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_85f55_row7_col0" class="data row7 col0" >0.0816</td>
#       <td id="T_85f55_row7_col1" class="data row7 col1" >0.0126</td>
#       <td id="T_85f55_row7_col2" class="data row7 col2" >0.1122</td>
#       <td id="T_85f55_row7_col3" class="data row7 col3" >0.1323</td>
#       <td id="T_85f55_row7_col4" class="data row7 col4" >0.0843</td>
#       <td id="T_85f55_row7_col5" class="data row7 col5" >0.3038</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_85f55_row8_col0" class="data row8 col0" >0.0870</td>
#       <td id="T_85f55_row8_col1" class="data row8 col1" >0.0131</td>
#       <td id="T_85f55_row8_col2" class="data row8 col2" >0.1146</td>
#       <td id="T_85f55_row8_col3" class="data row8 col3" >0.3306</td>
#       <td id="T_85f55_row8_col4" class="data row8 col4" >0.0824</td>
#       <td id="T_85f55_row8_col5" class="data row8 col5" >0.3004</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_85f55_row9_col0" class="data row9 col0" >0.1047</td>
#       <td id="T_85f55_row9_col1" class="data row9 col1" >0.0182</td>
#       <td id="T_85f55_row9_col2" class="data row9 col2" >0.1350</td>
#       <td id="T_85f55_row9_col3" class="data row9 col3" >-0.2529</td>
#       <td id="T_85f55_row9_col4" class="data row9 col4" >0.0987</td>
#       <td id="T_85f55_row9_col5" class="data row9 col5" >0.3316</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_85f55_row10_col0" class="data row10 col0" >0.1009</td>
#       <td id="T_85f55_row10_col1" class="data row10 col1" >0.0175</td>
#       <td id="T_85f55_row10_col2" class="data row10 col2" >0.1310</td>
#       <td id="T_85f55_row10_col3" class="data row10 col3" >-0.0734</td>
#       <td id="T_85f55_row10_col4" class="data row10 col4" >0.0967</td>
#       <td id="T_85f55_row10_col5" class="data row10 col5" >0.3801</td>
#     </tr>
#     <tr>
#       <th id="T_85f55_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_85f55_row11_col0" class="data row11 col0" >0.0147</td>
#       <td id="T_85f55_row11_col1" class="data row11 col1" >0.0049</td>
#       <td id="T_85f55_row11_col2" class="data row11 col2" >0.0179</td>
#       <td id="T_85f55_row11_col3" class="data row11 col3" >0.3055</td>
#       <td id="T_85f55_row11_col4" class="data row11 col4" >0.0139</td>
#       <td id="T_85f55_row11_col5" class="data row11 col5" >0.1031</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Given the sheer number of variables, will only plot the first 10
# 'feature_all' will plot everything
plot_model(gbr, plot = 'feature')

# %% [markdown]
# ### KNN Model - note that it does not support feature importance

# %%
knn = create_model('knn')
knn_results = pull()
# Out:
# <style type="text/css">
# #T_615b2_row10_col0, #T_615b2_row10_col1, #T_615b2_row10_col2, #T_615b2_row10_col3, #T_615b2_row10_col4, #T_615b2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_615b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_615b2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_615b2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_615b2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_615b2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_615b2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_615b2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_615b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_615b2_row0_col0" class="data row0 col0" >0.0757</td>
#       <td id="T_615b2_row0_col1" class="data row0 col1" >0.0093</td>
#       <td id="T_615b2_row0_col2" class="data row0 col2" >0.0962</td>
#       <td id="T_615b2_row0_col3" class="data row0 col3" >-0.1442</td>
#       <td id="T_615b2_row0_col4" class="data row0 col4" >0.0726</td>
#       <td id="T_615b2_row0_col5" class="data row0 col5" >0.2688</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_615b2_row1_col0" class="data row1 col0" >0.1125</td>
#       <td id="T_615b2_row1_col1" class="data row1 col1" >0.0184</td>
#       <td id="T_615b2_row1_col2" class="data row1 col2" >0.1357</td>
#       <td id="T_615b2_row1_col3" class="data row1 col3" >0.2439</td>
#       <td id="T_615b2_row1_col4" class="data row1 col4" >0.1018</td>
#       <td id="T_615b2_row1_col5" class="data row1 col5" >0.4880</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_615b2_row2_col0" class="data row2 col0" >0.0892</td>
#       <td id="T_615b2_row2_col1" class="data row2 col1" >0.0154</td>
#       <td id="T_615b2_row2_col2" class="data row2 col2" >0.1242</td>
#       <td id="T_615b2_row2_col3" class="data row2 col3" >0.0560</td>
#       <td id="T_615b2_row2_col4" class="data row2 col4" >0.0896</td>
#       <td id="T_615b2_row2_col5" class="data row2 col5" >0.3047</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_615b2_row3_col0" class="data row3 col0" >0.1129</td>
#       <td id="T_615b2_row3_col1" class="data row3 col1" >0.0202</td>
#       <td id="T_615b2_row3_col2" class="data row3 col2" >0.1422</td>
#       <td id="T_615b2_row3_col3" class="data row3 col3" >0.0541</td>
#       <td id="T_615b2_row3_col4" class="data row3 col4" >0.1052</td>
#       <td id="T_615b2_row3_col5" class="data row3 col5" >0.4943</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_615b2_row4_col0" class="data row4 col0" >0.1031</td>
#       <td id="T_615b2_row4_col1" class="data row4 col1" >0.0179</td>
#       <td id="T_615b2_row4_col2" class="data row4 col2" >0.1338</td>
#       <td id="T_615b2_row4_col3" class="data row4 col3" >-0.2392</td>
#       <td id="T_615b2_row4_col4" class="data row4 col4" >0.0966</td>
#       <td id="T_615b2_row4_col5" class="data row4 col5" >0.3091</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_615b2_row5_col0" class="data row5 col0" >0.1102</td>
#       <td id="T_615b2_row5_col1" class="data row5 col1" >0.0181</td>
#       <td id="T_615b2_row5_col2" class="data row5 col2" >0.1345</td>
#       <td id="T_615b2_row5_col3" class="data row5 col3" >-0.1132</td>
#       <td id="T_615b2_row5_col4" class="data row5 col4" >0.0987</td>
#       <td id="T_615b2_row5_col5" class="data row5 col5" >0.3670</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_615b2_row6_col0" class="data row6 col0" >0.1054</td>
#       <td id="T_615b2_row6_col1" class="data row6 col1" >0.0212</td>
#       <td id="T_615b2_row6_col2" class="data row6 col2" >0.1455</td>
#       <td id="T_615b2_row6_col3" class="data row6 col3" >0.0091</td>
#       <td id="T_615b2_row6_col4" class="data row6 col4" >0.1057</td>
#       <td id="T_615b2_row6_col5" class="data row6 col5" >0.3832</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_615b2_row7_col0" class="data row7 col0" >0.0860</td>
#       <td id="T_615b2_row7_col1" class="data row7 col1" >0.0109</td>
#       <td id="T_615b2_row7_col2" class="data row7 col2" >0.1042</td>
#       <td id="T_615b2_row7_col3" class="data row7 col3" >0.2513</td>
#       <td id="T_615b2_row7_col4" class="data row7 col4" >0.0779</td>
#       <td id="T_615b2_row7_col5" class="data row7 col5" >0.2989</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_615b2_row8_col0" class="data row8 col0" >0.0937</td>
#       <td id="T_615b2_row8_col1" class="data row8 col1" >0.0185</td>
#       <td id="T_615b2_row8_col2" class="data row8 col2" >0.1359</td>
#       <td id="T_615b2_row8_col3" class="data row8 col3" >0.0599</td>
#       <td id="T_615b2_row8_col4" class="data row8 col4" >0.0971</td>
#       <td id="T_615b2_row8_col5" class="data row8 col5" >0.3361</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_615b2_row9_col0" class="data row9 col0" >0.0881</td>
#       <td id="T_615b2_row9_col1" class="data row9 col1" >0.0147</td>
#       <td id="T_615b2_row9_col2" class="data row9 col2" >0.1212</td>
#       <td id="T_615b2_row9_col3" class="data row9 col3" >-0.0112</td>
#       <td id="T_615b2_row9_col4" class="data row9 col4" >0.0890</td>
#       <td id="T_615b2_row9_col5" class="data row9 col5" >0.2862</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_615b2_row10_col0" class="data row10 col0" >0.0977</td>
#       <td id="T_615b2_row10_col1" class="data row10 col1" >0.0164</td>
#       <td id="T_615b2_row10_col2" class="data row10 col2" >0.1273</td>
#       <td id="T_615b2_row10_col3" class="data row10 col3" >0.0166</td>
#       <td id="T_615b2_row10_col4" class="data row10 col4" >0.0934</td>
#       <td id="T_615b2_row10_col5" class="data row10 col5" >0.3536</td>
#     </tr>
#     <tr>
#       <th id="T_615b2_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_615b2_row11_col0" class="data row11 col0" >0.0122</td>
#       <td id="T_615b2_row11_col1" class="data row11 col1" >0.0037</td>
#       <td id="T_615b2_row11_col2" class="data row11 col2" >0.0153</td>
#       <td id="T_615b2_row11_col3" class="data row11 col3" >0.1485</td>
#       <td id="T_615b2_row11_col4" class="data row11 col4" >0.0106</td>
#       <td id="T_615b2_row11_col5" class="data row11 col5" >0.0764</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3a. Testing for Optimisation - Not necessary to run
# -----------------------------------------------------------------------------------

# %% [markdown]
# One of the important parameters in the hyperparameters is the number of iterations over which the K fold cross validation is done.
#
# 2 checks are done for this. The first scenario is over the range(0, 1000, 50). The optimisation ran overnight and showed that the ML algorithm did not see much improvement past 50.

# %%
# elapsed = []
# MAE_mean_iter = []
# MSE_mean_iter = []
# RMSE_mean_iter = []

# # The output from the (0, 1000, 50) is saved; there is no need to run this again. 
# # Line has been modified just so the code can run.
# for i in range(0, 51, 50):
#     start = time.time()
#     if i == 0:
#         i += 1    
#     tuned_cb = tune_model(cb, optimize = 'MSE', n_iter = i)
#     #print(tuned_cb)
#     MAE_mean_iter.append(pull()['MAE']['Mean'])
#     MSE_mean_iter.append(pull()['MSE']['Mean'])
#     RMSE_mean_iter.append(pull()['RMSE']['Mean'])
#     elapsed.append((time.time() - start))

# MAE_Mean = pd.DataFrame(MAE_mean_iter, index = elapsed, columns=['MAE Mean Error'])
# MAE_Mean.index.name = 'Elapsed Time'

# MSE_Mean = pd.DataFrame(MSE_mean_iter, index = elapsed, columns=['MSE Mean Error']) 
# MSE_Mean.index.name = 'Elapsed Time'

# RMSE_Mean = pd.DataFrame(RMSE_mean_iter, index = elapsed, columns=['RMSE Mean Error'])
# RMSE_Mean.index.name = 'Elapsed Time'

# res_50_iter = pd.concat([MAE_Mean, MSE_Mean, RMSE_Mean], axis=1)

# print(res_50_iter)

# %%
# b = sns.lineplot(data=res_50_iter)
# b.axes.set_title("Error as function of Elapsed Time",fontsize=20)
# b.set_xlabel("Elapsed Time",fontsize=20)
# b.set_ylabel("Error",fontsize=20)
# #b.set_yscale('log')
# b.tick_params(labelsize=18)

# %%
#res.to_csv('Run_Catboost_1000_Itr.csv')

# %%
# elapsed = []
# MAE_mean_iter = []
# MSE_mean_iter = []
# RMSE_mean_iter = []

# # This was run at (1, 51, 1) to get increments of 1
# # Right now, this is changed to (1, 51, 50) to allow the code to run efficiently
# for i in range(1, 51, 50):
#     start = time.time()
#     tuned_cb = tune_model(cb, optimize = 'MSE', n_iter = i)
#     MAE_mean_iter.append(pull()['MAE']['Mean'])
#     MSE_mean_iter.append(pull()['MSE']['Mean'])
#     RMSE_mean_iter.append(pull()['RMSE']['Mean'])
#     elapsed.append((time.time() - start))

# MAE_Mean = pd.DataFrame(MAE_mean_iter, index = elapsed, columns=['MAE Mean Error'])
# MAE_Mean.index.name = 'Elapsed Time'

# MSE_Mean = pd.DataFrame(MSE_mean_iter, index = elapsed, columns=['MSE Mean Error']) 
# MSE_Mean.index.name = 'Elapsed Time'

# RMSE_Mean = pd.DataFrame(RMSE_mean_iter, index = elapsed, columns=['RMSE Mean Error'])
# RMSE_Mean.index.name = 'Elapsed Time'

# res_1_iter = pd.concat([MAE_Mean, MSE_Mean, RMSE_Mean], axis=1)

# print(res_1_iter)

# res_1_iter.to_csv('Run_Catboost_50_Itr.csv')

# %%
# b = sns.lineplot(data=res_1_iter)
# b.axes.set_title("Error as function of Elapsed Time",fontsize=20)
# b.set_xlabel("Elapsed Time",fontsize=20)
# b.set_ylabel("Error",fontsize=20)
# #b.set_yscale('log')
# b.tick_params(labelsize=18)

# %%
# tuned_cb3 = tune_model(cb, optimize = 'RMSE', n_iter = 10)

# %%
# plot_model(tuned_cb3, plot = 'parameter')

# %% [markdown]
# ##### Gradient Boosting Regression

# %%
# gbr = create_model('gbr')
# print(gbr)

# %%
# tuned_gbr = tune_model(gbr, search_library = "tune-sklearn", search_algorithm="hyperopt", optimize="RMSE", n_iter=50)
# print(tuned_gbr)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3. Optimisation

# %% [markdown]
# ### a. Tune the Model

# %% [markdown]
# The earlier experiments allow one to determine which model performs efficiently, and the tuning needed to arrive at the answer. Here, we will create the 3 specific models , which we will than blend, and than finally produce a "tuned" blended model based on earlier optimised parameters

# %% [markdown]
# from pycaret.distributions import UniformDistribution, CategoricalDistribution
#
# catboost_param_dists = {
#     'iterations': CategoricalDistribution([500,100,300]),
#     'colsample_bylevel': UniformDistribution(0.5, 1.0),
#     'random_strength': CategoricalDistribution([0,0.1,0.2,1,10]),
#     'max_depth' : CategoricalDistribution([5,6,7,8,9])
# }

# %%
tuned_models = []

# %%
rf = create_model('rf', fold = 10)
rf = tune_model(rf, 
                optimize = 'RMSE', 
                n_iter = 50, 
                choose_better = True, 
                 #search_library = "tune-sklearn", 
                 #search_algorithm="Hyperopt",
                 #search_algorithm="Optuna",
                 #search_algorithm="bayesian",
                )
tuned_models.append(rf)
# Out:
# <style type="text/css">
# #T_0346b_row10_col0, #T_0346b_row10_col1, #T_0346b_row10_col2, #T_0346b_row10_col3, #T_0346b_row10_col4, #T_0346b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0346b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0346b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0346b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0346b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0346b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0346b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0346b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0346b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0346b_row0_col0" class="data row0 col0" >0.0704</td>
#       <td id="T_0346b_row0_col1" class="data row0 col1" >0.0093</td>
#       <td id="T_0346b_row0_col2" class="data row0 col2" >0.0963</td>
#       <td id="T_0346b_row0_col3" class="data row0 col3" >-0.1453</td>
#       <td id="T_0346b_row0_col4" class="data row0 col4" >0.0726</td>
#       <td id="T_0346b_row0_col5" class="data row0 col5" >0.2584</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0346b_row1_col0" class="data row1 col0" >0.1071</td>
#       <td id="T_0346b_row1_col1" class="data row1 col1" >0.0156</td>
#       <td id="T_0346b_row1_col2" class="data row1 col2" >0.1249</td>
#       <td id="T_0346b_row1_col3" class="data row1 col3" >0.3585</td>
#       <td id="T_0346b_row1_col4" class="data row1 col4" >0.0949</td>
#       <td id="T_0346b_row1_col5" class="data row1 col5" >0.4789</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0346b_row2_col0" class="data row2 col0" >0.0880</td>
#       <td id="T_0346b_row2_col1" class="data row2 col1" >0.0146</td>
#       <td id="T_0346b_row2_col2" class="data row2 col2" >0.1208</td>
#       <td id="T_0346b_row2_col3" class="data row2 col3" >0.1078</td>
#       <td id="T_0346b_row2_col4" class="data row2 col4" >0.0876</td>
#       <td id="T_0346b_row2_col5" class="data row2 col5" >0.3227</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0346b_row3_col0" class="data row3 col0" >0.1141</td>
#       <td id="T_0346b_row3_col1" class="data row3 col1" >0.0238</td>
#       <td id="T_0346b_row3_col2" class="data row3 col2" >0.1543</td>
#       <td id="T_0346b_row3_col3" class="data row3 col3" >-0.1131</td>
#       <td id="T_0346b_row3_col4" class="data row3 col4" >0.1157</td>
#       <td id="T_0346b_row3_col5" class="data row3 col5" >0.5586</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0346b_row4_col0" class="data row4 col0" >0.0860</td>
#       <td id="T_0346b_row4_col1" class="data row4 col1" >0.0137</td>
#       <td id="T_0346b_row4_col2" class="data row4 col2" >0.1171</td>
#       <td id="T_0346b_row4_col3" class="data row4 col3" >0.0515</td>
#       <td id="T_0346b_row4_col4" class="data row4 col4" >0.0846</td>
#       <td id="T_0346b_row4_col5" class="data row4 col5" >0.2699</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0346b_row5_col0" class="data row5 col0" >0.1055</td>
#       <td id="T_0346b_row5_col1" class="data row5 col1" >0.0170</td>
#       <td id="T_0346b_row5_col2" class="data row5 col2" >0.1302</td>
#       <td id="T_0346b_row5_col3" class="data row5 col3" >-0.0445</td>
#       <td id="T_0346b_row5_col4" class="data row5 col4" >0.0953</td>
#       <td id="T_0346b_row5_col5" class="data row5 col5" >0.3515</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0346b_row6_col0" class="data row6 col0" >0.0965</td>
#       <td id="T_0346b_row6_col1" class="data row6 col1" >0.0165</td>
#       <td id="T_0346b_row6_col2" class="data row6 col2" >0.1284</td>
#       <td id="T_0346b_row6_col3" class="data row6 col3" >0.2282</td>
#       <td id="T_0346b_row6_col4" class="data row6 col4" >0.0938</td>
#       <td id="T_0346b_row6_col5" class="data row6 col5" >0.3715</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0346b_row7_col0" class="data row7 col0" >0.0735</td>
#       <td id="T_0346b_row7_col1" class="data row7 col1" >0.0094</td>
#       <td id="T_0346b_row7_col2" class="data row7 col2" >0.0968</td>
#       <td id="T_0346b_row7_col3" class="data row7 col3" >0.3545</td>
#       <td id="T_0346b_row7_col4" class="data row7 col4" >0.0724</td>
#       <td id="T_0346b_row7_col5" class="data row7 col5" >0.2665</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0346b_row8_col0" class="data row8 col0" >0.0885</td>
#       <td id="T_0346b_row8_col1" class="data row8 col1" >0.0157</td>
#       <td id="T_0346b_row8_col2" class="data row8 col2" >0.1255</td>
#       <td id="T_0346b_row8_col3" class="data row8 col3" >0.1982</td>
#       <td id="T_0346b_row8_col4" class="data row8 col4" >0.0907</td>
#       <td id="T_0346b_row8_col5" class="data row8 col5" >0.3531</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0346b_row9_col0" class="data row9 col0" >0.0895</td>
#       <td id="T_0346b_row9_col1" class="data row9 col1" >0.0149</td>
#       <td id="T_0346b_row9_col2" class="data row9 col2" >0.1219</td>
#       <td id="T_0346b_row9_col3" class="data row9 col3" >-0.0225</td>
#       <td id="T_0346b_row9_col4" class="data row9 col4" >0.0891</td>
#       <td id="T_0346b_row9_col5" class="data row9 col5" >0.2887</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0346b_row10_col0" class="data row10 col0" >0.0919</td>
#       <td id="T_0346b_row10_col1" class="data row10 col1" >0.0150</td>
#       <td id="T_0346b_row10_col2" class="data row10 col2" >0.1216</td>
#       <td id="T_0346b_row10_col3" class="data row10 col3" >0.0973</td>
#       <td id="T_0346b_row10_col4" class="data row10 col4" >0.0897</td>
#       <td id="T_0346b_row10_col5" class="data row10 col5" >0.3520</td>
#     </tr>
#     <tr>
#       <th id="T_0346b_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_0346b_row11_col0" class="data row11 col0" >0.0134</td>
#       <td id="T_0346b_row11_col1" class="data row11 col1" >0.0039</td>
#       <td id="T_0346b_row11_col2" class="data row11 col2" >0.0158</td>
#       <td id="T_0346b_row11_col3" class="data row11 col3" >0.1736</td>
#       <td id="T_0346b_row11_col4" class="data row11 col4" >0.0117</td>
#       <td id="T_0346b_row11_col5" class="data row11 col5" >0.0932</td>
#     </tr>
#   </tbody>
# </table>

# %%
cb = create_model('catboost', fold = 10)
cb = tune_model(cb, 
                optimize = 'RMSE', 
                n_iter = 50, 
                choose_better = True,
                #search_library = "optuna", 
                #search_library = "tune-sklearn", 
                #search_algorithm="bayesian",
                #search_algorithm="hyperopt",
                #custom_grid = catboost_param_dists ,
                #early_stopping = "asha",
                #early_stopping_max_iters = 10,
                #return_tuner = False ,   
               )

tuned_models.append(cb)
# Out:
# <style type="text/css">
# #T_73d35_row10_col0, #T_73d35_row10_col1, #T_73d35_row10_col2, #T_73d35_row10_col3, #T_73d35_row10_col4, #T_73d35_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_73d35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73d35_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_73d35_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_73d35_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_73d35_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_73d35_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_73d35_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73d35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73d35_row0_col0" class="data row0 col0" >0.0761</td>
#       <td id="T_73d35_row0_col1" class="data row0 col1" >0.0093</td>
#       <td id="T_73d35_row0_col2" class="data row0 col2" >0.0965</td>
#       <td id="T_73d35_row0_col3" class="data row0 col3" >-0.1512</td>
#       <td id="T_73d35_row0_col4" class="data row0 col4" >0.0728</td>
#       <td id="T_73d35_row0_col5" class="data row0 col5" >0.2774</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73d35_row1_col0" class="data row1 col0" >0.1196</td>
#       <td id="T_73d35_row1_col1" class="data row1 col1" >0.0194</td>
#       <td id="T_73d35_row1_col2" class="data row1 col2" >0.1392</td>
#       <td id="T_73d35_row1_col3" class="data row1 col3" >0.2033</td>
#       <td id="T_73d35_row1_col4" class="data row1 col4" >0.1050</td>
#       <td id="T_73d35_row1_col5" class="data row1 col5" >0.5354</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73d35_row2_col0" class="data row2 col0" >0.0914</td>
#       <td id="T_73d35_row2_col1" class="data row2 col1" >0.0148</td>
#       <td id="T_73d35_row2_col2" class="data row2 col2" >0.1217</td>
#       <td id="T_73d35_row2_col3" class="data row2 col3" >0.0937</td>
#       <td id="T_73d35_row2_col4" class="data row2 col4" >0.0884</td>
#       <td id="T_73d35_row2_col5" class="data row2 col5" >0.3356</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73d35_row3_col0" class="data row3 col0" >0.1215</td>
#       <td id="T_73d35_row3_col1" class="data row3 col1" >0.0234</td>
#       <td id="T_73d35_row3_col2" class="data row3 col2" >0.1529</td>
#       <td id="T_73d35_row3_col3" class="data row3 col3" >-0.0935</td>
#       <td id="T_73d35_row3_col4" class="data row3 col4" >0.1145</td>
#       <td id="T_73d35_row3_col5" class="data row3 col5" >0.5907</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73d35_row4_col0" class="data row4 col0" >0.0866</td>
#       <td id="T_73d35_row4_col1" class="data row4 col1" >0.0134</td>
#       <td id="T_73d35_row4_col2" class="data row4 col2" >0.1159</td>
#       <td id="T_73d35_row4_col3" class="data row4 col3" >0.0696</td>
#       <td id="T_73d35_row4_col4" class="data row4 col4" >0.0840</td>
#       <td id="T_73d35_row4_col5" class="data row4 col5" >0.2805</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_73d35_row5_col0" class="data row5 col0" >0.1078</td>
#       <td id="T_73d35_row5_col1" class="data row5 col1" >0.0166</td>
#       <td id="T_73d35_row5_col2" class="data row5 col2" >0.1289</td>
#       <td id="T_73d35_row5_col3" class="data row5 col3" >-0.0224</td>
#       <td id="T_73d35_row5_col4" class="data row5 col4" >0.0945</td>
#       <td id="T_73d35_row5_col5" class="data row5 col5" >0.3671</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_73d35_row6_col0" class="data row6 col0" >0.0975</td>
#       <td id="T_73d35_row6_col1" class="data row6 col1" >0.0170</td>
#       <td id="T_73d35_row6_col2" class="data row6 col2" >0.1305</td>
#       <td id="T_73d35_row6_col3" class="data row6 col3" >0.2028</td>
#       <td id="T_73d35_row6_col4" class="data row6 col4" >0.0950</td>
#       <td id="T_73d35_row6_col5" class="data row6 col5" >0.3732</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_73d35_row7_col0" class="data row7 col0" >0.0862</td>
#       <td id="T_73d35_row7_col1" class="data row7 col1" >0.0107</td>
#       <td id="T_73d35_row7_col2" class="data row7 col2" >0.1035</td>
#       <td id="T_73d35_row7_col3" class="data row7 col3" >0.2612</td>
#       <td id="T_73d35_row7_col4" class="data row7 col4" >0.0776</td>
#       <td id="T_73d35_row7_col5" class="data row7 col5" >0.3196</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_73d35_row8_col0" class="data row8 col0" >0.0931</td>
#       <td id="T_73d35_row8_col1" class="data row8 col1" >0.0162</td>
#       <td id="T_73d35_row8_col2" class="data row8 col2" >0.1274</td>
#       <td id="T_73d35_row8_col3" class="data row8 col3" >0.1731</td>
#       <td id="T_73d35_row8_col4" class="data row8 col4" >0.0922</td>
#       <td id="T_73d35_row8_col5" class="data row8 col5" >0.3832</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_73d35_row9_col0" class="data row9 col0" >0.0896</td>
#       <td id="T_73d35_row9_col1" class="data row9 col1" >0.0140</td>
#       <td id="T_73d35_row9_col2" class="data row9 col2" >0.1183</td>
#       <td id="T_73d35_row9_col3" class="data row9 col3" >0.0381</td>
#       <td id="T_73d35_row9_col4" class="data row9 col4" >0.0864</td>
#       <td id="T_73d35_row9_col5" class="data row9 col5" >0.2930</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_73d35_row10_col0" class="data row10 col0" >0.0969</td>
#       <td id="T_73d35_row10_col1" class="data row10 col1" >0.0155</td>
#       <td id="T_73d35_row10_col2" class="data row10 col2" >0.1235</td>
#       <td id="T_73d35_row10_col3" class="data row10 col3" >0.0775</td>
#       <td id="T_73d35_row10_col4" class="data row10 col4" >0.0910</td>
#       <td id="T_73d35_row10_col5" class="data row10 col5" >0.3756</td>
#     </tr>
#     <tr>
#       <th id="T_73d35_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_73d35_row11_col0" class="data row11 col0" >0.0141</td>
#       <td id="T_73d35_row11_col1" class="data row11 col1" >0.0039</td>
#       <td id="T_73d35_row11_col2" class="data row11 col2" >0.0156</td>
#       <td id="T_73d35_row11_col3" class="data row11 col3" >0.1296</td>
#       <td id="T_73d35_row11_col4" class="data row11 col4" >0.0117</td>
#       <td id="T_73d35_row11_col5" class="data row11 col5" >0.1011</td>
#     </tr>
#   </tbody>
# </table>

# %%
knn = create_model('knn', fold = 10)
knn = tune_model(knn, 
                 optimize = 'RMSE', 
                 n_iter = 50, 
                 choose_better = True, 
                 #search_library = "tune-sklearn", 
                 #search_algorithm="Hyperopt",
                 #search_algorithm="Optuna",
                 #search_algorithm="bayesian",
                )
tuned_models.append(knn)
# Out:
# <style type="text/css">
# #T_203c3_row10_col0, #T_203c3_row10_col1, #T_203c3_row10_col2, #T_203c3_row10_col3, #T_203c3_row10_col4, #T_203c3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_203c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_203c3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_203c3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_203c3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_203c3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_203c3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_203c3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_203c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_203c3_row0_col0" class="data row0 col0" >0.0719</td>
#       <td id="T_203c3_row0_col1" class="data row0 col1" >0.0080</td>
#       <td id="T_203c3_row0_col2" class="data row0 col2" >0.0896</td>
#       <td id="T_203c3_row0_col3" class="data row0 col3" >0.0074</td>
#       <td id="T_203c3_row0_col4" class="data row0 col4" >0.0679</td>
#       <td id="T_203c3_row0_col5" class="data row0 col5" >0.2604</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_203c3_row1_col0" class="data row1 col0" >0.1189</td>
#       <td id="T_203c3_row1_col1" class="data row1 col1" >0.0189</td>
#       <td id="T_203c3_row1_col2" class="data row1 col2" >0.1376</td>
#       <td id="T_203c3_row1_col3" class="data row1 col3" >0.2225</td>
#       <td id="T_203c3_row1_col4" class="data row1 col4" >0.1036</td>
#       <td id="T_203c3_row1_col5" class="data row1 col5" >0.5201</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_203c3_row2_col0" class="data row2 col0" >0.0855</td>
#       <td id="T_203c3_row2_col1" class="data row2 col1" >0.0132</td>
#       <td id="T_203c3_row2_col2" class="data row2 col2" >0.1150</td>
#       <td id="T_203c3_row2_col3" class="data row2 col3" >0.1906</td>
#       <td id="T_203c3_row2_col4" class="data row2 col4" >0.0833</td>
#       <td id="T_203c3_row2_col5" class="data row2 col5" >0.3082</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_203c3_row3_col0" class="data row3 col0" >0.1088</td>
#       <td id="T_203c3_row3_col1" class="data row3 col1" >0.0197</td>
#       <td id="T_203c3_row3_col2" class="data row3 col2" >0.1402</td>
#       <td id="T_203c3_row3_col3" class="data row3 col3" >0.0811</td>
#       <td id="T_203c3_row3_col4" class="data row3 col4" >0.1048</td>
#       <td id="T_203c3_row3_col5" class="data row3 col5" >0.5338</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_203c3_row4_col0" class="data row4 col0" >0.0860</td>
#       <td id="T_203c3_row4_col1" class="data row4 col1" >0.0129</td>
#       <td id="T_203c3_row4_col2" class="data row4 col2" >0.1138</td>
#       <td id="T_203c3_row4_col3" class="data row4 col3" >0.1038</td>
#       <td id="T_203c3_row4_col4" class="data row4 col4" >0.0820</td>
#       <td id="T_203c3_row4_col5" class="data row4 col5" >0.2709</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_203c3_row5_col0" class="data row5 col0" >0.1119</td>
#       <td id="T_203c3_row5_col1" class="data row5 col1" >0.0178</td>
#       <td id="T_203c3_row5_col2" class="data row5 col2" >0.1332</td>
#       <td id="T_203c3_row5_col3" class="data row5 col3" >-0.0932</td>
#       <td id="T_203c3_row5_col4" class="data row5 col4" >0.0977</td>
#       <td id="T_203c3_row5_col5" class="data row5 col5" >0.3768</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_203c3_row6_col0" class="data row6 col0" >0.1020</td>
#       <td id="T_203c3_row6_col1" class="data row6 col1" >0.0183</td>
#       <td id="T_203c3_row6_col2" class="data row6 col2" >0.1353</td>
#       <td id="T_203c3_row6_col3" class="data row6 col3" >0.1432</td>
#       <td id="T_203c3_row6_col4" class="data row6 col4" >0.0979</td>
#       <td id="T_203c3_row6_col5" class="data row6 col5" >0.3796</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_203c3_row7_col0" class="data row7 col0" >0.0850</td>
#       <td id="T_203c3_row7_col1" class="data row7 col1" >0.0097</td>
#       <td id="T_203c3_row7_col2" class="data row7 col2" >0.0986</td>
#       <td id="T_203c3_row7_col3" class="data row7 col3" >0.3300</td>
#       <td id="T_203c3_row7_col4" class="data row7 col4" >0.0738</td>
#       <td id="T_203c3_row7_col5" class="data row7 col5" >0.3079</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_203c3_row8_col0" class="data row8 col0" >0.0892</td>
#       <td id="T_203c3_row8_col1" class="data row8 col1" >0.0156</td>
#       <td id="T_203c3_row8_col2" class="data row8 col2" >0.1248</td>
#       <td id="T_203c3_row8_col3" class="data row8 col3" >0.2067</td>
#       <td id="T_203c3_row8_col4" class="data row8 col4" >0.0896</td>
#       <td id="T_203c3_row8_col5" class="data row8 col5" >0.3520</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_203c3_row9_col0" class="data row9 col0" >0.0893</td>
#       <td id="T_203c3_row9_col1" class="data row9 col1" >0.0131</td>
#       <td id="T_203c3_row9_col2" class="data row9 col2" >0.1143</td>
#       <td id="T_203c3_row9_col3" class="data row9 col3" >0.1016</td>
#       <td id="T_203c3_row9_col4" class="data row9 col4" >0.0839</td>
#       <td id="T_203c3_row9_col5" class="data row9 col5" >0.2950</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_203c3_row10_col0" class="data row10 col0" >0.0949</td>
#       <td id="T_203c3_row10_col1" class="data row10 col1" >0.0147</td>
#       <td id="T_203c3_row10_col2" class="data row10 col2" >0.1202</td>
#       <td id="T_203c3_row10_col3" class="data row10 col3" >0.1294</td>
#       <td id="T_203c3_row10_col4" class="data row10 col4" >0.0885</td>
#       <td id="T_203c3_row10_col5" class="data row10 col5" >0.3605</td>
#     </tr>
#     <tr>
#       <th id="T_203c3_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_203c3_row11_col0" class="data row11 col0" >0.0140</td>
#       <td id="T_203c3_row11_col1" class="data row11 col1" >0.0038</td>
#       <td id="T_203c3_row11_col2" class="data row11 col2" >0.0162</td>
#       <td id="T_203c3_row11_col3" class="data row11 col3" >0.1127</td>
#       <td id="T_203c3_row11_col4" class="data row11 col4" >0.0118</td>
#       <td id="T_203c3_row11_col5" class="data row11 col5" >0.0917</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### b. Ensemble the Model

# %% [markdown]
# pycaret.regression.ensemble_model(estimator, method: str = 'Bagging', fold: Optional[Union[int, Any]] = None, n_estimators: int = 10, round: int = 4, choose_better: bool = False, optimize: str = 'R2', fit_kwargs: Optional[dict] = None, groups: Optional[Union[str, Any]] = None, verbose: bool = True, return_train_score: bool = False)

# %%
prediction_model = []

# %%
tuned_bagged_rf = ensemble_model(estimator = rf, method = 'Bagging', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_bagged_rf)
# Out:
# <style type="text/css">
# #T_58e88_row10_col0, #T_58e88_row10_col1, #T_58e88_row10_col2, #T_58e88_row10_col3, #T_58e88_row10_col4, #T_58e88_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_58e88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58e88_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_58e88_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_58e88_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_58e88_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_58e88_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_58e88_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58e88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58e88_row0_col0" class="data row0 col0" >0.0716</td>
#       <td id="T_58e88_row0_col1" class="data row0 col1" >0.0084</td>
#       <td id="T_58e88_row0_col2" class="data row0 col2" >0.0919</td>
#       <td id="T_58e88_row0_col3" class="data row0 col3" >-0.0430</td>
#       <td id="T_58e88_row0_col4" class="data row0 col4" >0.0695</td>
#       <td id="T_58e88_row0_col5" class="data row0 col5" >0.2620</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_58e88_row1_col0" class="data row1 col0" >0.1159</td>
#       <td id="T_58e88_row1_col1" class="data row1 col1" >0.0178</td>
#       <td id="T_58e88_row1_col2" class="data row1 col2" >0.1334</td>
#       <td id="T_58e88_row1_col3" class="data row1 col3" >0.2686</td>
#       <td id="T_58e88_row1_col4" class="data row1 col4" >0.1003</td>
#       <td id="T_58e88_row1_col5" class="data row1 col5" >0.5009</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_58e88_row2_col0" class="data row2 col0" >0.0886</td>
#       <td id="T_58e88_row2_col1" class="data row2 col1" >0.0149</td>
#       <td id="T_58e88_row2_col2" class="data row2 col2" >0.1219</td>
#       <td id="T_58e88_row2_col3" class="data row2 col3" >0.0904</td>
#       <td id="T_58e88_row2_col4" class="data row2 col4" >0.0884</td>
#       <td id="T_58e88_row2_col5" class="data row2 col5" >0.3240</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_58e88_row3_col0" class="data row3 col0" >0.1148</td>
#       <td id="T_58e88_row3_col1" class="data row3 col1" >0.0222</td>
#       <td id="T_58e88_row3_col2" class="data row3 col2" >0.1488</td>
#       <td id="T_58e88_row3_col3" class="data row3 col3" >-0.0358</td>
#       <td id="T_58e88_row3_col4" class="data row3 col4" >0.1113</td>
#       <td id="T_58e88_row3_col5" class="data row3 col5" >0.5595</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_58e88_row4_col0" class="data row4 col0" >0.0832</td>
#       <td id="T_58e88_row4_col1" class="data row4 col1" >0.0135</td>
#       <td id="T_58e88_row4_col2" class="data row4 col2" >0.1161</td>
#       <td id="T_58e88_row4_col3" class="data row4 col3" >0.0665</td>
#       <td id="T_58e88_row4_col4" class="data row4 col4" >0.0838</td>
#       <td id="T_58e88_row4_col5" class="data row4 col5" >0.2636</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_58e88_row5_col0" class="data row5 col0" >0.1074</td>
#       <td id="T_58e88_row5_col1" class="data row5 col1" >0.0170</td>
#       <td id="T_58e88_row5_col2" class="data row5 col2" >0.1302</td>
#       <td id="T_58e88_row5_col3" class="data row5 col3" >-0.0446</td>
#       <td id="T_58e88_row5_col4" class="data row5 col4" >0.0953</td>
#       <td id="T_58e88_row5_col5" class="data row5 col5" >0.3598</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_58e88_row6_col0" class="data row6 col0" >0.0988</td>
#       <td id="T_58e88_row6_col1" class="data row6 col1" >0.0173</td>
#       <td id="T_58e88_row6_col2" class="data row6 col2" >0.1314</td>
#       <td id="T_58e88_row6_col3" class="data row6 col3" >0.1924</td>
#       <td id="T_58e88_row6_col4" class="data row6 col4" >0.0954</td>
#       <td id="T_58e88_row6_col5" class="data row6 col5" >0.3732</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_58e88_row7_col0" class="data row7 col0" >0.0785</td>
#       <td id="T_58e88_row7_col1" class="data row7 col1" >0.0096</td>
#       <td id="T_58e88_row7_col2" class="data row7 col2" >0.0979</td>
#       <td id="T_58e88_row7_col3" class="data row7 col3" >0.3394</td>
#       <td id="T_58e88_row7_col4" class="data row7 col4" >0.0733</td>
#       <td id="T_58e88_row7_col5" class="data row7 col5" >0.2872</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_58e88_row8_col0" class="data row8 col0" >0.0897</td>
#       <td id="T_58e88_row8_col1" class="data row8 col1" >0.0158</td>
#       <td id="T_58e88_row8_col2" class="data row8 col2" >0.1257</td>
#       <td id="T_58e88_row8_col3" class="data row8 col3" >0.1953</td>
#       <td id="T_58e88_row8_col4" class="data row8 col4" >0.0903</td>
#       <td id="T_58e88_row8_col5" class="data row8 col5" >0.3504</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_58e88_row9_col0" class="data row9 col0" >0.0882</td>
#       <td id="T_58e88_row9_col1" class="data row9 col1" >0.0139</td>
#       <td id="T_58e88_row9_col2" class="data row9 col2" >0.1179</td>
#       <td id="T_58e88_row9_col3" class="data row9 col3" >0.0434</td>
#       <td id="T_58e88_row9_col4" class="data row9 col4" >0.0859</td>
#       <td id="T_58e88_row9_col5" class="data row9 col5" >0.2811</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_58e88_row10_col0" class="data row10 col0" >0.0937</td>
#       <td id="T_58e88_row10_col1" class="data row10 col1" >0.0150</td>
#       <td id="T_58e88_row10_col2" class="data row10 col2" >0.1215</td>
#       <td id="T_58e88_row10_col3" class="data row10 col3" >0.1073</td>
#       <td id="T_58e88_row10_col4" class="data row10 col4" >0.0894</td>
#       <td id="T_58e88_row10_col5" class="data row10 col5" >0.3562</td>
#     </tr>
#     <tr>
#       <th id="T_58e88_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_58e88_row11_col0" class="data row11 col0" >0.0143</td>
#       <td id="T_58e88_row11_col1" class="data row11 col1" >0.0038</td>
#       <td id="T_58e88_row11_col2" class="data row11 col2" >0.0160</td>
#       <td id="T_58e88_row11_col3" class="data row11 col3" >0.1292</td>
#       <td id="T_58e88_row11_col4" class="data row11 col4" >0.0117</td>
#       <td id="T_58e88_row11_col5" class="data row11 col5" >0.0957</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_boosted_rf = ensemble_model(estimator = rf, method = 'Boosting', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_boosted_rf)
# Out:
# <style type="text/css">
# #T_daf4e_row10_col0, #T_daf4e_row10_col1, #T_daf4e_row10_col2, #T_daf4e_row10_col3, #T_daf4e_row10_col4, #T_daf4e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_daf4e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_daf4e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_daf4e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_daf4e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_daf4e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_daf4e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_daf4e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_daf4e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_daf4e_row0_col0" class="data row0 col0" >0.0779</td>
#       <td id="T_daf4e_row0_col1" class="data row0 col1" >0.0104</td>
#       <td id="T_daf4e_row0_col2" class="data row0 col2" >0.1021</td>
#       <td id="T_daf4e_row0_col3" class="data row0 col3" >-0.2891</td>
#       <td id="T_daf4e_row0_col4" class="data row0 col4" >0.0771</td>
#       <td id="T_daf4e_row0_col5" class="data row0 col5" >0.2909</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_daf4e_row1_col0" class="data row1 col0" >0.1244</td>
#       <td id="T_daf4e_row1_col1" class="data row1 col1" >0.0214</td>
#       <td id="T_daf4e_row1_col2" class="data row1 col2" >0.1462</td>
#       <td id="T_daf4e_row1_col3" class="data row1 col3" >0.1217</td>
#       <td id="T_daf4e_row1_col4" class="data row1 col4" >0.1102</td>
#       <td id="T_daf4e_row1_col5" class="data row1 col5" >0.5676</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_daf4e_row2_col0" class="data row2 col0" >0.0990</td>
#       <td id="T_daf4e_row2_col1" class="data row2 col1" >0.0168</td>
#       <td id="T_daf4e_row2_col2" class="data row2 col2" >0.1295</td>
#       <td id="T_daf4e_row2_col3" class="data row2 col3" >-0.0257</td>
#       <td id="T_daf4e_row2_col4" class="data row2 col4" >0.0943</td>
#       <td id="T_daf4e_row2_col5" class="data row2 col5" >0.3565</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_daf4e_row3_col0" class="data row3 col0" >0.1223</td>
#       <td id="T_daf4e_row3_col1" class="data row3 col1" >0.0234</td>
#       <td id="T_daf4e_row3_col2" class="data row3 col2" >0.1531</td>
#       <td id="T_daf4e_row3_col3" class="data row3 col3" >-0.0962</td>
#       <td id="T_daf4e_row3_col4" class="data row3 col4" >0.1148</td>
#       <td id="T_daf4e_row3_col5" class="data row3 col5" >0.5957</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_daf4e_row4_col0" class="data row4 col0" >0.0816</td>
#       <td id="T_daf4e_row4_col1" class="data row4 col1" >0.0127</td>
#       <td id="T_daf4e_row4_col2" class="data row4 col2" >0.1129</td>
#       <td id="T_daf4e_row4_col3" class="data row4 col3" >0.1179</td>
#       <td id="T_daf4e_row4_col4" class="data row4 col4" >0.0817</td>
#       <td id="T_daf4e_row4_col5" class="data row4 col5" >0.2673</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_daf4e_row5_col0" class="data row5 col0" >0.1102</td>
#       <td id="T_daf4e_row5_col1" class="data row5 col1" >0.0176</td>
#       <td id="T_daf4e_row5_col2" class="data row5 col2" >0.1325</td>
#       <td id="T_daf4e_row5_col3" class="data row5 col3" >-0.0809</td>
#       <td id="T_daf4e_row5_col4" class="data row5 col4" >0.0970</td>
#       <td id="T_daf4e_row5_col5" class="data row5 col5" >0.3713</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_daf4e_row6_col0" class="data row6 col0" >0.0945</td>
#       <td id="T_daf4e_row6_col1" class="data row6 col1" >0.0147</td>
#       <td id="T_daf4e_row6_col2" class="data row6 col2" >0.1211</td>
#       <td id="T_daf4e_row6_col3" class="data row6 col3" >0.3142</td>
#       <td id="T_daf4e_row6_col4" class="data row6 col4" >0.0882</td>
#       <td id="T_daf4e_row6_col5" class="data row6 col5" >0.3549</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_daf4e_row7_col0" class="data row7 col0" >0.0786</td>
#       <td id="T_daf4e_row7_col1" class="data row7 col1" >0.0098</td>
#       <td id="T_daf4e_row7_col2" class="data row7 col2" >0.0988</td>
#       <td id="T_daf4e_row7_col3" class="data row7 col3" >0.3271</td>
#       <td id="T_daf4e_row7_col4" class="data row7 col4" >0.0738</td>
#       <td id="T_daf4e_row7_col5" class="data row7 col5" >0.2895</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_daf4e_row8_col0" class="data row8 col0" >0.0946</td>
#       <td id="T_daf4e_row8_col1" class="data row8 col1" >0.0161</td>
#       <td id="T_daf4e_row8_col2" class="data row8 col2" >0.1268</td>
#       <td id="T_daf4e_row8_col3" class="data row8 col3" >0.1808</td>
#       <td id="T_daf4e_row8_col4" class="data row8 col4" >0.0920</td>
#       <td id="T_daf4e_row8_col5" class="data row8 col5" >0.3857</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_daf4e_row9_col0" class="data row9 col0" >0.0938</td>
#       <td id="T_daf4e_row9_col1" class="data row9 col1" >0.0161</td>
#       <td id="T_daf4e_row9_col2" class="data row9 col2" >0.1269</td>
#       <td id="T_daf4e_row9_col3" class="data row9 col3" >-0.1068</td>
#       <td id="T_daf4e_row9_col4" class="data row9 col4" >0.0929</td>
#       <td id="T_daf4e_row9_col5" class="data row9 col5" >0.3125</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_daf4e_row10_col0" class="data row10 col0" >0.0977</td>
#       <td id="T_daf4e_row10_col1" class="data row10 col1" >0.0159</td>
#       <td id="T_daf4e_row10_col2" class="data row10 col2" >0.1250</td>
#       <td id="T_daf4e_row10_col3" class="data row10 col3" >0.0463</td>
#       <td id="T_daf4e_row10_col4" class="data row10 col4" >0.0922</td>
#       <td id="T_daf4e_row10_col5" class="data row10 col5" >0.3792</td>
#     </tr>
#     <tr>
#       <th id="T_daf4e_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_daf4e_row11_col0" class="data row11 col0" >0.0159</td>
#       <td id="T_daf4e_row11_col1" class="data row11 col1" >0.0041</td>
#       <td id="T_daf4e_row11_col2" class="data row11 col2" >0.0164</td>
#       <td id="T_daf4e_row11_col3" class="data row11 col3" >0.1890</td>
#       <td id="T_daf4e_row11_col4" class="data row11 col4" >0.0125</td>
#       <td id="T_daf4e_row11_col5" class="data row11 col5" >0.1079</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_bagged_cb = ensemble_model(estimator = cb, method = 'Bagging', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_bagged_cb)
# Out:
# <style type="text/css">
# #T_14a2f_row10_col0, #T_14a2f_row10_col1, #T_14a2f_row10_col2, #T_14a2f_row10_col3, #T_14a2f_row10_col4, #T_14a2f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_14a2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14a2f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_14a2f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_14a2f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_14a2f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_14a2f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_14a2f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14a2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14a2f_row0_col0" class="data row0 col0" >0.0713</td>
#       <td id="T_14a2f_row0_col1" class="data row0 col1" >0.0084</td>
#       <td id="T_14a2f_row0_col2" class="data row0 col2" >0.0916</td>
#       <td id="T_14a2f_row0_col3" class="data row0 col3" >-0.0382</td>
#       <td id="T_14a2f_row0_col4" class="data row0 col4" >0.0694</td>
#       <td id="T_14a2f_row0_col5" class="data row0 col5" >0.2635</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14a2f_row1_col0" class="data row1 col0" >0.1219</td>
#       <td id="T_14a2f_row1_col1" class="data row1 col1" >0.0197</td>
#       <td id="T_14a2f_row1_col2" class="data row1 col2" >0.1404</td>
#       <td id="T_14a2f_row1_col3" class="data row1 col3" >0.1900</td>
#       <td id="T_14a2f_row1_col4" class="data row1 col4" >0.1054</td>
#       <td id="T_14a2f_row1_col5" class="data row1 col5" >0.5285</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_14a2f_row2_col0" class="data row2 col0" >0.0904</td>
#       <td id="T_14a2f_row2_col1" class="data row2 col1" >0.0149</td>
#       <td id="T_14a2f_row2_col2" class="data row2 col2" >0.1220</td>
#       <td id="T_14a2f_row2_col3" class="data row2 col3" >0.0891</td>
#       <td id="T_14a2f_row2_col4" class="data row2 col4" >0.0886</td>
#       <td id="T_14a2f_row2_col5" class="data row2 col5" >0.3342</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_14a2f_row3_col0" class="data row3 col0" >0.1177</td>
#       <td id="T_14a2f_row3_col1" class="data row3 col1" >0.0221</td>
#       <td id="T_14a2f_row3_col2" class="data row3 col2" >0.1487</td>
#       <td id="T_14a2f_row3_col3" class="data row3 col3" >-0.0335</td>
#       <td id="T_14a2f_row3_col4" class="data row3 col4" >0.1114</td>
#       <td id="T_14a2f_row3_col5" class="data row3 col5" >0.5774</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_14a2f_row4_col0" class="data row4 col0" >0.0839</td>
#       <td id="T_14a2f_row4_col1" class="data row4 col1" >0.0130</td>
#       <td id="T_14a2f_row4_col2" class="data row4 col2" >0.1140</td>
#       <td id="T_14a2f_row4_col3" class="data row4 col3" >0.0997</td>
#       <td id="T_14a2f_row4_col4" class="data row4 col4" >0.0825</td>
#       <td id="T_14a2f_row4_col5" class="data row4 col5" >0.2714</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_14a2f_row5_col0" class="data row5 col0" >0.1068</td>
#       <td id="T_14a2f_row5_col1" class="data row5 col1" >0.0164</td>
#       <td id="T_14a2f_row5_col2" class="data row5 col2" >0.1281</td>
#       <td id="T_14a2f_row5_col3" class="data row5 col3" >-0.0112</td>
#       <td id="T_14a2f_row5_col4" class="data row5 col4" >0.0940</td>
#       <td id="T_14a2f_row5_col5" class="data row5 col5" >0.3641</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_14a2f_row6_col0" class="data row6 col0" >0.0981</td>
#       <td id="T_14a2f_row6_col1" class="data row6 col1" >0.0171</td>
#       <td id="T_14a2f_row6_col2" class="data row6 col2" >0.1307</td>
#       <td id="T_14a2f_row6_col3" class="data row6 col3" >0.2002</td>
#       <td id="T_14a2f_row6_col4" class="data row6 col4" >0.0950</td>
#       <td id="T_14a2f_row6_col5" class="data row6 col5" >0.3739</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_14a2f_row7_col0" class="data row7 col0" >0.0852</td>
#       <td id="T_14a2f_row7_col1" class="data row7 col1" >0.0107</td>
#       <td id="T_14a2f_row7_col2" class="data row7 col2" >0.1033</td>
#       <td id="T_14a2f_row7_col3" class="data row7 col3" >0.2645</td>
#       <td id="T_14a2f_row7_col4" class="data row7 col4" >0.0774</td>
#       <td id="T_14a2f_row7_col5" class="data row7 col5" >0.3162</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_14a2f_row8_col0" class="data row8 col0" >0.0905</td>
#       <td id="T_14a2f_row8_col1" class="data row8 col1" >0.0163</td>
#       <td id="T_14a2f_row8_col2" class="data row8 col2" >0.1277</td>
#       <td id="T_14a2f_row8_col3" class="data row8 col3" >0.1698</td>
#       <td id="T_14a2f_row8_col4" class="data row8 col4" >0.0921</td>
#       <td id="T_14a2f_row8_col5" class="data row8 col5" >0.3691</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_14a2f_row9_col0" class="data row9 col0" >0.0898</td>
#       <td id="T_14a2f_row9_col1" class="data row9 col1" >0.0141</td>
#       <td id="T_14a2f_row9_col2" class="data row9 col2" >0.1187</td>
#       <td id="T_14a2f_row9_col3" class="data row9 col3" >0.0309</td>
#       <td id="T_14a2f_row9_col4" class="data row9 col4" >0.0867</td>
#       <td id="T_14a2f_row9_col5" class="data row9 col5" >0.2929</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_14a2f_row10_col0" class="data row10 col0" >0.0956</td>
#       <td id="T_14a2f_row10_col1" class="data row10 col1" >0.0153</td>
#       <td id="T_14a2f_row10_col2" class="data row10 col2" >0.1225</td>
#       <td id="T_14a2f_row10_col3" class="data row10 col3" >0.0961</td>
#       <td id="T_14a2f_row10_col4" class="data row10 col4" >0.0902</td>
#       <td id="T_14a2f_row10_col5" class="data row10 col5" >0.3691</td>
#     </tr>
#     <tr>
#       <th id="T_14a2f_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_14a2f_row11_col0" class="data row11 col0" >0.0150</td>
#       <td id="T_14a2f_row11_col1" class="data row11 col1" >0.0038</td>
#       <td id="T_14a2f_row11_col2" class="data row11 col2" >0.0159</td>
#       <td id="T_14a2f_row11_col3" class="data row11 col3" >0.1020</td>
#       <td id="T_14a2f_row11_col4" class="data row11 col4" >0.0118</td>
#       <td id="T_14a2f_row11_col5" class="data row11 col5" >0.0997</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_boosted_cb = ensemble_model(estimator = cb, method = 'Boosting', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_boosted_cb)
# Out:
# <style type="text/css">
# #T_f7b64_row10_col0, #T_f7b64_row10_col1, #T_f7b64_row10_col2, #T_f7b64_row10_col3, #T_f7b64_row10_col4, #T_f7b64_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f7b64">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7b64_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f7b64_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f7b64_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f7b64_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f7b64_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f7b64_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7b64_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7b64_row0_col0" class="data row0 col0" >0.0781</td>
#       <td id="T_f7b64_row0_col1" class="data row0 col1" >0.0103</td>
#       <td id="T_f7b64_row0_col2" class="data row0 col2" >0.1013</td>
#       <td id="T_f7b64_row0_col3" class="data row0 col3" >-0.2694</td>
#       <td id="T_f7b64_row0_col4" class="data row0 col4" >0.0766</td>
#       <td id="T_f7b64_row0_col5" class="data row0 col5" >0.2959</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7b64_row1_col0" class="data row1 col0" >0.1296</td>
#       <td id="T_f7b64_row1_col1" class="data row1 col1" >0.0230</td>
#       <td id="T_f7b64_row1_col2" class="data row1 col2" >0.1517</td>
#       <td id="T_f7b64_row1_col3" class="data row1 col3" >0.0550</td>
#       <td id="T_f7b64_row1_col4" class="data row1 col4" >0.1140</td>
#       <td id="T_f7b64_row1_col5" class="data row1 col5" >0.5845</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7b64_row2_col0" class="data row2 col0" >0.0960</td>
#       <td id="T_f7b64_row2_col1" class="data row2 col1" >0.0161</td>
#       <td id="T_f7b64_row2_col2" class="data row2 col2" >0.1269</td>
#       <td id="T_f7b64_row2_col3" class="data row2 col3" >0.0146</td>
#       <td id="T_f7b64_row2_col4" class="data row2 col4" >0.0924</td>
#       <td id="T_f7b64_row2_col5" class="data row2 col5" >0.3552</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7b64_row3_col0" class="data row3 col0" >0.1226</td>
#       <td id="T_f7b64_row3_col1" class="data row3 col1" >0.0235</td>
#       <td id="T_f7b64_row3_col2" class="data row3 col2" >0.1534</td>
#       <td id="T_f7b64_row3_col3" class="data row3 col3" >-0.1009</td>
#       <td id="T_f7b64_row3_col4" class="data row3 col4" >0.1148</td>
#       <td id="T_f7b64_row3_col5" class="data row3 col5" >0.5906</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7b64_row4_col0" class="data row4 col0" >0.0845</td>
#       <td id="T_f7b64_row4_col1" class="data row4 col1" >0.0126</td>
#       <td id="T_f7b64_row4_col2" class="data row4 col2" >0.1122</td>
#       <td id="T_f7b64_row4_col3" class="data row4 col3" >0.1286</td>
#       <td id="T_f7b64_row4_col4" class="data row4 col4" >0.0816</td>
#       <td id="T_f7b64_row4_col5" class="data row4 col5" >0.2844</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7b64_row5_col0" class="data row5 col0" >0.1084</td>
#       <td id="T_f7b64_row5_col1" class="data row5 col1" >0.0165</td>
#       <td id="T_f7b64_row5_col2" class="data row5 col2" >0.1283</td>
#       <td id="T_f7b64_row5_col3" class="data row5 col3" >-0.0140</td>
#       <td id="T_f7b64_row5_col4" class="data row5 col4" >0.0942</td>
#       <td id="T_f7b64_row5_col5" class="data row5 col5" >0.3736</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7b64_row6_col0" class="data row6 col0" >0.0961</td>
#       <td id="T_f7b64_row6_col1" class="data row6 col1" >0.0152</td>
#       <td id="T_f7b64_row6_col2" class="data row6 col2" >0.1233</td>
#       <td id="T_f7b64_row6_col3" class="data row6 col3" >0.2892</td>
#       <td id="T_f7b64_row6_col4" class="data row6 col4" >0.0900</td>
#       <td id="T_f7b64_row6_col5" class="data row6 col5" >0.3681</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f7b64_row7_col0" class="data row7 col0" >0.0891</td>
#       <td id="T_f7b64_row7_col1" class="data row7 col1" >0.0116</td>
#       <td id="T_f7b64_row7_col2" class="data row7 col2" >0.1079</td>
#       <td id="T_f7b64_row7_col3" class="data row7 col3" >0.1980</td>
#       <td id="T_f7b64_row7_col4" class="data row7 col4" >0.0807</td>
#       <td id="T_f7b64_row7_col5" class="data row7 col5" >0.3302</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f7b64_row8_col0" class="data row8 col0" >0.0879</td>
#       <td id="T_f7b64_row8_col1" class="data row8 col1" >0.0148</td>
#       <td id="T_f7b64_row8_col2" class="data row8 col2" >0.1216</td>
#       <td id="T_f7b64_row8_col3" class="data row8 col3" >0.2470</td>
#       <td id="T_f7b64_row8_col4" class="data row8 col4" >0.0881</td>
#       <td id="T_f7b64_row8_col5" class="data row8 col5" >0.3690</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f7b64_row9_col0" class="data row9 col0" >0.0904</td>
#       <td id="T_f7b64_row9_col1" class="data row9 col1" >0.0143</td>
#       <td id="T_f7b64_row9_col2" class="data row9 col2" >0.1196</td>
#       <td id="T_f7b64_row9_col3" class="data row9 col3" >0.0158</td>
#       <td id="T_f7b64_row9_col4" class="data row9 col4" >0.0873</td>
#       <td id="T_f7b64_row9_col5" class="data row9 col5" >0.2916</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f7b64_row10_col0" class="data row10 col0" >0.0983</td>
#       <td id="T_f7b64_row10_col1" class="data row10 col1" >0.0158</td>
#       <td id="T_f7b64_row10_col2" class="data row10 col2" >0.1246</td>
#       <td id="T_f7b64_row10_col3" class="data row10 col3" >0.0564</td>
#       <td id="T_f7b64_row10_col4" class="data row10 col4" >0.0920</td>
#       <td id="T_f7b64_row10_col5" class="data row10 col5" >0.3843</td>
#     </tr>
#     <tr>
#       <th id="T_f7b64_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_f7b64_row11_col0" class="data row11 col0" >0.0159</td>
#       <td id="T_f7b64_row11_col1" class="data row11 col1" >0.0042</td>
#       <td id="T_f7b64_row11_col2" class="data row11 col2" >0.0161</td>
#       <td id="T_f7b64_row11_col3" class="data row11 col3" >0.1597</td>
#       <td id="T_f7b64_row11_col4" class="data row11 col4" >0.0124</td>
#       <td id="T_f7b64_row11_col5" class="data row11 col5" >0.1065</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_bagged_knn = ensemble_model(estimator = knn, method = 'Bagging', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_bagged_knn)
# Out:
# <style type="text/css">
# #T_6335f_row10_col0, #T_6335f_row10_col1, #T_6335f_row10_col2, #T_6335f_row10_col3, #T_6335f_row10_col4, #T_6335f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6335f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6335f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6335f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6335f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6335f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6335f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6335f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6335f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6335f_row0_col0" class="data row0 col0" >0.0713</td>
#       <td id="T_6335f_row0_col1" class="data row0 col1" >0.0079</td>
#       <td id="T_6335f_row0_col2" class="data row0 col2" >0.0890</td>
#       <td id="T_6335f_row0_col3" class="data row0 col3" >0.0201</td>
#       <td id="T_6335f_row0_col4" class="data row0 col4" >0.0674</td>
#       <td id="T_6335f_row0_col5" class="data row0 col5" >0.2584</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6335f_row1_col0" class="data row1 col0" >0.1184</td>
#       <td id="T_6335f_row1_col1" class="data row1 col1" >0.0187</td>
#       <td id="T_6335f_row1_col2" class="data row1 col2" >0.1367</td>
#       <td id="T_6335f_row1_col3" class="data row1 col3" >0.2325</td>
#       <td id="T_6335f_row1_col4" class="data row1 col4" >0.1028</td>
#       <td id="T_6335f_row1_col5" class="data row1 col5" >0.5144</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6335f_row2_col0" class="data row2 col0" >0.0860</td>
#       <td id="T_6335f_row2_col1" class="data row2 col1" >0.0137</td>
#       <td id="T_6335f_row2_col2" class="data row2 col2" >0.1171</td>
#       <td id="T_6335f_row2_col3" class="data row2 col3" >0.1616</td>
#       <td id="T_6335f_row2_col4" class="data row2 col4" >0.0847</td>
#       <td id="T_6335f_row2_col5" class="data row2 col5" >0.3084</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6335f_row3_col0" class="data row3 col0" >0.1082</td>
#       <td id="T_6335f_row3_col1" class="data row3 col1" >0.0196</td>
#       <td id="T_6335f_row3_col2" class="data row3 col2" >0.1399</td>
#       <td id="T_6335f_row3_col3" class="data row3 col3" >0.0848</td>
#       <td id="T_6335f_row3_col4" class="data row3 col4" >0.1045</td>
#       <td id="T_6335f_row3_col5" class="data row3 col5" >0.5317</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6335f_row4_col0" class="data row4 col0" >0.0866</td>
#       <td id="T_6335f_row4_col1" class="data row4 col1" >0.0132</td>
#       <td id="T_6335f_row4_col2" class="data row4 col2" >0.1151</td>
#       <td id="T_6335f_row4_col3" class="data row4 col3" >0.0835</td>
#       <td id="T_6335f_row4_col4" class="data row4 col4" >0.0829</td>
#       <td id="T_6335f_row4_col5" class="data row4 col5" >0.2711</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6335f_row5_col0" class="data row5 col0" >0.1113</td>
#       <td id="T_6335f_row5_col1" class="data row5 col1" >0.0177</td>
#       <td id="T_6335f_row5_col2" class="data row5 col2" >0.1330</td>
#       <td id="T_6335f_row5_col3" class="data row5 col3" >-0.0896</td>
#       <td id="T_6335f_row5_col4" class="data row5 col4" >0.0975</td>
#       <td id="T_6335f_row5_col5" class="data row5 col5" >0.3721</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6335f_row6_col0" class="data row6 col0" >0.1025</td>
#       <td id="T_6335f_row6_col1" class="data row6 col1" >0.0189</td>
#       <td id="T_6335f_row6_col2" class="data row6 col2" >0.1376</td>
#       <td id="T_6335f_row6_col3" class="data row6 col3" >0.1144</td>
#       <td id="T_6335f_row6_col4" class="data row6 col4" >0.0995</td>
#       <td id="T_6335f_row6_col5" class="data row6 col5" >0.3813</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6335f_row7_col0" class="data row7 col0" >0.0852</td>
#       <td id="T_6335f_row7_col1" class="data row7 col1" >0.0099</td>
#       <td id="T_6335f_row7_col2" class="data row7 col2" >0.0995</td>
#       <td id="T_6335f_row7_col3" class="data row7 col3" >0.3175</td>
#       <td id="T_6335f_row7_col4" class="data row7 col4" >0.0746</td>
#       <td id="T_6335f_row7_col5" class="data row7 col5" >0.3098</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6335f_row8_col0" class="data row8 col0" >0.0897</td>
#       <td id="T_6335f_row8_col1" class="data row8 col1" >0.0161</td>
#       <td id="T_6335f_row8_col2" class="data row8 col2" >0.1268</td>
#       <td id="T_6335f_row8_col3" class="data row8 col3" >0.1807</td>
#       <td id="T_6335f_row8_col4" class="data row8 col4" >0.0910</td>
#       <td id="T_6335f_row8_col5" class="data row8 col5" >0.3540</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6335f_row9_col0" class="data row9 col0" >0.0885</td>
#       <td id="T_6335f_row9_col1" class="data row9 col1" >0.0130</td>
#       <td id="T_6335f_row9_col2" class="data row9 col2" >0.1141</td>
#       <td id="T_6335f_row9_col3" class="data row9 col3" >0.1044</td>
#       <td id="T_6335f_row9_col4" class="data row9 col4" >0.0837</td>
#       <td id="T_6335f_row9_col5" class="data row9 col5" >0.2926</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6335f_row10_col0" class="data row10 col0" >0.0948</td>
#       <td id="T_6335f_row10_col1" class="data row10 col1" >0.0149</td>
#       <td id="T_6335f_row10_col2" class="data row10 col2" >0.1209</td>
#       <td id="T_6335f_row10_col3" class="data row10 col3" >0.1210</td>
#       <td id="T_6335f_row10_col4" class="data row10 col4" >0.0889</td>
#       <td id="T_6335f_row10_col5" class="data row10 col5" >0.3594</td>
#     </tr>
#     <tr>
#       <th id="T_6335f_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_6335f_row11_col0" class="data row11 col0" >0.0139</td>
#       <td id="T_6335f_row11_col1" class="data row11 col1" >0.0038</td>
#       <td id="T_6335f_row11_col2" class="data row11 col2" >0.0162</td>
#       <td id="T_6335f_row11_col3" class="data row11 col3" >0.1067</td>
#       <td id="T_6335f_row11_col4" class="data row11 col4" >0.0117</td>
#       <td id="T_6335f_row11_col5" class="data row11 col5" >0.0905</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_boosted_knn = ensemble_model(estimator = knn, method = 'Boosting', n_estimators=50, optimize = 'RMSE')
prediction_model.append(tuned_boosted_knn)
# Out:
# <style type="text/css">
# #T_6353d_row10_col0, #T_6353d_row10_col1, #T_6353d_row10_col2, #T_6353d_row10_col3, #T_6353d_row10_col4, #T_6353d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6353d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6353d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6353d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6353d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6353d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6353d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6353d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6353d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6353d_row0_col0" class="data row0 col0" >0.0815</td>
#       <td id="T_6353d_row0_col1" class="data row0 col1" >0.0100</td>
#       <td id="T_6353d_row0_col2" class="data row0 col2" >0.1002</td>
#       <td id="T_6353d_row0_col3" class="data row0 col3" >-0.2418</td>
#       <td id="T_6353d_row0_col4" class="data row0 col4" >0.0757</td>
#       <td id="T_6353d_row0_col5" class="data row0 col5" >0.2965</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6353d_row1_col0" class="data row1 col0" >0.1142</td>
#       <td id="T_6353d_row1_col1" class="data row1 col1" >0.0176</td>
#       <td id="T_6353d_row1_col2" class="data row1 col2" >0.1325</td>
#       <td id="T_6353d_row1_col3" class="data row1 col3" >0.2786</td>
#       <td id="T_6353d_row1_col4" class="data row1 col4" >0.1004</td>
#       <td id="T_6353d_row1_col5" class="data row1 col5" >0.5082</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6353d_row2_col0" class="data row2 col0" >0.0917</td>
#       <td id="T_6353d_row2_col1" class="data row2 col1" >0.0137</td>
#       <td id="T_6353d_row2_col2" class="data row2 col2" >0.1172</td>
#       <td id="T_6353d_row2_col3" class="data row2 col3" >0.1595</td>
#       <td id="T_6353d_row2_col4" class="data row2 col4" >0.0853</td>
#       <td id="T_6353d_row2_col5" class="data row2 col5" >0.3343</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6353d_row3_col0" class="data row3 col0" >0.1152</td>
#       <td id="T_6353d_row3_col1" class="data row3 col1" >0.0217</td>
#       <td id="T_6353d_row3_col2" class="data row3 col2" >0.1473</td>
#       <td id="T_6353d_row3_col3" class="data row3 col3" >-0.0143</td>
#       <td id="T_6353d_row3_col4" class="data row3 col4" >0.1097</td>
#       <td id="T_6353d_row3_col5" class="data row3 col5" >0.5488</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6353d_row4_col0" class="data row4 col0" >0.0879</td>
#       <td id="T_6353d_row4_col1" class="data row4 col1" >0.0130</td>
#       <td id="T_6353d_row4_col2" class="data row4 col2" >0.1141</td>
#       <td id="T_6353d_row4_col3" class="data row4 col3" >0.0982</td>
#       <td id="T_6353d_row4_col4" class="data row4 col4" >0.0824</td>
#       <td id="T_6353d_row4_col5" class="data row4 col5" >0.2831</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6353d_row5_col0" class="data row5 col0" >0.1143</td>
#       <td id="T_6353d_row5_col1" class="data row5 col1" >0.0174</td>
#       <td id="T_6353d_row5_col2" class="data row5 col2" >0.1320</td>
#       <td id="T_6353d_row5_col3" class="data row5 col3" >-0.0727</td>
#       <td id="T_6353d_row5_col4" class="data row5 col4" >0.0967</td>
#       <td id="T_6353d_row5_col5" class="data row5 col5" >0.3843</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6353d_row6_col0" class="data row6 col0" >0.0981</td>
#       <td id="T_6353d_row6_col1" class="data row6 col1" >0.0167</td>
#       <td id="T_6353d_row6_col2" class="data row6 col2" >0.1291</td>
#       <td id="T_6353d_row6_col3" class="data row6 col3" >0.2200</td>
#       <td id="T_6353d_row6_col4" class="data row6 col4" >0.0938</td>
#       <td id="T_6353d_row6_col5" class="data row6 col5" >0.3738</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6353d_row7_col0" class="data row7 col0" >0.0862</td>
#       <td id="T_6353d_row7_col1" class="data row7 col1" >0.0106</td>
#       <td id="T_6353d_row7_col2" class="data row7 col2" >0.1031</td>
#       <td id="T_6353d_row7_col3" class="data row7 col3" >0.2669</td>
#       <td id="T_6353d_row7_col4" class="data row7 col4" >0.0771</td>
#       <td id="T_6353d_row7_col5" class="data row7 col5" >0.3145</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6353d_row8_col0" class="data row8 col0" >0.0831</td>
#       <td id="T_6353d_row8_col1" class="data row8 col1" >0.0134</td>
#       <td id="T_6353d_row8_col2" class="data row8 col2" >0.1156</td>
#       <td id="T_6353d_row8_col3" class="data row8 col3" >0.3196</td>
#       <td id="T_6353d_row8_col4" class="data row8 col4" >0.0830</td>
#       <td id="T_6353d_row8_col5" class="data row8 col5" >0.3292</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6353d_row9_col0" class="data row9 col0" >0.0930</td>
#       <td id="T_6353d_row9_col1" class="data row9 col1" >0.0154</td>
#       <td id="T_6353d_row9_col2" class="data row9 col2" >0.1241</td>
#       <td id="T_6353d_row9_col3" class="data row9 col3" >-0.0600</td>
#       <td id="T_6353d_row9_col4" class="data row9 col4" >0.0914</td>
#       <td id="T_6353d_row9_col5" class="data row9 col5" >0.3190</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6353d_row10_col0" class="data row10 col0" >0.0965</td>
#       <td id="T_6353d_row10_col1" class="data row10 col1" >0.0150</td>
#       <td id="T_6353d_row10_col2" class="data row10 col2" >0.1215</td>
#       <td id="T_6353d_row10_col3" class="data row10 col3" >0.0954</td>
#       <td id="T_6353d_row10_col4" class="data row10 col4" >0.0895</td>
#       <td id="T_6353d_row10_col5" class="data row10 col5" >0.3692</td>
#     </tr>
#     <tr>
#       <th id="T_6353d_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_6353d_row11_col0" class="data row11 col0" >0.0126</td>
#       <td id="T_6353d_row11_col1" class="data row11 col1" >0.0033</td>
#       <td id="T_6353d_row11_col2" class="data row11 col2" >0.0136</td>
#       <td id="T_6353d_row11_col3" class="data row11 col3" >0.1764</td>
#       <td id="T_6353d_row11_col4" class="data row11 col4" >0.0103</td>
#       <td id="T_6353d_row11_col5" class="data row11 col5" >0.0853</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### c. Blending all Models

# %% [markdown]
# pycaret.regression.blend_models(
# estimator_list: list, fold: Optional[Union[int, Any]] = None, round: int = 4, choose_better: bool = False, optimize: str = 'R2', weights: Optional[List[float]] = None, fit_kwargs: Optional[dict] = None, groups: Optional[Union[str, Any]] = None, verbose: bool = True, return_train_score: bool = False )

# %%
blend_5_soft = blend_models(estimator_list = tuned_models, fold=5, optimize = 'RMSE', choose_better = True)
prediction_model.append(blend_5_soft)
# Out:
# <style type="text/css">
# #T_b474d_row5_col0, #T_b474d_row5_col1, #T_b474d_row5_col2, #T_b474d_row5_col3, #T_b474d_row5_col4, #T_b474d_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b474d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b474d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b474d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b474d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b474d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b474d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b474d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b474d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b474d_row0_col0" class="data row0 col0" >0.0931</td>
#       <td id="T_b474d_row0_col1" class="data row0 col1" >0.0129</td>
#       <td id="T_b474d_row0_col2" class="data row0 col2" >0.1137</td>
#       <td id="T_b474d_row0_col3" class="data row0 col3" >0.2141</td>
#       <td id="T_b474d_row0_col4" class="data row0 col4" >0.0859</td>
#       <td id="T_b474d_row0_col5" class="data row0 col5" >0.3821</td>
#     </tr>
#     <tr>
#       <th id="T_b474d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b474d_row1_col0" class="data row1 col0" >0.1032</td>
#       <td id="T_b474d_row1_col1" class="data row1 col1" >0.0181</td>
#       <td id="T_b474d_row1_col2" class="data row1 col2" >0.1344</td>
#       <td id="T_b474d_row1_col3" class="data row1 col3" >0.0632</td>
#       <td id="T_b474d_row1_col4" class="data row1 col4" >0.0995</td>
#       <td id="T_b474d_row1_col5" class="data row1 col5" >0.4493</td>
#     </tr>
#     <tr>
#       <th id="T_b474d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b474d_row2_col0" class="data row2 col0" >0.0954</td>
#       <td id="T_b474d_row2_col1" class="data row2 col1" >0.0147</td>
#       <td id="T_b474d_row2_col2" class="data row2 col2" >0.1212</td>
#       <td id="T_b474d_row2_col3" class="data row2 col3" >0.0498</td>
#       <td id="T_b474d_row2_col4" class="data row2 col4" >0.0882</td>
#       <td id="T_b474d_row2_col5" class="data row2 col5" >0.3119</td>
#     </tr>
#     <tr>
#       <th id="T_b474d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b474d_row3_col0" class="data row3 col0" >0.0904</td>
#       <td id="T_b474d_row3_col1" class="data row3 col1" >0.0134</td>
#       <td id="T_b474d_row3_col2" class="data row3 col2" >0.1159</td>
#       <td id="T_b474d_row3_col3" class="data row3 col3" >0.2525</td>
#       <td id="T_b474d_row3_col4" class="data row3 col4" >0.0853</td>
#       <td id="T_b474d_row3_col5" class="data row3 col5" >0.3392</td>
#     </tr>
#     <tr>
#       <th id="T_b474d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b474d_row4_col0" class="data row4 col0" >0.0883</td>
#       <td id="T_b474d_row4_col1" class="data row4 col1" >0.0145</td>
#       <td id="T_b474d_row4_col2" class="data row4 col2" >0.1203</td>
#       <td id="T_b474d_row4_col3" class="data row4 col3" >0.1561</td>
#       <td id="T_b474d_row4_col4" class="data row4 col4" >0.0871</td>
#       <td id="T_b474d_row4_col5" class="data row4 col5" >0.3170</td>
#     </tr>
#     <tr>
#       <th id="T_b474d_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_b474d_row5_col0" class="data row5 col0" >0.0941</td>
#       <td id="T_b474d_row5_col1" class="data row5 col1" >0.0147</td>
#       <td id="T_b474d_row5_col2" class="data row5 col2" >0.1211</td>
#       <td id="T_b474d_row5_col3" class="data row5 col3" >0.1471</td>
#       <td id="T_b474d_row5_col4" class="data row5 col4" >0.0892</td>
#       <td id="T_b474d_row5_col5" class="data row5 col5" >0.3599</td>
#     </tr>
#     <tr>
#       <th id="T_b474d_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_b474d_row6_col0" class="data row6 col0" >0.0051</td>
#       <td id="T_b474d_row6_col1" class="data row6 col1" >0.0018</td>
#       <td id="T_b474d_row6_col2" class="data row6 col2" >0.0072</td>
#       <td id="T_b474d_row6_col3" class="data row6 col3" >0.0802</td>
#       <td id="T_b474d_row6_col4" class="data row6 col4" >0.0053</td>
#       <td id="T_b474d_row6_col5" class="data row6 col5" >0.0511</td>
#     </tr>
#   </tbody>
# </table>

# %%
blend_10_soft = blend_models(estimator_list = tuned_models, fold=10, optimize = 'RMSE', choose_better = True)
prediction_model.append(blend_10_soft)
# Out:
# <style type="text/css">
# #T_cfb79_row10_col0, #T_cfb79_row10_col1, #T_cfb79_row10_col2, #T_cfb79_row10_col3, #T_cfb79_row10_col4, #T_cfb79_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cfb79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfb79_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cfb79_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cfb79_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cfb79_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cfb79_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cfb79_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfb79_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cfb79_row0_col0" class="data row0 col0" >0.0719</td>
#       <td id="T_cfb79_row0_col1" class="data row0 col1" >0.0086</td>
#       <td id="T_cfb79_row0_col2" class="data row0 col2" >0.0929</td>
#       <td id="T_cfb79_row0_col3" class="data row0 col3" >-0.0667</td>
#       <td id="T_cfb79_row0_col4" class="data row0 col4" >0.0702</td>
#       <td id="T_cfb79_row0_col5" class="data row0 col5" >0.2626</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cfb79_row1_col0" class="data row1 col0" >0.1149</td>
#       <td id="T_cfb79_row1_col1" class="data row1 col1" >0.0178</td>
#       <td id="T_cfb79_row1_col2" class="data row1 col2" >0.1333</td>
#       <td id="T_cfb79_row1_col3" class="data row1 col3" >0.2703</td>
#       <td id="T_cfb79_row1_col4" class="data row1 col4" >0.1007</td>
#       <td id="T_cfb79_row1_col5" class="data row1 col5" >0.5107</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cfb79_row2_col0" class="data row2 col0" >0.0871</td>
#       <td id="T_cfb79_row2_col1" class="data row2 col1" >0.0140</td>
#       <td id="T_cfb79_row2_col2" class="data row2 col2" >0.1184</td>
#       <td id="T_cfb79_row2_col3" class="data row2 col3" >0.1428</td>
#       <td id="T_cfb79_row2_col4" class="data row2 col4" >0.0858</td>
#       <td id="T_cfb79_row2_col5" class="data row2 col5" >0.3186</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cfb79_row3_col0" class="data row3 col0" >0.1143</td>
#       <td id="T_cfb79_row3_col1" class="data row3 col1" >0.0219</td>
#       <td id="T_cfb79_row3_col2" class="data row3 col2" >0.1481</td>
#       <td id="T_cfb79_row3_col3" class="data row3 col3" >-0.0255</td>
#       <td id="T_cfb79_row3_col4" class="data row3 col4" >0.1109</td>
#       <td id="T_cfb79_row3_col5" class="data row3 col5" >0.5597</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cfb79_row4_col0" class="data row4 col0" >0.0846</td>
#       <td id="T_cfb79_row4_col1" class="data row4 col1" >0.0131</td>
#       <td id="T_cfb79_row4_col2" class="data row4 col2" >0.1144</td>
#       <td id="T_cfb79_row4_col3" class="data row4 col3" >0.0942</td>
#       <td id="T_cfb79_row4_col4" class="data row4 col4" >0.0826</td>
#       <td id="T_cfb79_row4_col5" class="data row4 col5" >0.2695</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cfb79_row5_col0" class="data row5 col0" >0.1069</td>
#       <td id="T_cfb79_row5_col1" class="data row5 col1" >0.0169</td>
#       <td id="T_cfb79_row5_col2" class="data row5 col2" >0.1300</td>
#       <td id="T_cfb79_row5_col3" class="data row5 col3" >-0.0403</td>
#       <td id="T_cfb79_row5_col4" class="data row5 col4" >0.0952</td>
#       <td id="T_cfb79_row5_col5" class="data row5 col5" >0.3609</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cfb79_row6_col0" class="data row6 col0" >0.0985</td>
#       <td id="T_cfb79_row6_col1" class="data row6 col1" >0.0171</td>
#       <td id="T_cfb79_row6_col2" class="data row6 col2" >0.1309</td>
#       <td id="T_cfb79_row6_col3" class="data row6 col3" >0.1987</td>
#       <td id="T_cfb79_row6_col4" class="data row6 col4" >0.0951</td>
#       <td id="T_cfb79_row6_col5" class="data row6 col5" >0.3743</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cfb79_row7_col0" class="data row7 col0" >0.0807</td>
#       <td id="T_cfb79_row7_col1" class="data row7 col1" >0.0096</td>
#       <td id="T_cfb79_row7_col2" class="data row7 col2" >0.0978</td>
#       <td id="T_cfb79_row7_col3" class="data row7 col3" >0.3409</td>
#       <td id="T_cfb79_row7_col4" class="data row7 col4" >0.0733</td>
#       <td id="T_cfb79_row7_col5" class="data row7 col5" >0.2951</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cfb79_row8_col0" class="data row8 col0" >0.0894</td>
#       <td id="T_cfb79_row8_col1" class="data row8 col1" >0.0156</td>
#       <td id="T_cfb79_row8_col2" class="data row8 col2" >0.1249</td>
#       <td id="T_cfb79_row8_col3" class="data row8 col3" >0.2050</td>
#       <td id="T_cfb79_row8_col4" class="data row8 col4" >0.0901</td>
#       <td id="T_cfb79_row8_col5" class="data row8 col5" >0.3601</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cfb79_row9_col0" class="data row9 col0" >0.0891</td>
#       <td id="T_cfb79_row9_col1" class="data row9 col1" >0.0137</td>
#       <td id="T_cfb79_row9_col2" class="data row9 col2" >0.1170</td>
#       <td id="T_cfb79_row9_col3" class="data row9 col3" >0.0589</td>
#       <td id="T_cfb79_row9_col4" class="data row9 col4" >0.0855</td>
#       <td id="T_cfb79_row9_col5" class="data row9 col5" >0.2910</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_cfb79_row10_col0" class="data row10 col0" >0.0937</td>
#       <td id="T_cfb79_row10_col1" class="data row10 col1" >0.0148</td>
#       <td id="T_cfb79_row10_col2" class="data row10 col2" >0.1208</td>
#       <td id="T_cfb79_row10_col3" class="data row10 col3" >0.1178</td>
#       <td id="T_cfb79_row10_col4" class="data row10 col4" >0.0890</td>
#       <td id="T_cfb79_row10_col5" class="data row10 col5" >0.3602</td>
#     </tr>
#     <tr>
#       <th id="T_cfb79_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_cfb79_row11_col0" class="data row11 col0" >0.0137</td>
#       <td id="T_cfb79_row11_col1" class="data row11 col1" >0.0037</td>
#       <td id="T_cfb79_row11_col2" class="data row11 col2" >0.0157</td>
#       <td id="T_cfb79_row11_col3" class="data row11 col3" >0.1309</td>
#       <td id="T_cfb79_row11_col4" class="data row11 col4" >0.0116</td>
#       <td id="T_cfb79_row11_col5" class="data row11 col5" >0.0955</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### d. Stacking all Models

# %% [markdown]
# pycaret.regression.stack_models(estimator_list: list, meta_model=None, meta_model_fold: Optional[Union[int, Any]] = 5, fold: Optional[Union[int, Any]] = None, round: int = 4, restack: bool = True, choose_better: bool = False, optimize: str = 'R2', fit_kwargs: Optional[dict] = None, groups: Optional[Union[str, Any]] = None, verbose: bool = True, return_train_score: bool = False)

# %%
stack_5 = stack_models(estimator_list = tuned_models, meta_model = rf, fold = 5, optimize = 'RMSE', choose_better= True)
prediction_model.append(stack_5)
# Out:
# <style type="text/css">
# #T_1156f_row5_col0, #T_1156f_row5_col1, #T_1156f_row5_col2, #T_1156f_row5_col3, #T_1156f_row5_col4, #T_1156f_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1156f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1156f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1156f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1156f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1156f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1156f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1156f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1156f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1156f_row0_col0" class="data row0 col0" >0.0893</td>
#       <td id="T_1156f_row0_col1" class="data row0 col1" >0.0123</td>
#       <td id="T_1156f_row0_col2" class="data row0 col2" >0.1107</td>
#       <td id="T_1156f_row0_col3" class="data row0 col3" >0.2548</td>
#       <td id="T_1156f_row0_col4" class="data row0 col4" >0.0837</td>
#       <td id="T_1156f_row0_col5" class="data row0 col5" >0.3627</td>
#     </tr>
#     <tr>
#       <th id="T_1156f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1156f_row1_col0" class="data row1 col0" >0.1065</td>
#       <td id="T_1156f_row1_col1" class="data row1 col1" >0.0201</td>
#       <td id="T_1156f_row1_col2" class="data row1 col2" >0.1417</td>
#       <td id="T_1156f_row1_col3" class="data row1 col3" >-0.0416</td>
#       <td id="T_1156f_row1_col4" class="data row1 col4" >0.1051</td>
#       <td id="T_1156f_row1_col5" class="data row1 col5" >0.4649</td>
#     </tr>
#     <tr>
#       <th id="T_1156f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1156f_row2_col0" class="data row2 col0" >0.1003</td>
#       <td id="T_1156f_row2_col1" class="data row2 col1" >0.0162</td>
#       <td id="T_1156f_row2_col2" class="data row2 col2" >0.1271</td>
#       <td id="T_1156f_row2_col3" class="data row2 col3" >-0.0451</td>
#       <td id="T_1156f_row2_col4" class="data row2 col4" >0.0923</td>
#       <td id="T_1156f_row2_col5" class="data row2 col5" >0.3196</td>
#     </tr>
#     <tr>
#       <th id="T_1156f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1156f_row3_col0" class="data row3 col0" >0.0888</td>
#       <td id="T_1156f_row3_col1" class="data row3 col1" >0.0131</td>
#       <td id="T_1156f_row3_col2" class="data row3 col2" >0.1144</td>
#       <td id="T_1156f_row3_col3" class="data row3 col3" >0.2719</td>
#       <td id="T_1156f_row3_col4" class="data row3 col4" >0.0843</td>
#       <td id="T_1156f_row3_col5" class="data row3 col5" >0.3321</td>
#     </tr>
#     <tr>
#       <th id="T_1156f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1156f_row4_col0" class="data row4 col0" >0.0867</td>
#       <td id="T_1156f_row4_col1" class="data row4 col1" >0.0145</td>
#       <td id="T_1156f_row4_col2" class="data row4 col2" >0.1206</td>
#       <td id="T_1156f_row4_col3" class="data row4 col3" >0.1510</td>
#       <td id="T_1156f_row4_col4" class="data row4 col4" >0.0874</td>
#       <td id="T_1156f_row4_col5" class="data row4 col5" >0.3030</td>
#     </tr>
#     <tr>
#       <th id="T_1156f_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_1156f_row5_col0" class="data row5 col0" >0.0943</td>
#       <td id="T_1156f_row5_col1" class="data row5 col1" >0.0152</td>
#       <td id="T_1156f_row5_col2" class="data row5 col2" >0.1229</td>
#       <td id="T_1156f_row5_col3" class="data row5 col3" >0.1182</td>
#       <td id="T_1156f_row5_col4" class="data row5 col4" >0.0906</td>
#       <td id="T_1156f_row5_col5" class="data row5 col5" >0.3564</td>
#     </tr>
#     <tr>
#       <th id="T_1156f_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_1156f_row6_col0" class="data row6 col0" >0.0077</td>
#       <td id="T_1156f_row6_col1" class="data row6 col1" >0.0028</td>
#       <td id="T_1156f_row6_col2" class="data row6 col2" >0.0109</td>
#       <td id="T_1156f_row6_col3" class="data row6 col3" >0.1382</td>
#       <td id="T_1156f_row6_col4" class="data row6 col4" >0.0079</td>
#       <td id="T_1156f_row6_col5" class="data row6 col5" >0.0577</td>
#     </tr>
#   </tbody>
# </table>

# %%
stack_10 = stack_models(estimator_list = tuned_models, meta_model = rf, fold = 10, optimize = 'RMSE', choose_better= True)
prediction_model.append(stack_10)
# Out:
# <style type="text/css">
# #T_140bd_row10_col0, #T_140bd_row10_col1, #T_140bd_row10_col2, #T_140bd_row10_col3, #T_140bd_row10_col4, #T_140bd_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_140bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_140bd_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_140bd_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_140bd_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_140bd_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_140bd_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_140bd_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_140bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_140bd_row0_col0" class="data row0 col0" >0.0745</td>
#       <td id="T_140bd_row0_col1" class="data row0 col1" >0.0093</td>
#       <td id="T_140bd_row0_col2" class="data row0 col2" >0.0963</td>
#       <td id="T_140bd_row0_col3" class="data row0 col3" >-0.1468</td>
#       <td id="T_140bd_row0_col4" class="data row0 col4" >0.0722</td>
#       <td id="T_140bd_row0_col5" class="data row0 col5" >0.2608</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_140bd_row1_col0" class="data row1 col0" >0.1012</td>
#       <td id="T_140bd_row1_col1" class="data row1 col1" >0.0151</td>
#       <td id="T_140bd_row1_col2" class="data row1 col2" >0.1229</td>
#       <td id="T_140bd_row1_col3" class="data row1 col3" >0.3788</td>
#       <td id="T_140bd_row1_col4" class="data row1 col4" >0.0939</td>
#       <td id="T_140bd_row1_col5" class="data row1 col5" >0.4703</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_140bd_row2_col0" class="data row2 col0" >0.0894</td>
#       <td id="T_140bd_row2_col1" class="data row2 col1" >0.0146</td>
#       <td id="T_140bd_row2_col2" class="data row2 col2" >0.1208</td>
#       <td id="T_140bd_row2_col3" class="data row2 col3" >0.1079</td>
#       <td id="T_140bd_row2_col4" class="data row2 col4" >0.0877</td>
#       <td id="T_140bd_row2_col5" class="data row2 col5" >0.3190</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_140bd_row3_col0" class="data row3 col0" >0.1169</td>
#       <td id="T_140bd_row3_col1" class="data row3 col1" >0.0239</td>
#       <td id="T_140bd_row3_col2" class="data row3 col2" >0.1547</td>
#       <td id="T_140bd_row3_col3" class="data row3 col3" >-0.1185</td>
#       <td id="T_140bd_row3_col4" class="data row3 col4" >0.1158</td>
#       <td id="T_140bd_row3_col5" class="data row3 col5" >0.5618</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_140bd_row4_col0" class="data row4 col0" >0.0874</td>
#       <td id="T_140bd_row4_col1" class="data row4 col1" >0.0137</td>
#       <td id="T_140bd_row4_col2" class="data row4 col2" >0.1172</td>
#       <td id="T_140bd_row4_col3" class="data row4 col3" >0.0498</td>
#       <td id="T_140bd_row4_col4" class="data row4 col4" >0.0841</td>
#       <td id="T_140bd_row4_col5" class="data row4 col5" >0.2687</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_140bd_row5_col0" class="data row5 col0" >0.1052</td>
#       <td id="T_140bd_row5_col1" class="data row5 col1" >0.0165</td>
#       <td id="T_140bd_row5_col2" class="data row5 col2" >0.1283</td>
#       <td id="T_140bd_row5_col3" class="data row5 col3" >-0.0141</td>
#       <td id="T_140bd_row5_col4" class="data row5 col4" >0.0937</td>
#       <td id="T_140bd_row5_col5" class="data row5 col5" >0.3470</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_140bd_row6_col0" class="data row6 col0" >0.0923</td>
#       <td id="T_140bd_row6_col1" class="data row6 col1" >0.0157</td>
#       <td id="T_140bd_row6_col2" class="data row6 col2" >0.1252</td>
#       <td id="T_140bd_row6_col3" class="data row6 col3" >0.2669</td>
#       <td id="T_140bd_row6_col4" class="data row6 col4" >0.0906</td>
#       <td id="T_140bd_row6_col5" class="data row6 col5" >0.3434</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_140bd_row7_col0" class="data row7 col0" >0.0723</td>
#       <td id="T_140bd_row7_col1" class="data row7 col1" >0.0083</td>
#       <td id="T_140bd_row7_col2" class="data row7 col2" >0.0913</td>
#       <td id="T_140bd_row7_col3" class="data row7 col3" >0.4254</td>
#       <td id="T_140bd_row7_col4" class="data row7 col4" >0.0683</td>
#       <td id="T_140bd_row7_col5" class="data row7 col5" >0.2616</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_140bd_row8_col0" class="data row8 col0" >0.0929</td>
#       <td id="T_140bd_row8_col1" class="data row8 col1" >0.0162</td>
#       <td id="T_140bd_row8_col2" class="data row8 col2" >0.1273</td>
#       <td id="T_140bd_row8_col3" class="data row8 col3" >0.1752</td>
#       <td id="T_140bd_row8_col4" class="data row8 col4" >0.0919</td>
#       <td id="T_140bd_row8_col5" class="data row8 col5" >0.3558</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_140bd_row9_col0" class="data row9 col0" >0.0841</td>
#       <td id="T_140bd_row9_col1" class="data row9 col1" >0.0131</td>
#       <td id="T_140bd_row9_col2" class="data row9 col2" >0.1146</td>
#       <td id="T_140bd_row9_col3" class="data row9 col3" >0.0970</td>
#       <td id="T_140bd_row9_col4" class="data row9 col4" >0.0830</td>
#       <td id="T_140bd_row9_col5" class="data row9 col5" >0.2586</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_140bd_row10_col0" class="data row10 col0" >0.0916</td>
#       <td id="T_140bd_row10_col1" class="data row10 col1" >0.0146</td>
#       <td id="T_140bd_row10_col2" class="data row10 col2" >0.1198</td>
#       <td id="T_140bd_row10_col3" class="data row10 col3" >0.1222</td>
#       <td id="T_140bd_row10_col4" class="data row10 col4" >0.0881</td>
#       <td id="T_140bd_row10_col5" class="data row10 col5" >0.3447</td>
#     </tr>
#     <tr>
#       <th id="T_140bd_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_140bd_row11_col0" class="data row11 col0" >0.0129</td>
#       <td id="T_140bd_row11_col1" class="data row11 col1" >0.0041</td>
#       <td id="T_140bd_row11_col2" class="data row11 col2" >0.0167</td>
#       <td id="T_140bd_row11_col3" class="data row11 col3" >0.1835</td>
#       <td id="T_140bd_row11_col4" class="data row11 col4" >0.0124</td>
#       <td id="T_140bd_row11_col5" class="data row11 col5" >0.0953</td>
#     </tr>
#   </tbody>
# </table>

# %%
prediction_model
# Out:
# [BaggingRegressor(base_estimator=RandomForestRegressor(bootstrap=False,
#                                                        ccp_alpha=0.0,
#                                                        criterion='mae',
#                                                        max_depth=9,
#                                                        max_features='sqrt',
#                                                        max_leaf_nodes=None,
#                                                        max_samples=None,
#                                                        min_impurity_decrease=0.0001,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=3,
#                                                        min_samples_split=10,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        n_estimators=60,
#                                                        n_jobs=-1,
#                                                        oob_score=False,
#                                                        random_state=42,
#                                                        verbose=0,
#                                                        warm_start=False),
#                   bootstrap=True, bootstrap_features=False, max_features=1.0,
#                   max_samples=1.0, n_estimators=50, n_jobs=None, oob_score=False,
#                   random_state=42, verbose=0, warm_start=False),
#  AdaBoostRegressor(base_estimator=RandomForestRegressor(bootstrap=False,
#                                                         ccp_alpha=0.0,
#                                                         criterion='mae',
#                                                         max_depth=9,
#                                                         max_features='sqrt',
#                                                         max_leaf_nodes=None,
#                                                         max_samples=None,
#                                                         min_impurity_decrease=0.0001,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=3,
#                                                         min_samples_split=10,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         n_estimators=60,
#                                                         n_jobs=-1,
#                                                         oob_score=False,
#                                                         random_state=42,
#                                                         verbose=0,
#                                                         warm_start=False),
#                    learning_rate=1.0, loss='linear', n_estimators=50,
#                    random_state=42),
#  BaggingRegressor(base_estimator=<catboost.core.CatBoostRegressor object at 0x00000215F7E4C610>,
#                   bootstrap=True, bootstrap_features=False, max_features=1.0,
#                   max_samples=1.0, n_estimators=50, n_jobs=None, oob_score=False,
#                   random_state=42, verbose=0, warm_start=False),
#  AdaBoostRegressor(base_estimator=<catboost.core.CatBoostRegressor object at 0x00000215F8064D30>,
#                    learning_rate=1.0, loss='linear', n_estimators=50,
#                    random_state=42),
#  BaggingRegressor(base_estimator=KNeighborsRegressor(algorithm='auto',
#                                                      leaf_size=30,
#                                                      metric='euclidean',
#                                                      metric_params=None,
#                                                      n_jobs=-1, n_neighbors=26,
#                                                      p=2, weights='distance'),
#                   bootstrap=True, bootstrap_features=False, max_features=1.0,
#                   max_samples=1.0, n_estimators=50, n_jobs=None, oob_score=False,
#                   random_state=42, verbose=0, warm_start=False),
#  AdaBoostRegressor(base_estimator=KNeighborsRegressor(algorithm='auto',
#                                                       leaf_size=30,
#                                                       metric='euclidean',
#                                                       metric_params=None,
#                                                       n_jobs=-1, n_neighbors=26,
#                                                       p=2, weights='distance'),
#                    learning_rate=1.0, loss='linear', n_estimators=50,
#                    random_state=42),
#  VotingRegressor(estimators=[('rf',
#                               RandomForestRegressor(bootstrap=False,
#                                                     ccp_alpha=0.0,
#                                                     criterion='mae', max_depth=9,
#                                                     max_features='sqrt',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
#                                                     min_impurity_decrease=0.0001,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=3,
#                                                     min_samples_split=10,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     n_estimators=60, n_jobs=-1,
#                                                     oob_score=False,
#                                                     random_state=42, verbose=0,
#                                                     warm_start=False)),
#                              ('catboost',
#                               <catboost.core.CatBoostRegressor object at 0x00000215F7FEC670>),
#                              ('knn',
#                               KNeighborsRegressor(algorithm='auto', leaf_size=30,
#                                                   metric='euclidean',
#                                                   metric_params=None, n_jobs=-1,
#                                                   n_neighbors=26, p=2,
#                                                   weights='distance'))],
#                  n_jobs=-1, verbose=False, weights=None),
#  KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=-1, n_neighbors=26, p=2,
#                      weights='distance'),
#  KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=-1, n_neighbors=26, p=2,
#                      weights='distance'),
#  StackingRegressor(cv=5,
#                    estimators=[('rf',
#                                 RandomForestRegressor(bootstrap=False,
#                                                       ccp_alpha=0.0,
#                                                       criterion='mae',
#                                                       max_depth=9,
#                                                       max_features='sqrt',
#                                                       max_leaf_nodes=None,
#                                                       max_samples=None,
#                                                       min_impurity_decrease=0.0001,
#                                                       min_impurity_split=None,
#                                                       min_samples_leaf=3,
#                                                       min_samples_split=10,
#                                                       min_weight_fraction_leaf=0.0,
#                                                       n_estimators=60, n_jobs=-1,
#                                                       oob_score=False,
#                                                       random_s...
#                    final_estimator=RandomForestRegressor(bootstrap=False,
#                                                          ccp_alpha=0.0,
#                                                          criterion='mae',
#                                                          max_depth=9,
#                                                          max_features='sqrt',
#                                                          max_leaf_nodes=None,
#                                                          max_samples=None,
#                                                          min_impurity_decrease=0.0001,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=3,
#                                                          min_samples_split=10,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=60,
#                                                          n_jobs=-1,
#                                                          oob_score=False,
#                                                          random_state=42,
#                                                          verbose=0,
#                                                          warm_start=False),
#                    n_jobs=-1, passthrough=True, verbose=0)]

# %%
for model in prediction_model:
    print(model.__class__.__name__)
    display(predict_model(model))
# Out:
# BaggingRegressor
# <style type="text/css">
# </style>
# <table id="T_50ea6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50ea6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_50ea6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_50ea6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_50ea6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_50ea6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_50ea6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_50ea6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50ea6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50ea6_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_50ea6_row0_col1" class="data row0 col1" >0.0955</td>
#       <td id="T_50ea6_row0_col2" class="data row0 col2" >0.0146</td>
#       <td id="T_50ea6_row0_col3" class="data row0 col3" >0.1209</td>
#       <td id="T_50ea6_row0_col4" class="data row0 col4" >0.1370</td>
#       <td id="T_50ea6_row0_col5" class="data row0 col5" >0.0886</td>
#       <td id="T_50ea6_row0_col6" class="data row0 col6" >0.3605</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.254193
# 1    -1.673975                    0.0               1.0  0.504560  0.333924
# 2    -0.414861                    1.0               1.0  0.380000  0.346893
# 3    -1.673975                    0.0               0.0  0.290000  0.381032
# 4    -0.414861                    1.0               1.0  0.650000  0.322834
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.339472
# 131  -0.414861                    0.0               0.0  0.060521  0.318677
# 132  -0.414861                    1.0               0.0  0.274000  0.370381
# 133   1.153353                    0.0               1.0  0.422148  0.380131
# 134  -0.414861                    0.0               1.0  0.410000  0.377646
#
# [135 rows x 20 columns]
# AdaBoostRegressor
# <style type="text/css">
# </style>
# <table id="T_e04cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e04cc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e04cc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e04cc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e04cc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e04cc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e04cc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e04cc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e04cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e04cc_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_e04cc_row0_col1" class="data row0 col1" >0.0947</td>
#       <td id="T_e04cc_row0_col2" class="data row0 col2" >0.0141</td>
#       <td id="T_e04cc_row0_col3" class="data row0 col3" >0.1188</td>
#       <td id="T_e04cc_row0_col4" class="data row0 col4" >0.1667</td>
#       <td id="T_e04cc_row0_col5" class="data row0 col5" >0.0871</td>
#       <td id="T_e04cc_row0_col6" class="data row0 col6" >0.3611</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.228380
# 1    -1.673975                    0.0               1.0  0.504560  0.330563
# 2    -0.414861                    1.0               1.0  0.380000  0.403006
# 3    -1.673975                    0.0               0.0  0.290000  0.348555
# 4    -0.414861                    1.0               1.0  0.650000  0.307266
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.377055
# 131  -0.414861                    0.0               0.0  0.060521  0.350640
# 132  -0.414861                    1.0               0.0  0.274000  0.361434
# 133   1.153353                    0.0               1.0  0.422148  0.381573
# 134  -0.414861                    0.0               1.0  0.410000  0.394452
#
# [135 rows x 20 columns]
# BaggingRegressor
# <style type="text/css">
# </style>
# <table id="T_8c808">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c808_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8c808_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8c808_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8c808_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8c808_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8c808_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8c808_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c808_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c808_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_8c808_row0_col1" class="data row0 col1" >0.0966</td>
#       <td id="T_8c808_row0_col2" class="data row0 col2" >0.0147</td>
#       <td id="T_8c808_row0_col3" class="data row0 col3" >0.1211</td>
#       <td id="T_8c808_row0_col4" class="data row0 col4" >0.1339</td>
#       <td id="T_8c808_row0_col5" class="data row0 col5" >0.0890</td>
#       <td id="T_8c808_row0_col6" class="data row0 col6" >0.3750</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.273355
# 1    -1.673975                    0.0               1.0  0.504560  0.342198
# 2    -0.414861                    1.0               1.0  0.380000  0.349897
# 3    -1.673975                    0.0               0.0  0.290000  0.383649
# 4    -0.414861                    1.0               1.0  0.650000  0.320164
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.344402
# 131  -0.414861                    0.0               0.0  0.060521  0.344649
# 132  -0.414861                    1.0               0.0  0.274000  0.379351
# 133   1.153353                    0.0               1.0  0.422148  0.369109
# 134  -0.414861                    0.0               1.0  0.410000  0.399359
#
# [135 rows x 20 columns]
# AdaBoostRegressor
# <style type="text/css">
# </style>
# <table id="T_c5e5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5e5c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c5e5c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c5e5c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c5e5c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c5e5c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c5e5c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c5e5c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5e5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5e5c_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_c5e5c_row0_col1" class="data row0 col1" >0.0945</td>
#       <td id="T_c5e5c_row0_col2" class="data row0 col2" >0.0144</td>
#       <td id="T_c5e5c_row0_col3" class="data row0 col3" >0.1200</td>
#       <td id="T_c5e5c_row0_col4" class="data row0 col4" >0.1505</td>
#       <td id="T_c5e5c_row0_col5" class="data row0 col5" >0.0881</td>
#       <td id="T_c5e5c_row0_col6" class="data row0 col6" >0.3694</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.244776
# 1    -1.673975                    0.0               1.0  0.504560  0.346343
# 2    -0.414861                    1.0               1.0  0.380000  0.385818
# 3    -1.673975                    0.0               0.0  0.290000  0.387956
# 4    -0.414861                    1.0               1.0  0.650000  0.294952
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.362096
# 131  -0.414861                    0.0               0.0  0.060521  0.356960
# 132  -0.414861                    1.0               0.0  0.274000  0.372018
# 133   1.153353                    0.0               1.0  0.422148  0.366714
# 134  -0.414861                    0.0               1.0  0.410000  0.414638
#
# [135 rows x 20 columns]
# BaggingRegressor
# <style type="text/css">
# </style>
# <table id="T_75c23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75c23_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_75c23_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_75c23_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_75c23_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_75c23_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_75c23_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_75c23_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75c23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75c23_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_75c23_row0_col1" class="data row0 col1" >0.1001</td>
#       <td id="T_75c23_row0_col2" class="data row0 col2" >0.0154</td>
#       <td id="T_75c23_row0_col3" class="data row0 col3" >0.1243</td>
#       <td id="T_75c23_row0_col4" class="data row0 col4" >0.0881</td>
#       <td id="T_75c23_row0_col5" class="data row0 col5" >0.0912</td>
#       <td id="T_75c23_row0_col6" class="data row0 col6" >0.3818</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.263740
# 1    -1.673975                    0.0               1.0  0.504560  0.356845
# 2    -0.414861                    1.0               1.0  0.380000  0.351972
# 3    -1.673975                    0.0               0.0  0.290000  0.338394
# 4    -0.414861                    1.0               1.0  0.650000  0.323359
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.351560
# 131  -0.414861                    0.0               0.0  0.060521  0.326852
# 132  -0.414861                    1.0               0.0  0.274000  0.390328
# 133   1.153353                    0.0               1.0  0.422148  0.354685
# 134  -0.414861                    0.0               1.0  0.410000  0.387435
#
# [135 rows x 20 columns]
# AdaBoostRegressor
# <style type="text/css">
# </style>
# <table id="T_d8ce5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8ce5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d8ce5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d8ce5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d8ce5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d8ce5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d8ce5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d8ce5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8ce5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8ce5_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_d8ce5_row0_col1" class="data row0 col1" >0.1031</td>
#       <td id="T_d8ce5_row0_col2" class="data row0 col2" >0.0163</td>
#       <td id="T_d8ce5_row0_col3" class="data row0 col3" >0.1276</td>
#       <td id="T_d8ce5_row0_col4" class="data row0 col4" >0.0387</td>
#       <td id="T_d8ce5_row0_col5" class="data row0 col5" >0.0938</td>
#       <td id="T_d8ce5_row0_col6" class="data row0 col6" >0.3960</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.236959
# 1    -1.673975                    0.0               1.0  0.504560  0.359269
# 2    -0.414861                    1.0               1.0  0.380000  0.405977
# 3    -1.673975                    0.0               0.0  0.290000  0.350105
# 4    -0.414861                    1.0               1.0  0.650000  0.273630
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.378190
# 131  -0.414861                    0.0               0.0  0.060521  0.329543
# 132  -0.414861                    1.0               0.0  0.274000  0.382901
# 133   1.153353                    0.0               1.0  0.422148  0.355457
# 134  -0.414861                    0.0               1.0  0.410000  0.397196
#
# [135 rows x 20 columns]
# VotingRegressor
# <style type="text/css">
# </style>
# <table id="T_8df48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8df48_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8df48_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8df48_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8df48_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8df48_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8df48_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8df48_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8df48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8df48_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_8df48_row0_col1" class="data row0 col1" >0.0971</td>
#       <td id="T_8df48_row0_col2" class="data row0 col2" >0.0149</td>
#       <td id="T_8df48_row0_col3" class="data row0 col3" >0.1219</td>
#       <td id="T_8df48_row0_col4" class="data row0 col4" >0.1226</td>
#       <td id="T_8df48_row0_col5" class="data row0 col5" >0.0894</td>
#       <td id="T_8df48_row0_col6" class="data row0 col6" >0.3689</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.252517
# 1    -1.673975                    0.0               1.0  0.504560  0.341089
# 2    -0.414861                    1.0               1.0  0.380000  0.349908
# 3    -1.673975                    0.0               0.0  0.290000  0.368564
# 4    -0.414861                    1.0               1.0  0.650000  0.311917
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.345938
# 131  -0.414861                    0.0               0.0  0.060521  0.323783
# 132  -0.414861                    1.0               0.0  0.274000  0.363110
# 133   1.153353                    0.0               1.0  0.422148  0.366011
# 134  -0.414861                    0.0               1.0  0.410000  0.386131
#
# [135 rows x 20 columns]
# KNeighborsRegressor
# <style type="text/css">
# </style>
# <table id="T_6c8d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c8d1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6c8d1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6c8d1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6c8d1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6c8d1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6c8d1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6c8d1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c8d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c8d1_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_6c8d1_row0_col1" class="data row0 col1" >0.1009</td>
#       <td id="T_6c8d1_row0_col2" class="data row0 col2" >0.0157</td>
#       <td id="T_6c8d1_row0_col3" class="data row0 col3" >0.1253</td>
#       <td id="T_6c8d1_row0_col4" class="data row0 col4" >0.0739</td>
#       <td id="T_6c8d1_row0_col5" class="data row0 col5" >0.0919</td>
#       <td id="T_6c8d1_row0_col6" class="data row0 col6" >0.3838</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.262658
# 1    -1.673975                    0.0               1.0  0.504560  0.352162
# 2    -0.414861                    1.0               1.0  0.380000  0.356903
# 3    -1.673975                    0.0               0.0  0.290000  0.335824
# 4    -0.414861                    1.0               1.0  0.650000  0.310681
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.354147
# 131  -0.414861                    0.0               0.0  0.060521  0.322705
# 132  -0.414861                    1.0               0.0  0.274000  0.386880
# 133   1.153353                    0.0               1.0  0.422148  0.352227
# 134  -0.414861                    0.0               1.0  0.410000  0.379509
#
# [135 rows x 20 columns]
# KNeighborsRegressor
# <style type="text/css">
# </style>
# <table id="T_eabe5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eabe5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eabe5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_eabe5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_eabe5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_eabe5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_eabe5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_eabe5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eabe5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eabe5_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_eabe5_row0_col1" class="data row0 col1" >0.1009</td>
#       <td id="T_eabe5_row0_col2" class="data row0 col2" >0.0157</td>
#       <td id="T_eabe5_row0_col3" class="data row0 col3" >0.1253</td>
#       <td id="T_eabe5_row0_col4" class="data row0 col4" >0.0739</td>
#       <td id="T_eabe5_row0_col5" class="data row0 col5" >0.0919</td>
#       <td id="T_eabe5_row0_col6" class="data row0 col6" >0.3838</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.262658
# 1    -1.673975                    0.0               1.0  0.504560  0.352162
# 2    -0.414861                    1.0               1.0  0.380000  0.356903
# 3    -1.673975                    0.0               0.0  0.290000  0.335824
# 4    -0.414861                    1.0               1.0  0.650000  0.310681
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.354147
# 131  -0.414861                    0.0               0.0  0.060521  0.322705
# 132  -0.414861                    1.0               0.0  0.274000  0.386880
# 133   1.153353                    0.0               1.0  0.422148  0.352227
# 134  -0.414861                    0.0               1.0  0.410000  0.379509
#
# [135 rows x 20 columns]
# StackingRegressor
# <style type="text/css">
# </style>
# <table id="T_e23cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e23cc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e23cc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e23cc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e23cc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e23cc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e23cc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e23cc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e23cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e23cc_row0_col0" class="data row0 col0" >Stacking Regressor</td>
#       <td id="T_e23cc_row0_col1" class="data row0 col1" >0.0941</td>
#       <td id="T_e23cc_row0_col2" class="data row0 col2" >0.0148</td>
#       <td id="T_e23cc_row0_col3" class="data row0 col3" >0.1215</td>
#       <td id="T_e23cc_row0_col4" class="data row0 col4" >0.1286</td>
#       <td id="T_e23cc_row0_col5" class="data row0 col5" >0.0888</td>
#       <td id="T_e23cc_row0_col6" class="data row0 col6" >0.3440</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.233750
# 1    -1.673975                    0.0               1.0  0.504560  0.337726
# 2    -0.414861                    1.0               1.0  0.380000  0.344445
# 3    -1.673975                    0.0               0.0  0.290000  0.342298
# 4    -0.414861                    1.0               1.0  0.650000  0.302457
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.339602
# 131  -0.414861                    0.0               0.0  0.060521  0.291118
# 132  -0.414861                    1.0               0.0  0.274000  0.321588
# 133   1.153353                    0.0               1.0  0.422148  0.402405
# 134  -0.414861                    0.0               1.0  0.410000  0.392862
#
# [135 rows x 20 columns]

# %% [markdown]
# From the results above, the best models are
#
# 1. blend_5_soft
# 2. stack_10
# 3. tuned_boosted_cb
# 4. tuned_boosted_rf

# %% [markdown]
# ## 4. Save the Model

# %%
save_model(blend_5_soft, 'Blended_model_15072022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='URF',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='me...
#                                                                      n_estimators=60,
#                                                                      n_jobs=-1,
#                                                                      oob_score=False,
#                                                                      random_state=42,
#                                                                      verbose=0,
#                                                                      warm_start=False)),
#                                               ('catboost',
#                                                <catboost.core.CatBoostRegressor object at 0x00000215F7FEC670>),
#                                               ('knn',
#                                                KNeighborsRegressor(algorithm='auto',
#                                                                    leaf_size=30,
#                                                                    metric='euclidean',
#                                                                    metric_params=None,
#                                                                    n_jobs=-1,
#                                                                    n_neighbors=26,
#                                                                    p=2,
#                                                                    weights='distance'))],
#                                   n_jobs=-1, verbose=False, weights=None)]],
#           verbose=False),
#  'Blended_model_15072022.pkl')

# %%
save_model(stack_10, 'Stacked_model_15072022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='URF',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='me...
#                                                                           ccp_alpha=0.0,
#                                                                           criterion='mae',
#                                                                           max_depth=9,
#                                                                           max_features='sqrt',
#                                                                           max_leaf_nodes=None,
#                                                                           max_samples=None,
#                                                                           min_impurity_decrease=0.0001,
#                                                                           min_impurity_split=None,
#                                                                           min_samples_leaf=3,
#                                                                           min_samples_split=10,
#                                                                           min_weight_fraction_leaf=0.0,
#                                                                           n_estimators=60,
#                                                                           n_jobs=-1,
#                                                                           oob_score=False,
#                                                                           random_state=42,
#                                                                           verbose=0,
#                                                                           warm_start=False),
#                                     n_jobs=-1, passthrough=True, verbose=0)]],
#           verbose=False),
#  'Stacked_model_15072022.pkl')

# %%
save_model(tuned_boosted_cb, 'Boosted_cb_15072022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='URF',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='me...
#                   Fix_multicollinearity(correlation_with_target_preference=None,
#                                         correlation_with_target_threshold=0.0,
#                                         target_variable='URF', threshold=0.7)),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   AdaBoostRegressor(base_estimator=<catboost.core.CatBoostRegressor object at 0x00000215F8064D30>,
#                                     learning_rate=1.0, loss='linear',
#                                     n_estimators=50, random_state=42)]],
#           verbose=False),
#  'Boosted_cb_15072022.pkl')

# %%
save_model(tuned_boosted_rf, 'Boosted_rf_15072022')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='URF',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='me...
#                                                                          max_depth=9,
#                                                                          max_features='sqrt',
#                                                                          max_leaf_nodes=None,
#                                                                          max_samples=None,
#                                                                          min_impurity_decrease=0.0001,
#                                                                          min_impurity_split=None,
#                                                                          min_samples_leaf=3,
#                                                                          min_samples_split=10,
#                                                                          min_weight_fraction_leaf=0.0,
#                                                                          n_estimators=60,
#                                                                          n_jobs=-1,
#                                                                          oob_score=False,
#                                                                          random_state=42,
#                                                                          verbose=0,
#                                                                          warm_start=False),
#                                     learning_rate=1.0, loss='linear',
#                                     n_estimators=50, random_state=42)]],
#           verbose=False),
#  'Boosted_rf_15072022.pkl')

# %% [markdown]
# ## 5. Finalise the model

# %%
final_blend = finalize_model(blend_5_soft)

# %%
final_stack = finalize_model(stack_10)

# %%
final_cb = finalize_model(tuned_boosted_cb)

# %%
final_rf = finalize_model(tuned_boosted_rf)

# %% [markdown]
# ### Plots to analyse Model

# %%
model = final_blend
predict_model(model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_731ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_731ab_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_731ab_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_731ab_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_731ab_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_731ab_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_731ab_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_731ab_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_731ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_731ab_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_731ab_row0_col1" class="data row0 col1" >0.0452</td>
#       <td id="T_731ab_row0_col2" class="data row0 col2" >0.0033</td>
#       <td id="T_731ab_row0_col3" class="data row0 col3" >0.0578</td>
#       <td id="T_731ab_row0_col4" class="data row0 col4" >0.8027</td>
#       <td id="T_731ab_row0_col5" class="data row0 col5" >0.0423</td>
#       <td id="T_731ab_row0_col6" class="data row0 col6" >0.1730</td>
#     </tr>
#   </tbody>
# </table>
#      Well Spacing  Gross Pay       Swi  Oil FVFi      Temp  Permeability  \
# 0        0.602711  -0.997380  1.342416  0.615049 -0.184962     -0.777062
# 1        1.402515  -1.041017 -0.189573  1.074563  0.301265     -0.279372
# 2       -1.186079   0.794820  0.987307  0.949207  1.465668     -0.654778
# 3       -0.294680  -1.118747 -0.784482  0.628467  0.158020     -0.704353
# 4       -1.344908   1.931956 -0.521203 -1.333851 -0.328036      1.276756
# ..            ...        ...       ...       ...       ...           ...
# 130     -1.263619   1.931956  0.617352  0.541186  0.685477     -0.172917
# 131     -1.344908  -0.005199 -1.102301 -1.333851  0.005136      1.902584
# 132     -0.294680  -1.314870  0.227689 -0.845153 -0.328036      1.757420
# 133     -0.810540  -1.279495 -1.102301 -0.036777 -1.443602     -0.757408
# 134      0.602711   1.109476 -0.819347 -1.333851  2.128427      1.826020
#
#      API Gravity  Viscosity      OOIP  Major Gas Cap  Geologic Play  \
# 0       0.917657  -0.391974 -0.073592      -0.530323      -1.150668
# 1       0.917657  -0.413451 -0.615333       5.219486      -1.154283
# 2      -0.303106  -0.407896 -1.057891      -0.530323       0.008801
# 3       0.058473  -0.376108 -0.615333      -0.530323      -1.168779
# 4      -1.408754   0.186547  1.946271      -0.530323      -0.005210
# ..           ...        ...       ...            ...            ...
# 130    -0.519274  -0.362942  2.235092      -0.530323       0.008801
# 131    -2.366800   3.449037  2.154622      -0.530323       0.018079
# 132    -1.582771   2.186584 -1.069115      -0.530323       1.686849
# 133     1.404480  -0.328901 -1.105840      -0.530323       1.295368
# 134    -0.303106  -0.423079  0.535967       1.766413       0.008801
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.067872              1.783713        -0.455652      -0.686846
# 1             1.625201             -0.740646        -0.455652      -0.686846
# 2            -0.041225             -0.740646        -0.455652      -0.686846
# 3            -0.859795             -0.740646        -0.455652      -0.686846
# 4            -0.041225             -0.740646         2.217926       1.694416
# ..                 ...                   ...              ...            ...
# 130          -0.041225             -0.740646        -0.455652      -0.686846
# 131           0.217763              1.826869         2.127502       1.694416
# 132          -0.889504             -0.740646        -0.455652      -0.686846
# 133          -0.889504             -0.740646        -0.455652      -0.686846
# 134          -0.041225             -0.740646        -0.455652      -0.686846
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0    -1.673975                    0.0               0.0  0.250000  0.257105
# 1    -1.673975                    0.0               1.0  0.504560  0.450866
# 2    -0.414861                    1.0               1.0  0.380000  0.352758
# 3    -1.673975                    0.0               0.0  0.290000  0.340732
# 4    -0.414861                    1.0               1.0  0.650000  0.479340
# ..         ...                    ...               ...       ...       ...
# 130  -0.414861                    1.0               1.0  0.370000  0.356265
# 131  -0.414861                    0.0               0.0  0.060521  0.165119
# 132  -0.414861                    1.0               0.0  0.274000  0.302048
# 133   1.153353                    0.0               1.0  0.422148  0.394699
# 134  -0.414861                    0.0               1.0  0.410000  0.397363
#
# [135 rows x 20 columns]

# %%
plot_model(model)

# %%
# Prediction Error 
plot_model(model, plot = 'error')

# %%
# Cooks Distance Plot
plot_model(model, plot='cooks')

# %%
# Learning Curve
plot_model(model, plot='learning')

# %%
# Manifold Learning
plot_model(model, plot='manifold')

# %%
# Model Hyperparameter
plot_model(model, plot='parameter')
# Out:
#                                                    Parameters
# estimators  [('rf', RandomForestRegressor(bootstrap=False,...
# n_jobs                                                     -1
# verbose                                                 False
# weights                                                  None

# %% [markdown]
# ## 6. Blind Test

# %%
dfblind = pd.read_excel("BlindTest_SSOIL.xlsx", thousands=',', skiprows = skiprows)
#dfblind = dfblind.loc[:, ~df.columns.str.contains('^Unnamed')] 
dfblind.head()
# Out:
#    Lithology Code  Well Spacing  Net Pay Pay  Gross Pay  Porosity   Swi  \
# 0               1       20.0000          8.6       12.0      30.0  32.0
# 1               1       10.0000         10.0       60.0      25.0  40.0
# 2               1       20.0000         11.0      110.0      28.0  25.0
# 3               1       10.0000        190.0      480.0      27.0  22.0
# 4               1        2.3662        556.0     1500.0      25.5  20.0
#
#    Oil FVFi  Temp  Permeability  API Gravity  ...  Fractured Faulted  \
# 0     1.100   118        1200.0         17.0  ...                  1
# 1     1.100   110        1500.0         34.0  ...                  0
# 2     1.060   125        1500.0         20.0  ...                  0
# 3     1.140   146         430.0         23.5  ...                  0
# 4     1.311   190          58.0         27.7  ...                  0
#
#    Shale Breaks  Major Gas Cap  Geologic Play  Deposition System  \
# 0             0              0           2407                151
# 1             1              0           2407                151
# 2             1              1           2407                151
# 3             0              0            418                181
# 4             1              0            414                181
#
#    Diagenetic Overprint  Structural Comp  Heterogeniety  Trap Type       URF
# 0                     1               10              1          2  0.274000
# 1                     1               10              1          1  0.360000
# 2                     1               10              1          2  0.320000
# 3                     1               10              1          2  0.258000
# 4                     1               30              3          2  0.309771
#
# [5 rows x 24 columns]

# %%
BlindPredict = predict_model(final_blend, data=dfblind, round=2)

# %%
BlindPredict
# Out:
#     Lithology Code  Well Spacing  Net Pay Pay  Gross Pay  Porosity   Swi  \
# 0                1       20.0000          8.6       12.0      30.0  32.0
# 1                1       10.0000         10.0       60.0      25.0  40.0
# 2                1       20.0000         11.0      110.0      28.0  25.0
# 3                1       10.0000        190.0      480.0      27.0  22.0
# 4                1        2.3662        556.0     1500.0      25.5  20.0
# ..             ...           ...          ...        ...       ...   ...
# 80               1       40.0000         40.0      520.0      14.7  21.0
# 81               1       10.0000         71.0      100.0      19.0  33.5
# 82               1       20.0000        150.0      250.0      10.3  10.0
# 83               1       20.0000        105.0      300.0      16.3  11.5
# 84               1      640.0000         60.0      160.0       7.0  20.0
#
#     Oil FVFi  Temp  Permeability  API Gravity  ...  Shale Breaks  \
# 0      1.100   118        1200.0         17.0  ...             0
# 1      1.100   110        1500.0         34.0  ...             1
# 2      1.060   125        1500.0         20.0  ...             1
# 3      1.140   146         430.0         23.5  ...             0
# 4      1.311   190          58.0         27.7  ...             1
# ..       ...   ...           ...          ...  ...           ...
# 80     1.700   140          34.0         47.0  ...             0
# 81     1.130   100          52.0         37.0  ...             0
# 82     1.126   165          20.0         34.0  ...             0
# 83     1.050   125         190.0         25.0  ...             0
# 84     1.010   148           6.0         26.0  ...             0
#
#     Major Gas Cap  Geologic Play  Deposition System  Diagenetic Overprint  \
# 0               0           2407                151                     1
# 1               0           2407                151                     1
# 2               1           2407                151                     1
# 3               0            418                181                     1
# 4               0            414                181                     1
# ..            ...            ...                ...                   ...
# 80              1            704                110                     1
# 81              0            831                151                     1
# 82              0            825                110                     1
# 83              0            825                110                     1
# 84              0            824                222                     4
#
#     Structural Comp  Heterogeniety  Trap Type       URF     Label
# 0                10              1          2  0.274000  0.302048
# 1                10              1          1  0.360000  0.408779
# 2                10              1          2  0.320000  0.385504
# 3                10              1          2  0.258000  0.329302
# 4                30              3          2  0.309771  0.358089
# ..              ...            ...        ...       ...       ...
# 80               10              1          1  0.470000  0.395405
# 81               31              1          2  0.470000  0.427398
# 82               31              1          2  0.450000  0.406115
# 83               31              1          2  0.400000  0.398105
# 84               20              1          3  0.176548  0.225953
#
# [85 rows x 25 columns]

# %%
a = BlindPredict['URF']
b = BlindPredict['Label']

plt.figure(figsize=(14, 8))
plt.scatter(a, b, color='blue')
plt.plot(a, a, color = 'red', label = 'x=y')
plt.xlabel("Recovery Factor (%)", size=14)
plt.ylabel("Evaluated Recovery Factor (%)", size=14)

#plt.tight_layout()
plt.show()

# %%
count = 'Completed Process'
elapsed = (time.time() - start)
print ("%s in %s seconds" % (count,elapsed))
# Out:
# Completed Process in 1988.906864643097 seconds
