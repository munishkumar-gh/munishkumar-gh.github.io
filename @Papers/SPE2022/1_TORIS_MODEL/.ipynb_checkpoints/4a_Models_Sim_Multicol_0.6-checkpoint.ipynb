# %% [markdown]
# <a href="https://www.spe.org/events/en/2022/conference/22apog/asia-pacific-oil-and-gas-conference-and-exhibition.html"><img src = "https://www.spe.org/binaries/content/gallery/specms/speevents/organization-logos/spe-logo-2020.png" width = 200>
#
# <h1 align=center><font size = 5>Prediction of Recovery Factor using Machine Learning Methods</font></h1>

# %% [markdown]
# <h1 align=center><font size = 4> Munish Kumar, Kannapan Swaminathan</font></h1>
# <h1 align=center><font size = 4> Part 4a: Simplified Experiment</font></h1>
# <h1 align=center><font size = 3> ERCE 2022 </font></h1>

# %% [markdown]
# ###### References

# %% [markdown]
# 1. https://www.kaggle.com/code/kkhandekar/an-introduction-to-pycaret/notebook.
# 2. https://towardsdatascience.com/5-things-you-dont-know-about-pycaret-528db0436eec
# 3. https://www.dataquest.io/blog/understanding-regression-error-metrics/
# 4. https://www.analyticsvidhya.com/blog/2021/07/automl-using-pycaret-with-a-regression-use-case/
# 5. https://www.datacamp.com/community/tutorials/guide-for-automating-ml-workflows-using-pycaret
# 6. https://pycaret.readthedocs.io/en/latest/api/regression.html
# 7. http://www.pycaret.org/tutorials/html/REG102.html
# 8. https://githubhelp.com/ray-project/tune-sklearn

# %% [markdown]
# ## Check PyCaret Version

# %%
from pycaret.utils import version

# %%
version()
# Out:
# '2.3.6'

# %% [markdown]
# #### Libraries

# %%
# Only install the following libraries if you dont have it, otherwise leave it commented out

#!conda install -c anaconda natsort --yes
#!conda install -c anaconda xlrd --yes

#!pip install natsort --user
#!pip install xlrd --user
#!pip install pycaret[full] --user
#!pip install mlflow --user
#!pip install tune-sklearn ray[tune] --user
#!pip install optuna -- user
#!pip install hyperopt --user
#!pip install redis --user

# General Libraries
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import NullFormatter
import time
import re
import requests
import pickle
import seaborn as sns
import os
import glob
import sys
from natsort import natsorted
sns.set()

import plotly.graph_objects as go
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# Sklearn Liraries
from sklearn import preprocessing

import datetime
from datetime import timedelta, date 
start = time.time()
# %matplotlib inline

import ray
from ray import tune

# Forces the print statement to show everything and not truncate
# np.set_printoptions(threshold=sys.maxsize) 
print('Libraries imported')
# Out:
# Libraries imported

# %%
#Receive Data
#dir_name = r'C:\Users\kswaminathan\OneDrive\01_KannaLibrary\15_Analogs'
#dir_name = r'C:\Users\mkumar\Documents\GitHub\@Papers\SPE2022\Final'
dir_name = r'C:\Users\mkumar\Documents\GitHub\@Papers\SPE2022\Final\1_TORIS_MODEL'
filename_suffix = 'csv'

# %% [markdown]
# ##### Read in the data

# %%
skiprows = 0
#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
df = pd.read_excel("dftorisv2.xlsx", thousands=',', skiprows = skiprows)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')] 
df.head()
# Out:
#    Lithology Code  Well Spacing  Net Pay Pay  Gross Pay  Porosity      Swi  \
# 0               1         120.0        320.0      600.0      14.0  40.0000
# 1               1         160.0        100.0      160.0      18.1  35.0000
# 2               1         160.0        100.0      300.0      15.7  51.6333
# 3               1          80.0        350.0     1400.0      13.0  30.0000
# 4               1         160.0        194.0      550.0      23.0  35.0000
#
#    Oil FVFi  Temp  Permeability  API Gravity  ...  Fractured Faulted  \
# 0     1.586   153          10.0         41.0  ...                  0
# 1     1.230   163          65.0         35.6  ...                  0
# 2     1.190   185         102.0         32.9  ...                  0
# 3     1.230   153           3.0         35.0  ...                  1
# 4     1.380   200         450.0         27.0  ...                  1
#
#    Shale Breaks  Major Gas Cap  Geologic Play  Deposition System  \
# 0             0              0            303                132
# 1             0              0            303                132
# 2             1              0            303                132
# 3             1              0            303                131
# 4             1              1            302                131
#
#    Diagenetic Overprint  Structural Comp  Heterogeniety  Trap Type       URF
# 0                     1               10              1          2  0.352836
# 1                     1               10              1          2  0.321570
# 2                     1               10              1          2  0.277514
# 3                     1               10              1          2  0.380000
# 4                     7               10              1          3  0.425909
#
# [5 rows x 24 columns]

# %% [markdown]
# # Plot as Heat map to check for highly correlated variables
# plt.figure(figsize=(15, 15))
# ax = sns.heatmap(df.corr(), annot=True, fmt=".2f")

# %% [markdown]
# In observing the heat map above, I define highly correlated variables as having collinearity coeeficients of > 0.7. There was no highly correlated values

# %% [markdown]
# ##### Convert to float - to ensure it is a numerical feature

# %%
df_drop = df.copy()
df_drop = df_drop[df_drop['URF']<0.51].astype(float)
df_drop = df_drop.astype(float)

# Confirm properties of final dataframe
print(len(df_drop))
print(df_drop.info())
print(df_drop.describe(include='all'))
print(df_drop.columns.values)
# Out:
# 389
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 448
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Lithology Code        389 non-null    float64
#  1   Well Spacing          389 non-null    float64
#  2   Net Pay Pay           389 non-null    float64
#  3   Gross Pay             389 non-null    float64
#  4   Porosity              389 non-null    float64
#  5   Swi                   389 non-null    float64
#  6   Oil FVFi              389 non-null    float64
#  7   Temp                  389 non-null    float64
#  8   Permeability          389 non-null    float64
#  9   API Gravity           389 non-null    float64
#  10  Viscosity             389 non-null    float64
#  11  OOIP                  389 non-null    float64
#  12  Initial GOR           389 non-null    float64
#  13  Pressure Initial      389 non-null    float64
#  14  Fractured Faulted     389 non-null    float64
#  15  Shale Breaks          389 non-null    float64
#  16  Major Gas Cap         389 non-null    float64
#  17  Geologic Play         389 non-null    float64
#  18  Deposition System     389 non-null    float64
#  19  Diagenetic Overprint  389 non-null    float64
#  20  Structural Comp       389 non-null    float64
#  21  Heterogeniety         389 non-null    float64
#  22  Trap Type             389 non-null    float64
#  23  URF                   389 non-null    float64
# dtypes: float64(24)
# memory usage: 76.0 KB
# None
#        Lithology Code  Well Spacing  Net Pay Pay    Gross Pay    Porosity  \
# count      389.000000    389.000000    389.00000   389.000000  389.000000
# mean         1.370180     35.596521    105.23419   265.815476   18.901748
# std          0.548414     48.309240    169.12706   356.222093    8.386664
# min          1.000000      0.888626      5.00000    10.000000    3.000000
# 25%          1.000000     10.000000     24.00000    50.000000   12.000000
# 50%          1.000000     20.000000     50.00000   150.000000   17.600000
# 75%          2.000000     40.000000    122.00000   300.000000   25.000000
# max          3.000000    640.000000   2300.00000  2300.000000   51.000000
#
#               Swi    Oil FVFi        Temp  Permeability  API Gravity  ...  \
# count  389.000000  389.000000  389.000000    389.000000   389.000000  ...
# mean    30.811191    1.246868  137.709512    400.614239    32.053008  ...
# std      9.800326    0.198589   43.918392   1507.468685     8.795249  ...
# min     10.000000    1.000000   63.000000      0.100000     6.000000  ...
# 25%     25.000000    1.099000  105.000000     10.000000    27.000000  ...
# 50%     30.000000    1.200000  130.000000     52.000000    34.000000  ...
# 75%     36.000000    1.330000  164.000000    300.000000    38.000000  ...
# max     68.000000    2.127000  266.000000  26816.500000    52.000000  ...
#
#        Fractured Faulted  Shale Breaks  Major Gas Cap  Geologic Play  \
# count         389.000000    389.000000     389.000000     389.000000
# mean            0.341902      0.604113       3.488432     623.172237
# std             0.474958      0.489670      45.908448     713.036410
# min             0.000000      0.000000       0.000000       6.000000
# 25%             0.000000      0.000000       0.000000      44.000000
# 50%             0.000000      1.000000       0.000000     414.000000
# 75%             1.000000      1.000000       0.000000     830.000000
# max             1.000000      1.000000     680.000000    2417.000000
#
#        Deposition System  Diagenetic Overprint  Structural Comp  \
# count         389.000000            389.000000       389.000000
# mean          183.660668              2.244216        13.732648
# std            37.931952              2.141754         8.621807
# min           110.000000              1.000000        10.000000
# 25%           152.000000              1.000000        10.000000
# 50%           181.000000              1.000000        10.000000
# 75%           222.000000              3.000000        10.000000
# max           270.000000              9.000000        50.000000
#
#        Heterogeniety   Trap Type         URF
# count     389.000000  389.000000  389.000000
# mean        1.408740    2.236504    0.315459
# std         0.638156    0.666275    0.105761
# min         1.000000    1.000000    0.024000
# 25%         1.000000    2.000000    0.250000
# 50%         1.000000    2.000000    0.311000
# 75%         2.000000    3.000000    0.400000
# max         3.000000    3.000000    0.507298
#
# [8 rows x 24 columns]
# ['Lithology Code' 'Well Spacing' 'Net Pay Pay' 'Gross Pay' 'Porosity'
#  'Swi' 'Oil FVFi' 'Temp' 'Permeability' 'API Gravity' 'Viscosity' 'OOIP'
#  'Initial GOR' 'Pressure Initial' 'Fractured Faulted' 'Shale Breaks'
#  'Major Gas Cap' 'Geologic Play' 'Deposition System'
#  'Diagenetic Overprint' 'Structural Comp' 'Heterogeniety' 'Trap Type'
#  'URF']

# %% [markdown]
# Final Data set has 450 rows and 24 columns.

# %% [markdown]
# ### Train, Validation, and Test Split

# %% [markdown]
# # Creates a mask where values that are true go into the training/test set
# # Note that I done it so that the random number is predictable
#
# msk = np.random.seed(0)
# msk = np.random.rand(len(df_drop))<0.8
#
# raw_train_validate_set = df_drop[msk]
# raw_test_set = df_drop[~msk]
#
# print(raw_train_validate_set.shape)
# print(raw_test_set.shape)

# %% [markdown]
# raw_train_validate_set.to_excel(r'dfssoil.xlsx', index = False, header=True)
# raw_test_set.to_excel(r'BlindTest_SSOIL.xlsx', index = False, header=True)

# %% [markdown]
# We split the data set 80-20 into a "train-validate" set and a "test" set. The test set is external asn will never be seen by the model.

# %% [markdown]
# ## 1. Pycaret Implementation

# %% [markdown]
# Pycaret will be used in the machine learning portion. Pycaret is a low-code machine learning library in Python that automates machine learning workflows. One of its key benefits is its ability to run a large number of differnt machine learning algorithms, but with only a few lines of code

# %%
skiprows = 0
#Means read in the ',' as thousand seperator. Also drops all columns which are unnamed.
df = pd.read_excel("dfssoil.xlsx", thousands=',', skiprows = skiprows)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')] 
df.head()
# Out:
#    Lithology Code  Well Spacing  Net Pay Pay  Gross Pay  Porosity      Swi  \
# 0               1         120.0        320.0      600.0      14.0  40.0000
# 1               1         160.0        100.0      160.0      18.1  35.0000
# 2               1         160.0        100.0      300.0      15.7  51.6333
# 3               1          80.0        350.0     1400.0      13.0  30.0000
# 4               1         160.0        194.0      550.0      23.0  35.0000
#
#    Oil FVFi  Temp  Permeability  API Gravity  ...  Fractured Faulted  \
# 0     1.586   153          10.0         41.0  ...                  0
# 1     1.230   163          65.0         35.6  ...                  0
# 2     1.190   185         102.0         32.9  ...                  0
# 3     1.230   153           3.0         35.0  ...                  1
# 4     1.380   200         450.0         27.0  ...                  1
#
#    Shale Breaks  Major Gas Cap  Geologic Play  Deposition System  \
# 0             0              0            303                132
# 1             0              0            303                132
# 2             1              0            303                132
# 3             1              0            303                131
# 4             1              1            302                131
#
#    Diagenetic Overprint  Structural Comp  Heterogeniety  Trap Type       URF
# 0                     1               10              1          2  0.352836
# 1                     1               10              1          2  0.321570
# 2                     1               10              1          2  0.277514
# 3                     1               10              1          2  0.380000
# 4                     7               10              1          3  0.425909
#
# [5 rows x 24 columns]

# %%
from pycaret.regression import *

#Create a copy
model_df = df_drop.copy()
target = 'URF'

# no resampling
clf_none = setup(
            data=model_df,
            target=target,
            session_id=42,
            normalize=True,
            transformation = True,
            ignore_low_variance=True,
            remove_outliers = True, #outliers_threshold = 0.2,
            #remove_multicollinearity = True, multicollinearity_threshold = 0.6,
            train_size=0.7)
# Out:
# <style type="text/css">
# #T_e00e5_row27_col1, #T_e00e5_row29_col1, #T_e00e5_row34_col1, #T_e00e5_row38_col1, #T_e00e5_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e00e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e00e5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e00e5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e00e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e00e5_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e00e5_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e00e5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e00e5_row1_col1" class="data row1 col1" >URF</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e00e5_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_e00e5_row2_col1" class="data row2 col1" >(389, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e00e5_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_e00e5_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e00e5_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_e00e5_row4_col1" class="data row4 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e00e5_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_e00e5_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e00e5_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_e00e5_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e00e5_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_e00e5_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e00e5_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_e00e5_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e00e5_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_e00e5_row9_col1" class="data row9 col1" >(258, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e00e5_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_e00e5_row10_col1" class="data row10 col1" >(117, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e00e5_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_e00e5_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e00e5_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_e00e5_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e00e5_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_e00e5_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e00e5_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_e00e5_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e00e5_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_e00e5_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e00e5_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_e00e5_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e00e5_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_e00e5_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e00e5_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_e00e5_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e00e5_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_e00e5_row19_col1" class="data row19 col1" >0097</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e00e5_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_e00e5_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e00e5_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_e00e5_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e00e5_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_e00e5_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e00e5_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_e00e5_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e00e5_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_e00e5_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e00e5_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_e00e5_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_e00e5_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_e00e5_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_e00e5_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_e00e5_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_e00e5_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_e00e5_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_e00e5_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_e00e5_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e00e5_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_e00e5_row30_col0" class="data row

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_82181 th {
#   text-align: left;
# }
# #T_82181_row0_col0, #T_82181_row0_col1, #T_82181_row0_col6, #T_82181_row1_col0, #T_82181_row1_col1, #T_82181_row1_col2, #T_82181_row1_col3, #T_82181_row1_col4, #T_82181_row1_col5, #T_82181_row1_col6, #T_82181_row2_col0, #T_82181_row2_col2, #T_82181_row2_col3, #T_82181_row2_col4, #T_82181_row2_col5, #T_82181_row3_col0, #T_82181_row3_col1, #T_82181_row3_col2, #T_82181_row3_col3, #T_82181_row3_col4, #T_82181_row3_col5, #T_82181_row3_col6, #T_82181_row4_col0, #T_82181_row4_col1, #T_82181_row4_col2, #T_82181_row4_col3, #T_82181_row4_col4, #T_82181_row4_col5, #T_82181_row4_col6, #T_82181_row5_col0, #T_82181_row5_col1, #T_82181_row5_col2, #T_82181_row5_col3, #T_82181_row5_col4, #T_82181_row5_col5, #T_82181_row5_col6, #T_82181_row6_col0, #T_82181_row6_col1, #T_82181_row6_col2, #T_82181_row6_col3, #T_82181_row6_col4, #T_82181_row6_col5, #T_82181_row6_col6, #T_82181_row7_col0, #T_82181_row7_col1, #T_82181_row7_col2, #T_82181_row7_col3, #T_82181_row7_col4, #T_82181_row7_col5, #T_82181_row7_col6, #T_82181_row8_col0, #T_82181_row8_col1, #T_82181_row8_col2, #T_82181_row8_col3, #T_82181_row8_col4, #T_82181_row8_col5, #T_82181_row8_col6, #T_82181_row9_col0, #T_82181_row9_col1, #T_82181_row9_col2, #T_82181_row9_col3, #T_82181_row9_col4, #T_82181_row9_col5, #T_82181_row9_col6, #T_82181_row10_col0, #T_82181_row10_col1, #T_82181_row10_col2, #T_82181_row10_col3, #T_82181_row10_col4, #T_82181_row10_col5, #T_82181_row10_col6, #T_82181_row11_col0, #T_82181_row11_col1, #T_82181_row11_col2, #T_82181_row11_col3, #T_82181_row11_col4, #T_82181_row11_col5, #T_82181_row11_col6, #T_82181_row12_col0, #T_82181_row12_col1, #T_82181_row12_col2, #T_82181_row12_col3, #T_82181_row12_col4, #T_82181_row12_col5, #T_82181_row12_col6, #T_82181_row13_col0, #T_82181_row13_col1, #T_82181_row13_col2, #T_82181_row13_col3, #T_82181_row13_col4, #T_82181_row13_col5, #T_82181_row13_col6, #T_82181_row14_col0, #T_82181_row14_col1, #T_82181_row14_col2, #T_82181_row14_col3, #T_82181_row14_col4, #T_82181_row14_col5, #T_82181_row14_col6, #T_82181_row15_col0, #T_82181_row15_col1, #T_82181_row15_col2, #T_82181_row15_col3, #T_82181_row15_col4, #T_82181_row15_col5, #T_82181_row15_col6, #T_82181_row16_col0, #T_82181_row16_col1, #T_82181_row16_col2, #T_82181_row16_col3, #T_82181_row16_col4, #T_82181_row16_col5, #T_82181_row16_col6, #T_82181_row17_col0, #T_82181_row17_col1, #T_82181_row17_col2, #T_82181_row17_col3, #T_82181_row17_col4, #T_82181_row17_col5, #T_82181_row17_col6, #T_82181_row18_col0, #T_82181_row18_col1, #T_82181_row18_col2, #T_82181_row18_col3, #T_82181_row18_col4, #T_82181_row18_col5, #T_82181_row18_col6, #T_82181_row19_col0, #T_82181_row19_col1, #T_82181_row19_col2, #T_82181_row19_col3, #T_82181_row19_col4, #T_82181_row19_col5, #T_82181_row19_col6 {
#   text-align: left;
# }
# #T_82181_row0_col2, #T_82181_row0_col3, #T_82181_row0_col4, #T_82181_row0_col5, #T_82181_row2_col1, #T_82181_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_82181_row0_col7, #T_82181_row1_col7, #T_82181_row2_col7, #T_82181_row3_col7, #T_82181_row4_col7, #T_82181_row5_col7, #T_82181_row6_col7, #T_82181_row7_col7, #T_82181_row8_col7, #T_82181_row9_col7, #T_82181_row10_col7, #T_82181_row11_col7, #T_82181_row12_col7, #T_82181_row14_col7, #T_82181_row15_col7, #T_82181_row16_col7, #T_82181_row17_col7, #T_82181_row18_col7, #T_82181_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_82181_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_82181">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82181_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_82181_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_82181_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_82181_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_82181_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_82181_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_82181_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_82181_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82181_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_82181_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_82181_row0_col1" class="data row0 col1" >0.0791</td>
#       <td id="T_82181_row0_col2" class="data row0 col2" >0.0096</td>
#       <td id="T_82181_row0_col3" class="data row0 col3" >0.0976</td>
#       <td id="T_82181_row0_col4" class="data row0 col4" >0.0949</td>
#       <td id="T_82181_row0_col5" class="data row0 col5" >0.0754</td>
#       <td id="T_82181_row0_col6" class="data row0 col6" >0.3462</td>
#       <td id="T_82181_row0_col7" class="data row0 col7" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_82181_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_82181_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_82181_row1_col1" class="data row1 col1" >0.0813</td>
#       <td id="T_82181_row1_col2" class="data row1 col2" >0.0100</td>
#       <td id="T_82181_row1_col3" class="data row1 col3" >0.0994</td>
#       <td id="T_82181_row1_col4" class="data row1 col4" >0.0741</td>
#       <td id="T_82181_row1_col5" class="data row1 col5" >0.0768</td>
#       <td id="T_82181_row1_col6" class="data row1 col6" >0.3650</td>
#       <td id="T_82181_row1_col7" class="data row1 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_82181_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_82181_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_82181_row2_col1" class="data row2 col1" >0.0789</td>
#       <td id="T_82181_row2_col2" class="data row2 col2" >0.0100</td>
#       <td id="T_82181_row2_col3" class="data row2 col3" >0.0993</td>
#       <td id="T_82181_row2_col4" class="data row2 col4" >0.0605</td>
#       <td id="T_82181_row2_col5" class="data row2 col5" >0.0766</td>
#       <td id="T_82181_row2_col6" class="data row2 col6" >0.3433</td>
#       <td id="T_82181_row2_col7" class="data row2 col7" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_82181_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_82181_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_82181_row3_col1" class="data row3 col1" >0.0820</td>
#       <td id="T_82181_row3_col2" class="data row3 col2" >0.0101</td>
#       <td id="T_82181_row3_col3" class="data row3 col3" >0.1001</td>
#       <td id="T_82181_row3_col4" class="data row3 col4" >0.0558</td>
#       <td id="T_82181_row3_col5" class="data row3 col5" >0.0774</td>
#       <td id="T_82181_row3_col6" class="data row3 col6" >0.3669</td>
#       <td id="T_82181_row3_col7" class="data row3 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_82181_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_82181_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#       <td id="T_82181_row4_col1" class="data row4 col1" >0.0821</td>
#       <td id="T_82181_row4_col2" class="data row4 col2" >0.0104</td>
#       <td id="T_82181_row4_col3" class="data row4 col3" >0.1015</td>
#       <td id="T_82181_row4_col4" class="data row4 col4" >0.0201</td>
#       <td id="T_82181_row4_col5" class="data row4 col5" >0.0782</td>
#       <td id="T_82181_row4_col6" class="data row4 col6" >0.3553</td>
#       <td id="T_82181_row4_col7" class="data row4 col7" >0.5480</td>
#     </tr>
#     <tr>
#       <th id="T_82181_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_82181_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_82181_row5_col1" class="data row5 col1" >0.0840</td>
#       <td id="T_82181_row5_col2" class="data row5 col2" >0.0106</td>
#       <td id="T_82181_row5_col3" class="data row5 col3" >0.1024</td>
#       <td i

# %% [markdown]
# top3 = compare_models(include=['rf', 'catboost', 'knn'], fold = 10, sort='MAE')

# %% [markdown]
# There is a performance improvement in going from 5 folds to 10 folds for all 3 models. To keep computation time reasonable, folds is kept at 10.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3. Optimisation

# %% [markdown]
# ### a. Tune the Model

# %%
tuned_models = []

# %%
rf = create_model('rf', fold = 10)
# rf = tune_model(rf, 
#                 #optimize = 'R2', 
#                 #n_iter = 10, 
#                 #choose_better = True, 
#                  #search_library = "tune-sklearn", 
#                  #search_algorithm="Hyperopt",
#                  #search_algorithm="Optuna",
#                  #search_algorithm="bayesian",
#                 )
tuned_models.append(rf)
# Out:
# <style type="text/css">
# #T_eccc6_row10_col0, #T_eccc6_row10_col1, #T_eccc6_row10_col2, #T_eccc6_row10_col3, #T_eccc6_row10_col4, #T_eccc6_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_eccc6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eccc6_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_eccc6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_eccc6_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_eccc6_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_eccc6_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_eccc6_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eccc6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eccc6_row0_col0" class="data row0 col0" >0.0719</td>
#       <td id="T_eccc6_row0_col1" class="data row0 col1" >0.0070</td>
#       <td id="T_eccc6_row0_col2" class="data row0 col2" >0.0838</td>
#       <td id="T_eccc6_row0_col3" class="data row0 col3" >0.2708</td>
#       <td id="T_eccc6_row0_col4" class="data row0 col4" >0.0643</td>
#       <td id="T_eccc6_row0_col5" class="data row0 col5" >0.2783</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eccc6_row1_col0" class="data row1 col0" >0.0820</td>
#       <td id="T_eccc6_row1_col1" class="data row1 col1" >0.0098</td>
#       <td id="T_eccc6_row1_col2" class="data row1 col2" >0.0992</td>
#       <td id="T_eccc6_row1_col3" class="data row1 col3" >0.1249</td>
#       <td id="T_eccc6_row1_col4" class="data row1 col4" >0.0754</td>
#       <td id="T_eccc6_row1_col5" class="data row1 col5" >0.3083</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eccc6_row2_col0" class="data row2 col0" >0.0871</td>
#       <td id="T_eccc6_row2_col1" class="data row2 col1" >0.0103</td>
#       <td id="T_eccc6_row2_col2" class="data row2 col2" >0.1017</td>
#       <td id="T_eccc6_row2_col3" class="data row2 col3" >0.1094</td>
#       <td id="T_eccc6_row2_col4" class="data row2 col4" >0.0802</td>
#       <td id="T_eccc6_row2_col5" class="data row2 col5" >0.4517</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eccc6_row3_col0" class="data row3 col0" >0.0764</td>
#       <td id="T_eccc6_row3_col1" class="data row3 col1" >0.0093</td>
#       <td id="T_eccc6_row3_col2" class="data row3 col2" >0.0965</td>
#       <td id="T_eccc6_row3_col3" class="data row3 col3" >-0.0422</td>
#       <td id="T_eccc6_row3_col4" class="data row3 col4" >0.0718</td>
#       <td id="T_eccc6_row3_col5" class="data row3 col5" >0.2345</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eccc6_row4_col0" class="data row4 col0" >0.0689</td>
#       <td id="T_eccc6_row4_col1" class="data row4 col1" >0.0082</td>
#       <td id="T_eccc6_row4_col2" class="data row4 col2" >0.0904</td>
#       <td id="T_eccc6_row4_col3" class="data row4 col3" >0.2823</td>
#       <td id="T_eccc6_row4_col4" class="data row4 col4" >0.0719</td>
#       <td id="T_eccc6_row4_col5" class="data row4 col5" >0.4067</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eccc6_row5_col0" class="data row5 col0" >0.0946</td>
#       <td id="T_eccc6_row5_col1" class="data row5 col1" >0.0122</td>
#       <td id="T_eccc6_row5_col2" class="data row5 col2" >0.1103</td>
#       <td id="T_eccc6_row5_col3" class="data row5 col3" >-0.0124</td>
#       <td id="T_eccc6_row5_col4" class="data row5 col4" >0.0855</td>
#       <td id="T_eccc6_row5_col5" class="data row5 col5" >0.4212</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eccc6_row6_col0" class="data row6 col0" >0.0921</td>
#       <td id="T_eccc6_row6_col1" class="data row6 col1" >0.0116</td>
#       <td id="T_eccc6_row6_col2" class="data row6 col2" >0.1075</td>
#       <td id="T_eccc6_row6_col3" class="data row6 col3" >0.0897</td>
#       <td id="T_eccc6_row6_col4" class="data row6 col4" >0.0828</td>
#       <td id="T_eccc6_row6_col5" class="data row6 col5" >0.3932</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eccc6_row7_col0" class="data row7 col0" >0.0743</td>
#       <td id="T_eccc6_row7_col1" class="data row7 col1" >0.0088</td>
#       <td id="T_eccc6_row7_col2" class="data row7 col2" >0.0939</td>
#       <td id="T_eccc6_row7_col3" class="data row7 col3" >0.1147</td>
#       <td id="T_eccc6_row7_col4" class="data row7 col4" >0.0719</td>
#       <td id="T_eccc6_row7_col5" class="data row7 col5" >0.3066</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eccc6_row8_col0" class="data row8 col0" >0.0744</td>
#       <td id="T_eccc6_row8_col1" class="data row8 col1" >0.0091</td>
#       <td id="T_eccc6_row8_col2" class="data row8 col2" >0.0954</td>
#       <td id="T_eccc6_row8_col3" class="data row8 col3" >0.2563</td>
#       <td id="T_eccc6_row8_col4" class="data row8 col4" >0.0757</td>
#       <td id="T_eccc6_row8_col5" class="data row8 col5" >0.4663</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eccc6_row9_col0" class="data row9 col0" >0.0701</td>
#       <td id="T_eccc6_row9_col1" class="data row9 col1" >0.0077</td>
#       <td id="T_eccc6_row9_col2" class="data row9 col2" >0.0876</td>
#       <td id="T_eccc6_row9_col3" class="data row9 col3" >0.0247</td>
#       <td id="T_eccc6_row9_col4" class="data row9 col4" >0.0673</td>
#       <td id="T_eccc6_row9_col5" class="data row9 col5" >0.2739</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_eccc6_row10_col0" class="data row10 col0" >0.0792</td>
#       <td id="T_eccc6_row10_col1" class="data row10 col1" >0.0094</td>
#       <td id="T_eccc6_row10_col2" class="data row10 col2" >0.0966</td>
#       <td id="T_eccc6_row10_col3" class="data row10 col3" >0.1218</td>
#       <td id="T_eccc6_row10_col4" class="data row10 col4" >0.0747</td>
#       <td id="T_eccc6_row10_col5" class="data row10 col5" >0.3541</td>
#     </tr>
#     <tr>
#       <th id="T_eccc6_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_eccc6_row11_col0" class="data row11 col0" >0.0088</td>
#       <td id="T_eccc6_row11_col1" class="data row11 col1" >0.0015</td>
#       <td id="T_eccc6_row11_col2" class="data row11 col2" >0.0079</td>
#       <td id="T_eccc6_row11_col3" class="data row11 col3" >0.1103</td>
#       <td id="T_eccc6_row11_col4" class="data row11 col4" >0.0063</td>
#       <td id="T_eccc6_row11_col5" class="data row11 col5" >0.0786</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# knn = create_model('knn', fold = 10)
# et = tune_model(knn,
#                 optimize = 'RMSE',
#                 n_iter = 50,
#                 choose_better = True,
#                  #search_library = "tune-sklearn",
#                  #search_algorithm="Hyperopt",
#                  #search_algorithm="Optuna",
#                  #search_algorithm="bayesian",
#                 )
# tuned_models.append(knn)

# %% [markdown]
# catboost = create_model('catboost', fold = 10)
# catboost = tune_model(catboost,
#                 optimize = 'RMSE',
#                 n_iter = 50,
#                 choose_better = True,
#                  #search_library = "tune-sklearn",
#                  #search_algorithm="Hyperopt",
#                  #search_algorithm="Optuna",
#                  #search_algorithm="bayesian",
#                 )
# tuned_models.append(catboost)

# %% [markdown]
# ## 5. Finalise the model

# %%
final_et = finalize_model(rf)
#final_et = finalize_model(et)

# %% [markdown]
# ### Plots to analyse Model

# %%
model = final_et
predict_model(model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_00808">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00808_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_00808_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_00808_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_00808_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_00808_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_00808_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_00808_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00808_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00808_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_00808_row0_col1" class="data row0 col1" >0.0541</td>
#       <td id="T_00808_row0_col2" class="data row0 col2" >0.0045</td>
#       <td id="T_00808_row0_col3" class="data row0 col3" >0.0673</td>
#       <td id="T_00808_row0_col4" class="data row0 col4" >0.5234</td>
#       <td id="T_00808_row0_col5" class="data row0 col5" >0.0517</td>
#       <td id="T_00808_row0_col6" class="data row0 col6" >0.2161</td>
#     </tr>
#   </tbody>
# </table>
#      Lithology Code  Well Spacing  Net Pay Pay  Gross Pay  Porosity       Swi  \
# 0          1.278363     -0.317933    -0.570965  -0.432758 -0.614983  0.993341
# 1          1.278363     -0.588456    -0.768439  -0.925601  1.075115  0.601281
# 2         -0.747858     -0.960141     1.296303   0.428737  0.882441 -0.127487
# 3         -0.747858     -0.108011     1.751994   1.111281  1.167877 -0.019050
# 4         -0.747858     -0.889276    -1.074622  -0.301112 -0.312769  1.743410
# ..              ...           ...          ...        ...       ...       ...
# 112        1.278363     -0.317933    -0.710624   0.314134 -0.773352  0.500954
# 113       -0.747858      0.566382    -0.857280   0.952801 -1.450868  0.500954
# 114       -0.747858     -1.541353     1.952262   1.740779  1.167877 -0.574740
# 115       -0.747858     -1.552540     2.059103   2.023666  0.931571 -1.158622
# 116        1.278363      0.566382     1.080183   0.788136 -1.486480 -0.348597
#
#      Oil FVFi      Temp  Permeability  API Gravity  ...  Geologic Play  \
# 0   -0.024916 -1.411283     -0.749942    -0.409921  ...       1.741019
# 1   -1.321303  1.053108      1.821618     0.724199  ...       0.035328
# 2    0.550234  0.467919      0.913642    -0.074394  ...       1.738702
# 3   -0.024916  0.467919      0.592483    -0.409921  ...       0.047310
# 4   -0.481726 -1.830020     -0.696673     0.724199  ...       1.343635
# ..        ...       ...           ...          ...  ...            ...
# 112  1.665250 -0.883360     -0.859384    -0.409921  ...      -1.114509
# 113  1.270444  0.252219     -0.788580     0.977308  ...      -0.857610
# 114  0.641415  0.467919      0.508940    -0.986081  ...       0.047310
# 115  0.601136  1.160109     -0.437413    -0.642849  ...       0.042528
# 116  0.909238 -0.560587     -0.851437     0.047361  ...      -1.099533
#
#      Deposition System  Diagenetic Overprint  Structural Comp  Heterogeniety  \
# 0            -0.334302             -0.771450        -0.474465      -0.734534
# 1            -0.614598             -0.771450         2.138047       1.658903
# 2            -0.845371             -0.771450         2.141053      -0.734534
# 3            -0.037963             -0.771450         2.138047      -0.734534
# 4            -0.903901             -0.771450        -0.474465      -0.734534
# ..                 ...                   ...              ...            ...
# 112           1.152146              1.014279        -0.474465       1.248263
# 113          -0.557782             -0.771450        -0.474465      -0.734534
# 114          -0.037963             -0.771450        -0.474465      -0.734534
# 115          -0.037963             -0.771450         2.138047       1.658903
# 116           1.152146              1.014279        -0.474465       1.248263
#
#      Trap Type  Fractured Faulted_1.0  Shale Breaks_1.0       URF     Label
# 0     1.178916                    0.0               0.0  0.350000  0.326975
# 1     1.178916                    1.0               0.0  0.364000  0.348507
# 2    -0.377187                    1.0               0.0  0.500000  0.403397
# 3    -0.377187                    1.0               1.0  0.450000  0.377296
# 4    -1.670245                    0.0               1.0  0.290986  0.304834
# ..         ...                    ...               ...       ...       ...
# 112   1.178916                    0.0               0.0  0.230528  0.272999
# 113  -0.377187                    1.0               1.0  0.110731  0.280874
# 114  -0.377187                    1.0               1.0  0.400000  0.335528
# 115  -0.377187                    0.0               1.0  0.309771  0.337418
# 116  -0.377187                    0.0               0.0  0.263000  0.295373
#
# [117 rows x 25 columns]

# %%
plot_model(model)

# %% [markdown]
# ## 6. Blind Test

# %%
dfblind = pd.read_excel("BlindTest_SSOIL.xlsx", thousands=',', skiprows = skiprows)
#dfblind = dfblind.loc[:, ~df.columns.str.contains('^Unnamed')] 
dfblind.head()
# Out:
#    Lithology Code  Well Spacing  Net Pay Pay  Gross Pay  Porosity   Swi  \
# 0               1       20.0000          8.6      12.00      30.0  32.0
# 1               1       10.0000         10.0      60.00      25.0  40.0
# 2               1       20.0000         20.0     140.00      25.0  25.0
# 3               1        2.3662        556.0    1500.00      25.5  20.0
# 4               1       63.1147         23.1      27.72      26.0  30.0
#
#    Oil FVFi  Temp  Permeability  API Gravity  ...  Fractured Faulted  \
# 0     1.100   118        1200.0         17.0  ...                  1
# 1     1.100   110        1500.0         34.0  ...                  0
# 2     1.060   120        1000.0         20.0  ...                  0
# 3     1.311   190          58.0         27.7  ...                  0
# 4     1.236   142         250.0         32.0  ...                  1
#
#    Shale Breaks  Major Gas Cap  Geologic Play  Deposition System  \
# 0             0              0           2407                151
# 1             1              0           2407                151
# 2             1              1           2407                151
# 3             1              0            414                181
# 4             1              0            404                153
#
#    Diagenetic Overprint  Structural Comp  Heterogeniety  Trap Type       URF
# 0                     1               10              1          2  0.274000
# 1                     1               10              1          1  0.360000
# 2                     1               10              1          2  0.330000
# 3                     1               30              3          2  0.309771
# 4                     1               10              1          3  0.488715
#
# [5 rows x 24 columns]

# %%
BlindPredict = predict_model(final_et, data=dfblind, round=2)

# %%
BlindPredict
# Out:
#     Lithology Code  Well Spacing  Net Pay Pay  Gross Pay  Porosity   Swi  \
# 0                1       20.0000          8.6      12.00      30.0  32.0
# 1                1       10.0000         10.0      60.00      25.0  40.0
# 2                1       20.0000         20.0     140.00      25.0  25.0
# 3                1        2.3662        556.0    1500.00      25.5  20.0
# 4                1       63.1147         23.1      27.72      26.0  30.0
# ..             ...           ...          ...        ...       ...   ...
# 67               1       80.0000         30.0      95.00       8.0  29.0
# 68               1       10.0000         71.0     100.00      19.0  33.5
# 69               1       20.0000         77.0     186.00      14.1  10.0
# 70               1       40.0000         35.0      75.00      19.0  36.0
# 71               1       20.0000        150.0     250.00      10.3  10.0
#
#     Oil FVFi  Temp  Permeability  API Gravity  ...  Shale Breaks  \
# 0      1.100   118        1200.0         17.0  ...             0
# 1      1.100   110        1500.0         34.0  ...             1
# 2      1.060   120        1000.0         20.0  ...             1
# 3      1.311   190          58.0         27.7  ...             1
# 4      1.236   142         250.0         32.0  ...             1
# ..       ...   ...           ...          ...  ...           ...
# 67     1.100   232           3.0         35.0  ...             0
# 68     1.130   100          52.0         37.0  ...             0
# 69     1.031   154         137.0         24.6  ...             0
# 70     1.370   150          70.0         36.0  ...             0
# 71     1.126   165          20.0         34.0  ...             0
#
#     Major Gas Cap  Geologic Play  Deposition System  Diagenetic Overprint  \
# 0               0           2407                151                     1
# 1               0           2407                151                     1
# 2               1           2407                151                     1
# 3               0            414                181                     1
# 4               0            404                153                     1
# ..            ...            ...                ...                   ...
# 67              0            838                112                     1
# 68              0            831                151                     1
# 69              0            840                110                     1
# 70              1            831                150                     1
# 71              0            825                110                     1
#
#     Structural Comp  Heterogeniety  Trap Type       URF     Label
# 0                10              1          2  0.274000  0.300585
# 1                10              1          1  0.360000  0.329415
# 2                10              1          2  0.330000  0.328983
# 3                30              3          2  0.309771  0.341347
# 4                10              1          3  0.488715  0.390925
# ..              ...            ...        ...       ...       ...
# 67               10              1          3  0.390000  0.360770
# 68               31              1          2  0.470000  0.379437
# 69               10              1          2  0.371956  0.366728
# 70               30              1          2  0.140187  0.319283
# 71               31              1          2  0.450000  0.387854
#
# [72 rows x 25 columns]

# %%
a = BlindPredict['URF']
b = BlindPredict['Label']

plt.figure(figsize=(14, 8))
plt.scatter(a, b, color='blue')
plt.plot(a, a, color = 'red', label = 'x=y')
plt.xlabel("Recovery Factor (%)", size=14)
plt.ylabel("Evaluated Recovery Factor (%)", size=14)

#plt.tight_layout()
plt.show()

# %%
count = 'Completed Process'
elapsed = (time.time() - start)
print ("%s in %s seconds" % (count,elapsed))
# Out:
# Completed Process in 342.15182089805603 seconds
